# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B1.2 radar + gauges 1 min + cmls -> gauges 1 min [xrlg1_yg1g]

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 1500
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B12_xrlg1_yg1.pt'
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 20
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 + 60
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn()

# %%
# Boucle avec 5 modes d'évaluation
last_epoch = 0
val_steps = ['eval_opportunity_cost_spat',
             # 'eval_added_value_few_spat',
             # 'eval_added_value_half_spat',
             'eval_added_value_full_spat',
             # 'eval_added_value_full_id',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 1300

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}

  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    #Validation steps
    model.eval()
    with torch.no_grad():

      # splitting
      np_val_inputs_few = 1
      np_val_inputs_half = npoints//4  # 5
      np_val_inputs_comp = npoints//2 - np_val_inputs_half - np_val_inputs_few  # 4
      np_val_targets = npoints//2 # 10

      # val split
      split_val = [np_val_inputs_few, np_val_inputs_half, np_val_inputs_comp, np_val_targets]
      split_few, split_half, split_comp, split_targets = point_gt(images, npoints=npoints,
                                                                    use_fcn=use_fcn,
                                                                    split=split_val)
      _, point_measurements_fcn_eval_few, _ = split_few
      _, point_measurements_fcn_eval_half, _ = split_half
      _, point_measurements_fcn_eval_comp, _ = split_comp
      _, point_measurements_fcn_val_targets, _ = split_targets

      # 4 first val steps (10 last pluvios for testing generalization)
      targets = point_measurements_fcn_val_targets

      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          0 * point_measurements_fcn_eval_few - 0.1
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()

      # val step 2 : eval_added_value_few_spat
      # step = 'eval_added_value_few_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_few
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 3 : eval_added_value_half_spat
      # step = 'eval_added_value_half_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_half
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 4 : eval_added_value_full_spat
      step = 'eval_added_value_full_spat'

      point_measurements_fcn_eval_full = point_measurements_fcn_eval_few + \
                                          point_measurements_fcn_eval_half + \
                                          point_measurements_fcn_eval_comp

      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_few >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_half >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_comp >= 0)

      point_measurements_fcn_eval_full[point_measurements_fcn_eval_full<0] = -0.1

      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          point_measurements_fcn_eval_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, split_few, split_half, split_comp, split_targets
      torch.cuda.empty_cache()

      # # last val step, on the 10 first pluvios : eval_added_value_full_id
      # step = 'eval_added_value_full_id'
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, point_measurements_fcn_eval_full) # inputs pluvios serve as targets
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      del point_measurements_fcn_eval_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    np_train_inputs = torch.randint(0,9,(1,))
    np_train_targets = npoints // 2 - np_train_inputs
    split_train = [np_train_inputs, np_train_targets]


    # split  train
    split_inputs, split_targets = point_gt(images, npoints=npoints,
                                           use_fcn=use_fcn,
                                           split=split_train)

    _, point_measurements_fcn_train_inputs, _ = split_inputs
    _, point_measurements_fcn_train_targets, _ = split_targets

    # B12 specificty :
    point_measurements_fcn_train_targets[point_measurements_fcn_train_inputs >=0] = point_measurements_fcn_train_inputs[point_measurements_fcn_train_inputs >=0] 
      
    inputs = torch.cat([noisy_images,
                        segment_measurements_fcn,
                        point_measurements_fcn_train_inputs
                        ], dim=1)
    targets = point_measurements_fcn_train_targets

    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)

    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm

    del split_inputs, inputs, outputs, split_targets, loss, regression_loss, regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, segment_measurements_fcn
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step]))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 1300
#
# eval_opportunity_cost_spat, Regression Loss: 0.0261, Regression Loss 1h: 311.5339, Segmentation Loss:0.0937
# Train Confusion Matrix:
# [[3139315   56979]
#  [  83229  560477]]
# Accuracy: 0.9635, CSI: 0.7999, Sensitivity: 0.8707, Specificity: 0.9822, False Alarm Ratio: 0.0923
#
#
# eval_added_value_full_spat, Regression Loss: 0.0229, Regression Loss 1h: 342.2385, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3141127   55167]
#  [  74785  568921]]
# Accuracy: 0.9662, CSI: 0.8141, Sensitivity: 0.8838, Specificity: 0.9827, False Alarm Ratio: 0.0884
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 197.2416, Segmentation Loss:0.0505
# Train Confusion Matrix:
# [[3163619   31442]
#  [  44089  600850]]
# Accuracy: 0.9803, CSI: 0.8883, Sensitivity: 0.9316, Specificity: 0.9902, False Alarm Ratio: 0.0497
#
#
# epoch duration : 90.08027911186218
# saving step
# epoch n° 1301
#
# eval_opportunity_cost_spat, Regression Loss: 0.1184, Regression Loss 1h: 476.6229, Segmentation Loss:0.1091
# Train Confusion Matrix:
# [[3131225   64725]
#  [  80295  563755]]
# Accuracy: 0.9622, CSI: 0.7954, Sensitivity: 0.8753, Specificity: 0.9797, False Alarm Ratio: 0.1030
#
#
# eval_added_value_full_spat, Regression Loss: 0.0595, Regression Loss 1h: 416.7101, Segmentation Loss:0.0943
# Train Confusion Matrix:
# [[3134903   61047]
#  [  73260  570790]]
# Accuracy: 0.9650, CSI: 0.8095, Sensitivity: 0.8863, Specificity: 0.9809, False Alarm Ratio: 0.0966
#
#
# train, Regression Loss: 0.0161, Regression Loss 1h: 219.4885, Segmentation Loss:0.0568
# Train Confusion Matrix:
# [[3164594   35335]
#  [  49994  590077]]
# Accuracy: 0.9778, CSI: 0.8737, Sensitivity: 0.9219, Specificity: 0.9890, False Alarm Ratio: 0.0565
#
#
# epoch duration : 89.80259442329407
# epoch n° 1302
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 338.4160, Segmentation Loss:0.0908
# Train Confusion Matrix:
# [[3144020   57662]
#  [  79355  558963]]
# Accuracy: 0.9643, CSI: 0.8031, Sensitivity: 0.8757, Specificity: 0.9820, False Alarm Ratio: 0.0935
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 355.5912, Segmentation Loss:0.0844
# Train Confusion Matrix:
# [[3147696   53986]
#  [  74308  564010]]
# Accuracy: 0.9666, CSI: 0.8147, Sensitivity: 0.8836, Specificity: 0.9831, False Alarm Ratio: 0.0874
#
#
# train, Regression Loss: 0.0159, Regression Loss 1h: 218.7168, Segmentation Loss:0.0517
# Train Confusion Matrix:
# [[3170663   32456]
#  [  45345  591536]]
# Accuracy: 0.9797, CSI: 0.8838, Sensitivity: 0.9288, Specificity: 0.9899, False Alarm Ratio: 0.0520
#
#
# epoch duration : 91.40558242797852
# epoch n° 1303
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 330.7912, Segmentation Loss:0.0920
# Train Confusion Matrix:
# [[3132560   61368]
#  [  77486  568586]]
# Accuracy: 0.9638, CSI: 0.8037, Sensitivity: 0.8801, Specificity: 0.9808, False Alarm Ratio: 0.0974
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 356.6242, Segmentation Loss:0.0842
# Train Confusion Matrix:
# [[3136785   57143]
#  [  71841  574231]]
# Accuracy: 0.9664, CSI: 0.8166, Sensitivity: 0.8888, Specificity: 0.9821, False Alarm Ratio: 0.0905
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 211.5389, Segmentation Loss:0.0513
# Train Confusion Matrix:
# [[3160820   32051]
#  [  45221  601908]]
# Accuracy: 0.9799, CSI: 0.8862, Sensitivity: 0.9301, Specificity: 0.9900, False Alarm Ratio: 0.0506
#
#
# epoch duration : 88.65486025810242
# epoch n° 1304
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 335.5784, Segmentation Loss:0.0883
# Train Confusion Matrix:
# [[3148188   56825]
#  [  76962  558025]]
# Accuracy: 0.9652, CSI: 0.8066, Sensitivity: 0.8788, Specificity: 0.9823, False Alarm Ratio: 0.0924
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 355.9849, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[3152258   52755]
#  [  71924  563063]]
# Accuracy: 0.9675, CSI: 0.8187, Sensitivity: 0.8867, Specificity: 0.9835, False Alarm Ratio: 0.0857
#
#
# train, Regression Loss: 0.0163, Regression Loss 1h: 230.5655, Segmentation Loss:0.0539
# Train Confusion Matrix:
# [[3172969   34536]
#  [  47034  585461]]
# Accuracy: 0.9788, CSI: 0.8777, Sensitivity: 0.9256, Specificity: 0.9892, False Alarm Ratio: 0.0557
#
#
# epoch duration : 90.63671708106995
# epoch n° 1305
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 327.0545, Segmentation Loss:0.0897
# Train Confusion Matrix:
# [[3137605   60922]
#  [  74821  566652]]
# Accuracy: 0.9647, CSI: 0.8067, Sensitivity: 0.8834, Specificity: 0.9810, False Alarm Ratio: 0.0971
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 360.8309, Segmentation Loss:0.0823
# Train Confusion Matrix:
# [[3141349   57178]
#  [  68487  572986]]
# Accuracy: 0.9673, CSI: 0.8201, Sensitivity: 0.8932, Specificity: 0.9821, False Alarm Ratio: 0.0907
#
#
# train, Regression Loss: 0.0155, Regression Loss 1h: 223.2809, Segmentation Loss:0.0523
# Train Confusion Matrix:
# [[3160688   33149]
#  [  45885  600278]]
# Accuracy: 0.9794, CSI: 0.8837, Sensitivity: 0.9290, Specificity: 0.9896, False Alarm Ratio: 0.0523
#
#
# epoch duration : 90.37575435638428
# epoch n° 1306
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 329.3820, Segmentation Loss:0.0893
# Train Confusion Matrix:
# [[3148752   55426]
#  [  79189  556633]]
# Accuracy: 0.9649, CSI: 0.8053, Sensitivity: 0.8755, Specificity: 0.9827, False Alarm Ratio: 0.0906
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 357.8697, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3152044   52134]
#  [  72454  563368]]
# Accuracy: 0.9676, CSI: 0.8189, Sensitivity: 0.8860, Specificity: 0.9837, False Alarm Ratio: 0.0847
#
#
# train, Regression Loss: 0.0141, Regression Loss 1h: 208.3784, Segmentation Loss:0.0477
# Train Confusion Matrix:
# [[3175505   30343]
#  [  41786  592366]]
# Accuracy: 0.9812, CSI: 0.8915, Sensitivity: 0.9341, Specificity: 0.9905, False Alarm Ratio: 0.0487
#
#
# epoch duration : 90.52783274650574
# epoch n° 1307
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 313.7727, Segmentation Loss:0.0903
# Train Confusion Matrix:
# [[3133664   63178]
#  [  73418  569740]]
# Accuracy: 0.9644, CSI: 0.8066, Sensitivity: 0.8858, Specificity: 0.9802, False Alarm Ratio: 0.0998
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 353.5765, Segmentation Loss:0.0829
# Train Confusion Matrix:
# [[3138154   58688]
#  [  67674  575484]]
# Accuracy: 0.9671, CSI: 0.8200, Sensitivity: 0.8948, Specificity: 0.9816, False Alarm Ratio: 0.0925
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 222.7447, Segmentation Loss:0.0510
# Train Confusion Matrix:
# [[3162041   32381]
#  [  44384  601194]]
# Accuracy: 0.9800, CSI: 0.8868, Sensitivity: 0.9312, Specificity: 0.9899, False Alarm Ratio: 0.0511
#
#
# epoch duration : 90.57737350463867
# epoch n° 1308
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 433.6015, Segmentation Loss:0.0881
# Train Confusion Matrix:
# [[3137822   58355]
#  [  75115  568708]]
# Accuracy: 0.9652, CSI: 0.8099, Sensitivity: 0.8833, Specificity: 0.9817, False Alarm Ratio: 0.0931
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 439.7306, Segmentation Loss:0.0813
# Train Confusion Matrix:
# [[3140847   55330]
#  [  68927  574896]]
# Accuracy: 0.9676, CSI: 0.8223, Sensitivity: 0.8929, Specificity: 0.9827, False Alarm Ratio: 0.0878
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 270.5114, Segmentation Loss:0.0486
# Train Confusion Matrix:
# [[3166900   31143]
#  [  42711  599246]]
# Accuracy: 0.9808, CSI: 0.8903, Sensitivity: 0.9335, Specificity: 0.9903, False Alarm Ratio: 0.0494
#
#
# epoch duration : 90.1921660900116
# epoch n° 1309
#
# eval_opportunity_cost_spat, Regression Loss: 0.0306, Regression Loss 1h: 518.1432, Segmentation Loss:0.1024
# Train Confusion Matrix:
# [[3139577   62346]
#  [  86985  551092]]
# Accuracy: 0.9611, CSI: 0.7868, Sensitivity: 0.8637, Specificity: 0.9805, False Alarm Ratio: 0.1016
#
#
# eval_added_value_full_spat, Regression Loss: 0.0264, Regression Loss 1h: 507.9849, Segmentation Loss:0.0937
# Train Confusion Matrix:
# [[3140939   60984]
#  [  78418  559659]]
# Accuracy: 0.9637, CSI: 0.8006, Sensitivity: 0.8771, Specificity: 0.9810, False Alarm Ratio: 0.0983
#
#
# train, Regression Loss: 0.0191, Regression Loss 1h: 248.6831, Segmentation Loss:0.0575
# Train Confusion Matrix:
# [[3162536   35669]
#  [  49627  592168]]
# Accuracy: 0.9778, CSI: 0.8741, Sensitivity: 0.9227, Specificity: 0.9888, False Alarm Ratio: 0.0568
#
#
# epoch duration : 91.90215563774109
# epoch n° 1310
#
# eval_opportunity_cost_spat, Regression Loss: 0.0260, Regression Loss 1h: 402.9774, Segmentation Loss:0.0937
# Train Confusion Matrix:
# [[3132421   60059]
#  [  79462  568058]]
# Accuracy: 0.9637, CSI: 0.8028, Sensitivity: 0.8773, Specificity: 0.9812, False Alarm Ratio: 0.0956
#
#
# eval_added_value_full_spat, Regression Loss: 0.0231, Regression Loss 1h: 396.0631, Segmentation Loss:0.0859
# Train Confusion Matrix:
# [[3135187   57293]
#  [  72830  574690]]
# Accuracy: 0.9661, CSI: 0.8154, Sensitivity: 0.8875, Specificity: 0.9821, False Alarm Ratio: 0.0907
#
#
# train, Regression Loss: 0.0157, Regression Loss 1h: 213.9196, Segmentation Loss:0.0507
# Train Confusion Matrix:
# [[3161563   31518]
#  [  44109  602810]]
# Accuracy: 0.9803, CSI: 0.8885, Sensitivity: 0.9318, Specificity: 0.9901, False Alarm Ratio: 0.0497
#
#
# epoch duration : 91.11368155479431
# saving step
# epoch n° 1311
#
# eval_opportunity_cost_spat, Regression Loss: 0.0261, Regression Loss 1h: 378.7932, Segmentation Loss:0.0957
# Train Confusion Matrix:
# [[3129361   63962]
#  [  78847  567830]]
# Accuracy: 0.9628, CSI: 0.7990, Sensitivity: 0.8781, Specificity: 0.9800, False Alarm Ratio: 0.1012
#
#
# eval_added_value_full_spat, Regression Loss: 0.0231, Regression Loss 1h: 383.5906, Segmentation Loss:0.0874
# Train Confusion Matrix:
# [[3133696   59627]
#  [  72719  573958]]
# Accuracy: 0.9655, CSI: 0.8126, Sensitivity: 0.8875, Specificity: 0.9813, False Alarm Ratio: 0.0941
#
#
# train, Regression Loss: 0.0171, Regression Loss 1h: 240.7732, Segmentation Loss:0.0576
# Train Confusion Matrix:
# [[3153243   36154]
#  [  50280  600323]]
# Accuracy: 0.9775, CSI: 0.8741, Sensitivity: 0.9227, Specificity: 0.9887, False Alarm Ratio: 0.0568
#
#
# epoch duration : 89.58516216278076
# epoch n° 1312
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 355.7504, Segmentation Loss:0.0933
# Train Confusion Matrix:
# [[3139266   56814]
#  [  82974  560946]]
# Accuracy: 0.9636, CSI: 0.8005, Sensitivity: 0.8711, Specificity: 0.9822, False Alarm Ratio: 0.0920
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 344.1387, Segmentation Loss:0.0850
# Train Confusion Matrix:
# [[3140482   55598]
#  [  73550  570370]]
# Accuracy: 0.9664, CSI: 0.8154, Sensitivity: 0.8858, Specificity: 0.9826, False Alarm Ratio: 0.0888
#
#
# train, Regression Loss: 0.0156, Regression Loss 1h: 223.1282, Segmentation Loss:0.0542
# Train Confusion Matrix:
# [[3161727   33607]
#  [  47392  597274]]
# Accuracy: 0.9789, CSI: 0.8806, Sensitivity: 0.9265, Specificity: 0.9895, False Alarm Ratio: 0.0533
#
#
# epoch duration : 89.69576740264893
# epoch n° 1313
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 332.1600, Segmentation Loss:0.0906
# Train Confusion Matrix:
# [[3137074   57942]
#  [  77759  567225]]
# Accuracy: 0.9647, CSI: 0.8069, Sensitivity: 0.8794, Specificity: 0.9819, False Alarm Ratio: 0.0927
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 351.3720, Segmentation Loss:0.0832
# Train Confusion Matrix:
# [[3140386   54630]
#  [  71500  573484]]
# Accuracy: 0.9672, CSI: 0.8197, Sensitivity: 0.8891, Specificity: 0.9829, False Alarm Ratio: 0.0870
#
#
# train, Regression Loss: 0.0161, Regression Loss 1h: 225.3311, Segmentation Loss:0.0560
# Train Confusion Matrix:
# [[3156524   35226]
#  [  48688  599562]]
# Accuracy: 0.9781, CSI: 0.8772, Sensitivity: 0.9249, Specificity: 0.9890, False Alarm Ratio: 0.0555
#
#
# epoch duration : 90.79869818687439
# epoch n° 1314
#
# eval_opportunity_cost_spat, Regression Loss: 0.0298, Regression Loss 1h: 456.0598, Segmentation Loss:0.0899
# Train Confusion Matrix:
# [[3143081   54912]
#  [  77459  564548]]
# Accuracy: 0.9655, CSI: 0.8101, Sensitivity: 0.8793, Specificity: 0.9828, False Alarm Ratio: 0.0886
#
#
# eval_added_value_full_spat, Regression Loss: 0.0260, Regression Loss 1h: 454.5069, Segmentation Loss:0.0826
# Train Confusion Matrix:
# [[3144584   53409]
#  [  69644  572363]]
# Accuracy: 0.9680, CSI: 0.8231, Sensitivity: 0.8915, Specificity: 0.9833, False Alarm Ratio: 0.0853
#
#
# train, Regression Loss: 0.0163, Regression Loss 1h: 224.4555, Segmentation Loss:0.0526
# Train Confusion Matrix:
# [[3169882   33438]
#  [  46014  590666]]
# Accuracy: 0.9793, CSI: 0.8814, Sensitivity: 0.9277, Specificity: 0.9896, False Alarm Ratio: 0.0536
#
#
# epoch duration : 89.88643336296082
# epoch n° 1315
#
# eval_opportunity_cost_spat, Regression Loss: 0.0252, Regression Loss 1h: 333.7510, Segmentation Loss:0.0885
# Train Confusion Matrix:
# [[3135751   55739]
#  [  77880  570630]]
# Accuracy: 0.9652, CSI: 0.8103, Sensitivity: 0.8799, Specificity: 0.9825, False Alarm Ratio: 0.0890
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 345.4978, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[3137371   54119]
#  [  70387  578123]]
# Accuracy: 0.9676, CSI: 0.8228, Sensitivity: 0.8915, Specificity: 0.9830, False Alarm Ratio: 0.0856
#
#
# train, Regression Loss: 0.0155, Regression Loss 1h: 214.1792, Segmentation Loss:0.0506
# Train Confusion Matrix:
# [[3161822   32044]
#  [  44227  601907]]
# Accuracy: 0.9801, CSI: 0.8875, Sensitivity: 0.9316, Specificity: 0.9900, False Alarm Ratio: 0.0505
#
#
# epoch duration : 88.8348376750946
# epoch n° 1316
#
# eval_opportunity_cost_spat, Regression Loss: 0.0252, Regression Loss 1h: 361.3437, Segmentation Loss:0.0899
# Train Confusion Matrix:
# [[3139122   58801]
#  [  76760  565317]]
# Accuracy: 0.9647, CSI: 0.8066, Sensitivity: 0.8805, Specificity: 0.9816, False Alarm Ratio: 0.0942
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 380.3534, Segmentation Loss:0.0827
# Train Confusion Matrix:
# [[3142531   55392]
#  [  70923  571154]]
# Accuracy: 0.9671, CSI: 0.8189, Sensitivity: 0.8895, Specificity: 0.9827, False Alarm Ratio: 0.0884
#
#
# train, Regression Loss: 0.0158, Regression Loss 1h: 234.8919, Segmentation Loss:0.0535
# Train Confusion Matrix:
# [[3164588   33815]
#  [  47283  594314]]
# Accuracy: 0.9789, CSI: 0.8799, Sensitivity: 0.9263, Specificity: 0.9894, False Alarm Ratio: 0.0538
#
#
# epoch duration : 90.81026721000671
# epoch n° 1317
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 352.2803, Segmentation Loss:0.0930
# Train Confusion Matrix:
# [[3136016   60160]
#  [  79669  564155]]
# Accuracy: 0.9636, CSI: 0.8014, Sensitivity: 0.8763, Specificity: 0.9812, False Alarm Ratio: 0.0964
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 380.1235, Segmentation Loss:0.0851
# Train Confusion Matrix:
# [[3140666   55510]
#  [  74365  569459]]
# Accuracy: 0.9662, CSI: 0.8143, Sensitivity: 0.8845, Specificity: 0.9826, False Alarm Ratio: 0.0888
#
#
# train, Regression Loss: 0.0155, Regression Loss 1h: 222.7516, Segmentation Loss:0.0515
# Train Confusion Matrix:
# [[3166560   32572]
#  [  45376  595492]]
# Accuracy: 0.9797, CSI: 0.8843, Sensitivity: 0.9292, Specificity: 0.9898, False Alarm Ratio: 0.0519
#
#
# epoch duration : 90.78992104530334
# epoch n° 1318
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 336.9475, Segmentation Loss:0.0881
# Train Confusion Matrix:
# [[3142848   55740]
#  [  77799  563613]]
# Accuracy: 0.9652, CSI: 0.8085, Sensitivity: 0.8787, Specificity: 0.9826, False Alarm Ratio: 0.0900
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 358.4107, Segmentation Loss:0.0809
# Train Confusion Matrix:
# [[3145172   53416]
#  [  71100  570312]]
# Accuracy: 0.9676, CSI: 0.8208, Sensitivity: 0.8892, Specificity: 0.9833, False Alarm Ratio: 0.0856
#
#
# train, Regression Loss: 0.0147, Regression Loss 1h: 212.7354, Segmentation Loss:0.0494
# Train Confusion Matrix:
# [[3168520   31795]
#  [  43176  596509]]
# Accuracy: 0.9805, CSI: 0.8883, Sensitivity: 0.9325, Specificity: 0.9901, False Alarm Ratio: 0.0506
#
#
# epoch duration : 87.54224014282227
# epoch n° 1319
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 347.1367, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3141295   55624]
#  [  75597  567484]]
# Accuracy: 0.9658, CSI: 0.8122, Sensitivity: 0.8824, Specificity: 0.9826, False Alarm Ratio: 0.0893
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 381.0107, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[3144430   52489]
#  [  69743  573338]]
# Accuracy: 0.9682, CSI: 0.8243, Sensitivity: 0.8915, Specificity: 0.9836, False Alarm Ratio: 0.0839
#
#
# train, Regression Loss: 0.0148, Regression Loss 1h: 223.7026, Segmentation Loss:0.0503
# Train Confusion Matrix:
# [[3163525   32120]
#  [  43621  600734]]
# Accuracy: 0.9803, CSI: 0.8880, Sensitivity: 0.9323, Specificity: 0.9899, False Alarm Ratio: 0.0508
#
#
# epoch duration : 90.87306427955627
# epoch n° 1320
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 347.4357, Segmentation Loss:0.0884
# Train Confusion Matrix:
# [[3143399   55977]
#  [  77480  563144]]
# Accuracy: 0.9652, CSI: 0.8084, Sensitivity: 0.8791, Specificity: 0.9825, False Alarm Ratio: 0.0904
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 383.6707, Segmentation Loss:0.0814
# Train Confusion Matrix:
# [[3146715   52661]
#  [  71718  568906]]
# Accuracy: 0.9676, CSI: 0.8206, Sensitivity: 0.8880, Specificity: 0.9835, False Alarm Ratio: 0.0847
#
#
# train, Regression Loss: 0.0158, Regression Loss 1h: 244.0816, Segmentation Loss:0.0547
# Train Confusion Matrix:
# [[3163980   34372]
#  [  48076  593572]]
# Accuracy: 0.9785, CSI: 0.8780, Sensitivity: 0.9251, Specificity: 0.9893, False Alarm Ratio: 0.0547
#
#
# epoch duration : 90.4244065284729
# saving step
# epoch n° 1321
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 348.6695, Segmentation Loss:0.0913
# Train Confusion Matrix:
# [[3144222   57610]
#  [  80091  558077]]
# Accuracy: 0.9641, CSI: 0.8021, Sensitivity: 0.8745, Specificity: 0.9820, False Alarm Ratio: 0.0936
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 381.4636, Segmentation Loss:0.0835
# Train Confusion Matrix:
# [[3147790   54042]
#  [  73439  564729]]
# Accuracy: 0.9668, CSI: 0.8158, Sensitivity: 0.8849, Specificity: 0.9831, False Alarm Ratio: 0.0873
#
#
# train, Regression Loss: 0.0154, Regression Loss 1h: 235.1647, Segmentation Loss:0.0536
# Train Confusion Matrix:
# [[3169577   33539]
#  [  47073  589811]]
# Accuracy: 0.9790, CSI: 0.8798, Sensitivity: 0.9261, Specificity: 0.9895, False Alarm Ratio: 0.0538
#
#
# epoch duration : 90.10171365737915
# epoch n° 1322
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 345.6578, Segmentation Loss:0.0908
# Train Confusion Matrix:
# [[3137716   56137]
#  [  80296  565851]]
# Accuracy: 0.9645, CSI: 0.8057, Sensitivity: 0.8757, Specificity: 0.9824, False Alarm Ratio: 0.0903
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 374.9017, Segmentation Loss:0.0832
# Train Confusion Matrix:
# [[3140916   52937]
#  [  73789  572358]]
# Accuracy: 0.9670, CSI: 0.8187, Sensitivity: 0.8858, Specificity: 0.9834, False Alarm Ratio: 0.0847
#
#
# train, Regression Loss: 0.0157, Regression Loss 1h: 224.9332, Segmentation Loss:0.0510
# Train Confusion Matrix:
# [[3162858   32323]
#  [  44599  600220]]
# Accuracy: 0.9800, CSI: 0.8864, Sensitivity: 0.9308, Specificity: 0.9899, False Alarm Ratio: 0.0511
#
#
# epoch duration : 90.75689053535461
# epoch n° 1323
#
# eval_opportunity_cost_spat, Regression Loss: 0.0255, Regression Loss 1h: 351.9167, Segmentation Loss:0.0868
# Train Confusion Matrix:
# [[3142160   57842]
#  [  73970  566028]]
# Accuracy: 0.9657, CSI: 0.8111, Sensitivity: 0.8844, Specificity: 0.9819, False Alarm Ratio: 0.0927
#
#
# eval_added_value_full_spat, Regression Loss: 0.0226, Regression Loss 1h: 380.0282, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3144675   55327]
#  [  68277  571721]]
# Accuracy: 0.9678, CSI: 0.8222, Sensitivity: 0.8933, Specificity: 0.9827, False Alarm Ratio: 0.0882
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 224.3233, Segmentation Loss:0.0492
# Train Confusion Matrix:
# [[3164508   31237]
#  [  43093  601162]]
# Accuracy: 0.9806, CSI: 0.8900, Sensitivity: 0.9331, Specificity: 0.9902, False Alarm Ratio: 0.0494
#
#
# epoch duration : 91.9919023513794
# epoch n° 1324
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 350.5527, Segmentation Loss:0.0896
# Train Confusion Matrix:
# [[3138699   58023]
#  [  77539  565739]]
# Accuracy: 0.9647, CSI: 0.8067, Sensitivity: 0.8795, Specificity: 0.9818, False Alarm Ratio: 0.0930
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 379.9336, Segmentation Loss:0.0823
# Train Confusion Matrix:
# [[3141278   55444]
#  [  70667  572611]]
# Accuracy: 0.9672, CSI: 0.8195, Sensitivity: 0.8901, Specificity: 0.9827, False Alarm Ratio: 0.0883
#
#
# train, Regression Loss: 0.0152, Regression Loss 1h: 230.2510, Segmentation Loss:0.0500
# Train Confusion Matrix:
# [[3166188   32023]
#  [  43549  598240]]
# Accuracy: 0.9803, CSI: 0.8878, Sensitivity: 0.9321, Specificity: 0.9900, False Alarm Ratio: 0.0508
#
#
# epoch duration : 91.03612542152405
# epoch n° 1325
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 342.9196, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3149251   54432]
#  [  77693  558624]]
# Accuracy: 0.9656, CSI: 0.8087, Sensitivity: 0.8779, Specificity: 0.9830, False Alarm Ratio: 0.0888
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 370.9399, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3153097   50586]
#  [  72566  563751]]
# Accuracy: 0.9679, CSI: 0.8207, Sensitivity: 0.8860, Specificity: 0.9842, False Alarm Ratio: 0.0823
#
#
# train, Regression Loss: 0.0168, Regression Loss 1h: 253.2257, Segmentation Loss:0.0558
# Train Confusion Matrix:
# [[3166049   35285]
#  [  49296  589370]]
# Accuracy: 0.9780, CSI: 0.8745, Sensitivity: 0.9228, Specificity: 0.9890, False Alarm Ratio: 0.0565
#
#
# epoch duration : 88.7168915271759
# epoch n° 1326
#
# eval_opportunity_cost_spat, Regression Loss: 0.0239, Regression Loss 1h: 350.5241, Segmentation Loss:0.0889
# Train Confusion Matrix:
# [[3135358   62615]
#  [  71481  570546]]
# Accuracy: 0.9651, CSI: 0.8097, Sensitivity: 0.8887, Specificity: 0.9804, False Alarm Ratio: 0.0989
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 380.5999, Segmentation Loss:0.0818
# Train Confusion Matrix:
# [[3139871   58102]
#  [  66648  575379]]
# Accuracy: 0.9675, CSI: 0.8218, Sensitivity: 0.8962, Specificity: 0.9818, False Alarm Ratio: 0.0917
#
#
# train, Regression Loss: 0.0149, Regression Loss 1h: 237.5181, Segmentation Loss:0.0529
# Train Confusion Matrix:
# [[3161888   33342]
#  [  46365  598405]]
# Accuracy: 0.9792, CSI: 0.8825, Sensitivity: 0.9281, Specificity: 0.9896, False Alarm Ratio: 0.0528
#
#
# epoch duration : 90.64988851547241
# epoch n° 1327
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 344.9997, Segmentation Loss:0.0880
# Train Confusion Matrix:
# [[3146018   54176]
#  [  78992  560814]]
# Accuracy: 0.9653, CSI: 0.8081, Sensitivity: 0.8765, Specificity: 0.9831, False Alarm Ratio: 0.0881
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 382.3860, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[3149710   50484]
#  [  73578  566228]]
# Accuracy: 0.9677, CSI: 0.8203, Sensitivity: 0.8850, Specificity: 0.9842, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0162, Regression Loss 1h: 230.2534, Segmentation Loss:0.0534
# Train Confusion Matrix:
# [[3166998   33809]
#  [  46767  592426]]
# Accuracy: 0.9790, CSI: 0.8803, Sensitivity: 0.9268, Specificity: 0.9894, False Alarm Ratio: 0.0540
#
#
# epoch duration : 92.43285799026489
# epoch n° 1328
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 322.9745, Segmentation Loss:0.0879
# Train Confusion Matrix:
# [[3133003   59813]
#  [  73561  573623]]
# Accuracy: 0.9653, CSI: 0.8114, Sensitivity: 0.8863, Specificity: 0.9813, False Alarm Ratio: 0.0944
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 361.1616, Segmentation Loss:0.0809
# Train Confusion Matrix:
# [[3136856   55960]
#  [  68105  579079]]
# Accuracy: 0.9677, CSI: 0.8236, Sensitivity: 0.8948, Specificity: 0.9825, False Alarm Ratio: 0.0881
#
#
# train, Regression Loss: 0.0158, Regression Loss 1h: 226.7325, Segmentation Loss:0.0523
# Train Confusion Matrix:
# [[3163184   33425]
#  [  46189  597202]]
# Accuracy: 0.9793, CSI: 0.8824, Sensitivity: 0.9282, Specificity: 0.9895, False Alarm Ratio: 0.0530
#
#
# epoch duration : 88.95010113716125
# epoch n° 1329
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 326.3935, Segmentation Loss:0.0865
# Train Confusion Matrix:
# [[3149156   56323]
#  [  74230  560291]]
# Accuracy: 0.9660, CSI: 0.8110, Sensitivity: 0.8830, Specificity: 0.9824, False Alarm Ratio: 0.0913
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 357.7074, Segmentation Loss:0.0798
# Train Confusion Matrix:
# [[3152132   53347]
#  [  68446  566075]]
# Accuracy: 0.9683, CSI: 0.8229, Sensitivity: 0.8921, Specificity: 0.9834, False Alarm Ratio: 0.0861
#
#
# train, Regression Loss: 0.0166, Regression Loss 1h: 243.9507, Segmentation Loss:0.0535
# Train Confusion Matrix:
# [[3176897   34275]
#  [  46907  581921]]
# Accuracy: 0.9789, CSI: 0.8776, Sensitivity: 0.9254, Specificity: 0.9893, False Alarm Ratio: 0.0556
#
#
# epoch duration : 89.41253089904785
# epoch n° 1330
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 371.8420, Segmentation Loss:0.0871
# Train Confusion Matrix:
# [[3136231   58235]
#  [  73439  572095]]
# Accuracy: 0.9657, CSI: 0.8129, Sensitivity: 0.8862, Specificity: 0.9818, False Alarm Ratio: 0.0924
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 393.6519, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[3138838   55628]
#  [  66990  578544]]
# Accuracy: 0.9681, CSI: 0.8251, Sensitivity: 0.8962, Specificity: 0.9826, False Alarm Ratio: 0.0877
#
#
# train, Regression Loss: 0.0148, Regression Loss 1h: 234.3994, Segmentation Loss:0.0498
# Train Confusion Matrix:
# [[3163427   31555]
#  [  43593  601425]]
# Accuracy: 0.9804, CSI: 0.8889, Sensitivity: 0.9324, Specificity: 0.9901, False Alarm Ratio: 0.0499
#
#
# epoch duration : 89.01480460166931
# saving step
# epoch n° 1331
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 419.5553, Segmentation Loss:0.0870
# Train Confusion Matrix:
# [[3148872   54398]
#  [  76508  560222]]
# Accuracy: 0.9659, CSI: 0.8106, Sensitivity: 0.8798, Specificity: 0.9830, False Alarm Ratio: 0.0885
#
#
# eval_added_value_full_spat, Regression Loss: 0.0212, Regression Loss 1h: 492.1189, Segmentation Loss:0.0798
# Train Confusion Matrix:
# [[3151206   52064]
#  [  69107  567623]]
# Accuracy: 0.9684, CSI: 0.8241, Sensitivity: 0.8915, Specificity: 0.9837, False Alarm Ratio: 0.0840
#
#
# train, Regression Loss: 0.0157, Regression Loss 1h: 305.8937, Segmentation Loss:0.0526
# Train Confusion Matrix:
# [[3167471   33402]
#  [  45922  593205]]
# Accuracy: 0.9793, CSI: 0.8821, Sensitivity: 0.9281, Specificity: 0.9896, False Alarm Ratio: 0.0533
#
#
# epoch duration : 89.05694770812988
# epoch n° 1332
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 417.3305, Segmentation Loss:0.0894
# Train Confusion Matrix:
# [[3147954   56566]
#  [  78915  556565]]
# Accuracy: 0.9647, CSI: 0.8042, Sensitivity: 0.8758, Specificity: 0.9823, False Alarm Ratio: 0.0923
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 470.5961, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[3150987   53533]
#  [  71928  563552]]
# Accuracy: 0.9673, CSI: 0.8179, Sensitivity: 0.8868, Specificity: 0.9833, False Alarm Ratio: 0.0868
#
#
# train, Regression Loss: 0.0145, Regression Loss 1h: 283.9723, Segmentation Loss:0.0506
# Train Confusion Matrix:
# [[3170875   32077]
#  [  44595  592453]]
# Accuracy: 0.9800, CSI: 0.8854, Sensitivity: 0.9300, Specificity: 0.9900, False Alarm Ratio: 0.0514
#
#
# epoch duration : 90.6881058216095
# epoch n° 1333
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 326.9122, Segmentation Loss:0.0877
# Train Confusion Matrix:
# [[3135703   58645]
#  [  74021  571631]]
# Accuracy: 0.9655, CSI: 0.8116, Sensitivity: 0.8854, Specificity: 0.9816, False Alarm Ratio: 0.0930
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 371.0879, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[3140426   53922]
#  [  70001  575651]]
# Accuracy: 0.9677, CSI: 0.8229, Sensitivity: 0.8916, Specificity: 0.9831, False Alarm Ratio: 0.0856
#
#
# train, Regression Loss: 0.0154, Regression Loss 1h: 260.9073, Segmentation Loss:0.0523
# Train Confusion Matrix:
# [[3156819   32995]
#  [  45677  604509]]
# Accuracy: 0.9795, CSI: 0.8848, Sensitivity: 0.9297, Specificity: 0.9897, False Alarm Ratio: 0.0518
#
#
# epoch duration : 89.99700736999512
# epoch n° 1334
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 378.9719, Segmentation Loss:0.0875
# Train Confusion Matrix:
# [[3139869   56776]
#  [  76076  567279]]
# Accuracy: 0.9654, CSI: 0.8102, Sensitivity: 0.8818, Specificity: 0.9822, False Alarm Ratio: 0.0910
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 380.1987, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3143300   53345]
#  [  70178  573177]]
# Accuracy: 0.9678, CSI: 0.8227, Sensitivity: 0.8909, Specificity: 0.9833, False Alarm Ratio: 0.0851
#
#
# train, Regression Loss: 0.0159, Regression Loss 1h: 249.2101, Segmentation Loss:0.0537
# Train Confusion Matrix:
# [[3158247   34568]
#  [  46997  600188]]
# Accuracy: 0.9788, CSI: 0.8804, Sensitivity: 0.9274, Specificity: 0.9892, False Alarm Ratio: 0.0545
#
#
# epoch duration : 90.49111557006836
# epoch n° 1335
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 330.6748, Segmentation Loss:0.0887
# Train Confusion Matrix:
# [[3138352   56994]
#  [  77632  567022]]
# Accuracy: 0.9649, CSI: 0.8081, Sensitivity: 0.8796, Specificity: 0.9822, False Alarm Ratio: 0.0913
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 362.5053, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3142522   52824]
#  [  72189  572465]]
# Accuracy: 0.9674, CSI: 0.8208, Sensitivity: 0.8880, Specificity: 0.9835, False Alarm Ratio: 0.0845
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 236.5487, Segmentation Loss:0.0519
# Train Confusion Matrix:
# [[3161213   33137]
#  [  45651  599999]]
# Accuracy: 0.9795, CSI: 0.8839, Sensitivity: 0.9293, Specificity: 0.9896, False Alarm Ratio: 0.0523
#
#
# epoch duration : 91.48654913902283
# epoch n° 1336
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 354.5285, Segmentation Loss:0.0885
# Train Confusion Matrix:
# [[3136731   56203]
#  [  77740  569326]]
# Accuracy: 0.9651, CSI: 0.8095, Sensitivity: 0.8799, Specificity: 0.9824, False Alarm Ratio: 0.0898
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 364.3142, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[3139391   53543]
#  [  71298  575768]]
# Accuracy: 0.9675, CSI: 0.8218, Sensitivity: 0.8898, Specificity: 0.9832, False Alarm Ratio: 0.0851
#
#
# train, Regression Loss: 0.0155, Regression Loss 1h: 246.4730, Segmentation Loss:0.0531
# Train Confusion Matrix:
# [[3156701   33651]
#  [  46704  602944]]
# Accuracy: 0.9791, CSI: 0.8824, Sensitivity: 0.9281, Specificity: 0.9895, False Alarm Ratio: 0.0529
#
#
# epoch duration : 91.18454456329346
# epoch n° 1337
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 351.3201, Segmentation Loss:0.0887
# Train Confusion Matrix:
# [[3138682   56739]
#  [  77294  567285]]
# Accuracy: 0.9651, CSI: 0.8089, Sensitivity: 0.8801, Specificity: 0.9822, False Alarm Ratio: 0.0909
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 359.4187, Segmentation Loss:0.0821
# Train Confusion Matrix:
# [[3141835   53586]
#  [  71788  572791]]
# Accuracy: 0.9674, CSI: 0.8204, Sensitivity: 0.8886, Specificity: 0.9832, False Alarm Ratio: 0.0855
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 231.2833, Segmentation Loss:0.0493
# Train Confusion Matrix:
# [[3159866   31837]
#  [  43122  605175]]
# Accuracy: 0.9805, CSI: 0.8898, Sensitivity: 0.9335, Specificity: 0.9900, False Alarm Ratio: 0.0500
#
#
# epoch duration : 91.91029906272888
# epoch n° 1338
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 341.3028, Segmentation Loss:0.0906
# Train Confusion Matrix:
# [[3140052   57208]
#  [  79827  562913]]
# Accuracy: 0.9643, CSI: 0.8042, Sensitivity: 0.8758, Specificity: 0.9821, False Alarm Ratio: 0.0923
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 372.8913, Segmentation Loss:0.0832
# Train Confusion Matrix:
# [[3143054   54206]
#  [  73155  569585]]
# Accuracy: 0.9668, CSI: 0.8173, Sensitivity: 0.8862, Specificity: 0.9830, False Alarm Ratio: 0.0869
#
#
# train, Regression Loss: 0.0157, Regression Loss 1h: 247.9574, Segmentation Loss:0.0533
# Train Confusion Matrix:
# [[3159734   34179]
#  [  46959  599128]]
# Accuracy: 0.9789, CSI: 0.8807, Sensitivity: 0.9273, Specificity: 0.9893, False Alarm Ratio: 0.0540
#
#
# epoch duration : 90.31791496276855
# epoch n° 1339
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 372.4578, Segmentation Loss:0.0891
# Train Confusion Matrix:
# [[3148289   58014]
#  [  76593  557104]]
# Accuracy: 0.9649, CSI: 0.8054, Sensitivity: 0.8791, Specificity: 0.9819, False Alarm Ratio: 0.0943
#
#
# eval_added_value_full_spat, Regression Loss: 0.0212, Regression Loss 1h: 402.9189, Segmentation Loss:0.0820
# Train Confusion Matrix:
# [[3151459   54844]
#  [  70208  563489]]
# Accuracy: 0.9674, CSI: 0.8184, Sensitivity: 0.8892, Specificity: 0.9829, False Alarm Ratio: 0.0887
#
#
# train, Regression Loss: 0.0153, Regression Loss 1h: 258.4477, Segmentation Loss:0.0543
# Train Confusion Matrix:
# [[3171135   34134]
#  [  47964  586767]]
# Accuracy: 0.9786, CSI: 0.8773, Sensitivity: 0.9244, Specificity: 0.9894, False Alarm Ratio: 0.0550
#
#
# epoch duration : 90.97323417663574
# epoch n° 1340
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 348.1484, Segmentation Loss:0.0874
# Train Confusion Matrix:
# [[3139410   56956]
#  [  75114  568520]]
# Accuracy: 0.9656, CSI: 0.8115, Sensitivity: 0.8833, Specificity: 0.9822, False Alarm Ratio: 0.0911
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 374.0575, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3143127   53239]
#  [  69895  573739]]
# Accuracy: 0.9679, CSI: 0.8233, Sensitivity: 0.8914, Specificity: 0.9833, False Alarm Ratio: 0.0849
#
#
# train, Regression Loss: 0.0154, Regression Loss 1h: 243.6661, Segmentation Loss:0.0519
# Train Confusion Matrix:
# [[3162492   33496]
#  [  45579  598433]]
# Accuracy: 0.9794, CSI: 0.8833, Sensitivity: 0.9292, Specificity: 0.9895, False Alarm Ratio: 0.0530
#
#
# epoch duration : 90.142258644104
# saving step
# epoch n° 1341
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 354.8323, Segmentation Loss:0.0858
# Train Confusion Matrix:
# [[3137066   56843]
#  [  73612  572479]]
# Accuracy: 0.9660, CSI: 0.8144, Sensitivity: 0.8861, Specificity: 0.9822, False Alarm Ratio: 0.0903
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 368.4898, Segmentation Loss:0.0794
# Train Confusion Matrix:
# [[3139663   54246]
#  [  67845  578246]]
# Accuracy: 0.9682, CSI: 0.8257, Sensitivity: 0.8950, Specificity: 0.9830, False Alarm Ratio: 0.0858
#
#
# train, Regression Loss: 0.0147, Regression Loss 1h: 232.5118, Segmentation Loss:0.0484
# Train Confusion Matrix:
# [[3161828   31300]
#  [  42139  604733]]
# Accuracy: 0.9809, CSI: 0.8917, Sensitivity: 0.9349, Specificity: 0.9902, False Alarm Ratio: 0.0492
#
#
# epoch duration : 90.12804555892944
# epoch n° 1342
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 330.6880, Segmentation Loss:0.0869
# Train Confusion Matrix:
# [[3139837   56864]
#  [  74855  568444]]
# Accuracy: 0.9657, CSI: 0.8119, Sensitivity: 0.8836, Specificity: 0.9822, False Alarm Ratio: 0.0909
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 358.9824, Segmentation Loss:0.0802
# Train Confusion Matrix:
# [[3143629   53072]
#  [  69487  573812]]
# Accuracy: 0.9681, CSI: 0.8240, Sensitivity: 0.8920, Specificity: 0.9834, False Alarm Ratio: 0.0847
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 234.6710, Segmentation Loss:0.0508
# Train Confusion Matrix:
# [[3164926   32680]
#  [  44219  598175]]
# Accuracy: 0.9800, CSI: 0.8861, Sensitivity: 0.9312, Specificity: 0.9898, False Alarm Ratio: 0.0518
#
#
# epoch duration : 91.42680931091309
# epoch n° 1343
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 337.9463, Segmentation Loss:0.0880
# Train Confusion Matrix:
# [[3138158   58280]
#  [  75123  568439]]
# Accuracy: 0.9653, CSI: 0.8099, Sensitivity: 0.8833, Specificity: 0.9818, False Alarm Ratio: 0.0930
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 356.9361, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[3142337   54101]
#  [  69541  574021]]
# Accuracy: 0.9678, CSI: 0.8228, Sensitivity: 0.8919, Specificity: 0.9831, False Alarm Ratio: 0.0861
#
#
# train, Regression Loss: 0.0144, Regression Loss 1h: 228.6468, Segmentation Loss:0.0502
# Train Confusion Matrix:
# [[3161082   32588]
#  [  43943  602387]]
# Accuracy: 0.9801, CSI: 0.8873, Sensitivity: 0.9320, Specificity: 0.9898, False Alarm Ratio: 0.0513
#
#
# epoch duration : 88.77844953536987
# epoch n° 1344
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 365.0252, Segmentation Loss:0.0896
# Train Confusion Matrix:
# [[3140283   57273]
#  [  78522  563922]]
# Accuracy: 0.9646, CSI: 0.8059, Sensitivity: 0.8778, Specificity: 0.9821, False Alarm Ratio: 0.0922
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 377.7723, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[3144005   53551]
#  [  72447  569997]]
# Accuracy: 0.9672, CSI: 0.8190, Sensitivity: 0.8872, Specificity: 0.9833, False Alarm Ratio: 0.0859
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 232.9337, Segmentation Loss:0.0520
# Train Confusion Matrix:
# [[3161210   33256]
#  [  45791  599743]]
# Accuracy: 0.9794, CSI: 0.8835, Sensitivity: 0.9291, Specificity: 0.9896, False Alarm Ratio: 0.0525
#
#
# epoch duration : 90.33363628387451
# epoch n° 1345
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 375.9114, Segmentation Loss:0.0877
# Train Confusion Matrix:
# [[3142139   56648]
#  [  76218  564995]]
# Accuracy: 0.9654, CSI: 0.8096, Sensitivity: 0.8811, Specificity: 0.9823, False Alarm Ratio: 0.0911
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 389.2269, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[3145072   53715]
#  [  70143  571070]]
# Accuracy: 0.9677, CSI: 0.8218, Sensitivity: 0.8906, Specificity: 0.9832, False Alarm Ratio: 0.0860
#
#
# train, Regression Loss: 0.0152, Regression Loss 1h: 249.3061, Segmentation Loss:0.0525
# Train Confusion Matrix:
# [[3166049   33395]
#  [  46093  594463]]
# Accuracy: 0.9793, CSI: 0.8821, Sensitivity: 0.9280, Specificity: 0.9896, False Alarm Ratio: 0.0532
#
#
# epoch duration : 91.04151248931885
# epoch n° 1346
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 335.8804, Segmentation Loss:0.0884
# Train Confusion Matrix:
# [[3133287   59185]
#  [  74878  572650]]
# Accuracy: 0.9651, CSI: 0.8103, Sensitivity: 0.8844, Specificity: 0.9815, False Alarm Ratio: 0.0937
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 359.8420, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[3136581   55891]
#  [  69238  578290]]
# Accuracy: 0.9674, CSI: 0.8221, Sensitivity: 0.8931, Specificity: 0.9825, False Alarm Ratio: 0.0881
#
#
# train, Regression Loss: 0.0141, Regression Loss 1h: 221.5298, Segmentation Loss:0.0476
# Train Confusion Matrix:
# [[3162018   30612]
#  [  41466  605904]]
# Accuracy: 0.9812, CSI: 0.8937, Sensitivity: 0.9359, Specificity: 0.9904, False Alarm Ratio: 0.0481
#
#
# epoch duration : 90.2169713973999
# epoch n° 1347
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 349.7164, Segmentation Loss:0.0882
# Train Confusion Matrix:
# [[3137822   57881]
#  [  76249  568048]]
# Accuracy: 0.9651, CSI: 0.8090, Sensitivity: 0.8817, Specificity: 0.9819, False Alarm Ratio: 0.0925
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 370.1378, Segmentation Loss:0.0818
# Train Confusion Matrix:
# [[3140373   55330]
#  [  69980  574317]]
# Accuracy: 0.9674, CSI: 0.8209, Sensitivity: 0.8914, Specificity: 0.9827, False Alarm Ratio: 0.0879
#
#
# train, Regression Loss: 0.0152, Regression Loss 1h: 235.4971, Segmentation Loss:0.0500
# Train Confusion Matrix:
# [[3161234   32136]
#  [  43767  602863]]
# Accuracy: 0.9802, CSI: 0.8882, Sensitivity: 0.9323, Specificity: 0.9899, False Alarm Ratio: 0.0506
#
#
# epoch duration : 90.19432473182678
# epoch n° 1348
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 372.9111, Segmentation Loss:0.0888
# Train Confusion Matrix:
# [[3135583   55851]
#  [  79069  569497]]
# Accuracy: 0.9649, CSI: 0.8085, Sensitivity: 0.8781, Specificity: 0.9825, False Alarm Ratio: 0.0893
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 403.3904, Segmentation Loss:0.0818
# Train Confusion Matrix:
# [[3139331   52103]
#  [  73384  575182]]
# Accuracy: 0.9673, CSI: 0.8209, Sensitivity: 0.8869, Specificity: 0.9837, False Alarm Ratio: 0.0831
#
#
# train, Regression Loss: 0.0162, Regression Loss 1h: 259.9192, Segmentation Loss:0.0549
# Train Confusion Matrix:
# [[3164306   34788]
#  [  48329  592577]]
# Accuracy: 0.9784, CSI: 0.8770, Sensitivity: 0.9246, Specificity: 0.9891, False Alarm Ratio: 0.0555
#
#
# epoch duration : 91.12763214111328
# epoch n° 1349
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 345.7305, Segmentation Loss:0.0882
# Train Confusion Matrix:
# [[3137602   59155]
#  [  74086  569157]]
# Accuracy: 0.9653, CSI: 0.8103, Sensitivity: 0.8848, Specificity: 0.9815, False Alarm Ratio: 0.0941
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 371.2126, Segmentation Loss:0.0811
# Train Confusion Matrix:
# [[3141277   55480]
#  [  68029  575214]]
# Accuracy: 0.9678, CSI: 0.8232, Sensitivity: 0.8942, Specificity: 0.9826, False Alarm Ratio: 0.0880
#
#
# train, Regression Loss: 0.0156, Regression Loss 1h: 246.3248, Segmentation Loss:0.0531
# Train Confusion Matrix:
# [[3167707   33841]
#  [  46769  591683]]
# Accuracy: 0.9790, CSI: 0.8801, Sensitivity: 0.9267, Specificity: 0.9894, False Alarm Ratio: 0.0541
#
#
# epoch duration : 89.91055583953857
# epoch n° 1350
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 336.2337, Segmentation Loss:0.0910
# Train Confusion Matrix:
# [[3143499   55235]
#  [  81981  559285]]
# Accuracy: 0.9643, CSI: 0.8030, Sensitivity: 0.8722, Specificity: 0.9827, False Alarm Ratio: 0.0899
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 359.9977, Segmentation Loss:0.0831
# Train Confusion Matrix:
# [[3145923   52811]
#  [  74089  567177]]
# Accuracy: 0.9670, CSI: 0.8172, Sensitivity: 0.8845, Specificity: 0.9835, False Alarm Ratio: 0.0852
#
#
# train, Regression Loss: 0.0149, Regression Loss 1h: 229.2009, Segmentation Loss:0.0510
# Train Confusion Matrix:
# [[3166588   32552]
#  [  44848  596012]]
# Accuracy: 0.9798, CSI: 0.8851, Sensitivity: 0.9300, Specificity: 0.9898, False Alarm Ratio: 0.0518
#
#
# epoch duration : 90.48550748825073
# saving step
# epoch n° 1351
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 336.0089, Segmentation Loss:0.0863
# Train Confusion Matrix:
# [[3142684   57786]
#  [  73650  565880]]
# Accuracy: 0.9658, CSI: 0.8115, Sensitivity: 0.8848, Specificity: 0.9819, False Alarm Ratio: 0.0927
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 349.5838, Segmentation Loss:0.0797
# Train Confusion Matrix:
# [[3145297   55173]
#  [  67288  572242]]
# Accuracy: 0.9681, CSI: 0.8237, Sensitivity: 0.8948, Specificity: 0.9828, False Alarm Ratio: 0.0879
#
#
# train, Regression Loss: 0.0157, Regression Loss 1h: 228.9327, Segmentation Loss:0.0514
# Train Confusion Matrix:
# [[3165080   33030]
#  [  44873  597017]]
# Accuracy: 0.9797, CSI: 0.8846, Sensitivity: 0.9301, Specificity: 0.9897, False Alarm Ratio: 0.0524
#
#
# epoch duration : 86.16179084777832
# epoch n° 1352
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 348.8181, Segmentation Loss:0.0900
# Train Confusion Matrix:
# [[3134417   58962]
#  [  77641  568980]]
# Accuracy: 0.9644, CSI: 0.8064, Sensitivity: 0.8799, Specificity: 0.9815, False Alarm Ratio: 0.0939
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 374.6129, Segmentation Loss:0.0825
# Train Confusion Matrix:
# [[3138508   54871]
#  [  72053  574568]]
# Accuracy: 0.9669, CSI: 0.8191, Sensitivity: 0.8886, Specificity: 0.9828, False Alarm Ratio: 0.0872
#
#
# train, Regression Loss: 0.0153, Regression Loss 1h: 236.5129, Segmentation Loss:0.0534
# Train Confusion Matrix:
# [[3161589   33803]
#  [  47112  597496]]
# Accuracy: 0.9789, CSI: 0.8807, Sensitivity: 0.9269, Specificity: 0.9894, False Alarm Ratio: 0.0535
#
#
# epoch duration : 89.94437885284424
# epoch n° 1353
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 348.1466, Segmentation Loss:0.0863
# Train Confusion Matrix:
# [[3142867   54447]
#  [  75909  566777]]
# Accuracy: 0.9661, CSI: 0.8130, Sensitivity: 0.8819, Specificity: 0.9830, False Alarm Ratio: 0.0876
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 370.8190, Segmentation Loss:0.0800
# Train Confusion Matrix:
# [[3146582   50732]
#  [  71767  570919]]
# Accuracy: 0.9681, CSI: 0.8233, Sensitivity: 0.8883, Specificity: 0.9841, False Alarm Ratio: 0.0816
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 212.2648, Segmentation Loss:0.0474
# Train Confusion Matrix:
# [[3168235   30056]
#  [  41895  599814]]
# Accuracy: 0.9813, CSI: 0.8929, Sensitivity: 0.9347, Specificity: 0.9906, False Alarm Ratio: 0.0477
#
#
# epoch duration : 89.57384538650513
# epoch n° 1354
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 329.5376, Segmentation Loss:0.0882
# Train Confusion Matrix:
# [[3138485   59350]
#  [  74251  567914]]
# Accuracy: 0.9652, CSI: 0.8096, Sensitivity: 0.8844, Specificity: 0.9814, False Alarm Ratio: 0.0946
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 354.0442, Segmentation Loss:0.0809
# Train Confusion Matrix:
# [[3142503   55332]
#  [  68696  573469]]
# Accuracy: 0.9677, CSI: 0.8222, Sensitivity: 0.8930, Specificity: 0.9827, False Alarm Ratio: 0.0880
#
#
# train, Regression Loss: 0.0148, Regression Loss 1h: 226.4820, Segmentation Loss:0.0503
# Train Confusion Matrix:
# [[3167286   32331]
#  [  44217  596166]]
# Accuracy: 0.9801, CSI: 0.8862, Sensitivity: 0.9310, Specificity: 0.9899, False Alarm Ratio: 0.0514
#
#
# epoch duration : 89.69568276405334
# epoch n° 1355
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 343.3773, Segmentation Loss:0.0885
# Train Confusion Matrix:
# [[3148120   56404]
#  [  77291  558185]]
# Accuracy: 0.9652, CSI: 0.8068, Sensitivity: 0.8784, Specificity: 0.9824, False Alarm Ratio: 0.0918
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 358.5782, Segmentation Loss:0.0812
# Train Confusion Matrix:
# [[3152519   52005]
#  [  71428  564048]]
# Accuracy: 0.9679, CSI: 0.8205, Sensitivity: 0.8876, Specificity: 0.9838, False Alarm Ratio: 0.0844
#
#
# train, Regression Loss: 0.0153, Regression Loss 1h: 224.5252, Segmentation Loss:0.0517
# Train Confusion Matrix:
# [[3170869   32969]
#  [  45456  590706]]
# Accuracy: 0.9796, CSI: 0.8828, Sensitivity: 0.9285, Specificity: 0.9897, False Alarm Ratio: 0.0529
#
#
# epoch duration : 89.80044293403625
# epoch n° 1356
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 332.5869, Segmentation Loss:0.0873
# Train Confusion Matrix:
# [[3141106   55821]
#  [  76266  566807]]
# Accuracy: 0.9656, CSI: 0.8110, Sensitivity: 0.8814, Specificity: 0.9825, False Alarm Ratio: 0.0897
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 347.6436, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[3143286   53641]
#  [  69711  573362]]
# Accuracy: 0.9679, CSI: 0.8230, Sensitivity: 0.8916, Specificity: 0.9832, False Alarm Ratio: 0.0856
#
#
# ...
# Train Confusion Matrix:
# [[3134812   64928]
#  [  76682  563578]]
# Accuracy: 0.9631, CSI: 0.7992, Sensitivity: 0.8802, Specificity: 0.9797, False Alarm Ratio: 0.1033
#
#
# eval_added_value_full_spat, Regression Loss: 0.0287, Regression Loss 1h: 354.8921, Segmentation Loss:0.0870
# Train Confusion Matrix:
# [[3143902   55838]
#  [  72817  567443]]
# Accuracy: 0.9665, CSI: 0.8152, Sensitivity: 0.8863, Specificity: 0.9825, False Alarm Ratio: 0.0896
#
#
# train, Regression Loss: 0.0176, Regression Loss 1h: 228.8843, Segmentation Loss:0.0592
# Train Confusion Matrix:
# [[3161579   36360]
#  [  52090  589971]]
# Accuracy: 0.9770, CSI: 0.8696, Sensitivity: 0.9189, Specificity: 0.9886, False Alarm Ratio: 0.0581
#
#
# epoch duration : 89.71447587013245
# epoch n° 1483
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 329.2726, Segmentation Loss:0.0869
# Train Confusion Matrix:
# [[3150838   53484]
#  [  77306  558372]]
# Accuracy: 0.9659, CSI: 0.8102, Sensitivity: 0.8784, Specificity: 0.9833, False Alarm Ratio: 0.0874
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 358.1889, Segmentation Loss:0.0801
# Train Confusion Matrix:
# [[3152384   51938]
#  [  69779  565899]]
# Accuracy: 0.9683, CSI: 0.8230, Sensitivity: 0.8902, Specificity: 0.9838, False Alarm Ratio: 0.0841
#
#
# train, Regression Loss: 0.0158, Regression Loss 1h: 216.5905, Segmentation Loss:0.0524
# Train Confusion Matrix:
# [[3172009   33142]
#  [  45554  589295]]
# Accuracy: 0.9795, CSI: 0.8822, Sensitivity: 0.9282, Specificity: 0.9897, False Alarm Ratio: 0.0532
#
#
# epoch duration : 92.14614701271057
# epoch n° 1484
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 330.6283, Segmentation Loss:0.0879
# Train Confusion Matrix:
# [[3146937   54767]
#  [  77569  560727]]
# Accuracy: 0.9655, CSI: 0.8091, Sensitivity: 0.8785, Specificity: 0.9829, False Alarm Ratio: 0.0890
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 352.7251, Segmentation Loss:0.0806
# Train Confusion Matrix:
# [[3150535   51169]
#  [  71588  566708]]
# Accuracy: 0.9680, CSI: 0.8220, Sensitivity: 0.8878, Specificity: 0.9840, False Alarm Ratio: 0.0828
#
#
# train, Regression Loss: 0.0155, Regression Loss 1h: 228.4033, Segmentation Loss:0.0537
# Train Confusion Matrix:
# [[3167237   33732]
#  [  46992  592039]]
# Accuracy: 0.9790, CSI: 0.8800, Sensitivity: 0.9265, Specificity: 0.9895, False Alarm Ratio: 0.0539
#
#
# epoch duration : 86.94228672981262
# epoch n° 1485
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 356.5317, Segmentation Loss:0.0889
# Train Confusion Matrix:
# [[3137056   57907]
#  [  75891  569146]]
# Accuracy: 0.9652, CSI: 0.8097, Sensitivity: 0.8823, Specificity: 0.9819, False Alarm Ratio: 0.0923
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 363.3928, Segmentation Loss:0.0814
# Train Confusion Matrix:
# [[3140262   54701]
#  [  69593  575444]]
# Accuracy: 0.9676, CSI: 0.8224, Sensitivity: 0.8921, Specificity: 0.9829, False Alarm Ratio: 0.0868
#
#
# train, Regression Loss: 0.0144, Regression Loss 1h: 217.7901, Segmentation Loss:0.0500
# Train Confusion Matrix:
# [[3158952   31439]
#  [  43909  605700]]
# Accuracy: 0.9804, CSI: 0.8894, Sensitivity: 0.9324, Specificity: 0.9901, False Alarm Ratio: 0.0493
#
#
# epoch duration : 91.80600595474243
# epoch n° 1486
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 340.6988, Segmentation Loss:0.0883
# Train Confusion Matrix:
# [[3140817   53662]
#  [  80073  565448]]
# Accuracy: 0.9652, CSI: 0.8087, Sensitivity: 0.8760, Specificity: 0.9832, False Alarm Ratio: 0.0867
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 354.0645, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[3143946   50533]
#  [  73885  571636]]
# Accuracy: 0.9676, CSI: 0.8213, Sensitivity: 0.8855, Specificity: 0.9842, False Alarm Ratio: 0.0812
#
#
# train, Regression Loss: 0.0144, Regression Loss 1h: 225.7687, Segmentation Loss:0.0490
# Train Confusion Matrix:
# [[3167488   31010]
#  [  42976  598526]]
# Accuracy: 0.9807, CSI: 0.8900, Sensitivity: 0.9330, Specificity: 0.9903, False Alarm Ratio: 0.0493
#
#
# epoch duration : 91.07367944717407
# epoch n° 1487
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 372.8582, Segmentation Loss:0.0868
# Train Confusion Matrix:
# [[3141564   56710]
#  [  73846  567880]]
# Accuracy: 0.9660, CSI: 0.8131, Sensitivity: 0.8849, Specificity: 0.9823, False Alarm Ratio: 0.0908
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 387.3380, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[3145151   53123]
#  [  68415  573311]]
# Accuracy: 0.9683, CSI: 0.8251, Sensitivity: 0.8934, Specificity: 0.9834, False Alarm Ratio: 0.0848
#
#
# train, Regression Loss: 0.0156, Regression Loss 1h: 242.0524, Segmentation Loss:0.0514
# Train Confusion Matrix:
# [[3164565   33289]
#  [  45030  597116]]
# Accuracy: 0.9796, CSI: 0.8840, Sensitivity: 0.9299, Specificity: 0.9896, False Alarm Ratio: 0.0528
#
#
# epoch duration : 90.52826237678528
# epoch n° 1488
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 372.3222, Segmentation Loss:0.0880
# Train Confusion Matrix:
# [[3142305   57952]
#  [  75156  564587]]
# Accuracy: 0.9653, CSI: 0.8092, Sensitivity: 0.8825, Specificity: 0.9819, False Alarm Ratio: 0.0931
#
#
# eval_added_value_full_spat, Regression Loss: 0.0211, Regression Loss 1h: 381.5184, Segmentation Loss:0.0806
# Train Confusion Matrix:
# [[3145923   54334]
#  [  69093  570650]]
# Accuracy: 0.9679, CSI: 0.8222, Sensitivity: 0.8920, Specificity: 0.9830, False Alarm Ratio: 0.0869
#
#
# train, Regression Loss: 0.0156, Regression Loss 1h: 256.1894, Segmentation Loss:0.0533
# Train Confusion Matrix:
# [[3168804   33720]
#  [  46781  590695]]
# Accuracy: 0.9790, CSI: 0.8801, Sensitivity: 0.9266, Specificity: 0.9895, False Alarm Ratio: 0.0540
#
#
# epoch duration : 90.48716259002686
# epoch n° 1489
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 369.0540, Segmentation Loss:0.0839
# Train Confusion Matrix:
# [[3150883   53874]
#  [  73297  561946]]
# Accuracy: 0.9669, CSI: 0.8155, Sensitivity: 0.8846, Specificity: 0.9832, False Alarm Ratio: 0.0875
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 373.0680, Segmentation Loss:0.0779
# Train Confusion Matrix:
# [[3153770   50987]
#  [  68188  567055]]
# Accuracy: 0.9690, CSI: 0.8263, Sensitivity: 0.8927, Specificity: 0.9841, False Alarm Ratio: 0.0825
#
#
# train, Regression Loss: 0.0148, Regression Loss 1h: 218.1429, Segmentation Loss:0.0478
# Train Confusion Matrix:
# [[3172238   30964]
#  [  41588  595210]]
# Accuracy: 0.9811, CSI: 0.8914, Sensitivity: 0.9347, Specificity: 0.9903, False Alarm Ratio: 0.0494
#
#
# epoch duration : 91.91986775398254
# epoch n° 1490
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 346.1825, Segmentation Loss:0.0875
# Train Confusion Matrix:
# [[3150729   55750]
#  [  76445  557076]]
# Accuracy: 0.9656, CSI: 0.8082, Sensitivity: 0.8793, Specificity: 0.9826, False Alarm Ratio: 0.0910
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 355.6687, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3153703   52776]
#  [  70449  563072]]
# Accuracy: 0.9679, CSI: 0.8204, Sensitivity: 0.8888, Specificity: 0.9835, False Alarm Ratio: 0.0857
#
#
# train, Regression Loss: 0.0149, Regression Loss 1h: 233.0650, Segmentation Loss:0.0491
# Train Confusion Matrix:
# [[3173760   30944]
#  [  43148  592148]]
# Accuracy: 0.9807, CSI: 0.8888, Sensitivity: 0.9321, Specificity: 0.9903, False Alarm Ratio: 0.0497
#
#
# epoch duration : 91.49170804023743
# saving step
# epoch n° 1491
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 344.1746, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3130206   57860]
#  [  72143  579791]]
# Accuracy: 0.9661, CSI: 0.8168, Sensitivity: 0.8893, Specificity: 0.9819, False Alarm Ratio: 0.0907
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 365.0344, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[3134645   53421]
#  [  67891  584043]]
# Accuracy: 0.9684, CSI: 0.8280, Sensitivity: 0.8959, Specificity: 0.9832, False Alarm Ratio: 0.0838
#
#
# train, Regression Loss: 0.0164, Regression Loss 1h: 235.9237, Segmentation Loss:0.0546
# Train Confusion Matrix:
# [[3152893   35257]
#  [  47665  604185]]
# Accuracy: 0.9784, CSI: 0.8793, Sensitivity: 0.9269, Specificity: 0.9889, False Alarm Ratio: 0.0551
#
#
# epoch duration : 87.45918273925781
# epoch n° 1492
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 357.3058, Segmentation Loss:0.0896
# Train Confusion Matrix:
# [[3140612   54191]
#  [  81412  563785]]
# Accuracy: 0.9647, CSI: 0.8061, Sensitivity: 0.8738, Specificity: 0.9830, False Alarm Ratio: 0.0877
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 381.8520, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[3143905   50898]
#  [  74751  570446]]
# Accuracy: 0.9673, CSI: 0.8195, Sensitivity: 0.8841, Specificity: 0.9841, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0148, Regression Loss 1h: 226.2786, Segmentation Loss:0.0497
# Train Confusion Matrix:
# [[3162981   31138]
#  [  43457  602424]]
# Accuracy: 0.9806, CSI: 0.8898, Sensitivity: 0.9327, Specificity: 0.9903, False Alarm Ratio: 0.0491
#
#
# epoch duration : 87.4839415550232
# epoch n° 1493
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 346.2577, Segmentation Loss:0.0890
# Train Confusion Matrix:
# [[3145620   59011]
#  [  75591  559778]]
# Accuracy: 0.9649, CSI: 0.8062, Sensitivity: 0.8810, Specificity: 0.9816, False Alarm Ratio: 0.0954
#
#
# eval_added_value_full_spat, Regression Loss: 0.0210, Regression Loss 1h: 372.8832, Segmentation Loss:0.0812
# Train Confusion Matrix:
# [[3148817   55814]
#  [  68270  567099]]
# Accuracy: 0.9677, CSI: 0.8205, Sensitivity: 0.8926, Specificity: 0.9826, False Alarm Ratio: 0.0896
#
#
# train, Regression Loss: 0.0136, Regression Loss 1h: 217.1497, Segmentation Loss:0.0484
# Train Confusion Matrix:
# [[3169045   30619]
#  [  42594  597742]]
# Accuracy: 0.9809, CSI: 0.8909, Sensitivity: 0.9335, Specificity: 0.9904, False Alarm Ratio: 0.0487
#
#
# epoch duration : 90.68743443489075
# epoch n° 1494
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 335.4402, Segmentation Loss:0.0869
# Train Confusion Matrix:
# [[3145718   53746]
#  [  77504  563032]]
# Accuracy: 0.9658, CSI: 0.8110, Sensitivity: 0.8790, Specificity: 0.9832, False Alarm Ratio: 0.0871
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 363.5213, Segmentation Loss:0.0798
# Train Confusion Matrix:
# [[3149066   50398]
#  [  70987  569549]]
# Accuracy: 0.9684, CSI: 0.8243, Sensitivity: 0.8892, Specificity: 0.9842, False Alarm Ratio: 0.0813
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 232.6533, Segmentation Loss:0.0523
# Train Confusion Matrix:
# [[3163577   32595]
#  [  46024  597804]]
# Accuracy: 0.9795, CSI: 0.8838, Sensitivity: 0.9285, Specificity: 0.9898, False Alarm Ratio: 0.0517
#
#
# epoch duration : 89.09153342247009
# epoch n° 1495
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 337.2922, Segmentation Loss:0.0846
# Train Confusion Matrix:
# [[3143677   55867]
#  [  72161  568295]]
# Accuracy: 0.9667, CSI: 0.8161, Sensitivity: 0.8873, Specificity: 0.9825, False Alarm Ratio: 0.0895
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 359.1771, Segmentation Loss:0.0780
# Train Confusion Matrix:
# [[3146598   52946]
#  [  66346  574110]]
# Accuracy: 0.9689, CSI: 0.8280, Sensitivity: 0.8964, Specificity: 0.9835, False Alarm Ratio: 0.0844
#
#
# train, Regression Loss: 0.0144, Regression Loss 1h: 212.0240, Segmentation Loss:0.0474
# Train Confusion Matrix:
# [[3167374   30940]
#  [  41272  600414]]
# Accuracy: 0.9812, CSI: 0.8926, Sensitivity: 0.9357, Specificity: 0.9903, False Alarm Ratio: 0.0490
#
#
# epoch duration : 89.61387991905212
# epoch n° 1496
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 341.6306, Segmentation Loss:0.0862
# Train Confusion Matrix:
# [[3140668   56951]
#  [  73693  568688]]
# Accuracy: 0.9660, CSI: 0.8132, Sensitivity: 0.8853, Specificity: 0.9822, False Alarm Ratio: 0.0910
#
#
# eval_added_value_full_spat, Regression Loss: 0.0210, Regression Loss 1h: 378.7391, Segmentation Loss:0.0795
# Train Confusion Matrix:
# [[3144450   53169]
#  [  68706  573675]]
# Accuracy: 0.9683, CSI: 0.8248, Sensitivity: 0.8930, Specificity: 0.9834, False Alarm Ratio: 0.0848
#
#
# train, Regression Loss: 0.0151, Regression Loss 1h: 234.1613, Segmentation Loss:0.0503
# Train Confusion Matrix:
# [[3166966   31895]
#  [  43898  597241]]
# Accuracy: 0.9803, CSI: 0.8874, Sensitivity: 0.9315, Specificity: 0.9900, False Alarm Ratio: 0.0507
#
#
# epoch duration : 89.02563142776489
# epoch n° 1497
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 499.2589, Segmentation Loss:0.0887
# Train Confusion Matrix:
# [[3141184   56135]
#  [  77530  565151]]
# Accuracy: 0.9652, CSI: 0.8087, Sensitivity: 0.8794, Specificity: 0.9824, False Alarm Ratio: 0.0904
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 464.5591, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[3143106   54213]
#  [  69226  573455]]
# Accuracy: 0.9679, CSI: 0.8229, Sensitivity: 0.8923, Specificity: 0.9830, False Alarm Ratio: 0.0864
#
#
# train, Regression Loss: 0.0136, Regression Loss 1h: 209.4074, Segmentation Loss:0.0455
# Train Confusion Matrix:
# [[3168432   29137]
#  [  39751  602680]]
# Accuracy: 0.9821, CSI: 0.8974, Sensitivity: 0.9381, Specificity: 0.9909, False Alarm Ratio: 0.0461
#
#
# epoch duration : 90.65031003952026
# epoch n° 1498
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 347.8611, Segmentation Loss:0.0869
# Train Confusion Matrix:
# [[3133376   57571]
#  [  73938  575115]]
# Accuracy: 0.9658, CSI: 0.8139, Sensitivity: 0.8861, Specificity: 0.9820, False Alarm Ratio: 0.0910
#
#
# eval_added_value_full_spat, Regression Loss: 0.0211, Regression Loss 1h: 365.0336, Segmentation Loss:0.0803
# Train Confusion Matrix:
# [[3136772   54175]
#  [  68538  580515]]
# Accuracy: 0.9680, CSI: 0.8255, Sensitivity: 0.8944, Specificity: 0.9830, False Alarm Ratio: 0.0854
#
#
# train, Regression Loss: 0.0150, Regression Loss 1h: 232.0436, Segmentation Loss:0.0509
# Train Confusion Matrix:
# [[3164263   32966]
#  [  44037  598734]]
# Accuracy: 0.9799, CSI: 0.8860, Sensitivity: 0.9315, Specificity: 0.9897, False Alarm Ratio: 0.0522
#
#
# epoch duration : 90.47007703781128
# epoch n° 1499
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 344.0588, Segmentation Loss:0.0869
# Train Confusion Matrix:
# [[3148606   52965]
#  [  78176  560253]]
# Accuracy: 0.9658, CSI: 0.8103, Sensitivity: 0.8775, Specificity: 0.9835, False Alarm Ratio: 0.0864
#
#
# eval_added_value_full_spat, Regression Loss: 0.0211, Regression Loss 1h: 366.1260, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[3150878   50693]
#  [  71042  567387]]
# Accuracy: 0.9683, CSI: 0.8233, Sensitivity: 0.8887, Specificity: 0.9842, False Alarm Ratio: 0.0820
#
#
# train, Regression Loss: 0.0143, Regression Loss 1h: 221.3781, Segmentation Loss:0.0498
# Train Confusion Matrix:
# [[3164583   31216]
#  [  44069  600132]]
# Accuracy: 0.9804, CSI: 0.8885, Sensitivity: 0.9316, Specificity: 0.9902, False Alarm Ratio: 0.0494
#
#
# epoch duration : 90.94955444335938
# epoch n° 1500
#
# eval_opportunity_cost_spat, Regression Loss: 0.0257, Regression Loss 1h: 339.0326, Segmentation Loss:0.0987
# Train Confusion Matrix:
# [[3115630   77444]
#  [  72535  574391]]
# Accuracy: 0.9609, CSI: 0.7930, Sensitivity: 0.8879, Specificity: 0.9757, False Alarm Ratio: 0.1188
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 366.3158, Segmentation Loss:0.0863
# Train Confusion Matrix:
# [[3130249   62825]
#  [  67940  578986]]
# Accuracy: 0.9659, CSI: 0.8158, Sensitivity: 0.8950, Specificity: 0.9803, False Alarm Ratio: 0.0979
#
#
# train, Regression Loss: 0.0162, Regression Loss 1h: 234.6122, Segmentation Loss:0.0514
# Train Confusion Matrix:
# [[3161455   33172]
#  [  44939  600434]]
# Accuracy: 0.9797, CSI: 0.8849, Sensitivity: 0.9304, Specificity: 0.9896, False Alarm Ratio: 0.0524
#
#
# epoch duration : 91.21929860115051
# saving step

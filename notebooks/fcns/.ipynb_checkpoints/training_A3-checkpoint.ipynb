# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A3.radar + cmls -> rain gauges 1 min + rain gauges 60 min (champ indépendant) [xrl_yg1g60i]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 1501
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_A3_xrl_yg1g60i.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image = 64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
# Petit UNet
ch_in = 72
ch_out = nsteps * 3 + 1
size = nsteps * 3
device = torch.device('cuda:0')
model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn(eval_independent_qpe_1h=True)

# %%
# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 390

# %%
model.train()
for epoch in range(last_epoch, num_epochs):
  print('epoch n°', epoch)
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)


    # pseudo radar
    noisy_images = make_noisy_images(images)

    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)  # Forward pass

    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()

    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
    
  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 390
# Training, Regression Loss: 0.0430, Regression Loss 1h: 2.1563, Segmentation Loss:0.1490
# Train Confusion Matrix:
# [[3119786   77845]
#  [ 140187  502182]]
# Accuracy: 0.9432, CSI: 0.6973, Sensitivity: 0.7818, Specificity: 0.9757, False Alarm Ratio: 0.1342
#
#
# saving step
# epoch n° 391
# Training, Regression Loss: 0.0431, Regression Loss 1h: 2.1528, Segmentation Loss:0.1430
# Train Confusion Matrix:
# [[3123998   77562]
#  [ 132129  506311]]
# Accuracy: 0.9454, CSI: 0.7071, Sensitivity: 0.7930, Specificity: 0.9758, False Alarm Ratio: 0.1328
#
#
# epoch n° 392
# Training, Regression Loss: 0.0430, Regression Loss 1h: 2.0785, Segmentation Loss:0.1462
# Train Confusion Matrix:
# [[3124144   76844]
#  [ 136780  502232]]
# Accuracy: 0.9444, CSI: 0.7016, Sensitivity: 0.7860, Specificity: 0.9760, False Alarm Ratio: 0.1327
#
#
# epoch n° 393
# Training, Regression Loss: 0.0430, Regression Loss 1h: 2.1044, Segmentation Loss:0.1488
# Train Confusion Matrix:
# [[3124794   76955]
#  [ 140106  498145]]
# Accuracy: 0.9435, CSI: 0.6965, Sensitivity: 0.7805, Specificity: 0.9760, False Alarm Ratio: 0.1338
#
#
# epoch n° 394
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.1599, Segmentation Loss:0.1490
# Train Confusion Matrix:
# [[3118156   75731]
#  [ 139854  506259]]
# Accuracy: 0.9439, CSI: 0.7013, Sensitivity: 0.7835, Specificity: 0.9763, False Alarm Ratio: 0.1301
#
#
# epoch n° 395
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.1748, Segmentation Loss:0.1453
# Train Confusion Matrix:
# [[3127297   75492]
#  [ 136036  501175]]
# Accuracy: 0.9449, CSI: 0.7032, Sensitivity: 0.7865, Specificity: 0.9764, False Alarm Ratio: 0.1309
#
#
# epoch n° 396
# Training, Regression Loss: 0.0444, Regression Loss 1h: 2.1690, Segmentation Loss:0.1366
# Train Confusion Matrix:
# [[3111163   77679]
#  [ 123930  527228]]
# Accuracy: 0.9475, CSI: 0.7234, Sensitivity: 0.8097, Specificity: 0.9756, False Alarm Ratio: 0.1284
#
#
# epoch n° 397
# Training, Regression Loss: 0.0439, Regression Loss 1h: 2.1472, Segmentation Loss:0.1470
# Train Confusion Matrix:
# [[3115598   77458]
#  [ 137260  509684]]
# Accuracy: 0.9441, CSI: 0.7036, Sensitivity: 0.7878, Specificity: 0.9757, False Alarm Ratio: 0.1319
#
#
# epoch n° 398
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.1024, Segmentation Loss:0.1440
# Train Confusion Matrix:
# [[3121433   77145]
#  [ 134269  507153]]
# Accuracy: 0.9449, CSI: 0.7058, Sensitivity: 0.7907, Specificity: 0.9759, False Alarm Ratio: 0.1320
#
#
# epoch n° 399
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.0886, Segmentation Loss:0.1474
# Train Confusion Matrix:
# [[3110513   77755]
#  [ 137089  514643]]
# Accuracy: 0.9441, CSI: 0.7055, Sensitivity: 0.7897, Specificity: 0.9756, False Alarm Ratio: 0.1313
#
#
# epoch n° 400
# Training, Regression Loss: 0.0431, Regression Loss 1h: 2.0340, Segmentation Loss:0.1469
# Train Confusion Matrix:
# [[3128668   75633]
#  [ 138359  497340]]
# Accuracy: 0.9443, CSI: 0.6992, Sensitivity: 0.7824, Specificity: 0.9764, False Alarm Ratio: 0.1320
#
#
# saving step
# epoch n° 401
# Training, Regression Loss: 0.0416, Regression Loss 1h: 2.0209, Segmentation Loss:0.1456
# Train Confusion Matrix:
# [[3119880   77118]
#  [ 135198  507804]]
# Accuracy: 0.9447, CSI: 0.7052, Sensitivity: 0.7897, Specificity: 0.9759, False Alarm Ratio: 0.1318
#
#
# epoch n° 402
# Training, Regression Loss: 0.0418, Regression Loss 1h: 2.1176, Segmentation Loss:0.1479
# Train Confusion Matrix:
# [[3119529   75905]
#  [ 139064  505502]]
# Accuracy: 0.9440, CSI: 0.7016, Sensitivity: 0.7843, Specificity: 0.9762, False Alarm Ratio: 0.1306
#
#
# epoch n° 403
# Training, Regression Loss: 0.0438, Regression Loss 1h: 2.1557, Segmentation Loss:0.1468
# Train Confusion Matrix:
# [[3126132   76493]
#  [ 137261  500114]]
# Accuracy: 0.9443, CSI: 0.7006, Sensitivity: 0.7846, Specificity: 0.9761, False Alarm Ratio: 0.1327
#
#
# epoch n° 404
# Training, Regression Loss: 0.0425, Regression Loss 1h: 1.9798, Segmentation Loss:0.1508
# Train Confusion Matrix:
# [[3117758   76298]
#  [ 141877  504067]]
# Accuracy: 0.9432, CSI: 0.6979, Sensitivity: 0.7804, Specificity: 0.9761, False Alarm Ratio: 0.1315
#
#
# epoch n° 405
# Training, Regression Loss: 0.0448, Regression Loss 1h: 2.2324, Segmentation Loss:0.1441
# Train Confusion Matrix:
# [[3123153   76636]
#  [ 134232  505979]]
# Accuracy: 0.9451, CSI: 0.7058, Sensitivity: 0.7903, Specificity: 0.9760, False Alarm Ratio: 0.1315
#
#
# epoch n° 406
# Training, Regression Loss: 0.0441, Regression Loss 1h: 2.1542, Segmentation Loss:0.1431
# Train Confusion Matrix:
# [[3119125   76748]
#  [ 133428  510699]]
# Accuracy: 0.9453, CSI: 0.7084, Sensitivity: 0.7929, Specificity: 0.9760, False Alarm Ratio: 0.1306
#
#
# epoch n° 407
# Training, Regression Loss: 0.0422, Regression Loss 1h: 2.0696, Segmentation Loss:0.1450
# Train Confusion Matrix:
# [[3123148   76327]
#  [ 135886  504639]]
# Accuracy: 0.9447, CSI: 0.7040, Sensitivity: 0.7879, Specificity: 0.9761, False Alarm Ratio: 0.1314
#
#
# epoch n° 408
# Training, Regression Loss: 0.0428, Regression Loss 1h: 2.0918, Segmentation Loss:0.1486
# Train Confusion Matrix:
# [[3119726   78337]
#  [ 139238  502699]]
# Accuracy: 0.9433, CSI: 0.6979, Sensitivity: 0.7831, Specificity: 0.9755, False Alarm Ratio: 0.1348
#
#
# epoch n° 409
# Training, Regression Loss: 0.0440, Regression Loss 1h: 2.1647, Segmentation Loss:0.1453
# Train Confusion Matrix:
# [[3121099   75995]
#  [ 136348  506558]]
# Accuracy: 0.9447, CSI: 0.7046, Sensitivity: 0.7879, Specificity: 0.9762, False Alarm Ratio: 0.1305
#
#
# epoch n° 410
# Training, Regression Loss: 0.0430, Regression Loss 1h: 2.1081, Segmentation Loss:0.1428
# Train Confusion Matrix:
# [[3119961   76894]
#  [ 132457  510688]]
# Accuracy: 0.9455, CSI: 0.7093, Sensitivity: 0.7940, Specificity: 0.9759, False Alarm Ratio: 0.1309
#
#
# saving step
# epoch n° 411
# Training, Regression Loss: 0.0425, Regression Loss 1h: 2.0453, Segmentation Loss:0.1411
# Train Confusion Matrix:
# [[3126542   76159]
#  [ 129954  507345]]
# Accuracy: 0.9463, CSI: 0.7111, Sensitivity: 0.7961, Specificity: 0.9762, False Alarm Ratio: 0.1305
#
#
# epoch n° 412
# Training, Regression Loss: 0.0421, Regression Loss 1h: 2.0297, Segmentation Loss:0.1451
# Train Confusion Matrix:
# [[3130285   75072]
#  [ 135699  498944]]
# Accuracy: 0.9451, CSI: 0.7030, Sensitivity: 0.7862, Specificity: 0.9766, False Alarm Ratio: 0.1308
#
#
# epoch n° 413
# Training, Regression Loss: 0.0415, Regression Loss 1h: 2.0623, Segmentation Loss:0.1486
# Train Confusion Matrix:
# [[3127517   76833]
#  [ 140026  495624]]
# Accuracy: 0.9435, CSI: 0.6956, Sensitivity: 0.7797, Specificity: 0.9760, False Alarm Ratio: 0.1342
#
#
# epoch n° 414
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.1135, Segmentation Loss:0.1470
# Train Confusion Matrix:
# [[3137805   74979]
#  [ 138705  488511]]
# Accuracy: 0.9444, CSI: 0.6957, Sensitivity: 0.7789, Specificity: 0.9767, False Alarm Ratio: 0.1331
#
#
# epoch n° 415
# Training, Regression Loss: 0.0438, Regression Loss 1h: 2.0690, Segmentation Loss:0.1414
# Train Confusion Matrix:
# [[3124222   76088]
#  [ 129935  509755]]
# Accuracy: 0.9463, CSI: 0.7122, Sensitivity: 0.7969, Specificity: 0.9762, False Alarm Ratio: 0.1299
#
#
# epoch n° 416
# Training, Regression Loss: 0.0420, Regression Loss 1h: 2.0143, Segmentation Loss:0.1462
# Train Confusion Matrix:
# [[3125164   75466]
#  [ 137565  501805]]
# Accuracy: 0.9445, CSI: 0.7020, Sensitivity: 0.7848, Specificity: 0.9764, False Alarm Ratio: 0.1307
#
#
# epoch n° 417
# Training, Regression Loss: 0.0429, Regression Loss 1h: 2.1279, Segmentation Loss:0.1395
# Train Confusion Matrix:
# [[3121404   76117]
#  [ 127670  514809]]
# Accuracy: 0.9469, CSI: 0.7164, Sensitivity: 0.8013, Specificity: 0.9762, False Alarm Ratio: 0.1288
#
#
# epoch n° 418
# Training, Regression Loss: 0.0426, Regression Loss 1h: 2.0758, Segmentation Loss:0.1465
# Train Confusion Matrix:
# [[3123497   76337]
#  [ 136831  503335]]
# Accuracy: 0.9445, CSI: 0.7025, Sensitivity: 0.7863, Specificity: 0.9761, False Alarm Ratio: 0.1317
#
#
# epoch n° 419
# Training, Regression Loss: 0.0421, Regression Loss 1h: 2.0409, Segmentation Loss:0.1474
# Train Confusion Matrix:
# [[3127112   76631]
#  [ 138651  497606]]
# Accuracy: 0.9439, CSI: 0.6980, Sensitivity: 0.7821, Specificity: 0.9761, False Alarm Ratio: 0.1334
#
#
# saving step
# epoch n° 421
# Training, Regression Loss: 0.0431, Regression Loss 1h: 2.1266, Segmentation Loss:0.1422
# Train Confusion Matrix:
# [[3126436   76882]
#  [ 131401  505281]]
# Accuracy: 0.9458, CSI: 0.7081, Sensitivity: 0.7936, Specificity: 0.9760, False Alarm Ratio: 0.1321
#
#
# epoch n° 422
# Training, Regression Loss: 0.0428, Regression Loss 1h: 2.0175, Segmentation Loss:0.1464
# Train Confusion Matrix:
# [[3132719   75498]
#  [ 137862  493921]]
# Accuracy: 0.9444, CSI: 0.6983, Sensitivity: 0.7818, Specificity: 0.9765, False Alarm Ratio: 0.1326
#
#
# epoch n° 423
# Training, Regression Loss: 0.0420, Regression Loss 1h: 2.0607, Segmentation Loss:0.1438
# Train Confusion Matrix:
# [[3133004   75212]
#  [ 134748  497036]]
# Accuracy: 0.9453, CSI: 0.7030, Sensitivity: 0.7867, Specificity: 0.9766, False Alarm Ratio: 0.1314
#
#
# epoch n° 424
# Training, Regression Loss: 0.0438, Regression Loss 1h: 2.0536, Segmentation Loss:0.1424
# Train Confusion Matrix:
# [[3111097   77806]
#  [ 131274  519823]]
# Accuracy: 0.9456, CSI: 0.7132, Sensitivity: 0.7984, Specificity: 0.9756, False Alarm Ratio: 0.1302
#
#
# epoch n° 425
# Training, Regression Loss: 0.0432, Regression Loss 1h: 2.0334, Segmentation Loss:0.1408
# Train Confusion Matrix:
# [[3121897   76290]
#  [ 131479  510334]]
# Accuracy: 0.9459, CSI: 0.7107, Sensitivity: 0.7951, Specificity: 0.9761, False Alarm Ratio: 0.1300
#
#
# epoch n° 426
# Training, Regression Loss: 0.0417, Regression Loss 1h: 2.0354, Segmentation Loss:0.1485
# Train Confusion Matrix:
# [[3123692   76630]
#  [ 139419  500259]]
# Accuracy: 0.9437, CSI: 0.6984, Sensitivity: 0.7820, Specificity: 0.9761, False Alarm Ratio: 0.1328
#
#
# epoch n° 427
# Training, Regression Loss: 0.0423, Regression Loss 1h: 1.9978, Segmentation Loss:0.1454
# Train Confusion Matrix:
# [[3129127   75029]
#  [ 137477  498367]]
# Accuracy: 0.9447, CSI: 0.7011, Sensitivity: 0.7838, Specificity: 0.9766, False Alarm Ratio: 0.1309
#
#
# epoch n° 428
# Training, Regression Loss: 0.0417, Regression Loss 1h: 2.0514, Segmentation Loss:0.1438
# Train Confusion Matrix:
# [[3122632   75784]
#  [ 133930  507654]]
# Accuracy: 0.9454, CSI: 0.7077, Sensitivity: 0.7913, Specificity: 0.9763, False Alarm Ratio: 0.1299
#
#
# epoch n° 429
# Training, Regression Loss: 0.0428, Regression Loss 1h: 1.9664, Segmentation Loss:0.1438
# Train Confusion Matrix:
# [[3124125   76076]
#  [ 133701  506098]]
# Accuracy: 0.9454, CSI: 0.7070, Sensitivity: 0.7910, Specificity: 0.9762, False Alarm Ratio: 0.1307
#
#
# epoch n° 430
# Training, Regression Loss: 0.0419, Regression Loss 1h: 1.9502, Segmentation Loss:0.1489
# Train Confusion Matrix:
# [[3119507   76514]
#  [ 140452  503527]]
# Accuracy: 0.9435, CSI: 0.6989, Sensitivity: 0.7819, Specificity: 0.9761, False Alarm Ratio: 0.1319
#
#
# saving step
# epoch n° 431
# Training, Regression Loss: 0.0419, Regression Loss 1h: 2.0285, Segmentation Loss:0.1447
# Train Confusion Matrix:
# [[3125968   75144]
#  [ 135020  503868]]
# Accuracy: 0.9453, CSI: 0.7057, Sensitivity: 0.7887, Specificity: 0.9765, False Alarm Ratio: 0.1298
#
#
# epoch n° 432
# Training, Regression Loss: 0.0427, Regression Loss 1h: 2.1742, Segmentation Loss:0.1451
# Train Confusion Matrix:
# [[3122445   76698]
#  [ 136077  504780]]
# Accuracy: 0.9446, CSI: 0.7035, Sensitivity: 0.7877, Specificity: 0.9760, False Alarm Ratio: 0.1319
#
#
# epoch n° 433
# Training, Regression Loss: 0.0437, Regression Loss 1h: 2.1456, Segmentation Loss:0.1381
# Train Confusion Matrix:
# [[3123404   75376]
#  [ 127372  513848]]
# Accuracy: 0.9472, CSI: 0.7171, Sensitivity: 0.8014, Specificity: 0.9764, False Alarm Ratio: 0.1279
#
#
# epoch n° 434
# Training, Regression Loss: 0.0413, Regression Loss 1h: 1.9849, Segmentation Loss:0.1448
# Train Confusion Matrix:
# [[3129519   75029]
#  [ 135315  500137]]
# Accuracy: 0.9452, CSI: 0.7039, Sensitivity: 0.7871, Specificity: 0.9766, False Alarm Ratio: 0.1304
#
#
# epoch n° 435
# Training, Regression Loss: 0.0426, Regression Loss 1h: 2.0770, Segmentation Loss:0.1438
# Train Confusion Matrix:
# [[3126882   75392]
#  [ 134937  502789]]
# Accuracy: 0.9452, CSI: 0.7051, Sensitivity: 0.7884, Specificity: 0.9765, False Alarm Ratio: 0.1304
#
#
# epoch n° 436
# Training, Regression Loss: 0.0417, Regression Loss 1h: 1.8873, Segmentation Loss:0.1450
# Train Confusion Matrix:
# [[3122863   75978]
#  [ 135942  505217]]
# Accuracy: 0.9448, CSI: 0.7045, Sensitivity: 0.7880, Specificity: 0.9762, False Alarm Ratio: 0.1307
#
#
# epoch n° 437
# Training, Regression Loss: 0.0429, Regression Loss 1h: 2.1110, Segmentation Loss:0.1448
# Train Confusion Matrix:
# [[3122318   76826]
#  [ 134312  506544]]
# Accuracy: 0.9450, CSI: 0.7058, Sensitivity: 0.7904, Specificity: 0.9760, False Alarm Ratio: 0.1317
#
#
# epoch n° 438
# Training, Regression Loss: 0.0426, Regression Loss 1h: 1.9117, Segmentation Loss:0.1399
# Train Confusion Matrix:
# [[3123940   75047]
#  [ 130421  510592]]
# Accuracy: 0.9465, CSI: 0.7131, Sensitivity: 0.7965, Specificity: 0.9765, False Alarm Ratio: 0.1281
#
#
# epoch n° 439
# Training, Regression Loss: 0.0423, Regression Loss 1h: 2.1346, Segmentation Loss:0.1430
# Train Confusion Matrix:
# [[3119046   75278]
#  [ 133185  512491]]
# Accuracy: 0.9457, CSI: 0.7109, Sensitivity: 0.7937, Specificity: 0.9764, False Alarm Ratio: 0.1281
#
#
# epoch n° 440
# Training, Regression Loss: 0.0426, Regression Loss 1h: 2.0531, Segmentation Loss:0.1447
# Train Confusion Matrix:
# [[3124433   75924]
#  [ 135511  504132]]
# Accuracy: 0.9449, CSI: 0.7045, Sensitivity: 0.7881, Specificity: 0.9763, False Alarm Ratio: 0.1309
#
#
# saving step
# epoch n° 441
# Training, Regression Loss: 0.0411, Regression Loss 1h: 1.9627, Segmentation Loss:0.1464
# Train Confusion Matrix:
# [[3119065   76110]
#  [ 137723  507102]]
# Accuracy: 0.9443, CSI: 0.7034, Sensitivity: 0.7864, Specificity: 0.9762, False Alarm Ratio: 0.1305
#
#
# epoch n° 442
# Training, Regression Loss: 0.0421, Regression Loss 1h: 2.0110, Segmentation Loss:0.1453
# Train Confusion Matrix:
# [[3128412   76253]
#  [ 136157  499178]]
# Accuracy: 0.9447, CSI: 0.7015, Sensitivity: 0.7857, Specificity: 0.9762, False Alarm Ratio: 0.1325
#
#
# epoch n° 443
# Training, Regression Loss: 0.0418, Regression Loss 1h: 2.0816, Segmentation Loss:0.1453
# Train Confusion Matrix:
# [[3125726   75961]
#  [ 136177  502136]]
# Accuracy: 0.9448, CSI: 0.7030, Sensitivity: 0.7867, Specificity: 0.9763, False Alarm Ratio: 0.1314
#
#
# epoch n° 444
# Training, Regression Loss: 0.0414, Regression Loss 1h: 2.0003, Segmentation Loss:0.1430
# Train Confusion Matrix:
# [[3116035   76462]
#  [ 133734  513769]]
# Accuracy: 0.9453, CSI: 0.7097, Sensitivity: 0.7935, Specificity: 0.9760, False Alarm Ratio: 0.1295
#
#
# epoch n° 445
# Training, Regression Loss: 0.0416, Regression Loss 1h: 2.0029, Segmentation Loss:0.1439
# Train Confusion Matrix:
# [[3130755   74966]
#  [ 133414  500865]]
# Accuracy: 0.9457, CSI: 0.7062, Sensitivity: 0.7897, Specificity: 0.9766, False Alarm Ratio: 0.1302
#
#
# epoch n° 446
# Training, Regression Loss: 0.0419, Regression Loss 1h: 2.0614, Segmentation Loss:0.1458
# Train Confusion Matrix:
# [[3128651   75659]
#  [ 136637  499053]]
# Accuracy: 0.9447, CSI: 0.7016, Sensitivity: 0.7851, Specificity: 0.9764, False Alarm Ratio: 0.1316
#
#
# epoch n° 447
# Training, Regression Loss: 0.0417, Regression Loss 1h: 2.0322, Segmentation Loss:0.1492
# Train Confusion Matrix:
# [[3124201   75867]
#  [ 140605  499327]]
# Accuracy: 0.9436, CSI: 0.6976, Sensitivity: 0.7803, Specificity: 0.9763, False Alarm Ratio: 0.1319
#
#
# epoch n° 448
# Training, Regression Loss: 0.0419, Regression Loss 1h: 1.9741, Segmentation Loss:0.1426
# Train Confusion Matrix:
# [[3121204   75596]
#  [ 132324  510876]]
# Accuracy: 0.9459, CSI: 0.7107, Sensitivity: 0.7943, Specificity: 0.9764, False Alarm Ratio: 0.1289
#
#
# epoch n° 449
# Training, Regression Loss: 0.0424, Regression Loss 1h: 2.1485, Segmentation Loss:0.1455
# Train Confusion Matrix:
# [[3121973   75132]
#  [ 136581  506314]]
# Accuracy: 0.9449, CSI: 0.7051, Sensitivity: 0.7876, Specificity: 0.9765, False Alarm Ratio: 0.1292
#
#
# epoch n° 450
# Training, Regression Loss: 0.0419, Regression Loss 1h: 1.9628, Segmentation Loss:0.1463
# Train Confusion Matrix:
# [[3130776   75202]
#  [ 137407  496615]]
# Accuracy: 0.9446, CSI: 0.7002, Sensitivity: 0.7833, Specificity: 0.9765, False Alarm Ratio: 0.1315
#
#
# saving step
# epoch n° 451
# Training, Regression Loss: 0.0423, Regression Loss 1h: 1.9989, Segmentation Loss:0.1424
# Train Confusion Matrix:
# [[3120954   76102]
#  [ 132702  510242]]
# Accuracy: 0.9456, CSI: 0.7096, Sensitivity: 0.7936, Specificity: 0.9762, False Alarm Ratio: 0.1298
#
#
# epoch n° 452
# Training, Regression Loss: 0.0416, Regression Loss 1h: 1.9488, Segmentation Loss:0.1437
# Train Confusion Matrix:
# [[3130304   75251]
#  [ 134515  499930]]
# Accuracy: 0.9454, CSI: 0.7044, Sensitivity: 0.7880, Specificity: 0.9765, False Alarm Ratio: 0.1308
#
#
# epoch n° 453
# Training, Regression Loss: 0.0418, Regression Loss 1h: 2.0925, Segmentation Loss:0.1424
# Train Confusion Matrix:
# [[3138516   73624]
#  [ 134478  493382]]
# Accuracy: 0.9458, CSI: 0.7033, Sensitivity: 0.7858, Specificity: 0.9771, False Alarm Ratio: 0.1298
#
#
# epoch n° 454
# Training, Regression Loss: 0.0410, Regression Loss 1h: 2.0086, Segmentation Loss:0.1416
# Train Confusion Matrix:
# [[3131609   74156]
#  [ 131930  502305]]
# Accuracy: 0.9463, CSI: 0.7091, Sensitivity: 0.7920, Specificity: 0.9769, False Alarm Ratio: 0.1286
#
#
# epoch n° 455
# Training, Regression Loss: 0.0424, Regression Loss 1h: 2.1207, Segmentation Loss:0.1446
# Train Confusion Matrix:
# [[3125624   75818]
#  [ 136054  502504]]
# Accuracy: 0.9448, CSI: 0.7034, Sensitivity: 0.7869, Specificity: 0.9763, False Alarm Ratio: 0.1311
#
#
# epoch n° 456
# Training, Regression Loss: 0.0431, Regression Loss 1h: 2.2183, Segmentation Loss:0.1470
# Train Confusion Matrix:
# [[3115497   76533]
#  [ 137771  510199]]
# Accuracy: 0.9442, CSI: 0.7042, Sensitivity: 0.7874, Specificity: 0.9760, False Alarm Ratio: 0.1304
#
#
# epoch n° 457

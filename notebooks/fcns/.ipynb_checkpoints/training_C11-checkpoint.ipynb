# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## C1 radar + cmls -> radar + rain gauges 1 min  [xrl_yrg1]
# 12 out channels are added
# At each loop's step:
#     - substep 1: segmentation step with the radar mask as target
#     - substep 2: regression step with raing gauge data as target

# %%
# ! git clone https://github.com/nanopiero/fusion.git

# %%
import torch
import logging
logger = logging.getLogger("torch")
logger.setLevel(logging.ERROR)  # Show only errors, ignore warnings

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_C1_xrl_yrg1.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
ch_in = 72
ch_out = nsteps * 3 + 2*12
size = nsteps * 3 

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
criterion = QPELoss_fcn()
criterion_segmentation = nn.CrossEntropyLoss()

# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")
model.train()
for epoch in range(last_epoch, num_epochs + 1):
  print('epoch n°', epoch)
  t = time.time()
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    optimizer.zero_grad()  # Zero the gradients
    # substep 1 : segmentation on radar targets
    inputs = torch.cat([0 * noisy_images, segment_measurements_fcn], dim=1)
    targets = noisy_images
      
    outputs = model(inputs)  # Forward pass
    loss = criterion_segmentation(outputs[:, -2*12:, ...].view(:,2,-1), targets.view(:,-1))
    loss.backward()  # Backward pass
      
    loss_segmentation_radar = loss.item()

      
    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn

    outputs = model(inputs)  # Forward pass
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass

    # substep 2
    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn

    outputs = model(inputs)  # Forward pass
    
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

      
    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()
    
    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix, loss_segmentation_radar))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 1000
# Training, Regression Loss: 0.0210, Regression Loss 1h: 292.8167, Segmentation Loss:0.0776
# Train Confusion Matrix:
# [[3154150   49100]
#  [  69372  567378]]
# Accuracy: 0.9691, CSI: 0.8273, Sensitivity: 0.8911, Specificity: 0.9847, False Alarm Ratio: 0.0796
#
#
# epoch duration : 62.25963640213013
# saving step
# epoch n° 1001
# Training, Regression Loss: 0.0216, Regression Loss 1h: 286.0824, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[3154099   47920]
#  [  67573  570408]]
# Accuracy: 0.9699, CSI: 0.8316, Sensitivity: 0.8941, Specificity: 0.9850, False Alarm Ratio: 0.0775
#
#
# epoch duration : 69.31887674331665
# epoch n° 1002
# Training, Regression Loss: 0.0217, Regression Loss 1h: 279.2225, Segmentation Loss:0.0742
# Train Confusion Matrix:
# [[3150675   47079]
#  [  65935  576311]]
# Accuracy: 0.9706, CSI: 0.8361, Sensitivity: 0.8973, Specificity: 0.9853, False Alarm Ratio: 0.0755
#
#
# epoch duration : 68.65868163108826
# epoch n° 1003
# Training, Regression Loss: 0.0216, Regression Loss 1h: 278.9398, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3142029   47675]
#  [  67727  582569]]
# Accuracy: 0.9699, CSI: 0.8347, Sensitivity: 0.8959, Specificity: 0.9851, False Alarm Ratio: 0.0756
#
#
# epoch duration : 69.94355463981628
# epoch n° 1004
# Training, Regression Loss: 0.0215, Regression Loss 1h: 281.1034, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3151983   48039]
#  [  68050  571928]]
# Accuracy: 0.9698, CSI: 0.8313, Sensitivity: 0.8937, Specificity: 0.9850, False Alarm Ratio: 0.0775
#
#
# epoch duration : 70.71085834503174
# epoch n° 1005
# Training, Regression Loss: 0.0214, Regression Loss 1h: 289.3144, Segmentation Loss:0.0737
# Train Confusion Matrix:
# [[3154386   47494]
#  [  65460  572660]]
# Accuracy: 0.9706, CSI: 0.8353, Sensitivity: 0.8974, Specificity: 0.9852, False Alarm Ratio: 0.0766
#
#
# epoch duration : 69.31421279907227
# epoch n° 1006
# Training, Regression Loss: 0.0215, Regression Loss 1h: 280.9219, Segmentation Loss:0.0751
# Train Confusion Matrix:
# [[3152894   47301]
#  [  67023  572782]]
# Accuracy: 0.9702, CSI: 0.8336, Sensitivity: 0.8952, Specificity: 0.9852, False Alarm Ratio: 0.0763
#
#
# epoch duration : 70.71963810920715
# epoch n° 1007
# Training, Regression Loss: 0.0216, Regression Loss 1h: 282.8729, Segmentation Loss:0.0744
# Train Confusion Matrix:
# [[3151091   47958]
#  [  66236  574715]]
# Accuracy: 0.9703, CSI: 0.8342, Sensitivity: 0.8967, Specificity: 0.9850, False Alarm Ratio: 0.0770
#
#
# epoch duration : 71.05729842185974
# epoch n° 1008
# Training, Regression Loss: 0.0216, Regression Loss 1h: 295.0239, Segmentation Loss:0.0769
# Train Confusion Matrix:
# [[3153605   48228]
#  [  68798  569369]]
# Accuracy: 0.9695, CSI: 0.8295, Sensitivity: 0.8922, Specificity: 0.9849, False Alarm Ratio: 0.0781
#
#
# epoch duration : 70.62591528892517
# epoch n° 1009
# Training, Regression Loss: 0.0212, Regression Loss 1h: 309.0711, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3155642   47962]
#  [  67740  568656]]
# Accuracy: 0.9699, CSI: 0.8309, Sensitivity: 0.8936, Specificity: 0.9850, False Alarm Ratio: 0.0778
#
#
# epoch duration : 70.90421557426453
# epoch n° 1010
# Training, Regression Loss: 0.0219, Regression Loss 1h: 291.4448, Segmentation Loss:0.0782
# Train Confusion Matrix:
# [[3146040   48958]
#  [  70306  574696]]
# Accuracy: 0.9689, CSI: 0.8281, Sensitivity: 0.8910, Specificity: 0.9847, False Alarm Ratio: 0.0785
#
#
# epoch duration : 70.99994850158691
# saving step
# epoch n° 1011
# Training, Regression Loss: 0.0221, Regression Loss 1h: 285.5254, Segmentation Loss:0.0760
# Train Confusion Matrix:
# [[3142679   48247]
#  [  67980  581094]]
# Accuracy: 0.9697, CSI: 0.8333, Sensitivity: 0.8953, Specificity: 0.9849, False Alarm Ratio: 0.0767
#
#
# epoch duration : 69.20251846313477
# epoch n° 1012
# Training, Regression Loss: 0.0221, Regression Loss 1h: 284.5200, Segmentation Loss:0.0739
# Train Confusion Matrix:
# [[3149391   46967]
#  [  65959  577683]]
# Accuracy: 0.9706, CSI: 0.8365, Sensitivity: 0.8975, Specificity: 0.9853, False Alarm Ratio: 0.0752
#
#
# epoch duration : 70.21396899223328
# epoch n° 1013
# Training, Regression Loss: 0.0217, Regression Loss 1h: 386.9719, Segmentation Loss:0.0752
# Train Confusion Matrix:
# [[3151801   47829]
#  [  66764  573606]]
# Accuracy: 0.9702, CSI: 0.8335, Sensitivity: 0.8957, Specificity: 0.9851, False Alarm Ratio: 0.0770
#
#
# epoch duration : 68.91747832298279
# epoch n° 1014
# Training, Regression Loss: 0.0217, Regression Loss 1h: 359.4595, Segmentation Loss:0.0767
# Train Confusion Matrix:
# [[3149109   48703]
#  [  68501  573687]]
# Accuracy: 0.9695, CSI: 0.8304, Sensitivity: 0.8933, Specificity: 0.9848, False Alarm Ratio: 0.0783
#
#
# epoch duration : 70.28284192085266
# epoch n° 1016
# Training, Regression Loss: 0.0221, Regression Loss 1h: 339.9452, Segmentation Loss:0.0743
# Train Confusion Matrix:
# [[3150010   47782]
#  [  65822  576386]]
# Accuracy: 0.9704, CSI: 0.8354, Sensitivity: 0.8975, Specificity: 0.9851, False Alarm Ratio: 0.0766
#
#
# epoch duration : 70.16349601745605
# epoch n° 1017
# Training, Regression Loss: 0.0214, Regression Loss 1h: 357.2482, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3156554   47494]
#  [  68538  567414]]
# Accuracy: 0.9698, CSI: 0.8302, Sensitivity: 0.8922, Specificity: 0.9852, False Alarm Ratio: 0.0772
#
#
# epoch duration : 70.72914361953735
# epoch n° 1018
# Training, Regression Loss: 0.0219, Regression Loss 1h: 324.0047, Segmentation Loss:0.0752
# Train Confusion Matrix:
# [[3137694   48026]
#  [  66733  587547]]
# Accuracy: 0.9701, CSI: 0.8366, Sensitivity: 0.8980, Specificity: 0.9849, False Alarm Ratio: 0.0756
#
#
# epoch duration : 70.82854914665222
# epoch n° 1019
# Training, Regression Loss: 0.0213, Regression Loss 1h: 355.5786, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3152907   47835]
#  [  67612  571646]]
# Accuracy: 0.9699, CSI: 0.8320, Sensitivity: 0.8942, Specificity: 0.9851, False Alarm Ratio: 0.0772
#
#
# epoch duration : 68.8444664478302
# epoch n° 1020
# Training, Regression Loss: 0.0211, Regression Loss 1h: 322.1042, Segmentation Loss:0.0763
# Train Confusion Matrix:
# [[3154542   48266]
#  [  67676  569516]]
# Accuracy: 0.9698, CSI: 0.8309, Sensitivity: 0.8938, Specificity: 0.9849, False Alarm Ratio: 0.0781
#
#
# epoch duration : 70.1218991279602
# saving step
# epoch n° 1021
# Training, Regression Loss: 0.0223, Regression Loss 1h: 326.6456, Segmentation Loss:0.0742
# Train Confusion Matrix:
# [[3149590   47344]
#  [  66211  576855]]
# Accuracy: 0.9704, CSI: 0.8355, Sensitivity: 0.8970, Specificity: 0.9852, False Alarm Ratio: 0.0758
#
#
# epoch duration : 70.00296235084534
# epoch n° 1022
# Training, Regression Loss: 0.0217, Regression Loss 1h: 312.0989, Segmentation Loss:0.0741
# Train Confusion Matrix:
# [[3155292   47430]
#  [  66159  571119]]
# Accuracy: 0.9704, CSI: 0.8341, Sensitivity: 0.8962, Specificity: 0.9852, False Alarm Ratio: 0.0767
#
#
# epoch duration : 69.70268607139587
# epoch n° 1023
# Training, Regression Loss: 0.0220, Regression Loss 1h: 300.3717, Segmentation Loss:0.0765
# Train Confusion Matrix:
# [[3142066   48393]
#  [  68652  580889]]
# Accuracy: 0.9695, CSI: 0.8323, Sensitivity: 0.8943, Specificity: 0.9848, False Alarm Ratio: 0.0769
#
#
# epoch duration : 70.19266510009766
# epoch n° 1024
# Training, Regression Loss: 0.0213, Regression Loss 1h: 293.8319, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3149903   47959]
#  [  66539  575599]]
# Accuracy: 0.9702, CSI: 0.8341, Sensitivity: 0.8964, Specificity: 0.9850, False Alarm Ratio: 0.0769
#
#
# epoch duration : 71.2941792011261
# epoch n° 1025
# Training, Regression Loss: 0.0219, Regression Loss 1h: 306.4123, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3142822   47678]
#  [  66875  582625]]
# Accuracy: 0.9702, CSI: 0.8357, Sensitivity: 0.8970, Specificity: 0.9851, False Alarm Ratio: 0.0756
#
#
# epoch duration : 71.12229108810425
# epoch n° 1026
# Training, Regression Loss: 0.0214, Regression Loss 1h: 286.5338, Segmentation Loss:0.0749
# Train Confusion Matrix:
# [[3152768   47068]
#  [  66892  573272]]
# Accuracy: 0.9703, CSI: 0.8342, Sensitivity: 0.8955, Specificity: 0.9853, False Alarm Ratio: 0.0759
#
#
# epoch duration : 71.01344180107117
# epoch n° 1027
# Training, Regression Loss: 0.0214, Regression Loss 1h: 291.8567, Segmentation Loss:0.0741
# Train Confusion Matrix:
# [[3151329   47512]
#  [  66043  575116]]
# Accuracy: 0.9704, CSI: 0.8351, Sensitivity: 0.8970, Specificity: 0.9851, False Alarm Ratio: 0.0763
#
#
# epoch duration : 70.92024350166321
# epoch n° 1028
# Training, Regression Loss: 0.0217, Regression Loss 1h: 280.9340, Segmentation Loss:0.0742
# Train Confusion Matrix:
# [[3153743   47356]
#  [  65741  573160]]
# Accuracy: 0.9705, CSI: 0.8352, Sensitivity: 0.8971, Specificity: 0.9852, False Alarm Ratio: 0.0763
#
#
# epoch duration : 70.02850914001465
# epoch n° 1029
# Training, Regression Loss: 0.0214, Regression Loss 1h: 296.0077, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3155993   48163]
#  [  67775  568069]]
# Accuracy: 0.9698, CSI: 0.8305, Sensitivity: 0.8934, Specificity: 0.9850, False Alarm Ratio: 0.0782
#
#
# epoch duration : 70.7408242225647
# epoch n° 1030
# Training, Regression Loss: 0.0222, Regression Loss 1h: 287.9525, Segmentation Loss:0.0728
# Train Confusion Matrix:
# [[3157776   46573]
#  [  64410  571241]]
# Accuracy: 0.9711, CSI: 0.8373, Sensitivity: 0.8987, Specificity: 0.9855, False Alarm Ratio: 0.0754
#
#
# epoch duration : 69.05594229698181
# saving step
# epoch n° 1031
# Training, Regression Loss: 0.0217, Regression Loss 1h: 295.0814, Segmentation Loss:0.0746
# Train Confusion Matrix:
# [[3153213   47521]
#  [  65953  573313]]
# Accuracy: 0.9704, CSI: 0.8348, Sensitivity: 0.8968, Specificity: 0.9852, False Alarm Ratio: 0.0765
#
#
# epoch duration : 69.76077485084534
# epoch n° 1032
# Training, Regression Loss: 0.0215, Regression Loss 1h: 294.8440, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3152478   47551]
#  [  67151  572820]]
# Accuracy: 0.9701, CSI: 0.8332, Sensitivity: 0.8951, Specificity: 0.9851, False Alarm Ratio: 0.0766
#
#
# epoch duration : 69.06012868881226
# epoch n° 1033
# Training, Regression Loss: 0.0220, Regression Loss 1h: 286.0131, Segmentation Loss:0.0744
# Train Confusion Matrix:
# [[3148178   47661]
#  [  66261  577900]]
# Accuracy: 0.9703, CSI: 0.8353, Sensitivity: 0.8971, Specificity: 0.9851, False Alarm Ratio: 0.0762
#
#
# epoch duration : 70.1445062160492
# epoch n° 1034
# Training, Regression Loss: 0.0224, Regression Loss 1h: 326.0109, Segmentation Loss:0.0763
# Train Confusion Matrix:
# [[3146013   47891]
#  [  67786  578310]]
# Accuracy: 0.9699, CSI: 0.8333, Sensitivity: 0.8951, Specificity: 0.9850, False Alarm Ratio: 0.0765
#
#
# epoch duration : 69.81431436538696
# epoch n° 1035
# Training, Regression Loss: 0.0217, Regression Loss 1h: 309.6978, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3147719   47833]
#  [  67887  576561]]
# Accuracy: 0.9699, CSI: 0.8328, Sensitivity: 0.8947, Specificity: 0.9850, False Alarm Ratio: 0.0766
#
#
# epoch duration : 70.11236429214478
# epoch n° 1036
# Training, Regression Loss: 0.0216, Regression Loss 1h: 322.3366, Segmentation Loss:0.0749
# Train Confusion Matrix:
# [[3147904   47628]
#  [  66561  577907]]
# Accuracy: 0.9703, CSI: 0.8350, Sensitivity: 0.8967, Specificity: 0.9851, False Alarm Ratio: 0.0761
#
#
# epoch duration : 70.70592594146729
# epoch n° 1037
# Training, Regression Loss: 0.0213, Regression Loss 1h: 302.2385, Segmentation Loss:0.0754
# Train Confusion Matrix:
# [[3148906   47756]
#  [  67300  576038]]
# Accuracy: 0.9700, CSI: 0.8335, Sensitivity: 0.8954, Specificity: 0.9851, False Alarm Ratio: 0.0766
#
#
# epoch duration : 69.84774732589722
# epoch n° 1038
# Training, Regression Loss: 0.0217, Regression Loss 1h: 315.5558, Segmentation Loss:0.0747
# Train Confusion Matrix:
# [[3148641   47441]
#  [  66402  577516]]
# Accuracy: 0.9704, CSI: 0.8353, Sensitivity: 0.8969, Specificity: 0.9852, False Alarm Ratio: 0.0759
#
#
# epoch duration : 67.8127748966217
# epoch n° 1039
# Training, Regression Loss: 0.0220, Regression Loss 1h: 332.7029, Segmentation Loss:0.0750
# Train Confusion Matrix:
# [[3143472   47796]
#  [  66413  582319]]
# Accuracy: 0.9703, CSI: 0.8360, Sensitivity: 0.8976, Specificity: 0.9850, False Alarm Ratio: 0.0759
#
#
# epoch duration : 70.00414609909058
# epoch n° 1040
# Training, Regression Loss: 0.0220, Regression Loss 1h: 337.1330, Segmentation Loss:0.0743
# Train Confusion Matrix:
# [[3153456   47000]
#  [  66340  573204]]
# Accuracy: 0.9705, CSI: 0.8349, Sensitivity: 0.8963, Specificity: 0.9853, False Alarm Ratio: 0.0758
#
#
# epoch duration : 68.96311688423157
# saving step
# epoch n° 1041
# Training, Regression Loss: 0.0220, Regression Loss 1h: 296.4623, Segmentation Loss:0.0756
# Train Confusion Matrix:
# [[3153430   47767]
#  [  67573  571230]]
# Accuracy: 0.9700, CSI: 0.8320, Sensitivity: 0.8942, Specificity: 0.9851, False Alarm Ratio: 0.0772
#
#
# epoch duration : 69.71838450431824
# epoch n° 1042
# Training, Regression Loss: 0.0219, Regression Loss 1h: 321.9025, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3147429   47719]
#  [  66375  578477]]
# Accuracy: 0.9703, CSI: 0.8353, Sensitivity: 0.8971, Specificity: 0.9851, False Alarm Ratio: 0.0762
#
#
# epoch duration : 70.15265846252441
# epoch n° 1043
# Training, Regression Loss: 0.0214, Regression Loss 1h: 315.0079, Segmentation Loss:0.0749
# Train Confusion Matrix:
# [[3149738   47602]
#  [  66875  575785]]
# Accuracy: 0.9702, CSI: 0.8342, Sensitivity: 0.8959, Specificity: 0.9851, False Alarm Ratio: 0.0764
#
#
# epoch duration : 69.9474549293518
# epoch n° 1044
# Training, Regression Loss: 0.0208, Regression Loss 1h: 307.7882, Segmentation Loss:0.0752
# Train Confusion Matrix:
# [[3148756   47375]
#  [  66782  577087]]
# Accuracy: 0.9703, CSI: 0.8349, Sensitivity: 0.8963, Specificity: 0.9852, False Alarm Ratio: 0.0759
#
#
# epoch duration : 69.59568977355957
# epoch n° 1045
# Training, Regression Loss: 0.0215, Regression Loss 1h: 303.6794, Segmentation Loss:0.0772
# Train Confusion Matrix:
# [[3150421   48215]
#  [  68665  572699]]
# Accuracy: 0.9696, CSI: 0.8305, Sensitivity: 0.8929, Specificity: 0.9849, False Alarm Ratio: 0.0777
#
#
# epoch duration : 70.48822331428528
# epoch n° 1046
# Training, Regression Loss: 0.0217, Regression Loss 1h: 294.2859, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3149695   47279]
#  [  68203  574823]]
# Accuracy: 0.9699, CSI: 0.8327, Sensitivity: 0.8939, Specificity: 0.9852, False Alarm Ratio: 0.0760
#
#
# epoch duration : 69.49708580970764
# epoch n° 1047
# Training, Regression Loss: 0.0214, Regression Loss 1h: 279.9538, Segmentation Loss:0.0760
# Train Confusion Matrix:
# [[3158325   48072]
#  [  67678  565925]]
# Accuracy: 0.9699, CSI: 0.8302, Sensitivity: 0.8932, Specificity: 0.9850, False Alarm Ratio: 0.0783
#
#
# epoch duration : 69.93217635154724
# epoch n° 1048
# Training, Regression Loss: 0.0218, Regression Loss 1h: 298.3665, Segmentation Loss:0.0741
# Train Confusion Matrix:
# [[3143151   47038]
#  [  65838  583973]]
# Accuracy: 0.9706, CSI: 0.8380, Sensitivity: 0.8987, Specificity: 0.9853, False Alarm Ratio: 0.0745
#
#
# epoch duration : 68.4281415939331
# epoch n° 1049
# Training, Regression Loss: 0.0216, Regression Loss 1h: 287.5482, Segmentation Loss:0.0764
# Train Confusion Matrix:
# [[3146611   48502]
#  [  68065  576822]]
# Accuracy: 0.9696, CSI: 0.8319, Sensitivity: 0.8945, Specificity: 0.9848, False Alarm Ratio: 0.0776
#
#
# epoch duration : 70.06624221801758
# epoch n° 1050
# Training, Regression Loss: 0.0215, Regression Loss 1h: 275.8286, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3143243   48082]
#  [  67792  580883]]
# Accuracy: 0.9698, CSI: 0.8337, Sensitivity: 0.8955, Specificity: 0.9849, False Alarm Ratio: 0.0764
#
#
# epoch duration : 67.73943138122559
# saving step
# epoch n° 1051
# Training, Regression Loss: 0.0214, Regression Loss 1h: 285.0594, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3153845   47174]
#  [  67073  571908]]
# Accuracy: 0.9702, CSI: 0.8335, Sensitivity: 0.8950, Specificity: 0.9853, False Alarm Ratio: 0.0762
#
#
# epoch duration : 70.13367533683777
# epoch n° 1052
# Training, Regression Loss: 0.0222, Regression Loss 1h: 289.9326, Segmentation Loss:0.0732
# Train Confusion Matrix:
# [[3153297   47089]
#  [  64593  575021]]
# Accuracy: 0.9709, CSI: 0.8374, Sensitivity: 0.8990, Specificity: 0.9853, False Alarm Ratio: 0.0757
#
#
# epoch duration : 67.65948557853699
# epoch n° 1053
# Training, Regression Loss: 0.0212, Regression Loss 1h: 288.3660, Segmentation Loss:0.0781
# Train Confusion Matrix:
# [[3155353   48383]
#  [  70003  566261]]
# Accuracy: 0.9692, CSI: 0.8271, Sensitivity: 0.8900, Specificity: 0.9849, False Alarm Ratio: 0.0787
#
#
# epoch duration : 69.19338130950928
# epoch n° 1054
# Training, Regression Loss: 0.0213, Regression Loss 1h: 294.8781, Segmentation Loss:0.0730
# Train Confusion Matrix:
# [[3149098   46976]
#  [  64731  579195]]
# Accuracy: 0.9709, CSI: 0.8383, Sensitivity: 0.8995, Specificity: 0.9853, False Alarm Ratio: 0.0750
#
#
# epoch duration : 69.19597101211548
# epoch n° 1055
# Training, Regression Loss: 0.0217, Regression Loss 1h: 304.1097, Segmentation Loss:0.0747
# Train Confusion Matrix:
# [[3150175   47285]
#  [  66565  575975]]
# Accuracy: 0.9704, CSI: 0.8350, Sensitivity: 0.8964, Specificity: 0.9852, False Alarm Ratio: 0.0759
#
#
# epoch duration : 69.45352578163147
# epoch n° 1056
# Training, Regression Loss: 0.0225, Regression Loss 1h: 332.6744, Segmentation Loss:0.0740
# Train Confusion Matrix:
# [[3144989   46445]
#  [  66091  582475]]
# Accuracy: 0.9707, CSI: 0.8381, Sensitivity: 0.8981, Specificity: 0.9854, False Alarm Ratio: 0.0738
#
#
# epoch duration : 67.09431433677673
# epoch n° 1057
# Training, Regression Loss: 0.0250, Regression Loss 1h: 416.1155, Segmentation Loss:0.0877
# Train Confusion Matrix:
# [[3152298   51648]
#  [  78452  557602]]
# Accuracy: 0.9661, CSI: 0.8108, Sensitivity: 0.8767, Specificity: 0.9839, False Alarm Ratio: 0.0848
#
#
# epoch duration : 67.65082788467407
# epoch n° 1058
# Training, Regression Loss: 0.0226, Regression Loss 1h: 344.9028, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3156694   49667]
#  [  73459  560180]]
# Accuracy: 0.9679, CSI: 0.8198, Sensitivity: 0.8841, Specificity: 0.9845, False Alarm Ratio: 0.0814
#
#
# epoch duration : 69.97017168998718
# epoch n° 1059
# Training, Regression Loss: 0.0225, Regression Loss 1h: 277.6124, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3147907   48629]
#  [  66931  576533]]
# Accuracy: 0.9699, CSI: 0.8330, Sensitivity: 0.8960, Specificity: 0.9848, False Alarm Ratio: 0.0778
#
#
# epoch duration : 70.35971713066101
# epoch n° 1060
# Training, Regression Loss: 0.0220, Regression Loss 1h: 287.6230, Segmentation Loss:0.0756
# Train Confusion Matrix:
# [[3147571   48532]
#  [  66990  576907]]
# Accuracy: 0.9699, CSI: 0.8332, Sensitivity: 0.8960, Specificity: 0.9848, False Alarm Ratio: 0.0776
#
#
# epoch duration : 69.1745216846466
# saving step
# epoch n° 1061
# Training, Regression Loss: 0.0229, Regression Loss 1h: 304.2468, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[3147389   49662]
#  [  72417  570532]]
# Accuracy: 0.9682, CSI: 0.8237, Sensitivity: 0.8874, Specificity: 0.9845, False Alarm Ratio: 0.0801
#
#
# epoch duration : 69.34050273895264
# epoch n° 1062
# Training, Regression Loss: 0.0233, Regression Loss 1h: 300.4302, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3156454   49292]
#  [  72740  561514]]
# Accuracy: 0.9682, CSI: 0.8215, Sensitivity: 0.8853, Specificity: 0.9846, False Alarm Ratio: 0.0807
#
#
# epoch duration : 68.64495396614075
# epoch n° 1063
# Training, Regression Loss: 0.0229, Regression Loss 1h: 309.7354, Segmentation Loss:0.0780
# Train Confusion Matrix:
# [[3145464   48532]
#  [  69698  576306]]
# Accuracy: 0.9692, CSI: 0.8298, Sensitivity: 0.8921, Specificity: 0.9848, False Alarm Ratio: 0.0777
#
#
# epoch duration : 69.17168259620667
# epoch n° 1064
# Training, Regression Loss: 0.0220, Regression Loss 1h: 320.2832, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3154285   47475]
#  [  66269  571971]]
# Accuracy: 0.9704, CSI: 0.8341, Sensitivity: 0.8962, Specificity: 0.9852, False Alarm Ratio: 0.0766
#
#
# epoch duration : 70.66432785987854
# epoch n° 1065
# Training, Regression Loss: 0.0223, Regression Loss 1h: 317.5809, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3144982   48247]
#  [  67250  579521]]
# Accuracy: 0.9699, CSI: 0.8338, Sensitivity: 0.8960, Specificity: 0.9849, False Alarm Ratio: 0.0769
#
#
# epoch duration : 69.89223122596741
# epoch n° 1066
# Training, Regression Loss: 0.0225, Regression Loss 1h: 303.3544, Segmentation Loss:0.0776
# Train Confusion Matrix:
# [[3151185   47777]
#  [  69120  571918]]
# Accuracy: 0.9696, CSI: 0.8303, Sensitivity: 0.8922, Specificity: 0.9851, False Alarm Ratio: 0.0771
#
#
# epoch duration : 69.79900002479553
# epoch n° 1067
# Training, Regression Loss: 0.0218, Regression Loss 1h: 295.5593, Segmentation Loss:0.0783
# Train Confusion Matrix:
# [[3149322   49067]
#  [  69586  572025]]
# Accuracy: 0.9691, CSI: 0.8282, Sensitivity: 0.8915, Specificity: 0.9847, False Alarm Ratio: 0.0790
#
#
# epoch duration : 70.15580582618713
# epoch n° 1068
# Training, Regression Loss: 0.0225, Regression Loss 1h: 343.2490, Segmentation Loss:0.0742
# Train Confusion Matrix:
# [[3152727   46894]
#  [  66168  574211]]
# Accuracy: 0.9706, CSI: 0.8355, Sensitivity: 0.8967, Specificity: 0.9853, False Alarm Ratio: 0.0755
#
#
# epoch duration : 69.42721462249756
# epoch n° 1069
# Training, Regression Loss: 0.0216, Regression Loss 1h: 315.1328, Segmentation Loss:0.0770
# Train Confusion Matrix:
# [[3148179   47933]
#  [  68894  574994]]
# Accuracy: 0.9696, CSI: 0.8311, Sensitivity: 0.8930, Specificity: 0.9850, False Alarm Ratio: 0.0769
#
#
# epoch duration : 70.19074869155884
# epoch n° 1070
# Training, Regression Loss: 0.0212, Regression Loss 1h: 311.4299, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3154576   47205]
#  [  67645  570574]]
# Accuracy: 0.9701, CSI: 0.8324, Sensitivity: 0.8940, Specificity: 0.9853, False Alarm Ratio: 0.0764
#
#
# epoch duration : 69.36660480499268
# saving step
# epoch n° 1071
# Training, Regression Loss: 0.0213, Regression Loss 1h: 314.2341, Segmentation Loss:0.0741
# Train Confusion Matrix:
# [[3149639   47318]
#  [  65704  577339]]
# Accuracy: 0.9706, CSI: 0.8363, Sensitivity: 0.8978, Specificity: 0.9852, False Alarm Ratio: 0.0758
#
#
# epoch duration : 68.91679239273071
# epoch n° 1072
# Training, Regression Loss: 0.0217, Regression Loss 1h: 303.0377, Segmentation Loss:0.0745
# Train Confusion Matrix:
# [[3159046   47400]
#  [  65810  567744]]
# Accuracy: 0.9705, CSI: 0.8337, Sensitivity: 0.8961, Specificity: 0.9852, False Alarm Ratio: 0.0771
#
#
# epoch duration : 69.63847494125366
# epoch n° 1073
# Training, Regression Loss: 0.0213, Regression Loss 1h: 314.2492, Segmentation Loss:0.0726
# Train Confusion Matrix:
# [[3151798   46455]
#  [  64184  577563]]
# Accuracy: 0.9712, CSI: 0.8392, Sensitivity: 0.9000, Specificity: 0.9855, False Alarm Ratio: 0.0744
#
#
# epoch duration : 70.15467667579651
# epoch n° 1074
# Training, Regression Loss: 0.0238, Regression Loss 1h: 356.5086, Segmentation Loss:0.0784
# Train Confusion Matrix:
# [[3148652   48632]
#  [  69545  573171]]
# Accuracy: 0.9692, CSI: 0.8291, Sensitivity: 0.8918, Specificity: 0.9848, False Alarm Ratio: 0.0782
#
#
# epoch duration : 68.90599012374878
# epoch n° 1075
# Training, Regression Loss: 0.0216, Regression Loss 1h: 321.9407, Segmentation Loss:0.0762
# Train Confusion Matrix:
# [[3151284   47479]
#  [  67479  573758]]
# Accuracy: 0.9701, CSI: 0.8331, Sensitivity: 0.8948, Specificity: 0.9852, False Alarm Ratio: 0.0764
#
#
# epoch duration : 70.1102979183197
# epoch n° 1076
# Training, Regression Loss: 0.0229, Regression Loss 1h: 328.6620, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3145127   48075]
#  [  66771  580027]]
# Accuracy: 0.9701, CSI: 0.8347, Sensitivity: 0.8968, Specificity: 0.9849, False Alarm Ratio: 0.0765
#
#
# epoch duration : 69.76818418502808
# epoch n° 1077
# Training, Regression Loss: 0.0218, Regression Loss 1h: 289.9910, Segmentation Loss:0.0721
# Train Confusion Matrix:
# [[3161299   46400]
#  [  63665  568636]]
# Accuracy: 0.9713, CSI: 0.8378, Sensitivity: 0.8993, Specificity: 0.9855, False Alarm Ratio: 0.0754
#
#
# epoch duration : 69.85304474830627
# epoch n° 1078
# Training, Regression Loss: 0.0209, Regression Loss 1h: 288.1866, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[3154666   47727]
#  [  67835  569772]]
# Accuracy: 0.9699, CSI: 0.8314, Sensitivity: 0.8936, Specificity: 0.9851, False Alarm Ratio: 0.0773
#
#
# epoch duration : 70.62518429756165
# epoch n° 1079
# Training, Regression Loss: 0.0218, Regression Loss 1h: 304.8750, Segmentation Loss:0.0728
# Train Confusion Matrix:
# [[3149676   46746]
#  [  64467  579111]]
# Accuracy: 0.9710, CSI: 0.8389, Sensitivity: 0.8998, Specificity: 0.9854, False Alarm Ratio: 0.0747
#
#
# epoch duration : 69.47649097442627
# epoch n° 1080
# Training, Regression Loss: 0.0213, Regression Loss 1h: 313.3126, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3160709   47198]
#  [  66916  565177]]
# Accuracy: 0.9703, CSI: 0.8320, Sensitivity: 0.8941, Specificity: 0.9853, False Alarm Ratio: 0.0771
#
#
# epoch duration : 70.62248301506042
# saving step
# epoch n° 1081
# Training, Regression Loss: 0.0212, Regression Loss 1h: 312.3620, Segmentation Loss:0.0763
# Train Confusion Matrix:
# [[3152100   47988]
#  [  68046  571866]]
# Accuracy: 0.9698, CSI: 0.8313, Sensitivity: 0.8937, Specificity: 0.9850, False Alarm Ratio: 0.0774
#
#
# epoch duration : 70.64413738250732
# epoch n° 1082
# Training, Regression Loss: 0.0213, Regression Loss 1h: 312.2278, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3151486   47266]
#  [  66620  574628]]
# Accuracy: 0.9703, CSI: 0.8346, Sensitivity: 0.8961, Specificity: 0.9852, False Alarm Ratio: 0.0760
#
#
# epoch duration : 70.35740661621094
# epoch n° 1083
# Training, Regression Loss: 0.0220, Regression Loss 1h: 312.8387, Segmentation Loss:0.0754
# Train Confusion Matrix:
# [[3146584   47598]
#  [  67158  578660]]
# Accuracy: 0.9701, CSI: 0.8345, Sensitivity: 0.8960, Specificity: 0.9851, False Alarm Ratio: 0.0760
#
#
# epoch duration : 70.26028180122375
# epoch n° 1084
# Training, Regression Loss: 0.0217, Regression Loss 1h: 353.9396, Segmentation Loss:0.0725
# Train Confusion Matrix:
# [[3150573   46900]
#  [  64051  578476]]
# Accuracy: 0.9711, CSI: 0.8391, Sensitivity: 0.9003, Specificity: 0.9853, False Alarm Ratio: 0.0750
#
#
# epoch duration : 70.22412276268005
# epoch n° 1085
# Training, Regression Loss: 0.0216, Regression Loss 1h: 324.6183, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3152673   47826]
#  [  67412  572089]]
# Accuracy: 0.9700, CSI: 0.8323, Sensitivity: 0.8946, Specificity: 0.9851, False Alarm Ratio: 0.0771
#
#
# epoch duration : 69.8922426700592
# epoch n° 1086
# Training, Regression Loss: 0.0216, Regression Loss 1h: 299.1969, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3151998   46562]
#  [  67219  574221]]
# Accuracy: 0.9704, CSI: 0.8346, Sensitivity: 0.8952, Specificity: 0.9854, False Alarm Ratio: 0.0750
#
#
# epoch duration : 69.21080088615417
# epoch n° 1087
# Training, Regression Loss: 0.0215, Regression Loss 1h: 313.0066, Segmentation Loss:0.0769
# Train Confusion Matrix:
# [[3153150   47292]
#  [  68607  570951]]
# Accuracy: 0.9698, CSI: 0.8313, Sensitivity: 0.8927, Specificity: 0.9852, False Alarm Ratio: 0.0765
#
#
# epoch duration : 70.28301739692688
# epoch n° 1088
# Training, Regression Loss: 0.0283, Regression Loss 1h: 314.3506, Segmentation Loss:0.0821
# Train Confusion Matrix:
# [[3150023   49016]
#  [  73481  567480]]
# Accuracy: 0.9681, CSI: 0.8225, Sensitivity: 0.8854, Specificity: 0.9847, False Alarm Ratio: 0.0795
#
#
# epoch duration : 71.17063355445862
# epoch n° 1089
# Training, Regression Loss: 0.0273, Regression Loss 1h: 259.4279, Segmentation Loss:0.0926
# Train Confusion Matrix:
# [[3136864   54623]
#  [  82932  565581]]
# Accuracy: 0.9642, CSI: 0.8044, Sensitivity: 0.8721, Specificity: 0.9829, False Alarm Ratio: 0.0881
#
#
# epoch duration : 70.46002078056335
# epoch n° 1090
# Training, Regression Loss: 0.0247, Regression Loss 1h: 265.0401, Segmentation Loss:0.0905
# Train Confusion Matrix:
# [[3144886   53503]
#  [  80893  560718]]
# Accuracy: 0.9650, CSI: 0.8067, Sensitivity: 0.8739, Specificity: 0.9833, False Alarm Ratio: 0.0871
#
#
# epoch duration : 68.9523754119873
# saving step
# epoch n° 1091
# Training, Regression Loss: 0.0226, Regression Loss 1h: 259.8847, Segmentation Loss:0.0813
# Train Confusion Matrix:
# [[3144299   50507]
#  [  72012  573182]]
# Accuracy: 0.9681, CSI: 0.8239, Sensitivity: 0.8884, Specificity: 0.9842, False Alarm Ratio: 0.0810
#
#
# epoch duration : 70.27107429504395
# epoch n° 1092
# Training, Regression Loss: 0.0229, Regression Loss 1h: 275.7729, Segmentation Loss:0.0784
# Train Confusion Matrix:
# [[3147524   49759]
#  [  68764  573953]]
# Accuracy: 0.9691, CSI: 0.8288, Sensitivity: 0.8930, Specificity: 0.9844, False Alarm Ratio: 0.0798
#
#
# epoch duration : 70.48952674865723
# epoch n° 1093
# Training, Regression Loss: 0.0230, Regression Loss 1h: 276.1361, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[3149988   49249]
#  [  70419  570344]]
# Accuracy: 0.9688, CSI: 0.8266, Sensitivity: 0.8901, Specificity: 0.9846, False Alarm Ratio: 0.0795
#
#
# epoch duration : 70.51429605484009
# epoch n° 1094
# Training, Regression Loss: 0.0221, Regression Loss 1h: 289.4194, Segmentation Loss:0.0770
# Train Confusion Matrix:
# [[3150211   47917]
#  [  68341  573531]]
# Accuracy: 0.9697, CSI: 0.8315, Sensitivity: 0.8935, Specificity: 0.9850, False Alarm Ratio: 0.0771
#
#
# epoch duration : 70.14338898658752
# epoch n° 1095
# Training, Regression Loss: 0.0224, Regression Loss 1h: 325.9247, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3146029   47721]
#  [  66297  579953]]
# Accuracy: 0.9703, CSI: 0.8357, Sensitivity: 0.8974, Specificity: 0.9851, False Alarm Ratio: 0.0760
#
#
# epoch duration : 68.83453607559204
# epoch n° 1096
# Training, Regression Loss: 0.0215, Regression Loss 1h: 311.9767, Segmentation Loss:0.0767
# Train Confusion Matrix:
# [[3147126   47911]
#  [  68645  576318]]
# Accuracy: 0.9696, CSI: 0.8318, Sensitivity: 0.8936, Specificity: 0.9850, False Alarm Ratio: 0.0768
#
#
# epoch duration : 68.33744955062866
# epoch n° 1097
# Training, Regression Loss: 0.0214, Regression Loss 1h: 284.8871, Segmentation Loss:0.0770
# Train Confusion Matrix:
# [[3152480   48558]
#  [  68489  570473]]
# Accuracy: 0.9695, CSI: 0.8298, Sensitivity: 0.8928, Specificity: 0.9848, False Alarm Ratio: 0.0784
#
#
# epoch duration : 69.14156150817871
# epoch n° 1098
# Training, Regression Loss: 0.0214, Regression Loss 1h: 290.3917, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3147445   47791]
#  [  66788  577976]]
# Accuracy: 0.9702, CSI: 0.8346, Sensitivity: 0.8964, Specificity: 0.9850, False Alarm Ratio: 0.0764
#
#
# epoch duration : 68.49672532081604
# epoch n° 1099
# Training, Regression Loss: 0.0214, Regression Loss 1h: 296.5018, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3159308   47060]
#  [  67970  565662]]
# Accuracy: 0.9700, CSI: 0.8310, Sensitivity: 0.8927, Specificity: 0.9853, False Alarm Ratio: 0.0768
#
#
# epoch duration : 70.96397042274475
# epoch n° 1100
# Training, Regression Loss: 0.0213, Regression Loss 1h: 279.5094, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3156111   47300]
#  [  67185  569404]]
# Accuracy: 0.9702, CSI: 0.8326, Sensitivity: 0.8945, Specificity: 0.9852, False Alarm Ratio: 0.0767
#
#
# epoch duration : 69.6105489730835
# saving step
# epoch n° 1101
# Training, Regression Loss: 0.0218, Regression Loss 1h: 272.4957, Segmentation Loss:0.0752
# Train Confusion Matrix:
# [[3157353   47254]
#  [  66636  568757]]
# Accuracy: 0.9703, CSI: 0.8332, Sensitivity: 0.8951, Specificity: 0.9853, False Alarm Ratio: 0.0767
#
#
# epoch duration : 68.02454257011414
# epoch n° 1102
# Training, Regression Loss: 0.0216, Regression Loss 1h: 271.2205, Segmentation Loss:0.0735
# Train Confusion Matrix:
# [[3154590   47131]
#  [  64972  573307]]
# Accuracy: 0.9708, CSI: 0.8364, Sensitivity: 0.8982, Specificity: 0.9853, False Alarm Ratio: 0.0760
#
#
# epoch duration : 70.01679873466492
# epoch n° 1103
# Training, Regression Loss: 0.0212, Regression Loss 1h: 264.3343, Segmentation Loss:0.0739
# Train Confusion Matrix:
# [[3149363   46315]
#  [  65569  578753]]
# Accuracy: 0.9709, CSI: 0.8380, Sensitivity: 0.8982, Specificity: 0.9855, False Alarm Ratio: 0.0741
#
#
# epoch duration : 69.56007122993469
# epoch n° 1104
# Training, Regression Loss: 0.0216, Regression Loss 1h: 282.4167, Segmentation Loss:0.0750
# Train Confusion Matrix:
# [[3151214   46728]
#  [  67213  574845]]
# Accuracy: 0.9703, CSI: 0.8346, Sensitivity: 0.8953, Specificity: 0.9854, False Alarm Ratio: 0.0752
#
#
# epoch duration : 68.4590654373169
# epoch n° 1105
# Training, Regression Loss: 0.0223, Regression Loss 1h: 307.8584, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3154771   47849]
#  [  66661  570719]]
# Accuracy: 0.9702, CSI: 0.8329, Sensitivity: 0.8954, Specificity: 0.9851, False Alarm Ratio: 0.0774
#
#
# epoch duration : 70.1218957901001
# epoch n° 1106
# Training, Regression Loss: 0.0222, Regression Loss 1h: 401.9473, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3149312   47534]
#  [  67517  575637]]
# Accuracy: 0.9700, CSI: 0.8334, Sensitivity: 0.8950, Specificity: 0.9851, False Alarm Ratio: 0.0763
#
#
# epoch duration : 68.39715671539307
# epoch n° 1107
# Training, Regression Loss: 0.0220, Regression Loss 1h: 370.8568, Segmentation Loss:0.0717
# Train Confusion Matrix:
# [[3156223   46627]
#  [  63108  574042]]
# Accuracy: 0.9714, CSI: 0.8395, Sensitivity: 0.9010, Specificity: 0.9854, False Alarm Ratio: 0.0751
#
#
# epoch duration : 69.3469455242157
# epoch n° 1108
# Training, Regression Loss: 0.0215, Regression Loss 1h: 346.8790, Segmentation Loss:0.0734
# Train Confusion Matrix:
# [[3166951   46030]
#  [  65454  561565]]
# Accuracy: 0.9710, CSI: 0.8344, Sensitivity: 0.8956, Specificity: 0.9857, False Alarm Ratio: 0.0758
#
#
# epoch duration : 71.44982385635376
# epoch n° 1109
# Training, Regression Loss: 0.0218, Regression Loss 1h: 310.9857, Segmentation Loss:0.0734
# Train Confusion Matrix:
# [[3155281   47211]
#  [  64731  572777]]
# Accuracy: 0.9708, CSI: 0.8365, Sensitivity: 0.8985, Specificity: 0.9853, False Alarm Ratio: 0.0761
#
#
# epoch duration : 70.41028547286987
# epoch n° 1110
# Training, Regression Loss: 0.0218, Regression Loss 1h: 312.2851, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3138749   48437]
#  [  67717  585097]]
# Accuracy: 0.9698, CSI: 0.8344, Sensitivity: 0.8963, Specificity: 0.9848, False Alarm Ratio: 0.0765
#
#
# epoch duration : 69.3734359741211
# saving step
# epoch n° 1111
# Training, Regression Loss: 0.0212, Regression Loss 1h: 309.8546, Segmentation Loss:0.0739
# Train Confusion Matrix:
# [[3145923   46739]
#  [  65865  581473]]
# Accuracy: 0.9707, CSI: 0.8378, Sensitivity: 0.8983, Specificity: 0.9854, False Alarm Ratio: 0.0744
#
#
# epoch duration : 69.73564648628235
# epoch n° 1112
# Training, Regression Loss: 0.0206, Regression Loss 1h: 330.7284, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3155817   47425]
#  [  66425  570333]]
# Accuracy: 0.9704, CSI: 0.8336, Sensitivity: 0.8957, Specificity: 0.9852, False Alarm Ratio: 0.0768
#
#
# epoch duration : 69.07259488105774
# epoch n° 1113
# Training, Regression Loss: 0.0211, Regression Loss 1h: 295.1192, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3145512   47389]
#  [  67493  579606]]
# Accuracy: 0.9701, CSI: 0.8346, Sensitivity: 0.8957, Specificity: 0.9852, False Alarm Ratio: 0.0756
#
#
# epoch duration : 68.57475590705872
# epoch n° 1114
# Training, Regression Loss: 0.0213, Regression Loss 1h: 315.3619, Segmentation Loss:0.0732
# Train Confusion Matrix:
# [[3145797   46388]
#  [  65125  582690]]
# Accuracy: 0.9710, CSI: 0.8394, Sensitivity: 0.8995, Specificity: 0.9855, False Alarm Ratio: 0.0737
#
#
# epoch duration : 69.6940336227417
# epoch n° 1115
# Training, Regression Loss: 0.0216, Regression Loss 1h: 290.6500, Segmentation Loss:0.0738
# Train Confusion Matrix:
# [[3148024   47224]
#  [  64952  579800]]
# Accuracy: 0.9708, CSI: 0.8379, Sensitivity: 0.8993, Specificity: 0.9852, False Alarm Ratio: 0.0753
#
#
# epoch duration : 69.15887355804443
# epoch n° 1116
# Training, Regression Loss: 0.0214, Regression Loss 1h: 312.3128, Segmentation Loss:0.0750
# Train Confusion Matrix:
# [[3154673   47257]
#  [  66782  571288]]
# Accuracy: 0.9703, CSI: 0.8336, Sensitivity: 0.8953, Specificity: 0.9852, False Alarm Ratio: 0.0764
#
#
# epoch duration : 68.80447745323181
# epoch n° 1117
# Training, Regression Loss: 0.0215, Regression Loss 1h: 304.4664, Segmentation Loss:0.0730
# Train Confusion Matrix:
# [[3148906   46985]
#  [  64202  579907]]
# Accuracy: 0.9710, CSI: 0.8391, Sensitivity: 0.9003, Specificity: 0.9853, False Alarm Ratio: 0.0749
#
#
# epoch duration : 70.90336847305298
# epoch n° 1118
# Training, Regression Loss: 0.0213, Regression Loss 1h: 289.2687, Segmentation Loss:0.0733
# Train Confusion Matrix:
# [[3145665   46659]
#  [  65174  582502]]
# Accuracy: 0.9709, CSI: 0.8389, Sensitivity: 0.8994, Specificity: 0.9854, False Alarm Ratio: 0.0742
#
#
# epoch duration : 69.01471209526062
# epoch n° 1119
# Training, Regression Loss: 0.0212, Regression Loss 1h: 288.9534, Segmentation Loss:0.0761
# Train Confusion Matrix:
# [[3137383   48057]
#  [  67707  586853]]
# Accuracy: 0.9699, CSI: 0.8352, Sensitivity: 0.8966, Specificity: 0.9849, False Alarm Ratio: 0.0757
#
#
# epoch duration : 71.15393114089966
# epoch n° 1120
# Training, Regression Loss: 0.0219, Regression Loss 1h: 284.9467, Segmentation Loss:0.0719
# Train Confusion Matrix:
# [[3144322   46847]
#  [  63317  585514]]
# Accuracy: 0.9713, CSI: 0.8416, Sensitivity: 0.9024, Specificity: 0.9853, False Alarm Ratio: 0.0741
#
#
# epoch duration : 70.33478927612305
# saving step
# epoch n° 1121
# Training, Regression Loss: 0.0215, Regression Loss 1h: 288.3973, Segmentation Loss:0.0737
# Train Confusion Matrix:
# [[3147471   46474]
#  [  65546  580509]]
# Accuracy: 0.9708, CSI: 0.8382, Sensitivity: 0.8985, Specificity: 0.9854, False Alarm Ratio: 0.0741
#
#
# epoch duration : 69.26273083686829
# epoch n° 1122
# Training, Regression Loss: 0.0213, Regression Loss 1h: 300.3310, Segmentation Loss:0.0742
# Train Confusion Matrix:
# [[3150428   47126]
#  [  66042  576404]]
# Accuracy: 0.9705, CSI: 0.8359, Sensitivity: 0.8972, Specificity: 0.9853, False Alarm Ratio: 0.0756
#
#
# epoch duration : 69.60490942001343
# epoch n° 1123
# Training, Regression Loss: 0.0214, Regression Loss 1h: 286.2891, Segmentation Loss:0.0721
# Train Confusion Matrix:
# [[3149779   46176]
#  [  64038  580007]]
# Accuracy: 0.9713, CSI: 0.8403, Sensitivity: 0.9006, Specificity: 0.9856, False Alarm Ratio: 0.0737
#
#
# epoch duration : 69.41943788528442
# epoch n° 1124
# Training, Regression Loss: 0.0217, Regression Loss 1h: 290.7894, Segmentation Loss:0.0720
# Train Confusion Matrix:
# [[3141466   46300]
#  [  63913  588321]]
# Accuracy: 0.9713, CSI: 0.8422, Sensitivity: 0.9020, Specificity: 0.9855, False Alarm Ratio: 0.0730
#
#
# epoch duration : 70.17009449005127
# epoch n° 1125
# Training, Regression Loss: 0.0211, Regression Loss 1h: 289.9347, Segmentation Loss:0.0746
# Train Confusion Matrix:
# [[3143123   47446]
#  [  66157  583274]]
# Accuracy: 0.9704, CSI: 0.8370, Sensitivity: 0.8981, Specificity: 0.9851, False Alarm Ratio: 0.0752
#
#
# epoch duration : 70.01201152801514
# epoch n° 1126
# Training, Regression Loss: 0.0215, Regression Loss 1h: 287.7818, Segmentation Loss:0.0720
# Train Confusion Matrix:
# [[3153862   46360]
#  [  63835  575943]]
# Accuracy: 0.9713, CSI: 0.8394, Sensitivity: 0.9002, Specificity: 0.9855, False Alarm Ratio: 0.0745
#
#
# epoch duration : 71.30967664718628
# epoch n° 1127
# Training, Regression Loss: 0.0213, Regression Loss 1h: 290.3395, Segmentation Loss:0.0735
# Train Confusion Matrix:
# [[3157608   46640]
#  [  65642  570110]]
# Accuracy: 0.9708, CSI: 0.8355, Sensitivity: 0.8967, Specificity: 0.9854, False Alarm Ratio: 0.0756
#
#
# epoch duration : 69.9676661491394
# epoch n° 1128
# Training, Regression Loss: 0.0209, Regression Loss 1h: 305.3837, Segmentation Loss:0.0728
# Train Confusion Matrix:
# [[3157342   46297]
#  [  64661  571700]]
# Accuracy: 0.9711, CSI: 0.8375, Sensitivity: 0.8984, Specificity: 0.9855, False Alarm Ratio: 0.0749
#
#
# epoch duration : 70.08107733726501
# epoch n° 1129
# Training, Regression Loss: 0.0213, Regression Loss 1h: 292.0844, Segmentation Loss:0.0746
# Train Confusion Matrix:
# [[3148239   46651]
#  [  66867  578243]]
# Accuracy: 0.9704, CSI: 0.8359, Sensitivity: 0.8963, Specificity: 0.9854, False Alarm Ratio: 0.0747
#
#
# epoch duration : 69.7352933883667
# epoch n° 1130
# Training, Regression Loss: 0.0209, Regression Loss 1h: 294.9675, Segmentation Loss:0.0727
# Train Confusion Matrix:
# [[3149776   45851]
#  [  64664  579709]]
# Accuracy: 0.9712, CSI: 0.8399, Sensitivity: 0.8996, Specificity: 0.9857, False Alarm Ratio: 0.0733
#
#
# epoch duration : 70.35487818717957
# saving step
# epoch n° 1131
# Training, Regression Loss: 0.0208, Regression Loss 1h: 296.8517, Segmentation Loss:0.0728
# Train Confusion Matrix:
# [[3149407   46825]
#  [  64845  578923]]
# Accuracy: 0.9709, CSI: 0.8383, Sensitivity: 0.8993, Specificity: 0.9853, False Alarm Ratio: 0.0748
#
#
# epoch duration : 69.99492835998535
# epoch n° 1132
# Training, Regression Loss: 0.0211, Regression Loss 1h: 302.0742, Segmentation Loss:0.0732
# Train Confusion Matrix:
# [[3147219   46738]
#  [  65259  580784]]
# Accuracy: 0.9708, CSI: 0.8383, Sensitivity: 0.8990, Specificity: 0.9854, False Alarm Ratio: 0.0745
#
#
# epoch duration : 68.44596457481384
# epoch n° 1133
# Training, Regression Loss: 0.0210, Regression Loss 1h: 307.8048, Segmentation Loss:0.0740
# Train Confusion Matrix:
# [[3156819   46614]
#  [  65800  570767]]
# Accuracy: 0.9707, CSI: 0.8355, Sensitivity: 0.8966, Specificity: 0.9854, False Alarm Ratio: 0.0755
#
#
# epoch duration : 69.79315829277039
# epoch n° 1134
# Training, Regression Loss: 0.0216, Regression Loss 1h: 298.9468, Segmentation Loss:0.0727
# Train Confusion Matrix:
# [[3159408   45853]
#  [  64902  569837]]
# Accuracy: 0.9712, CSI: 0.8373, Sensitivity: 0.8978, Specificity: 0.9857, False Alarm Ratio: 0.0745
#
#
# epoch duration : 69.32642912864685
# epoch n° 1135
# Training, Regression Loss: 0.0219, Regression Loss 1h: 304.9490, Segmentation Loss:0.0715
# Train Confusion Matrix:
# [[3158103   45532]
#  [  63497  572868]]
# Accuracy: 0.9716, CSI: 0.8401, Sensitivity: 0.9002, Specificity: 0.9858, False Alarm Ratio: 0.0736
#
#
# epoch duration : 70.04638075828552
# epoch n° 1136
# Training, Regression Loss: 0.0210, Regression Loss 1h: 304.8320, Segmentation Loss:0.0735
# Train Confusion Matrix:
# [[3154739   46286]
#  [  65109  573866]]
# Accuracy: 0.9710, CSI: 0.8374, Sensitivity: 0.8981, Specificity: 0.9855, False Alarm Ratio: 0.0746
#
#
# epoch duration : 70.35396480560303
# epoch n° 1137
# Training, Regression Loss: 0.0212, Regression Loss 1h: 287.1336, Segmentation Loss:0.0735
# Train Confusion Matrix:
# [[3151859   46214]
#  [  65430  576497]]
# Accuracy: 0.9709, CSI: 0.8378, Sensitivity: 0.8981, Specificity: 0.9855, False Alarm Ratio: 0.0742
#
#
# epoch duration : 68.55727338790894
# epoch n° 1138
# Training, Regression Loss: 0.0210, Regression Loss 1h: 292.7838, Segmentation Loss:0.0745
# Train Confusion Matrix:
# [[3145654   47226]
#  [  65957  581163]]
# Accuracy: 0.9705, CSI: 0.8370, Sensitivity: 0.8981, Specificity: 0.9852, False Alarm Ratio: 0.0752
#
#
# epoch duration : 67.82076573371887
# epoch n° 1139
# Training, Regression Loss: 0.0215, Regression Loss 1h: 296.9688, Segmentation Loss:0.0727
# Train Confusion Matrix:
# [[3147481   46568]
#  [  64327  581624]]
# Accuracy: 0.9711, CSI: 0.8399, Sensitivity: 0.9004, Specificity: 0.9854, False Alarm Ratio: 0.0741
#
#
# epoch duration : 67.72665929794312
# epoch n° 1140
# Training, Regression Loss: 0.0242, Regression Loss 1h: 328.0252, Segmentation Loss:0.0783
# Train Confusion Matrix:
# [[3146457   48831]
#  [  69498  575214]]
# Accuracy: 0.9692, CSI: 0.8294, Sensitivity: 0.8922, Specificity: 0.9847, False Alarm Ratio: 0.0782
#
#
# epoch duration : 68.56384897232056
# saving step
# epoch n° 1141
# Training, Regression Loss: 0.0226, Regression Loss 1h: 287.6116, Segmentation Loss:0.0773
# Train Confusion Matrix:
# [[3145259   48732]
#  [  68854  577155]]
# Accuracy: 0.9694, CSI: 0.8307, Sensitivity: 0.8934, Specificity: 0.9847, False Alarm Ratio: 0.0779
#
#
# epoch duration : 69.52467608451843
# epoch n° 1142
# Training, Regression Loss: 0.0219, Regression Loss 1h: 292.7623, Segmentation Loss:0.0738
# Train Confusion Matrix:
# [[3157161   46471]
#  [  65459  570909]]
# Accuracy: 0.9709, CSI: 0.8361, Sensitivity: 0.8971, Specificity: 0.9855, False Alarm Ratio: 0.0753
#
#
# epoch duration : 70.62198662757874
# epoch n° 1143
# Training, Regression Loss: 0.0215, Regression Loss 1h: 292.3016, Segmentation Loss:0.0744
# Train Confusion Matrix:
# [[3150707   46960]
#  [  66368  575965]]
# Accuracy: 0.9705, CSI: 0.8356, Sensitivity: 0.8967, Specificity: 0.9853, False Alarm Ratio: 0.0754
#
#
# epoch duration : 70.75736856460571
# epoch n° 1144
# Training, Regression Loss: 0.0219, Regression Loss 1h: 309.1683, Segmentation Loss:0.0723
# Train Confusion Matrix:
# [[3153153   45537]
#  [  64207  577103]]
# Accuracy: 0.9714, CSI: 0.8402, Sensitivity: 0.8999, Specificity: 0.9858, False Alarm Ratio: 0.0731
#
#
# epoch duration : 70.49566197395325
# epoch n° 1145
# Training, Regression Loss: 0.0216, Regression Loss 1h: 314.3559, Segmentation Loss:0.0743
# Train Confusion Matrix:
# [[3143834   47020]
#  [  66157  582989]]
# Accuracy: 0.9705, CSI: 0.8374, Sensitivity: 0.8981, Specificity: 0.9853, False Alarm Ratio: 0.0746
#
#
# epoch duration : 70.0547468662262
# epoch n° 1146
# Training, Regression Loss: 0.0212, Regression Loss 1h: 284.6653, Segmentation Loss:0.0761
# Train Confusion Matrix:
# [[3148311   47313]
#  [  67961  576415]]
# Accuracy: 0.9700, CSI: 0.8333, Sensitivity: 0.8945, Specificity: 0.9852, False Alarm Ratio: 0.0759
#
#
# epoch duration : 70.6376953125
# epoch n° 1147
# Training, Regression Loss: 0.0207, Regression Loss 1h: 286.7450, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3153635   47210]
#  [  66882  572273]]
# Accuracy: 0.9703, CSI: 0.8338, Sensitivity: 0.8954, Specificity: 0.9853, False Alarm Ratio: 0.0762
#
#
# epoch duration : 69.97532510757446
# epoch n° 1148
# Training, Regression Loss: 0.0217, Regression Loss 1h: 294.5144, Segmentation Loss:0.0708
# Train Confusion Matrix:
# [[3148555   45066]
#  [  62698  583681]]
# Accuracy: 0.9719, CSI: 0.8441, Sensitivity: 0.9030, Specificity: 0.9859, False Alarm Ratio: 0.0717
#
#
# epoch duration : 71.1332836151123
# epoch n° 1149
# Training, Regression Loss: 0.0212, Regression Loss 1h: 281.4699, Segmentation Loss:0.0744
# Train Confusion Matrix:
# [[3150951   46734]
#  [  66078  576237]]
# Accuracy: 0.9706, CSI: 0.8363, Sensitivity: 0.8971, Specificity: 0.9854, False Alarm Ratio: 0.0750
#
#
# epoch duration : 69.92672681808472
# epoch n° 1150
# Training, Regression Loss: 0.0218, Regression Loss 1h: 298.7902, Segmentation Loss:0.0737
# Train Confusion Matrix:
# [[3149947   46225]
#  [  65794  578034]]
# Accuracy: 0.9708, CSI: 0.8377, Sensitivity: 0.8978, Specificity: 0.9855, False Alarm Ratio: 0.0740
#
#
# epoch duration : 69.06536555290222
# saving step
# epoch n° 1151
# Training, Regression Loss: 0.0206, Regression Loss 1h: 287.9076, Segmentation Loss:0.0744
# Train Confusion Matrix:
# [[3151632   46964]
#  [  66762  574642]]
# Accuracy: 0.9704, CSI: 0.8348, Sensitivity: 0.8959, Specificity: 0.9853, False Alarm Ratio: 0.0756
#
#
# epoch duration : 69.30802488327026
# epoch n° 1152
# Training, Regression Loss: 0.0221, Regression Loss 1h: 286.9846, Segmentation Loss:0.0751
# Train Confusion Matrix:
# [[3153512   47230]
#  [  66418  572840]]
# Accuracy: 0.9704, CSI: 0.8345, Sensitivity: 0.8961, Specificity: 0.9852, False Alarm Ratio: 0.0762
#
#
# epoch duration : 69.24457907676697
# epoch n° 1153
# Training, Regression Loss: 0.0214, Regression Loss 1h: 293.9532, Segmentation Loss:0.0733
# Train Confusion Matrix:
# [[3150862   46668]
#  [  64809  577661]]
# Accuracy: 0.9710, CSI: 0.8382, Sensitivity: 0.8991, Specificity: 0.9854, False Alarm Ratio: 0.0747
#
#
# epoch duration : 69.97937822341919
# epoch n° 1154
# Training, Regression Loss: 0.0215, Regression Loss 1h: 336.6188, Segmentation Loss:0.0747
# Train Confusion Matrix:
# [[3155259   46702]
#  [  66844  571195]]
# Accuracy: 0.9704, CSI: 0.8342, Sensitivity: 0.8952, Specificity: 0.9854, False Alarm Ratio: 0.0756
#
#
# epoch duration : 69.12492728233337
# epoch n° 1155
# Training, Regression Loss: 0.0210, Regression Loss 1h: 279.3717, Segmentation Loss:0.0748
# Train Confusion Matrix:
# [[3153076   46921]
#  [  66988  573015]]
# Accuracy: 0.9703, CSI: 0.8342, Sensitivity: 0.8953, Specificity: 0.9853, False Alarm Ratio: 0.0757
#
#
# epoch duration : 71.21986794471741
# epoch n° 1156
# Training, Regression Loss: 0.0211, Regression Loss 1h: 282.5302, Segmentation Loss:0.0729
# Train Confusion Matrix:
# [[3148750   47090]
#  [  64825  579335]]
# Accuracy: 0.9709, CSI: 0.8381, Sensitivity: 0.8994, Specificity: 0.9853, False Alarm Ratio: 0.0752
#
#
# epoch duration : 70.48023295402527
# epoch n° 1157
# Training, Regression Loss: 0.0217, Regression Loss 1h: 283.6422, Segmentation Loss:0.0754
# Train Confusion Matrix:
# [[3154348   47236]
#  [  67410  571006]]
# Accuracy: 0.9701, CSI: 0.8328, Sensitivity: 0.8944, Specificity: 0.9852, False Alarm Ratio: 0.0764
#
#
# epoch duration : 70.78536248207092
# epoch n° 1158
# Training, Regression Loss: 0.0498, Regression Loss 1h: 327.9788, Segmentation Loss:0.1142
# Train Confusion Matrix:
# [[3136163   59614]
#  [ 101672  542551]]
# ...
# Train Confusion Matrix:
# [[3148457   46027]
#  [  64943  580573]]
# Accuracy: 0.9711, CSI: 0.8395, Sensitivity: 0.8994, Specificity: 0.9856, False Alarm Ratio: 0.0735
#
#
# epoch duration : 69.36686849594116
# epoch n° 1396
# Training, Regression Loss: 0.0207, Regression Loss 1h: 315.1070, Segmentation Loss:0.0710
# Train Confusion Matrix:
# [[3158513   44275]
#  [  63170  574042]]
# Accuracy: 0.9720, CSI: 0.8423, Sensitivity: 0.9009, Specificity: 0.9862, False Alarm Ratio: 0.0716
#
#
# epoch duration : 69.60785675048828
# epoch n° 1397
# Training, Regression Loss: 0.0203, Regression Loss 1h: 315.2216, Segmentation Loss:0.0714
# Train Confusion Matrix:
# [[3157920   44794]
#  [  63549  573737]]
# Accuracy: 0.9718, CSI: 0.8412, Sensitivity: 0.9003, Specificity: 0.9860, False Alarm Ratio: 0.0724
#
#
# epoch duration : 70.93215799331665
# epoch n° 1398
# Training, Regression Loss: 0.0209, Regression Loss 1h: 321.6481, Segmentation Loss:0.0717
# Train Confusion Matrix:
# [[3163532   44992]
#  [  63731  567745]]
# Accuracy: 0.9717, CSI: 0.8393, Sensitivity: 0.8991, Specificity: 0.9860, False Alarm Ratio: 0.0734
#
#
# epoch duration : 70.8023374080658
# epoch n° 1399
# Training, Regression Loss: 0.0211, Regression Loss 1h: 333.3159, Segmentation Loss:0.0698
# Train Confusion Matrix:
# [[3154747   44486]
#  [  61775  578992]]
# Accuracy: 0.9723, CSI: 0.8449, Sensitivity: 0.9036, Specificity: 0.9861, False Alarm Ratio: 0.0714
#
#
# epoch duration : 69.17499780654907
# epoch n° 1400
# Training, Regression Loss: 0.0207, Regression Loss 1h: 335.6054, Segmentation Loss:0.0710
# Train Confusion Matrix:
# [[3153971   45463]
#  [  62611  577955]]
# Accuracy: 0.9719, CSI: 0.8425, Sensitivity: 0.9023, Specificity: 0.9858, False Alarm Ratio: 0.0729
#
#
# epoch duration : 68.77811694145203
# saving step
# epoch n° 1401
# Training, Regression Loss: 0.0211, Regression Loss 1h: 335.9074, Segmentation Loss:0.0711
# Train Confusion Matrix:
# [[3147746   46008]
#  [  62794  583452]]
# Accuracy: 0.9717, CSI: 0.8428, Sensitivity: 0.9028, Specificity: 0.9856, False Alarm Ratio: 0.0731
#
#
# epoch duration : 68.59790968894958
# epoch n° 1402
# Training, Regression Loss: 0.0212, Regression Loss 1h: 340.0369, Segmentation Loss:0.0711
# Train Confusion Matrix:
# [[3156555   44947]
#  [  62975  575523]]
# Accuracy: 0.9719, CSI: 0.8421, Sensitivity: 0.9014, Specificity: 0.9860, False Alarm Ratio: 0.0724
#
#
# epoch duration : 70.73591828346252
# epoch n° 1403
# Training, Regression Loss: 0.0206, Regression Loss 1h: 337.9831, Segmentation Loss:0.0729
# Train Confusion Matrix:
# [[3160265   45409]
#  [  64872  569454]]
# Accuracy: 0.9713, CSI: 0.8378, Sensitivity: 0.8977, Specificity: 0.9858, False Alarm Ratio: 0.0739
#
#
# epoch duration : 69.3618278503418
# epoch n° 1404
# Training, Regression Loss: 0.0208, Regression Loss 1h: 327.5632, Segmentation Loss:0.0711
# Train Confusion Matrix:
# [[3148399   44172]
#  [  63455  583974]]
# Accuracy: 0.9720, CSI: 0.8444, Sensitivity: 0.9020, Specificity: 0.9862, False Alarm Ratio: 0.0703
#
#
# epoch duration : 69.79476642608643
# epoch n° 1405
# Training, Regression Loss: 0.0213, Regression Loss 1h: 331.5208, Segmentation Loss:0.0706
# Train Confusion Matrix:
# [[3157627   45253]
#  [  62177  574943]]
# Accuracy: 0.9720, CSI: 0.8426, Sensitivity: 0.9024, Specificity: 0.9859, False Alarm Ratio: 0.0730
#
#
# epoch duration : 69.21441626548767
# epoch n° 1406
# Training, Regression Loss: 0.0207, Regression Loss 1h: 329.6327, Segmentation Loss:0.0715
# Train Confusion Matrix:
# [[3153271   44902]
#  [  63617  578210]]
# Accuracy: 0.9717, CSI: 0.8420, Sensitivity: 0.9009, Specificity: 0.9860, False Alarm Ratio: 0.0721
#
#
# epoch duration : 69.38369297981262
# epoch n° 1407
# Training, Regression Loss: 0.0209, Regression Loss 1h: 334.9079, Segmentation Loss:0.0717
# Train Confusion Matrix:
# [[3149525   45810]
#  [  63616  581049]]
# Accuracy: 0.9715, CSI: 0.8415, Sensitivity: 0.9013, Specificity: 0.9857, False Alarm Ratio: 0.0731
#
#
# epoch duration : 69.98629903793335
# epoch n° 1408
# Training, Regression Loss: 0.0210, Regression Loss 1h: 333.3395, Segmentation Loss:0.0697
# Train Confusion Matrix:
# [[3159304   44392]
#  [  61779  574525]]
# Accuracy: 0.9724, CSI: 0.8440, Sensitivity: 0.9029, Specificity: 0.9861, False Alarm Ratio: 0.0717
#
#
# epoch duration : 69.9038872718811
# epoch n° 1409
# Training, Regression Loss: 0.0208, Regression Loss 1h: 328.2018, Segmentation Loss:0.0708
# Train Confusion Matrix:
# [[3153621   44579]
#  [  63128  578672]]
# Accuracy: 0.9720, CSI: 0.8431, Sensitivity: 0.9016, Specificity: 0.9861, False Alarm Ratio: 0.0715
#
#
# epoch duration : 69.35312938690186
# epoch n° 1410
# Training, Regression Loss: 0.0209, Regression Loss 1h: 339.4077, Segmentation Loss:0.0730
# Train Confusion Matrix:
# [[3159207   45871]
#  [  65638  569284]]
# Accuracy: 0.9710, CSI: 0.8362, Sensitivity: 0.8966, Specificity: 0.9857, False Alarm Ratio: 0.0746
#
#
# epoch duration : 69.9939935207367
# saving step
# epoch n° 1411
# Training, Regression Loss: 0.0207, Regression Loss 1h: 322.3294, Segmentation Loss:0.0702
# Train Confusion Matrix:
# [[3146460   44121]
#  [  62631  586788]]
# Accuracy: 0.9722, CSI: 0.8461, Sensitivity: 0.9036, Specificity: 0.9862, False Alarm Ratio: 0.0699
#
#
# epoch duration : 69.2179753780365
# epoch n° 1412
# Training, Regression Loss: 0.0210, Regression Loss 1h: 329.5623, Segmentation Loss:0.0693
# Train Confusion Matrix:
# [[3155883   44290]
#  [  61028  578799]]
# Accuracy: 0.9726, CSI: 0.8461, Sensitivity: 0.9046, Specificity: 0.9862, False Alarm Ratio: 0.0711
#
#
# epoch duration : 69.68363904953003
# epoch n° 1413
# Training, Regression Loss: 0.0209, Regression Loss 1h: 335.5234, Segmentation Loss:0.0708
# Train Confusion Matrix:
# [[3151616   44590]
#  [  62986  580808]]
# Accuracy: 0.9720, CSI: 0.8437, Sensitivity: 0.9022, Specificity: 0.9860, False Alarm Ratio: 0.0713
#
#
# epoch duration : 68.62341594696045
# epoch n° 1414
# Training, Regression Loss: 0.0214, Regression Loss 1h: 342.1433, Segmentation Loss:0.0688
# Train Confusion Matrix:
# [[3158528   44053]
#  [  60741  576678]]
# Accuracy: 0.9727, CSI: 0.8462, Sensitivity: 0.9047, Specificity: 0.9862, False Alarm Ratio: 0.0710
#
#
# epoch duration : 67.9498963356018
# epoch n° 1415
# Training, Regression Loss: 0.0210, Regression Loss 1h: 338.3526, Segmentation Loss:0.0725
# Train Confusion Matrix:
# [[3155956   45660]
#  [  64679  573705]]
# Accuracy: 0.9713, CSI: 0.8387, Sensitivity: 0.8987, Specificity: 0.9857, False Alarm Ratio: 0.0737
#
#
# epoch duration : 70.3945300579071
# epoch n° 1416
# Training, Regression Loss: 0.0215, Regression Loss 1h: 338.1970, Segmentation Loss:0.0721
# Train Confusion Matrix:
# [[3154013   45078]
#  [  64586  576323]]
# Accuracy: 0.9714, CSI: 0.8401, Sensitivity: 0.8992, Specificity: 0.9859, False Alarm Ratio: 0.0725
#
#
# epoch duration : 69.67635560035706
# epoch n° 1417
# Training, Regression Loss: 0.0210, Regression Loss 1h: 332.7790, Segmentation Loss:0.0735
# Train Confusion Matrix:
# [[3151541   46212]
#  [  65503  576744]]
# Accuracy: 0.9709, CSI: 0.8377, Sensitivity: 0.8980, Specificity: 0.9855, False Alarm Ratio: 0.0742
#
#
# epoch duration : 69.43050622940063
# epoch n° 1418
# Training, Regression Loss: 0.0210, Regression Loss 1h: 325.6584, Segmentation Loss:0.0701
# Train Confusion Matrix:
# [[3153977   44710]
#  [  62470  578843]]
# Accuracy: 0.9721, CSI: 0.8438, Sensitivity: 0.9026, Specificity: 0.9860, False Alarm Ratio: 0.0717
#
#
# epoch duration : 68.70727896690369
# epoch n° 1419
# Training, Regression Loss: 0.0203, Regression Loss 1h: 332.1800, Segmentation Loss:0.0712
# Train Confusion Matrix:
# [[3151499   45061]
#  [  63362  580078]]
# Accuracy: 0.9718, CSI: 0.8425, Sensitivity: 0.9015, Specificity: 0.9859, False Alarm Ratio: 0.0721
#
#
# epoch duration : 69.95676350593567
# epoch n° 1420
# Training, Regression Loss: 0.0210, Regression Loss 1h: 331.5953, Segmentation Loss:0.0717
# Train Confusion Matrix:
# [[3151658   44872]
#  [  63726  579744]]
# Accuracy: 0.9717, CSI: 0.8422, Sensitivity: 0.9010, Specificity: 0.9860, False Alarm Ratio: 0.0718
#
#
# epoch duration : 69.53181076049805
# saving step
# epoch n° 1421
# Training, Regression Loss: 0.0211, Regression Loss 1h: 328.2284, Segmentation Loss:0.0686
# Train Confusion Matrix:
# [[3157366   44094]
#  [  60883  577657]]
# Accuracy: 0.9727, CSI: 0.8462, Sensitivity: 0.9047, Specificity: 0.9862, False Alarm Ratio: 0.0709
#
#
# epoch duration : 68.54977774620056
# epoch n° 1422
# Training, Regression Loss: 0.0207, Regression Loss 1h: 331.8024, Segmentation Loss:0.0704
# Train Confusion Matrix:
# [[3147139   45133]
#  [  62300  585428]]
# Accuracy: 0.9720, CSI: 0.8449, Sensitivity: 0.9038, Specificity: 0.9859, False Alarm Ratio: 0.0716
#
#
# epoch duration : 69.54558753967285
# epoch n° 1423
# Training, Regression Loss: 0.0208, Regression Loss 1h: 338.5109, Segmentation Loss:0.0696
# Train Confusion Matrix:
# [[3163920   44320]
#  [  61209  570551]]
# Accuracy: 0.9725, CSI: 0.8439, Sensitivity: 0.9031, Specificity: 0.9862, False Alarm Ratio: 0.0721
#
#
# epoch duration : 69.99573945999146
# epoch n° 1424
# Training, Regression Loss: 0.0211, Regression Loss 1h: 328.9137, Segmentation Loss:0.0684
# Train Confusion Matrix:
# [[3152629   44019]
#  [  60649  582703]]
# Accuracy: 0.9727, CSI: 0.8477, Sensitivity: 0.9057, Specificity: 0.9862, False Alarm Ratio: 0.0702
#
#
# epoch duration : 71.50740051269531
# epoch n° 1425
# Training, Regression Loss: 0.0210, Regression Loss 1h: 336.9552, Segmentation Loss:0.0708
# Train Confusion Matrix:
# [[3160070   44626]
#  [  63554  571750]]
# Accuracy: 0.9718, CSI: 0.8409, Sensitivity: 0.9000, Specificity: 0.9861, False Alarm Ratio: 0.0724
#
#
# epoch duration : 70.54298043251038
# epoch n° 1426
# Training, Regression Loss: 0.0207, Regression Loss 1h: 328.7047, Segmentation Loss:0.0717
# Train Confusion Matrix:
# [[3151548   45694]
#  [  63597  579161]]
# Accuracy: 0.9715, CSI: 0.8413, Sensitivity: 0.9011, Specificity: 0.9857, False Alarm Ratio: 0.0731
#
#
# epoch duration : 71.15353012084961
# epoch n° 1427
# Training, Regression Loss: 0.0204, Regression Loss 1h: 333.9739, Segmentation Loss:0.0709
# Train Confusion Matrix:
# [[3157957   44695]
#  [  63191  574157]]
# Accuracy: 0.9719, CSI: 0.8418, Sensitivity: 0.9009, Specificity: 0.9860, False Alarm Ratio: 0.0722
#
#
# epoch duration : 71.28347492218018
# epoch n° 1428
# Training, Regression Loss: 0.0209, Regression Loss 1h: 335.1142, Segmentation Loss:0.0686
# Train Confusion Matrix:
# [[3152863   44277]
#  [  60679  582181]]
# Accuracy: 0.9727, CSI: 0.8473, Sensitivity: 0.9056, Specificity: 0.9862, False Alarm Ratio: 0.0707
#
#
# epoch duration : 70.94287991523743
# epoch n° 1429
# Training, Regression Loss: 0.0204, Regression Loss 1h: 336.7398, Segmentation Loss:0.0712
# Train Confusion Matrix:
# [[3160395   44436]
#  [  63872  571297]]
# Accuracy: 0.9718, CSI: 0.8406, Sensitivity: 0.8994, Specificity: 0.9861, False Alarm Ratio: 0.0722
#
#
# epoch duration : 70.61974453926086
# epoch n° 1430
# Training, Regression Loss: 0.0209, Regression Loss 1h: 330.6122, Segmentation Loss:0.0702
# Train Confusion Matrix:
# [[3148932   44162]
#  [  62023  584883]]
# Accuracy: 0.9723, CSI: 0.8463, Sensitivity: 0.9041, Specificity: 0.9862, False Alarm Ratio: 0.0702
#
#
# epoch duration : 68.7160975933075
# saving step
# epoch n° 1431
# Training, Regression Loss: 0.0214, Regression Loss 1h: 330.1819, Segmentation Loss:0.0718
# Train Confusion Matrix:
# [[3138477   45731]
#  [  63566  592226]]
# Accuracy: 0.9715, CSI: 0.8442, Sensitivity: 0.9031, Specificity: 0.9856, False Alarm Ratio: 0.0717
#
#
# epoch duration : 71.01483869552612
# epoch n° 1432
# Training, Regression Loss: 0.0206, Regression Loss 1h: 335.6650, Segmentation Loss:0.0733
# Train Confusion Matrix:
# [[3161121   45529]
#  [  65307  568043]]
# Accuracy: 0.9711, CSI: 0.8367, Sensitivity: 0.8969, Specificity: 0.9858, False Alarm Ratio: 0.0742
#
#
# epoch duration : 70.09612822532654
# epoch n° 1433
# Training, Regression Loss: 0.0206, Regression Loss 1h: 331.3858, Segmentation Loss:0.0709
# Train Confusion Matrix:
# [[3155911   45297]
#  [  62629  576163]]
# Accuracy: 0.9719, CSI: 0.8422, Sensitivity: 0.9020, Specificity: 0.9859, False Alarm Ratio: 0.0729
#
#
# epoch duration : 70.44113945960999
# epoch n° 1434
# Training, Regression Loss: 0.0214, Regression Loss 1h: 335.3569, Segmentation Loss:0.0709
# Train Confusion Matrix:
# [[3150141   45145]
#  [  62742  581972]]
# Accuracy: 0.9719, CSI: 0.8436, Sensitivity: 0.9027, Specificity: 0.9859, False Alarm Ratio: 0.0720
#
#
# epoch duration : 69.5053219795227
# epoch n° 1435
# Training, Regression Loss: 0.0213, Regression Loss 1h: 321.7844, Segmentation Loss:0.0690
# Train Confusion Matrix:
# [[3149563   44583]
#  [  60919  584935]]
# Accuracy: 0.9725, CSI: 0.8472, Sensitivity: 0.9057, Specificity: 0.9860, False Alarm Ratio: 0.0708
#
#
# epoch duration : 70.71073651313782
# epoch n° 1436
# Training, Regression Loss: 0.0209, Regression Loss 1h: 322.2484, Segmentation Loss:0.0721
# Train Confusion Matrix:
# [[3148111   45432]
#  [  64763  581694]]
# Accuracy: 0.9713, CSI: 0.8407, Sensitivity: 0.8998, Specificity: 0.9858, False Alarm Ratio: 0.0724
#
#
# epoch duration : 70.06899094581604
# epoch n° 1437
# Training, Regression Loss: 0.0213, Regression Loss 1h: 329.4650, Segmentation Loss:0.0701
# Train Confusion Matrix:
# [[3158486   44914]
#  [  62450  574150]]
# Accuracy: 0.9720, CSI: 0.8425, Sensitivity: 0.9019, Specificity: 0.9860, False Alarm Ratio: 0.0726
#
#
# epoch duration : 69.49558019638062
# epoch n° 1438
# Training, Regression Loss: 0.0206, Regression Loss 1h: 322.9209, Segmentation Loss:0.0694
# Train Confusion Matrix:
# [[3163713   43922]
#  [  61200  571165]]
# Accuracy: 0.9726, CSI: 0.8446, Sensitivity: 0.9032, Specificity: 0.9863, False Alarm Ratio: 0.0714
#
#
# epoch duration : 70.7501745223999
# epoch n° 1439
# Training, Regression Loss: 0.0208, Regression Loss 1h: 328.7877, Segmentation Loss:0.0708
# Train Confusion Matrix:
# [[3142657   45050]
#  [  62625  589668]]
# Accuracy: 0.9720, CSI: 0.8456, Sensitivity: 0.9040, Specificity: 0.9859, False Alarm Ratio: 0.0710
#
#
# epoch duration : 68.01768207550049
# epoch n° 1440
# Training, Regression Loss: 0.0208, Regression Loss 1h: 321.4929, Segmentation Loss:0.0705
# Train Confusion Matrix:
# [[3161383   45022]
#  [  62880  570715]]
# Accuracy: 0.9719, CSI: 0.8410, Sensitivity: 0.9008, Specificity: 0.9860, False Alarm Ratio: 0.0731
#
#
# epoch duration : 69.19619154930115
# saving step
# epoch n° 1441
# Training, Regression Loss: 0.0208, Regression Loss 1h: 327.4003, Segmentation Loss:0.0689
# Train Confusion Matrix:
# [[3152433   43999]
#  [  61072  582496]]
# Accuracy: 0.9726, CSI: 0.8472, Sensitivity: 0.9051, Specificity: 0.9862, False Alarm Ratio: 0.0702
#
#
# epoch duration : 69.83170175552368
# epoch n° 1442
# Training, Regression Loss: 0.0208, Regression Loss 1h: 332.9378, Segmentation Loss:0.0695
# Train Confusion Matrix:
# [[3149060   44875]
#  [  61400  584665]]
# Accuracy: 0.9723, CSI: 0.8462, Sensitivity: 0.9050, Specificity: 0.9859, False Alarm Ratio: 0.0713
#
#
# epoch duration : 71.07515168190002
# epoch n° 1443
# Training, Regression Loss: 0.0205, Regression Loss 1h: 336.4969, Segmentation Loss:0.0709
# Train Confusion Matrix:
# [[3157194   44650]
#  [  63280  574876]]
# Accuracy: 0.9719, CSI: 0.8419, Sensitivity: 0.9008, Specificity: 0.9861, False Alarm Ratio: 0.0721
#
#
# epoch duration : 69.55422306060791
# epoch n° 1444
# Training, Regression Loss: 0.0209, Regression Loss 1h: 343.6809, Segmentation Loss:0.0700
# Train Confusion Matrix:
# [[3160149   44427]
#  [  61850  573574]]
# Accuracy: 0.9723, CSI: 0.8437, Sensitivity: 0.9027, Specificity: 0.9861, False Alarm Ratio: 0.0719
#
#
# epoch duration : 68.55332374572754
# epoch n° 1445
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 46
#      42 optimizer.step()  # Update the weights
#      45 del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
# ---> 46 torch.cuda.empty_cache()
#      48 running_regression_loss += regression_loss
#      49 running_regression_loss_1h += regression_loss_1h
#
# File /opt/conda/lib/python3.10/site-packages/torch/cuda/memory.py:159, in empty_cache()
#     148 r"""Releases all unoccupied cached memory currently held by the caching
#     149 allocator so that those can be used in other GPU application and visible in
#     150 `nvidia-smi`.
#    (...)
#     156     more details about GPU memory management.
#     157 """
#     158 if is_initialized():
# --> 159     torch._C._cuda_emptyCache()
#
# KeyboardInterrupt:

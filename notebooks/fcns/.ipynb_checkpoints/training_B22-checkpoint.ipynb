# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B2 radar + gauges 1 min + cmls -> pluvios 1 min + cmls [xrlg1_yg1l]

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 1500
save_every = 1
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B2_xrlg1_yg1l.pt'
npairs = 40
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 20
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 + 60
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn(eval_segments=True)

# %%
# Boucle avec 5 modes d'évaluation
val_steps = ['eval_opportunity_cost_cml_spat',
             'eval_added_value_half_cml_spat',
             'eval_added_value_full_cml_spat',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
def segment_gt(images, pairs, filters, use_fcn=False, split=None, return_sampled_values_and_filters=False):
  """
  split : list of tuples (min link id, max link id + 1)) 
  """
    
  bs, nsteps, S, _ = images.shape
  _, nlinks, _, _ = filters.shape

  if split is None :
      filtered_images = images.unsqueeze(dim=2) * \
                    filters.unsqueeze(dim=1)     
      sampled_values = torch.sum(filtered_images,\
                        dim=(3,4))
      denom = torch.sum(filters.unsqueeze(dim=1),\
                        dim=(3,4))
      sampled_values /= denom 
      segment_measurements = torch.cat((pairs, sampled_values), dim=1)
        
    
      if not use_fcn:
        return segment_measurements, None
      else:
        sampled_values += 0.1
        filters = filters.unsqueeze(1) > 0
        filters = filters * sampled_values.view(bs, nsteps, nlinks, 1, 1)
        filters = filters.sum(dim=2)
        
      return segment_measurements, filters

  else :
      list_segments = []
      
      for (l0, l1) in split:
          partial_filters = filters[:,l0:l1,...]
          
          filtered_images = images.unsqueeze(dim=2) * \
                            partial_filters.unsqueeze(dim=1)     
          sampled_values = torch.sum(filtered_images,\
                            dim=(3,4))
          denom = torch.sum(partial_filters.unsqueeze(dim=1),\
                            dim=(3,4))
          sampled_values /= denom 
          segment_measurements = torch.cat((pairs[:,:,l0:l1], sampled_values), dim=1)
            
        
          if not use_fcn:
              if return_sampled_values_and_filters:
                list_segments.append((segment_measurements, None, sampled_values, partial_filters))
              else:
                list_segments.append((segment_measurements, None))
          else:
            sampled_values += 0.1
            link_inputs = partial_filters.unsqueeze(1) > 0 
            link_inputs = link_inputs * sampled_values.view(bs, nsteps, l1 - l0, 1, 1)
            link_inputs = link_inputs.sum(dim=2)

            if return_sampled_values_and_filters:
                list_segments.append((segment_measurements, link_inputs, sampled_values, partial_filters))
            else:
                list_segments.append((segment_measurements, link_inputs))
                
      return list_segments

# %%
import torch.nn as nn
from sklearn.metrics import confusion_matrix


class QPELoss_fcn(nn.Module):
    def __init__(self, eval_qpe_1h = False, eval_independent_qpe_1h=False, eval_segments=False):
        super(QPELoss_fcn, self).__init__()
        self.regression_loss = nn.MSELoss()
        self.segmentation_loss = nn.CrossEntropyLoss()
        self.eval_qpe_1h = eval_qpe_1h
        self.eval_independent_qpe_1h = eval_independent_qpe_1h
        self.eval_segments = eval_segments

    def forward(self, p, outputs, targets, sampled_values_and_filters=None):

      # sans supervision imparfaite, avec spatialisation
      bs, nsteps, S, _ = targets.shape
      targets = targets.view(bs, 1, nsteps, S**2)
      mask = (targets>=0)
      masked_targets = targets[mask]
      outputs_rnr0 = outputs[:, :nsteps, ...].view(bs, 1, nsteps, S**2)
      outputs_rnr1 = outputs[:, nsteps:2*nsteps, ...].view(bs, 1, nsteps, S**2)
      masked_outputs_rnr = torch.cat([outputs_rnr0[mask].view(bs, 1, -1), outputs_rnr1[mask].view(bs, 1, -1)], dim=1)
      masked_targets_rnr =  (masked_targets > 0).long().view(bs, -1)
      outputs_qpe = outputs[:, 2*nsteps:3*nsteps , ...]\
                                .view(bs, 1, nsteps, S**2)

      masked_outputs_qpe = outputs_qpe[mask][masked_targets > 0]
      masked_targets_qpe = masked_targets[masked_targets > 0]

      loss_rnr = self.segmentation_loss(masked_outputs_rnr, masked_targets_rnr)
      loss_qpe_1min = self.regression_loss(masked_outputs_qpe, masked_targets_qpe)
      loss = 1/(2*p[0]**2) * loss_qpe_1min + 1/(2*p[1]**2) * loss_rnr
      

      if self.eval_qpe_1h:
        loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])
        loss += 1/(2*p[2]**2) * loss_qpe_1h

      elif self.eval_independent_qpe_1h:
        outputs_qpe_1h = outputs[:, 3*nsteps, ...]\
                                .view(bs, 1, S**2)
          
        loss_qpe_1h = self.regression_loss(outputs_qpe_1h[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])   
        loss += 1/(2*p[2]**2) * loss_qpe_1h
      else:
        with torch.no_grad():
            loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                               targets.sum(dim=2)[mask[:, :, 0, ...]])
          
          
      if self.eval_segments:
          sampled_values, filters = sampled_values_and_filters
          #Pas très joli : on aurait aimé appler outputs_QPE, mais il a été applati
          filtered_outputs = outputs[:, 2*nsteps:3*nsteps , ...].unsqueeze(dim=2) * \
                             filters.unsqueeze(dim=1)
          sampled_pred_values = torch.sum(filtered_outputs,\
                            dim=(3,4))
          loss_segments = self.regression_loss(sampled_pred_values, sampled_values)
          loss += 1/(2*p[3]**2) * loss_segments
      else:
          loss_segments = 0.

      loss += torch.log(1 + p[0]**2 + p[1]**2 + self.eval_qpe_1h * p[2]**2 + self.eval_independent_qpe_1h * p[2]**2 + self.eval_segments * p[3]**2)


      with torch.no_grad():
        preds = masked_outputs_rnr.argmax(dim=1).flatten().cpu().numpy()
        targets = masked_targets_rnr.flatten().cpu().numpy()
        # Compute the confusion matrix
        cm = confusion_matrix(targets, preds, labels=np.arange(2))

      if self.eval_segments:
          return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr.item(), loss, cm, loss_segments.item()
      else:
          return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr.item(), loss, cm, loss_segments

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 0

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}
  running_integ_loss = {step:0.0 for step in steps}
    
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    
    #Validation steps
    model.eval()
    with torch.no_grad():
      # splitting rain gauges
      ng_val_inputs_full = npoints//2
      ng_val_targets = npoints//2
      splitg_val = [ng_val_inputs_full, ng_val_targets]
      point_measurements_fcn_val_full, point_measurements_fcn_val_targets = point_gt(images, npoints=npoints,
                                                                                      use_fcn=use_fcn,
                                                                                      split=splitg_val)
        
      _, point_measurements_fcn_val_full, _ = point_measurements_fcn_val_full
      _, point_measurements_fcn_val_targets, _ = point_measurements_fcn_val_targets


      # 4 first val steps 
      # segment_measurements = segment_gt(images, pairs, filters)
      splitl_val = [(0,5),(0,10),(0,20),(20,40)]
      segment_measurements_fcn_val_few, segment_measurements_fcn_val_half, segment_measurements_fcn_val_full, sampled_values_and_filters_val_targets \
              = segment_gt(images, pairs, filters, use_fcn=use_fcn, split=splitl_val, return_sampled_values_and_filters=True)
      
      _, segment_measurements_fcn_val_few, _, _ = segment_measurements_fcn_val_few # 5 cmls
      _, segment_measurements_fcn_val_half, _, _ = segment_measurements_fcn_val_half # 10 cmls 
      _, segment_measurements_fcn_val_full, _, _ = segment_measurements_fcn_val_full # 20 cmls 
      sampled_values_and_filters_val_targets = sampled_values_and_filters_val_targets[2:]  #20 cmls
        
      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_cml_spat'

      inputs = torch.cat([noisy_images,
                          0*segment_measurements_fcn_val_half,
                          point_measurements_fcn_val_full
                          ], dim=1)
      outputs = model(inputs)

      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
              criterion(model.p, outputs, point_measurements_fcn_val_targets, sampled_values_and_filters=sampled_values_and_filters_val_targets)
                        
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss
        
      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()

      # val step 2 : eval_added_value_few_spat
      # step = 'eval_added_value_few_cml_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn_val_few,
      #                     point_measurements_fcn_val_full
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
      #         criterion(model.p, outputs, point_measurements_fcn_val_targets, sampled_values_and_filters=sampled_values_and_filters_val_targets)
              
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm
      # running_integ_loss[step] += integ_loss
        
      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_few
      # torch.cuda.empty_cache()

      # val step 3 : eval_added_value_half_spat
      step = 'eval_added_value_half_cml_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn_val_half,
                          point_measurements_fcn_val_full
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
      criterion(model.p, outputs, point_measurements_fcn_val_targets, sampled_values_and_filters=sampled_values_and_filters_val_targets)   
      
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_half
      torch.cuda.empty_cache()

      # val step 4 : eval_added_value_full_spat
      step = 'eval_added_value_full_cml_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn_val_full,
                          point_measurements_fcn_val_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
              criterion(model.p, outputs, point_measurements_fcn_val_targets, sampled_values_and_filters=sampled_values_and_filters_val_targets)  
              
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_full, point_measurements_fcn_val_targets
      torch.cuda.empty_cache()

      # last val step, on the 10 first pluvios : eval_added_value_full_id
      # step = 'eval_added_value_full_id'
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = criterion(model.p, outputs, None,
      #                                                                                                segments=segment_measurements_fcn_eval_full) 
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm
      # running_integ_loss[step] += integ_loss

      # del outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, point_measurements_fcn_val_full, segment_measurements_fcn_val_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    ng_train_inputs = torch.randint(0,9,(1,))
    ng_train_targets = npoints // 2 - ng_train_inputs
    nl_train_inputs = torch.randint(0,19,(1,))
    nl_train_targets = npairs - nl_train_inputs
      
    # split train gauges
    splitg_train = [ng_train_inputs, ng_train_targets]
    point_measurements_fcn_train_inputs, point_measurements_fcn_train_targets = point_gt(images, npoints=npoints,
                                                                                           use_fcn=use_fcn,
                                                                                           split=splitg_train)
    _, point_measurements_fcn_train_inputs, _ = point_measurements_fcn_train_inputs
    _, point_measurements_fcn_train_targets, _ = point_measurements_fcn_train_targets

    # split train cmls
    splitl_train = [(0, nl_train_inputs), (nl_train_inputs, 20)]
    segment_measurements_fcn_train_inputs, sampled_values_and_filters_train_targets \
          = segment_gt(images, pairs, filters, use_fcn=use_fcn, split=splitl_train, return_sampled_values_and_filters=True)
  
    _, segment_measurements_fcn_train_inputs, _, _ = segment_measurements_fcn_train_inputs
    sampled_values_and_filters_train_targets = sampled_values_and_filters_train_targets[2:]


      
    inputs = torch.cat([noisy_images,
                        segment_measurements_fcn_train_inputs,
                        point_measurements_fcn_train_inputs
                        ], dim=1)


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = criterion(model.p, outputs, 
                                                                                                   point_measurements_fcn_train_targets,
                                                                                                   sampled_values_and_filters=sampled_values_and_filters_train_targets)

    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm
    running_integ_loss[step] += integ_loss

    del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, point_measurements_fcn_train_inputs, \
        point_measurements_fcn_train_targets, segment_measurements_fcn_train_inputs, sampled_values_and_filters_train_targets
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      integ_loss = running_integ_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step], integ_loss))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print(f'Integ Loss: {integ_loss:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 0
#
# epoch duration : 98.00024628639221
# saving step
# epoch n° 1
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4406, Regression Loss 1h: 83.6408, Segmentation Loss:0.4089
# Train Confusion Matrix:
# [[3196929      20]
#  [ 642878     173]]
# Accuracy: 0.8326, CSI: 0.0003, Sensitivity: 0.0003, Specificity: 1.0000, False Alarm Ratio: 0.1036
# Integ Loss: 0.0634
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4384, Regression Loss 1h: 82.1547, Segmentation Loss:0.4105
# Train Confusion Matrix:
# [[3165354   31595]
#  [ 610100   32951]]
# Accuracy: 0.8329, CSI: 0.0488, Sensitivity: 0.0512, Specificity: 0.9901, False Alarm Ratio: 0.4895
# Integ Loss: 0.0751
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4358, Regression Loss 1h: 80.4252, Segmentation Loss:0.4260
# Train Confusion Matrix:
# [[3115080   81869]
#  [ 575967   67084]]
# Accuracy: 0.8287, CSI: 0.0925, Sensitivity: 0.1043, Specificity: 0.9744, False Alarm Ratio: 0.5496
# Integ Loss: 0.1055
#
#
# train, Regression Loss: 0.4338, Regression Loss 1h: 80.7935, Segmentation Loss:0.4081
# Train Confusion Matrix:
# [[1943046   15657]
#  [ 376442   18775]]
# Accuracy: 0.8334, CSI: 0.0457, Sensitivity: 0.0475, Specificity: 0.9920, False Alarm Ratio: 0.4547
# Integ Loss: 0.0749
#
#
# epoch duration : 96.35695743560791
# saving step
# epoch n° 2
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4320, Regression Loss 1h: 81.1310, Segmentation Loss:0.3575
# Train Confusion Matrix:
# [[3176430   18928]
#  [ 582699   61943]]
# Accuracy: 0.8433, CSI: 0.0933, Sensitivity: 0.0961, Specificity: 0.9941, False Alarm Ratio: 0.2341
# Integ Loss: 0.0593
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4314, Regression Loss 1h: 80.1901, Segmentation Loss:0.3707
# Train Confusion Matrix:
# [[3149781   45577]
#  [ 565187   79455]]
# Accuracy: 0.8409, CSI: 0.1151, Sensitivity: 0.1233, Specificity: 0.9857, False Alarm Ratio: 0.3645
# Integ Loss: 0.0638
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4303, Regression Loss 1h: 79.0963, Segmentation Loss:0.3907
# Train Confusion Matrix:
# [[3102562   92796]
#  [ 539895  104747]]
# Accuracy: 0.8352, CSI: 0.1420, Sensitivity: 0.1625, Specificity: 0.9710, False Alarm Ratio: 0.4698
# Integ Loss: 0.0821
#
#
# train, Regression Loss: 0.4322, Regression Loss 1h: 80.0453, Segmentation Loss:0.3692
# Train Confusion Matrix:
# [[1996461   28725]
#  [ 358616   50758]]
# Accuracy: 0.8409, CSI: 0.1159, Sensitivity: 0.1240, Specificity: 0.9858, False Alarm Ratio: 0.3614
# Integ Loss: 0.0629
#
#
# epoch duration : 97.38172698020935
# saving step
# epoch n° 3
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4375, Regression Loss 1h: 86.2633, Segmentation Loss:0.3288
# Train Confusion Matrix:
# [[3128776   62644]
#  [ 464425  184155]]
# Accuracy: 0.8627, CSI: 0.2589, Sensitivity: 0.2839, Specificity: 0.9804, False Alarm Ratio: 0.2538
# Integ Loss: 0.0564
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4371, Regression Loss 1h: 85.3981, Segmentation Loss:0.3416
# Train Confusion Matrix:
# [[3102963   88457]
#  [ 461333  187247]]
# Accuracy: 0.8568, CSI: 0.2541, Sensitivity: 0.2887, Specificity: 0.9723, False Alarm Ratio: 0.3208
# Integ Loss: 0.0661
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4362, Regression Loss 1h: 84.4421, Segmentation Loss:0.3604
# Train Confusion Matrix:
# [[3054218  137202]
#  [ 449780  198800]]
# Accuracy: 0.8471, CSI: 0.2530, Sensitivity: 0.3065, Specificity: 0.9570, False Alarm Ratio: 0.4083
# Integ Loss: 0.0901
#
#
# train, Regression Loss: 0.4391, Regression Loss 1h: 84.2289, Segmentation Loss:0.3376
# Train Confusion Matrix:
# [[1938912   56959]
#  [ 281683  118606]]
# Accuracy: 0.8587, CSI: 0.2594, Sensitivity: 0.2963, Specificity: 0.9715, False Alarm Ratio: 0.3244
# Integ Loss: 0.0656
#
#
# epoch duration : 96.97135281562805
# saving step
# epoch n° 4
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4374, Regression Loss 1h: 84.6192, Segmentation Loss:0.3096
# Train Confusion Matrix:
# [[3133407   63618]
#  [ 396280  246695]]
# Accuracy: 0.8802, CSI: 0.3491, Sensitivity: 0.3837, Specificity: 0.9801, False Alarm Ratio: 0.2050
# Integ Loss: 0.0529
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4376, Regression Loss 1h: 84.0778, Segmentation Loss:0.3207
# Train Confusion Matrix:
# [[3103501   93524]
#  [ 397900  245075]]
# Accuracy: 0.8720, CSI: 0.3328, Sensitivity: 0.3812, Specificity: 0.9707, False Alarm Ratio: 0.2762
# Integ Loss: 0.0639
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4373, Regression Loss 1h: 83.4984, Segmentation Loss:0.3367
# Train Confusion Matrix:
# [[3059866  137159]
#  [ 392207  250768]]
# Accuracy: 0.8621, CSI: 0.3214, Sensitivity: 0.3900, Specificity: 0.9571, False Alarm Ratio: 0.3536
# Integ Loss: 0.0868
#
#
# train, Regression Loss: 0.4352, Regression Loss 1h: 84.0340, Segmentation Loss:0.3194
# Train Confusion Matrix:
# [[2030281   67452]
#  [ 256526  164781]]
# Accuracy: 0.8714, CSI: 0.3371, Sensitivity: 0.3911, Specificity: 0.9678, False Alarm Ratio: 0.2904
# Integ Loss: 0.0636
#
#
# epoch duration : 96.65956473350525
# saving step
# epoch n° 5
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4263, Regression Loss 1h: 82.7603, Segmentation Loss:0.2814
# Train Confusion Matrix:
# [[3121974   78612]
#  [ 321651  317763]]
# Accuracy: 0.8958, CSI: 0.4426, Sensitivity: 0.4970, Specificity: 0.9754, False Alarm Ratio: 0.1983
# Integ Loss: 0.0507
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4260, Regression Loss 1h: 82.2131, Segmentation Loss:0.2914
# Train Confusion Matrix:
# [[3105249   95337]
#  [ 335720  303694]]
# Accuracy: 0.8877, CSI: 0.4133, Sensitivity: 0.4750, Specificity: 0.9702, False Alarm Ratio: 0.2389
# Integ Loss: 0.0624
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4254, Regression Loss 1h: 81.6608, Segmentation Loss:0.3029
# Train Confusion Matrix:
# [[3082356  118230]
#  [ 341649  297765]]
# Accuracy: 0.8802, CSI: 0.3930, Sensitivity: 0.4657, Specificity: 0.9631, False Alarm Ratio: 0.2842
# Integ Loss: 0.0852
#
#
# train, Regression Loss: 0.4273, Regression Loss 1h: 82.6714, Segmentation Loss:0.2888
# Train Confusion Matrix:
# [[2009750   66340]
#  [ 211862  204208]]
# Accuracy: 0.8884, CSI: 0.4233, Sensitivity: 0.4908, Specificity: 0.9680, False Alarm Ratio: 0.2452
# Integ Loss: 0.0600
#
#
# epoch duration : 96.9409728050232
# saving step
# epoch n° 6
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4246, Regression Loss 1h: 83.1535, Segmentation Loss:0.2618
# Train Confusion Matrix:
# [[3110653   86561]
#  [ 276820  365966]]
# Accuracy: 0.9054, CSI: 0.5018, Sensitivity: 0.5693, Specificity: 0.9729, False Alarm Ratio: 0.1913
# Integ Loss: 0.0517
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4244, Regression Loss 1h: 82.8748, Segmentation Loss:0.2680
# Train Confusion Matrix:
# [[3096089  101125]
#  [ 281670  361116]]
# Accuracy: 0.9003, CSI: 0.4854, Sensitivity: 0.5618, Specificity: 0.9684, False Alarm Ratio: 0.2188
# Integ Loss: 0.0596
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4237, Regression Loss 1h: 82.4973, Segmentation Loss:0.2775
# Train Confusion Matrix:
# [[3077661  119553]
#  [ 285494  357292]]
# Accuracy: 0.8945, CSI: 0.4687, Sensitivity: 0.5558, Specificity: 0.9626, False Alarm Ratio: 0.2507
# Integ Loss: 0.0766
#
#
# train, Regression Loss: 0.4251, Regression Loss 1h: 83.6003, Segmentation Loss:0.2649
# Train Confusion Matrix:
# [[1836513   62886]
#  [ 163270  218291]]
# Accuracy: 0.9009, CSI: 0.4912, Sensitivity: 0.5721, Specificity: 0.9669, False Alarm Ratio: 0.2237
# Integ Loss: 0.0550
#
#
# epoch duration : 98.47921705245972
# saving step
# epoch n° 7
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4254, Regression Loss 1h: 79.4858, Segmentation Loss:0.2562
# Train Confusion Matrix:
# [[3126174   79308]
#  [ 270567  363951]]
# Accuracy: 0.9089, CSI: 0.5099, Sensitivity: 0.5736, Specificity: 0.9753, False Alarm Ratio: 0.1789
# Integ Loss: 0.0517
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4253, Regression Loss 1h: 79.2426, Segmentation Loss:0.2596
# Train Confusion Matrix:
# [[3110943   94539]
#  [ 267988  366530]]
# Accuracy: 0.9056, CSI: 0.5027, Sensitivity: 0.5777, Specificity: 0.9705, False Alarm Ratio: 0.2050
# Integ Loss: 0.0578
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4248, Regression Loss 1h: 78.9542, Segmentation Loss:0.2660
# Train Confusion Matrix:
# [[3091543  113939]
#  [ 265241  369277]]
# Accuracy: 0.9013, CSI: 0.4934, Sensitivity: 0.5820, Specificity: 0.9645, False Alarm Ratio: 0.2358
# Integ Loss: 0.0719
#
#
# train, Regression Loss: 0.4243, Regression Loss 1h: 79.6235, Segmentation Loss:0.2592
# Train Confusion Matrix:
# [[1919839   60636]
#  [ 164838  227807]]
# Accuracy: 0.9050, CSI: 0.5026, Sensitivity: 0.5802, Specificity: 0.9694, False Alarm Ratio: 0.2102
# Integ Loss: 0.0562
#
#
# epoch duration : 99.53195786476135
# saving step
# epoch n° 8
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4221, Regression Loss 1h: 81.6469, Segmentation Loss:0.2426
# Train Confusion Matrix:
# [[3109231   88651]
#  [ 243541  398577]]
# Accuracy: 0.9135, CSI: 0.5454, Sensitivity: 0.6207, Specificity: 0.9723, False Alarm Ratio: 0.1819
# Integ Loss: 0.0667
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4214, Regression Loss 1h: 81.4227, Segmentation Loss:0.2426
# Train Confusion Matrix:
# [[3100811   97071]
#  [ 239966  402152]]
# Accuracy: 0.9122, CSI: 0.5440, Sensitivity: 0.6263, Specificity: 0.9696, False Alarm Ratio: 0.1944
# Integ Loss: 0.0633
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4207, Regression Loss 1h: 81.1259, Segmentation Loss:0.2453
# Train Confusion Matrix:
# [[3088618  109264]
#  [ 236687  405431]]
# Accuracy: 0.9099, CSI: 0.5396, Sensitivity: 0.6314, Specificity: 0.9658, False Alarm Ratio: 0.2123
# Integ Loss: 0.0688
#
#
# train, Regression Loss: 0.4213, Regression Loss 1h: 80.8543, Segmentation Loss:0.2398
# Train Confusion Matrix:
# [[1815487   57166]
#  [ 142264  235323]]
# Accuracy: 0.9114, CSI: 0.5413, Sensitivity: 0.6232, Specificity: 0.9695, False Alarm Ratio: 0.1954
# Integ Loss: 0.0562
#
#
# epoch duration : 99.17216062545776
# saving step
# epoch n° 9
#
# eval_opportunity_cost_cml_spat, Regression Loss: 1.5027, Regression Loss 1h: 255.1930, Segmentation Loss:0.5981
# Train Confusion Matrix:
# [[3077206  119158]
#  [ 277765  365871]]
# Accuracy: 0.8966, CSI: 0.4796, Sensitivity: 0.5684, Specificity: 0.9627, False Alarm Ratio: 0.2457
# Integ Loss: 24.2663
#
#
# eval_added_value_half_cml_spat, Regression Loss: 5.5308, Regression Loss 1h: 584.8139, Segmentation Loss:0.7107
# Train Confusion Matrix:
# [[3059362  137002]
#  [ 276905  366731]]
# Accuracy: 0.8922, CSI: 0.4698, Sensitivity: 0.5698, Specificity: 0.9571, False Alarm Ratio: 0.2720
# Integ Loss: 107.7555
#
#
# eval_added_value_full_cml_spat, Regression Loss: 13.4258, Regression Loss 1h: 991.1696, Segmentation Loss:0.8295
# Train Confusion Matrix:
# [[3038302  158062]
#  [ 274976  368660]]
# Accuracy: 0.8872, CSI: 0.4598, Sensitivity: 0.5728, Specificity: 0.9505, False Alarm Ratio: 0.3001
# Integ Loss: 153.6462
#
#
# train, Regression Loss: 0.4301, Regression Loss 1h: 82.5477, Segmentation Loss:0.2616
# Train Confusion Matrix:
# [[1836376   51507]
#  [ 161107  216610]]
# Accuracy: 0.9062, CSI: 0.5047, Sensitivity: 0.5735, Specificity: 0.9727, False Alarm Ratio: 0.1921
# Integ Loss: 0.1064
#
#
# epoch duration : 98.72531628608704
# saving step
# epoch n° 11
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4278, Regression Loss 1h: 82.8548, Segmentation Loss:0.2309
# Train Confusion Matrix:
# [[3123523   77449]
#  [ 240273  398755]]
# Accuracy: 0.9173, CSI: 0.5565, Sensitivity: 0.6240, Specificity: 0.9758, False Alarm Ratio: 0.1626
# Integ Loss: 0.0397
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4338, Regression Loss 1h: 83.4084, Segmentation Loss:0.2338
# Train Confusion Matrix:
# [[3113178   87794]
#  [ 235239  403789]]
# Accuracy: 0.9159, CSI: 0.5556, Sensitivity: 0.6319, Specificity: 0.9726, False Alarm Ratio: 0.1786
# Integ Loss: 0.0437
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4436, Regression Loss 1h: 84.2423, Segmentation Loss:0.2382
# Train Confusion Matrix:
# [[3100525  100447]
#  [ 230873  408155]]
# Accuracy: 0.9137, CSI: 0.5520, Sensitivity: 0.6387, Specificity: 0.9686, False Alarm Ratio: 0.1975
# Integ Loss: 0.0580
#
#
# train, Regression Loss: 0.4368, Regression Loss 1h: 86.6875, Segmentation Loss:0.2303
# Train Confusion Matrix:
# [[1954812   56921]
#  [ 145431  262036]]
# Accuracy: 0.9164, CSI: 0.5643, Sensitivity: 0.6431, Specificity: 0.9717, False Alarm Ratio: 0.1785
# Integ Loss: 0.0410
#
#
# epoch duration : 99.14400267601013
# saving step
# epoch n° 12
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4206, Regression Loss 1h: 79.8027, Segmentation Loss:0.2167
# Train Confusion Matrix:
# [[3115871   86760]
#  [ 203381  433988]]
# Accuracy: 0.9244, CSI: 0.5993, Sensitivity: 0.6809, Specificity: 0.9729, False Alarm Ratio: 0.1666
# Integ Loss: 0.0363
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4199, Regression Loss 1h: 79.6554, Segmentation Loss:0.2162
# Train Confusion Matrix:
# [[3110956   91675]
#  [ 200144  437225]]
# Accuracy: 0.9240, CSI: 0.5997, Sensitivity: 0.6860, Specificity: 0.9714, False Alarm Ratio: 0.1733
# Integ Loss: 0.0362
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4191, Regression Loss 1h: 79.4843, Segmentation Loss:0.2167
# Train Confusion Matrix:
# [[3104063   98568]
#  [ 196796  440573]]
# Accuracy: 0.9231, CSI: 0.5987, Sensitivity: 0.6912, Specificity: 0.9692, False Alarm Ratio: 0.1828
# Integ Loss: 0.0372
#
#
# train, Regression Loss: 0.4125, Regression Loss 1h: 78.8705, Segmentation Loss:0.2149
# Train Confusion Matrix:
# [[1787438   51221]
#  [ 115588  249913]]
# Accuracy: 0.9243, CSI: 0.5997, Sensitivity: 0.6838, Specificity: 0.9721, False Alarm Ratio: 0.1701
# Integ Loss: 0.0366
#
#
# epoch duration : 99.78036713600159
# saving step
# epoch n° 13
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4238, Regression Loss 1h: 82.4460, Segmentation Loss:0.2259
# Train Confusion Matrix:
# [[3110662   81510]
#  [ 215306  432522]]
# Accuracy: 0.9227, CSI: 0.5930, Sensitivity: 0.6676, Specificity: 0.9745, False Alarm Ratio: 0.1586
# Integ Loss: 0.0347
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4228, Regression Loss 1h: 82.2148, Segmentation Loss:0.2236
# Train Confusion Matrix:
# [[3104300   87872]
#  [ 209593  438235]]
# Accuracy: 0.9225, CSI: 0.5957, Sensitivity: 0.6765, Specificity: 0.9725, False Alarm Ratio: 0.1670
# Integ Loss: 0.0345
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4219, Regression Loss 1h: 82.0430, Segmentation Loss:0.2228
# Train Confusion Matrix:
# [[3095113   97059]
#  [ 203413  444415]]
# Accuracy: 0.9218, CSI: 0.5966, Sensitivity: 0.6860, Specificity: 0.9696, False Alarm Ratio: 0.1792
# Integ Loss: 0.0352
#
#
# train, Regression Loss: 0.4224, Regression Loss 1h: 80.7690, Segmentation Loss:0.2204
# Train Confusion Matrix:
# [[1978336   56610]
#  [ 132449  278685]]
# Accuracy: 0.9227, CSI: 0.5958, Sensitivity: 0.6778, Specificity: 0.9722, False Alarm Ratio: 0.1688
# Integ Loss: 0.0342
#
#
# epoch duration : 99.11780786514282
# saving step
# epoch n° 14
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4197, Regression Loss 1h: 80.9988, Segmentation Loss:0.2180
# Train Confusion Matrix:
# [[3109362   90068]
#  [ 196634  443936]]
# Accuracy: 0.9253, CSI: 0.6076, Sensitivity: 0.6930, Specificity: 0.9718, False Alarm Ratio: 0.1687
# Integ Loss: 0.0352
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4184, Regression Loss 1h: 80.7666, Segmentation Loss:0.2151
# Train Confusion Matrix:
# [[3104883   94547]
#  [ 191330  449240]]
# Accuracy: 0.9256, CSI: 0.6111, Sensitivity: 0.7013, Specificity: 0.9704, False Alarm Ratio: 0.1739
# Integ Loss: 0.0346
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4171, Regression Loss 1h: 80.5202, Segmentation Loss:0.2137
# Train Confusion Matrix:
# [[3097864  101566]
#  [ 185878  454692]]
# Accuracy: 0.9251, CSI: 0.6127, Sensitivity: 0.7098, Specificity: 0.9683, False Alarm Ratio: 0.1826
# Integ Loss: 0.0348
#
#
# train, Regression Loss: 0.4187, Regression Loss 1h: 82.1130, Segmentation Loss:0.2119
# Train Confusion Matrix:
# [[1953222   53530]
#  [ 125219  279549]]
# Accuracy: 0.9259, CSI: 0.6100, Sensitivity: 0.6906, Specificity: 0.9733, False Alarm Ratio: 0.1607
# Integ Loss: 0.0341
#
#
# epoch duration : 98.54570698738098
# saving step
# epoch n° 15
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4184, Regression Loss 1h: 81.8678, Segmentation Loss:0.2187
# Train Confusion Matrix:
# [[3119706   77701]
#  [ 205791  436802]]
# Accuracy: 0.9262, CSI: 0.6064, Sensitivity: 0.6797, Specificity: 0.9757, False Alarm Ratio: 0.1510
# Integ Loss: 0.0340
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4171, Regression Loss 1h: 81.5658, Segmentation Loss:0.2148
# Train Confusion Matrix:
# [[3113436   83971]
#  [ 198823  443770]]
# Accuracy: 0.9264, CSI: 0.6108, Sensitivity: 0.6906, Specificity: 0.9737, False Alarm Ratio: 0.1591
# Integ Loss: 0.0333
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4155, Regression Loss 1h: 81.1889, Segmentation Loss:0.2132
# Train Confusion Matrix:
# [[3104291   93116]
#  [ 191925  450668]]
# Accuracy: 0.9258, CSI: 0.6126, Sensitivity: 0.7013, Specificity: 0.9709, False Alarm Ratio: 0.1712
# Integ Loss: 0.0336
#
#
# train, Regression Loss: 0.4149, Regression Loss 1h: 81.4746, Segmentation Loss:0.2165
# Train Confusion Matrix:
# [[1830599   49233]
#  [ 120854  264914]]
# Accuracy: 0.9249, CSI: 0.6090, Sensitivity: 0.6867, Specificity: 0.9738, False Alarm Ratio: 0.1567
# Integ Loss: 0.0331
#
#
# epoch duration : 99.42299389839172
# saving step
# epoch n° 16
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4256, Regression Loss 1h: 84.5629, Segmentation Loss:0.2098
# Train Confusion Matrix:
# [[3107875   85801]
#  [ 187707  458617]]
# Accuracy: 0.9288, CSI: 0.6264, Sensitivity: 0.7096, Specificity: 0.9731, False Alarm Ratio: 0.1576
# Integ Loss: 0.0343
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4241, Regression Loss 1h: 84.1949, Segmentation Loss:0.2058
# Train Confusion Matrix:
# [[3102973   90703]
#  [ 182148  464176]]
# Accuracy: 0.9289, CSI: 0.6298, Sensitivity: 0.7182, Specificity: 0.9716, False Alarm Ratio: 0.1635
# Integ Loss: 0.0335
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4225, Regression Loss 1h: 83.7614, Segmentation Loss:0.2041
# Train Confusion Matrix:
# [[3095211   98465]
#  [ 175915  470409]]
# Accuracy: 0.9285, CSI: 0.6316, Sensitivity: 0.7278, Specificity: 0.9692, False Alarm Ratio: 0.1731
# Integ Loss: 0.0337
#
#
# train, Regression Loss: 0.4171, Regression Loss 1h: 80.8059, Segmentation Loss:0.2050
# Train Confusion Matrix:
# [[1880169   52351]
#  [ 113325  273515]]
# Accuracy: 0.9286, CSI: 0.6228, Sensitivity: 0.7070, Specificity: 0.9729, False Alarm Ratio: 0.1607
# Integ Loss: 0.0330
#
#
# epoch duration : 98.787517786026
# saving step
# epoch n° 17
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4218, Regression Loss 1h: 81.6062, Segmentation Loss:0.2114
# Train Confusion Matrix:
# [[3118246   87529]
#  [ 186066  448159]]
# Accuracy: 0.9288, CSI: 0.6209, Sensitivity: 0.7066, Specificity: 0.9727, False Alarm Ratio: 0.1634
# Integ Loss: 0.0345
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4204, Regression Loss 1h: 81.3150, Segmentation Loss:0.2067
# Train Confusion Matrix:
# [[3115855   89920]
#  [ 182401  451824]]
# Accuracy: 0.9291, CSI: 0.6239, Sensitivity: 0.7124, Specificity: 0.9720, False Alarm Ratio: 0.1660
# Integ Loss: 0.0335
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4188, Regression Loss 1h: 80.9617, Segmentation Loss:0.2043
# Train Confusion Matrix:
# [[3110185   95590]
#  [ 178079  456146]]
# Accuracy: 0.9287, CSI: 0.6250, Sensitivity: 0.7192, Specificity: 0.9702, False Alarm Ratio: 0.1733
# Integ Loss: 0.0335
#
#
# train, Regression Loss: 0.4194, Regression Loss 1h: 81.7661, Segmentation Loss:0.2057
# Train Confusion Matrix:
# [[1777526   48962]
#  [ 106862  255450]]
# Accuracy: 0.9288, CSI: 0.6211, Sensitivity: 0.7051, Specificity: 0.9732, False Alarm Ratio: 0.1608
# Integ Loss: 0.0329
#
#
# epoch duration : 98.88908863067627
# saving step
# epoch n° 18
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4297, Regression Loss 1h: 85.2417, Segmentation Loss:0.2083
# Train Confusion Matrix:
# [[3112203   85276]
#  [ 184642  457879]]
# Accuracy: 0.9297, CSI: 0.6291, Sensitivity: 0.7126, Specificity: 0.9733, False Alarm Ratio: 0.1570
# Integ Loss: 0.0351
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4281, Regression Loss 1h: 84.8831, Segmentation Loss:0.2036
# Train Confusion Matrix:
# [[3108726   88753]
#  [ 179952  462569]]
# Accuracy: 0.9300, CSI: 0.6326, Sensitivity: 0.7199, Specificity: 0.9722, False Alarm Ratio: 0.1610
# Integ Loss: 0.0339
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4262, Regression Loss 1h: 84.4444, Segmentation Loss:0.2012
# Train Confusion Matrix:
# [[3101885   95594]
#  [ 174460  468061]]
# Accuracy: 0.9297, CSI: 0.6341, Sensitivity: 0.7285, Specificity: 0.9701, False Alarm Ratio: 0.1696
# Integ Loss: 0.0340
#
#
# train, Regression Loss: 0.4243, Regression Loss 1h: 83.2247, Segmentation Loss:0.1998
# Train Confusion Matrix:
# [[1821779   50864]
#  [ 104407  269350]]
# Accuracy: 0.9309, CSI: 0.6343, Sensitivity: 0.7207, Specificity: 0.9728, False Alarm Ratio: 0.1588
# Integ Loss: 0.0336
#
#
# epoch duration : 98.61471438407898
# saving step
# epoch n° 19
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4218, Regression Loss 1h: 85.0714, Segmentation Loss:0.2065
# Train Confusion Matrix:
# [[3106562   86414]
#  [ 182695  464329]]
# Accuracy: 0.9299, CSI: 0.6331, Sensitivity: 0.7176, Specificity: 0.9729, False Alarm Ratio: 0.1569
# Integ Loss: 0.0339
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4202, Regression Loss 1h: 84.7021, Segmentation Loss:0.2015
# Train Confusion Matrix:
# [[3103218   89758]
#  [ 177500  469524]]
# Accuracy: 0.9304, CSI: 0.6373, Sensitivity: 0.7257, Specificity: 0.9719, False Alarm Ratio: 0.1605
# Integ Loss: 0.0326
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4182, Regression Loss 1h: 84.2241, Segmentation Loss:0.1984
# Train Confusion Matrix:
# [[3096678   96298]
#  [ 171564  475460]]
# Accuracy: 0.9302, CSI: 0.6396, Sensitivity: 0.7348, Specificity: 0.9698, False Alarm Ratio: 0.1684
# Integ Loss: 0.0327
#
#
# train, Regression Loss: 0.4231, Regression Loss 1h: 86.7996, Segmentation Loss:0.1987
# Train Confusion Matrix:
# [[1842962   50551]
#  [ 108211  279236]]
# Accuracy: 0.9304, CSI: 0.6375, Sensitivity: 0.7207, Specificity: 0.9733, False Alarm Ratio: 0.1533
# Integ Loss: 0.0323
#
#
# epoch duration : 98.81631994247437
# saving step
# epoch n° 20
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4170, Regression Loss 1h: 78.9622, Segmentation Loss:0.2025
# Train Confusion Matrix:
# [[3111514   89201]
#  [ 176108  463177]]
# Accuracy: 0.9309, CSI: 0.6358, Sensitivity: 0.7245, Specificity: 0.9721, False Alarm Ratio: 0.1615
# Integ Loss: 0.0334
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4152, Regression Loss 1h: 78.5877, Segmentation Loss:0.1975
# Train Confusion Matrix:
# [[3107706   93009]
#  [ 170667  468618]]
# Accuracy: 0.9313, CSI: 0.6399, Sensitivity: 0.7330, Specificity: 0.9709, False Alarm Ratio: 0.1656
# Integ Loss: 0.0322
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4132, Regression Loss 1h: 78.1048, Segmentation Loss:0.1956
# Train Confusion Matrix:
# [[3100474  100241]
#  [ 164731  474554]]
# Accuracy: 0.9310, CSI: 0.6417, Sensitivity: 0.7423, Specificity: 0.9687, False Alarm Ratio: 0.1744
# Integ Loss: 0.0324
#
#
# train, Regression Loss: 0.4147, Regression Loss 1h: 78.6357, Segmentation Loss:0.1945
# Train Confusion Matrix:
# [[1911039   53423]
#  [ 104093  285365]]
# Accuracy: 0.9331, CSI: 0.6443, Sensitivity: 0.7327, Specificity: 0.9728, False Alarm Ratio: 0.1577
# Integ Loss: 0.0317
#
#
# epoch duration : 99.26726245880127
# saving step
# epoch n° 21
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4225, Regression Loss 1h: 85.0077, Segmentation Loss:0.2039
# Train Confusion Matrix:
# [[3098762   91075]
#  [ 174810  475353]]
# Accuracy: 0.9308, CSI: 0.6413, Sensitivity: 0.7311, Specificity: 0.9714, False Alarm Ratio: 0.1608
# Integ Loss: 0.0346
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4204, Regression Loss 1h: 84.5247, Segmentation Loss:0.1986
# Train Confusion Matrix:
# [[3094926   94911]
#  [ 169200  480963]]
# Accuracy: 0.9312, CSI: 0.6455, Sensitivity: 0.7398, Specificity: 0.9702, False Alarm Ratio: 0.1648
# Integ Loss: 0.0334
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4182, Regression Loss 1h: 83.9587, Segmentation Loss:0.1962
# Train Confusion Matrix:
# [[3086859  102978]
#  [ 162832  487331]]
# Accuracy: 0.9308, CSI: 0.6471, Sensitivity: 0.7496, Specificity: 0.9677, False Alarm Ratio: 0.1744
# Integ Loss: 0.0338
#
#
# train, Regression Loss: 0.4237, Regression Loss 1h: 87.3070, Segmentation Loss:0.1974
# Train Confusion Matrix:
# [[1943382   55003]
#  [ 110440  302695]]
# Accuracy: 0.9314, CSI: 0.6466, Sensitivity: 0.7327, Specificity: 0.9725, False Alarm Ratio: 0.1538
# Integ Loss: 0.0328
#
#
# epoch duration : 97.90652418136597
# saving step
# epoch n° 22
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4197, Regression Loss 1h: 82.1244, Segmentation Loss:0.2073
# Train Confusion Matrix:
# [[3111797   83072]
#  [ 185462  459669]]
# Accuracy: 0.9301, CSI: 0.6312, Sensitivity: 0.7125, Specificity: 0.9740, False Alarm Ratio: 0.1531
# Integ Loss: 0.0330
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4178, Regression Loss 1h: 81.7059, Segmentation Loss:0.2008
# Train Confusion Matrix:
# [[3107120   87749]
#  [ 178931  466200]]
# Accuracy: 0.9306, CSI: 0.6361, Sensitivity: 0.7226, Specificity: 0.9725, False Alarm Ratio: 0.1584
# Integ Loss: 0.0316
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4157, Regression Loss 1h: 81.2345, Segmentation Loss:0.1975
# Train Confusion Matrix:
# [[3098648   96221]
#  [ 171990  473141]]
# Accuracy: 0.9302, CSI: 0.6382, Sensitivity: 0.7334, Specificity: 0.9699, False Alarm Ratio: 0.1690
# Integ Loss: 0.0318
#
#
# train, Regression Loss: 0.4189, Regression Loss 1h: 82.8131, Segmentation Loss:0.1974
# Train Confusion Matrix:
# [[1971128   54222]
#  [ 115875  297175]]
# Accuracy: 0.9302, CSI: 0.6360, Sensitivity: 0.7195, Specificity: 0.9732, False Alarm Ratio: 0.1543
# Integ Loss: 0.0313
#
#
# epoch duration : 99.1380090713501
# saving step
# epoch n° 23
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4186, Regression Loss 1h: 79.8474, Segmentation Loss:0.2066
# Train Confusion Matrix:
# [[3120048   81307]
#  [ 184036  454609]]
# Accuracy: 0.9309, CSI: 0.6314, Sensitivity: 0.7118, Specificity: 0.9746, False Alarm Ratio: 0.1517
# Integ Loss: 0.0331
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4168, Regression Loss 1h: 79.4827, Segmentation Loss:0.1990
# Train Confusion Matrix:
# [[3116069   85286]
#  [ 177569  461076]]
# Accuracy: 0.9315, CSI: 0.6369, Sensitivity: 0.7220, Specificity: 0.9734, False Alarm Ratio: 0.1561
# Integ Loss: 0.0318
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4146, Regression Loss 1h: 78.9869, Segmentation Loss:0.1951
# Train Confusion Matrix:
# [[3109018   92337]
#  [ 170445  468200]]
# Accuracy: 0.9316, CSI: 0.6405, Sensitivity: 0.7331, Specificity: 0.9712, False Alarm Ratio: 0.1647
# Integ Loss: 0.0319
#
#
# train, Regression Loss: 0.4184, Regression Loss 1h: 80.3446, Segmentation Loss:0.1953
# Train Confusion Matrix:
# [[1895492   50891]
#  [ 108481  279856]]
# Accuracy: 0.9317, CSI: 0.6372, Sensitivity: 0.7207, Specificity: 0.9739, False Alarm Ratio: 0.1539
# Integ Loss: 0.0318
#
#
# epoch duration : 98.57556295394897
# saving step
# epoch n° 24
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4226, Regression Loss 1h: 83.5448, Segmentation Loss:0.2059
# Train Confusion Matrix:
# [[3115083   82315]
#  [ 182119  460483]]
# Accuracy: 0.9311, CSI: 0.6352, Sensitivity: 0.7166, Specificity: 0.9743, False Alarm Ratio: 0.1516
# Integ Loss: 0.0331
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4206, Regression Loss 1h: 83.0923, Segmentation Loss:0.1980
# Train Confusion Matrix:
# [[3111556   85842]
#  [ 175970  466632]]
# Accuracy: 0.9318, CSI: 0.6406, Sensitivity: 0.7262, Specificity: 0.9732, False Alarm Ratio: 0.1554
# Integ Loss: 0.0315
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4182, Regression Loss 1h: 82.5657, Segmentation Loss:0.1937
# Train Confusion Matrix:
# [[3104467   92931]
#  [ 168987  473615]]
# Accuracy: 0.9318, CSI: 0.6439, Sensitivity: 0.7370, Specificity: 0.9709, False Alarm Ratio: 0.1640
# Integ Loss: 0.0316
#
#
# train, Regression Loss: 0.4189, Regression Loss 1h: 82.7177, Segmentation Loss:0.1938
# Train Confusion Matrix:
# [[2027490   55304]
#  [ 115002  302044]]
# Accuracy: 0.9319, CSI: 0.6394, Sensitivity: 0.7242, Specificity: 0.9734, False Alarm Ratio: 0.1548
# Integ Loss: 0.0312
#
#
# epoch duration : 98.25396656990051
# saving step
# epoch n° 25
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4234, Regression Loss 1h: 81.6221, Segmentation Loss:0.2088
# Train Confusion Matrix:
# [[3118028   86471]
#  [ 177727  457774]]
# Accuracy: 0.9312, CSI: 0.6341, Sensitivity: 0.7203, Specificity: 0.9730, False Alarm Ratio: 0.1589
# Integ Loss: 0.0328
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4213, Regression Loss 1h: 81.1668, Segmentation Loss:0.2005
# Train Confusion Matrix:
# [[3113675   90824]
#  [ 171578  463923]]
# Accuracy: 0.9317, CSI: 0.6387, Sensitivity: 0.7300, Specificity: 0.9717, False Alarm Ratio: 0.1637
# Integ Loss: 0.0315
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4189, Regression Loss 1h: 80.6422, Segmentation Loss:0.1967
# Train Confusion Matrix:
# [[3105789   98710]
#  [ 164614  470887]]
# Accuracy: 0.9314, CSI: 0.6414, Sensitivity: 0.7410, Specificity: 0.9692, False Alarm Ratio: 0.1733
# Integ Loss: 0.0320
#
#
# train, Regression Loss: 0.4245, Regression Loss 1h: 82.8674, Segmentation Loss:0.1942
# Train Confusion Matrix:
# [[1849554   50307]
#  [ 103002  274257]]
# Accuracy: 0.9327, CSI: 0.6414, Sensitivity: 0.7270, Specificity: 0.9735, False Alarm Ratio: 0.1550
# Integ Loss: 0.0309
#
#
# epoch duration : 98.70741200447083
# saving step
# epoch n° 26
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4131, Regression Loss 1h: 78.1397, Segmentation Loss:0.2100
# Train Confusion Matrix:
# [[3119336   87695]
#  [ 178995  453974]]
# Accuracy: 0.9305, CSI: 0.6299, Sensitivity: 0.7172, Specificity: 0.9727, False Alarm Ratio: 0.1619
# Integ Loss: 0.0321
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4104, Regression Loss 1h: 77.4768, Segmentation Loss:0.2010
# Train Confusion Matrix:
# [[3116505   90526]
#  [ 173667  459302]]
# Accuracy: 0.9312, CSI: 0.6348, Sensitivity: 0.7256, Specificity: 0.9718, False Alarm Ratio: 0.1646
# Integ Loss: 0.0308
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4075, Regression Loss 1h: 76.7652, Segmentation Loss:0.1961
# Train Confusion Matrix:
# [[3109626   97405]
#  [ 167153  465816]]
# Accuracy: 0.9311, CSI: 0.6378, Sensitivity: 0.7359, Specificity: 0.9696, False Alarm Ratio: 0.1729
# Integ Loss: 0.0318
#
#
# train, Regression Loss: 0.4124, Regression Loss 1h: 77.9048, Segmentation Loss:0.1934
# Train Confusion Matrix:
# [[1964977   52544]
#  [ 109588  292091]]
# Accuracy: 0.9330, CSI: 0.6431, Sensitivity: 0.7272, Specificity: 0.9740, False Alarm Ratio: 0.1525
# Integ Loss: 0.0301
#
#
# epoch duration : 99.25206470489502
# saving step
# epoch n° 27
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4300, Regression Loss 1h: 84.5985, Segmentation Loss:0.2000
# Train Confusion Matrix:
# [[3109379   84478]
#  [ 172658  473485]]
# Accuracy: 0.9330, CSI: 0.6481, Sensitivity: 0.7328, Specificity: 0.9735, False Alarm Ratio: 0.1514
# Integ Loss: 0.0333
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4272, Regression Loss 1h: 83.9619, Segmentation Loss:0.1920
# Train Confusion Matrix:
# [[3107715   86142]
#  [ 168282  477861]]
# Accuracy: 0.9337, CSI: 0.6526, Sensitivity: 0.7396, Specificity: 0.9730, False Alarm Ratio: 0.1527
# Integ Loss: 0.0318
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4244, Regression Loss 1h: 83.2988, Segmentation Loss:0.1871
# Train Confusion Matrix:
# [[3102794   91063]
#  [ 163312  482831]]
# Accuracy: 0.9338, CSI: 0.6549, Sensitivity: 0.7473, Specificity: 0.9715, False Alarm Ratio: 0.1587
# Integ Loss: 0.0323
#
#
# train, Regression Loss: 0.4235, Regression Loss 1h: 83.6837, Segmentation Loss:0.1863
# Train Confusion Matrix:
# [[1918313   52220]
#  [ 104362  290545]]
# Accuracy: 0.9338, CSI: 0.6498, Sensitivity: 0.7357, Specificity: 0.9735, False Alarm Ratio: 0.1523
# Integ Loss: 0.0311
#
#
# epoch duration : 99.30635666847229
# saving step
# epoch n° 28
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4175, Regression Loss 1h: 82.8561, Segmentation Loss:0.2012
# Train Confusion Matrix:
# [[3111017   84313]
#  [ 175373  469297]]
# Accuracy: 0.9324, CSI: 0.6438, Sensitivity: 0.7280, Specificity: 0.9736, False Alarm Ratio: 0.1523
# Integ Loss: 0.0317
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4140, Regression Loss 1h: 81.9500, Segmentation Loss:0.1928
# Train Confusion Matrix:
# [[3107781   87549]
#  [ 169937  474733]]
# Accuracy: 0.9329, CSI: 0.6483, Sensitivity: 0.7364, Specificity: 0.9726, False Alarm Ratio: 0.1557
# Integ Loss: 0.0301
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4108, Regression Loss 1h: 81.1458, Segmentation Loss:0.1891
# Train Confusion Matrix:
# [[3101063   94267]
#  [ 163433  481237]]
# Accuracy: 0.9329, CSI: 0.6513, Sensitivity: 0.7465, Specificity: 0.9705, False Alarm Ratio: 0.1638
# Integ Loss: 0.0313
#
#
# train, Regression Loss: 0.4189, Regression Loss 1h: 84.2093, Segmentation Loss:0.1855
# Train Confusion Matrix:
# [[1974444   52668]
#  [ 109198  298250]]
# Accuracy: 0.9335, CSI: 0.6482, Sensitivity: 0.7320, Specificity: 0.9740, False Alarm Ratio: 0.1501
# Integ Loss: 0.0304
#
#
# epoch duration : 99.67039799690247
# saving step
# epoch n° 29
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4210, Regression Loss 1h: 79.6888, Segmentation Loss:0.2033
# Train Confusion Matrix:
# [[3113151   91614]
#  [ 166442  468793]]
# Accuracy: 0.9328, CSI: 0.6450, Sensitivity: 0.7380, Specificity: 0.9714, False Alarm Ratio: 0.1635
# Integ Loss: 0.0321
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4172, Regression Loss 1h: 78.7303, Segmentation Loss:0.1936
# Train Confusion Matrix:
# [[3112379   92386]
#  [ 162608  472627]]
# Accuracy: 0.9336, CSI: 0.6496, Sensitivity: 0.7440, Specificity: 0.9712, False Alarm Ratio: 0.1635
# Integ Loss: 0.0309
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4143, Regression Loss 1h: 78.0047, Segmentation Loss:0.1888
# Train Confusion Matrix:
# [[3107435   97330]
#  [ 157971  477264]]
# Accuracy: 0.9335, CSI: 0.6515, Sensitivity: 0.7513, Specificity: 0.9696, False Alarm Ratio: 0.1694
# Integ Loss: 0.0321
#
#
# train, Regression Loss: 0.4213, Regression Loss 1h: 80.3259, Segmentation Loss:0.1836
# Train Confusion Matrix:
# [[1902032   49786]
#  [ 100972  281930]]
# Accuracy: 0.9354, CSI: 0.6516, Sensitivity: 0.7363, Specificity: 0.9745, False Alarm Ratio: 0.1501
# Integ Loss: 0.0297
#
#
# epoch duration : 99.46336960792542
# saving step
# epoch n° 30
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4206, Regression Loss 1h: 82.0698, Segmentation Loss:0.2004
# Train Confusion Matrix:
# [[3109817   88887]
#  [ 168264  473032]]
# Accuracy: 0.9330, CSI: 0.6478, Sensitivity: 0.7376, Specificity: 0.9722, False Alarm Ratio: 0.1582
# Integ Loss: 0.0326
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4170, Regression Loss 1h: 81.1756, Segmentation Loss:0.1908
# Train Confusion Matrix:
# [[3106497   92207]
#  [ 162255  479041]]
# Accuracy: 0.9337, CSI: 0.6531, Sensitivity: 0.7470, Specificity: 0.9712, False Alarm Ratio: 0.1614
# Integ Loss: 0.0311
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4140, Regression Loss 1h: 80.4614, Segmentation Loss:0.1862
# Train Confusion Matrix:
# [[3100078   98626]
#  [ 156043  485253]]
# Accuracy: 0.9337, CSI: 0.6558, Sensitivity: 0.7567, Specificity: 0.9692, False Alarm Ratio: 0.1689
# Integ Loss: 0.0322
#
#
# train, Regression Loss: 0.4186, Regression Loss 1h: 82.6062, Segmentation Loss:0.1837
# Train Confusion Matrix:
# [[1789568   48632]
#  [  96110  273690]]
# Accuracy: 0.9344, CSI: 0.6541, Sensitivity: 0.7401, Specificity: 0.9735, False Alarm Ratio: 0.1509
# Integ Loss: 0.0304
#
#
# epoch duration : 98.89152383804321
# saving step
# epoch n° 31
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4233, Regression Loss 1h: 83.8416, Segmentation Loss:0.2080
# Train Confusion Matrix:
# [[3096770   95854]
#  [ 165564  481812]]
# Accuracy: 0.9319, CSI: 0.6483, Sensitivity: 0.7443, Specificity: 0.9700, False Alarm Ratio: 0.1659
# Integ Loss: 0.0328
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4195, Regression Loss 1h: 82.8746, Segmentation Loss:0.1974
# Train Confusion Matrix:
# [[3095369   97255]
#  [ 162032  485344]]
# Accuracy: 0.9325, CSI: 0.6518, Sensitivity: 0.7497, Specificity: 0.9695, False Alarm Ratio: 0.1669
# Integ Loss: 0.0315
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4168, Regression Loss 1h: 82.1973, Segmentation Loss:0.1923
# Train Confusion Matrix:
# [[3090978  101646]
#  [ 157895  489481]]
# Accuracy: 0.9324, CSI: 0.6535, Sensitivity: 0.7561, Specificity: 0.9682, False Alarm Ratio: 0.1720
# Integ Loss: 0.0328
#
#
# train, Regression Loss: 0.4228, Regression Loss 1h: 83.7539, Segmentation Loss:0.1835
# Train Confusion Matrix:
# [[1718553   46001]
#  [  93200  265766]]
# Accuracy: 0.9344, CSI: 0.6563, Sensitivity: 0.7404, Specificity: 0.9739, False Alarm Ratio: 0.1475
# Integ Loss: 0.0306
#
#
# epoch duration : 98.82159543037415
# saving step
# epoch n° 32
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4193, Regression Loss 1h: 83.3037, Segmentation Loss:0.1996
# Train Confusion Matrix:
# [[3108301   82910]
#  [ 172505  476284]]
# Accuracy: 0.9335, CSI: 0.6509, Sensitivity: 0.7341, Specificity: 0.9740, False Alarm Ratio: 0.1483
# Integ Loss: 0.0328
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4156, Regression Loss 1h: 82.3871, Segmentation Loss:0.1899
# Train Confusion Matrix:
# [[3106657   84554]
#  [ 167741  481048]]
# Accuracy: 0.9343, CSI: 0.6560, Sensitivity: 0.7415, Specificity: 0.9735, False Alarm Ratio: 0.1495
# Integ Loss: 0.0316
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4128, Regression Loss 1h: 81.6849, Segmentation Loss:0.1855
# Train Confusion Matrix:
# [[3101276   89935]
#  [ 162653  486136]]
# Accuracy: 0.9342, CSI: 0.6581, Sensitivity: 0.7493, Specificity: 0.9718, False Alarm Ratio: 0.1561
# Integ Loss: 0.0329
#
#
# train, Regression Loss: 0.4198, Regression Loss 1h: 82.9660, Segmentation Loss:0.1843
# Train Confusion Matrix:
# [[1977312   53179]
#  [ 105083  306666]]
# Accuracy: 0.9352, CSI: 0.6596, Sensitivity: 0.7448, Specificity: 0.9738, False Alarm Ratio: 0.1478
# Integ Loss: 0.0307
#
#
# epoch duration : 99.50964069366455
# saving step
# epoch n° 33
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4180, Regression Loss 1h: 81.5353, Segmentation Loss:0.2107
# Train Confusion Matrix:
# [[3111422   86445]
#  [ 177753  464380]]
# Accuracy: 0.9312, CSI: 0.6374, Sensitivity: 0.7232, Specificity: 0.9730, False Alarm Ratio: 0.1569
# Integ Loss: 0.0313
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4151, Regression Loss 1h: 80.8604, Segmentation Loss:0.1992
# Train Confusion Matrix:
# [[3108455   89412]
#  [ 172118  470015]]
# Accuracy: 0.9319, CSI: 0.6425, Sensitivity: 0.7320, Specificity: 0.9720, False Alarm Ratio: 0.1598
# Integ Loss: 0.0299
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4127, Regression Loss 1h: 80.2881, Segmentation Loss:0.1943
# Train Confusion Matrix:
# [[3102119   95748]
#  [ 166049  476084]]
# Accuracy: 0.9318, CSI: 0.6452, Sensitivity: 0.7414, Specificity: 0.9701, False Alarm Ratio: 0.1674
# Integ Loss: 0.0302
#
#
# train, Regression Loss: 0.4148, Regression Loss 1h: 80.8178, Segmentation Loss:0.1907
# Train Confusion Matrix:
# [[1946222   49471]
#  [ 112040  288427]]
# Accuracy: 0.9326, CSI: 0.6410, Sensitivity: 0.7202, Specificity: 0.9752, False Alarm Ratio: 0.1464
# Integ Loss: 0.0293
#
#
# epoch duration : 99.09735798835754
# saving step
# epoch n° 34
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4188, Regression Loss 1h: 82.5487, Segmentation Loss:0.2043
# Train Confusion Matrix:
# [[3104564   90561]
#  [ 167180  477695]]
# Accuracy: 0.9329, CSI: 0.6495, Sensitivity: 0.7408, Specificity: 0.9717, False Alarm Ratio: 0.1594
# Integ Loss: 0.0322
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4157, Regression Loss 1h: 81.8819, Segmentation Loss:0.1962
# Train Confusion Matrix:
# [[3097039   98086]
#  [ 159101  485774]]
# Accuracy: 0.9330, CSI: 0.6538, Sensitivity: 0.7533, Specificity: 0.9693, False Alarm Ratio: 0.1680
# Integ Loss: 0.0309
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4133, Regression Loss 1h: 81.3783, Segmentation Loss:0.1952
# Train Confusion Matrix:
# [[3086252  108873]
#  [ 152856  492019]]
# Accuracy: 0.9318, CSI: 0.6528, Sensitivity: 0.7630, Specificity: 0.9659, False Alarm Ratio: 0.1812
# Integ Loss: 0.0315
#
#
# train, Regression Loss: 0.4153, Regression Loss 1h: 82.3257, Segmentation Loss:0.1852
# Train Confusion Matrix:
# [[1831822   48366]
#  [ 101828  279744]]
# Accuracy: 0.9336, CSI: 0.6507, Sensitivity: 0.7331, Specificity: 0.9743, False Alarm Ratio: 0.1474
# Integ Loss: 0.0296
#
#
# epoch duration : 99.43778467178345
# saving step
# epoch n° 35
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4231, Regression Loss 1h: 81.1725, Segmentation Loss:0.2110
# Train Confusion Matrix:
# [[3117582   86334]
#  [ 176248  459836]]
# Accuracy: 0.9316, CSI: 0.6365, Sensitivity: 0.7229, Specificity: 0.9731, False Alarm Ratio: 0.1581
# Integ Loss: 0.0322
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4198, Regression Loss 1h: 80.6095, Segmentation Loss:0.1991
# Train Confusion Matrix:
# [[3114473   89443]
#  [ 170375  465709]]
# Accuracy: 0.9323, CSI: 0.6419, Sensitivity: 0.7322, Specificity: 0.9721, False Alarm Ratio: 0.1611
# Integ Loss: 0.0308
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4175, Regression Loss 1h: 80.4682, Segmentation Loss:0.1933
# Train Confusion Matrix:
# [[3109874   94042]
#  [ 165864  470220]]
# Accuracy: 0.9323, CSI: 0.6440, Sensitivity: 0.7392, Specificity: 0.9706, False Alarm Ratio: 0.1667
# Integ Loss: 0.0315
#
#
# train, Regression Loss: 0.4192, Regression Loss 1h: 82.1004, Segmentation Loss:0.1863
# Train Confusion Matrix:
# [[1836470   47443]
#  [ 103619  270388]]
# Accuracy: 0.9331, CSI: 0.6416, Sensitivity: 0.7229, Specificity: 0.9748, False Alarm Ratio: 0.1493
# Integ Loss: 0.0296
#
#
# epoch duration : 99.50748991966248
# saving step
# epoch n° 36
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4121, Regression Loss 1h: 78.5403, Segmentation Loss:0.2219
# Train Confusion Matrix:
# [[3082400  118153]
#  [ 163267  476180]]
# Accuracy: 0.9267, CSI: 0.6285, Sensitivity: 0.7447, Specificity: 0.9631, False Alarm Ratio: 0.1988
# Integ Loss: 0.0317
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4082, Regression Loss 1h: 77.6940, Segmentation Loss:0.2050
# Train Confusion Matrix:
# [[3087143  113410]
#  [ 157913  481534]]
# Accuracy: 0.9293, CSI: 0.6396, Sensitivity: 0.7530, Specificity: 0.9646, False Alarm Ratio: 0.1906
# Integ Loss: 0.0303
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4057, Regression Loss 1h: 77.1769, Segmentation Loss:0.1972
# Train Confusion Matrix:
# [[3088551  112002]
#  [ 154633  484814]]
# Accuracy: 0.9306, CSI: 0.6452, Sensitivity: 0.7582, Specificity: 0.9650, False Alarm Ratio: 0.1877
# Integ Loss: 0.0311
#
#
# train, Regression Loss: 0.4093, Regression Loss 1h: 78.7419, Segmentation Loss:0.1855
# Train Confusion Matrix:
# [[2002086   52436]
#  [ 111741  299017]]
# Accuracy: 0.9334, CSI: 0.6456, Sensitivity: 0.7280, Specificity: 0.9745, False Alarm Ratio: 0.1492
# Integ Loss: 0.0296
#
#
# epoch duration : 98.65795350074768
# saving step
# epoch n° 37
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4143, Regression Loss 1h: 78.7072, Segmentation Loss:0.2177
# Train Confusion Matrix:
# [[3103505  100940]
#  [ 170900  464655]]
# Accuracy: 0.9292, CSI: 0.6309, Sensitivity: 0.7311, Specificity: 0.9685, False Alarm Ratio: 0.1785
# Integ Loss: 0.0321
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4105, Regression Loss 1h: 77.8764, Segmentation Loss:0.2046
# Train Confusion Matrix:
# [[3100899  103546]
#  [ 164924  470631]]
# Accuracy: 0.9301, CSI: 0.6368, Sensitivity: 0.7405, Specificity: 0.9677, False Alarm Ratio: 0.1803
# Integ Loss: 0.0310
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4078, Regression Loss 1h: 77.2673, Segmentation Loss:0.1989
# Train Confusion Matrix:
# [[3097751  106694]
#  [ 161304  474251]]
# Accuracy: 0.9302, CSI: 0.6389, Sensitivity: 0.7462, Specificity: 0.9667, False Alarm Ratio: 0.1837
# Integ Loss: 0.0321
#
#
# train, Regression Loss: 0.4114, Regression Loss 1h: 76.9554, Segmentation Loss:0.1837
# Train Confusion Matrix:
# [[1729427   44688]
#  [  95170  254235]]
# Accuracy: 0.9341, CSI: 0.6451, Sensitivity: 0.7276, Specificity: 0.9748, False Alarm Ratio: 0.1495
# Integ Loss: 0.0292
#
#
# epoch duration : 99.26360511779785
# saving step
# epoch n° 38
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4124, Regression Loss 1h: 78.2670, Segmentation Loss:0.2086
# Train Confusion Matrix:
# [[3096124  105890]
#  [ 153081  484905]]
# Accuracy: 0.9326, CSI: 0.6519, Sensitivity: 0.7601, Specificity: 0.9669, False Alarm Ratio: 0.1792
# Integ Loss: 0.0314
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4086, Regression Loss 1h: 77.4125, Segmentation Loss:0.1961
# Train Confusion Matrix:
# [[3094018  107996]
#  [ 149948  488038]]
# Accuracy: 0.9328, CSI: 0.6542, Sensitivity: 0.7650, Specificity: 0.9663, False Alarm Ratio: 0.1812
# Integ Loss: 0.0302
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4061, Regression Loss 1h: 76.9676, Segmentation Loss:0.1913
# Train Confusion Matrix:
# [[3090937  111077]
#  [ 147031  490955]]
# Accuracy: 0.9328, CSI: 0.6554, Sensitivity: 0.7695, Specificity: 0.9653, False Alarm Ratio: 0.1845
# Integ Loss: 0.0312
#
#
# train, Regression Loss: 0.4085, Regression Loss 1h: 76.4661, Segmentation Loss:0.1773
# Train Confusion Matrix:
# [[1867856   49355]
#  [  96029  286920]]
# Accuracy: 0.9368, CSI: 0.6637, Sensitivity: 0.7492, Specificity: 0.9743, False Alarm Ratio: 0.1468
# Integ Loss: 0.0293
#
#
# epoch duration : 99.89258551597595
# saving step
# epoch n° 39
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4162, Regression Loss 1h: 80.8378, Segmentation Loss:0.2217
# Train Confusion Matrix:
# [[3096567  103345]
#  [ 168487  471601]]
# Accuracy: 0.9292, CSI: 0.6344, Sensitivity: 0.7368, Specificity: 0.9677, False Alarm Ratio: 0.1797
# Integ Loss: 0.0318
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4124, Regression Loss 1h: 79.9250, Segmentation Loss:0.2073
# Train Confusion Matrix:
# [[3094160  105752]
#  [ 161863  478225]]
# Accuracy: 0.9303, CSI: 0.6412, Sensitivity: 0.7471, Specificity: 0.9670, False Alarm Ratio: 0.1811
# Integ Loss: 0.0309
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4103, Regression Loss 1h: 79.4185, Segmentation Loss:0.2006
# Train Confusion Matrix:
# [[3090912  109000]
#  [ 157668  482420]]
# Accuracy: 0.9306, CSI: 0.6440, Sensitivity: 0.7537, Specificity: 0.9659, False Alarm Ratio: 0.1843
# Integ Loss: 0.0317
#
#
# train, Regression Loss: 0.4147, Regression Loss 1h: 81.3626, Segmentation Loss:0.1863
# Train Confusion Matrix:
# [[1883317   48180]
#  [ 104981  282882]]
# Accuracy: 0.9340, CSI: 0.6487, Sensitivity: 0.7293, Specificity: 0.9751, False Alarm Ratio: 0.1455
# Integ Loss: 0.0288
#
#
# epoch duration : 100.15958428382874
# saving step
# epoch n° 40
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4204, Regression Loss 1h: 81.8307, Segmentation Loss:0.2036
# Train Confusion Matrix:
# [[3097896  101355]
#  [ 158148  482601]]
# Accuracy: 0.9324, CSI: 0.6503, Sensitivity: 0.7532, Specificity: 0.9683, False Alarm Ratio: 0.1736
# Integ Loss: 0.0322
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4163, Regression Loss 1h: 81.0733, Segmentation Loss:0.1888
# Train Confusion Matrix:
# [[3101715   97536]
#  [ 154319  486430]]
# Accuracy: 0.9344, CSI: 0.6589, Sensitivity: 0.7592, Specificity: 0.9695, False Alarm Ratio: 0.1670
# Integ Loss: 0.0311
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4137, Regression Loss 1h: 80.9538, Segmentation Loss:0.1828
# Train Confusion Matrix:
# [[3100576   98675]
#  [ 150764  489985]]
# Accuracy: 0.9350, CSI: 0.6627, Sensitivity: 0.7647, Specificity: 0.9692, False Alarm Ratio: 0.1676
# Integ Loss: 0.0322
#
#
# train, Regression Loss: 0.4197, Regression Loss 1h: 83.5130, Segmentation Loss:0.1751
# Train Confusion Matrix:
# [[1899828   50905]
#  [  99541  295966]]
# Accuracy: 0.9359, CSI: 0.6630, Sensitivity: 0.7483, Specificity: 0.9739, False Alarm Ratio: 0.1468
# Integ Loss: 0.0299
#
#
# epoch duration : 99.35025024414062
# saving step
# epoch n° 41
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4139, Regression Loss 1h: 79.4090, Segmentation Loss:0.2170
# Train Confusion Matrix:
# [[3099239  107344]
#  [ 160611  472806]]
# Accuracy: 0.9302, CSI: 0.6383, Sensitivity: 0.7464, Specificity: 0.9665, False Alarm Ratio: 0.1850
# Integ Loss: 0.0320
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4118, Regression Loss 1h: 78.9827, Segmentation Loss:0.2019
# Train Confusion Matrix:
# [[3098865  107718]
#  [ 154719  478698]]
# Accuracy: 0.9317, CSI: 0.6459, Sensitivity: 0.7557, Specificity: 0.9664, False Alarm Ratio: 0.1837
# Integ Loss: 0.0306
#
#
# ...
# [[1936543   41306]
#  [ 311387   83884]]
# Accuracy: 0.8514, CSI: 0.1921, Sensitivity: 0.2122, Specificity: 0.9791, False Alarm Ratio: 0.3299
# Integ Loss: 0.0524
#
#
# epoch duration : 99.39308977127075
# saving step
# epoch n° 295
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4370, Regression Loss 1h: 81.6782, Segmentation Loss:0.3662
# Train Confusion Matrix:
# [[3129956   66967]
#  [ 504944  138133]]
# Accuracy: 0.8511, CSI: 0.1945, Sensitivity: 0.2148, Specificity: 0.9791, False Alarm Ratio: 0.3265
# Integ Loss: 0.0534
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4367, Regression Loss 1h: 81.5195, Segmentation Loss:0.3663
# Train Confusion Matrix:
# [[3126438   70485]
#  [ 503339  139738]]
# Accuracy: 0.8506, CSI: 0.1958, Sensitivity: 0.2173, Specificity: 0.9780, False Alarm Ratio: 0.3353
# Integ Loss: 0.0531
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4365, Regression Loss 1h: 81.3787, Segmentation Loss:0.3709
# Train Confusion Matrix:
# [[3115532   81391]
#  [ 498086  144991]]
# Accuracy: 0.8491, CSI: 0.2001, Sensitivity: 0.2255, Specificity: 0.9745, False Alarm Ratio: 0.3595
# Integ Loss: 0.0533
#
#
# train, Regression Loss: 0.4378, Regression Loss 1h: 81.2302, Segmentation Loss:0.3641
# Train Confusion Matrix:
# [[1804097   39470]
#  [ 292166   79947]]
# Accuracy: 0.8503, CSI: 0.1942, Sensitivity: 0.2148, Specificity: 0.9786, False Alarm Ratio: 0.3305
# Integ Loss: 0.0529
#
#
# epoch duration : 98.70313334465027
# saving step
# epoch n° 296
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4429, Regression Loss 1h: 83.6714, Segmentation Loss:0.3687
# Train Confusion Matrix:
# [[3127951   64621]
#  [ 510801  136627]]
# Accuracy: 0.8502, CSI: 0.1919, Sensitivity: 0.2110, Specificity: 0.9798, False Alarm Ratio: 0.3211
# Integ Loss: 0.0540
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4427, Regression Loss 1h: 83.5827, Segmentation Loss:0.3667
# Train Confusion Matrix:
# [[3124123   68449]
#  [ 508759  138669]]
# Accuracy: 0.8497, CSI: 0.1937, Sensitivity: 0.2142, Specificity: 0.9786, False Alarm Ratio: 0.3305
# Integ Loss: 0.0536
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4422, Regression Loss 1h: 83.3581, Segmentation Loss:0.3703
# Train Confusion Matrix:
# [[3111356   81216]
#  [ 502470  144958]]
# Accuracy: 0.8480, CSI: 0.1989, Sensitivity: 0.2239, Specificity: 0.9746, False Alarm Ratio: 0.3591
# Integ Loss: 0.0539
#
#
# train, Regression Loss: 0.4407, Regression Loss 1h: 82.0490, Segmentation Loss:0.3668
# Train Confusion Matrix:
# [[1895346   42107]
#  [ 306919   86508]]
# Accuracy: 0.8503, CSI: 0.1986, Sensitivity: 0.2199, Specificity: 0.9783, False Alarm Ratio: 0.3274
# Integ Loss: 0.0534
#
#
# epoch duration : 99.55487012863159
# saving step
# epoch n° 297
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4383, Regression Loss 1h: 79.7444, Segmentation Loss:0.3637
# Train Confusion Matrix:
# [[3139302   61739]
#  [ 506135  132824]]
# Accuracy: 0.8521, CSI: 0.1896, Sensitivity: 0.2079, Specificity: 0.9807, False Alarm Ratio: 0.3173
# Integ Loss: 0.0530
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4381, Regression Loss 1h: 79.6780, Segmentation Loss:0.3614
# Train Confusion Matrix:
# [[3135329   65712]
#  [ 504054  134905]]
# Accuracy: 0.8516, CSI: 0.1914, Sensitivity: 0.2111, Specificity: 0.9795, False Alarm Ratio: 0.3275
# Integ Loss: 0.0526
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4376, Regression Loss 1h: 79.5786, Segmentation Loss:0.3653
# Train Confusion Matrix:
# [[3122967   78074]
#  [ 497528  141431]]
# Accuracy: 0.8501, CSI: 0.1972, Sensitivity: 0.2213, Specificity: 0.9756, False Alarm Ratio: 0.3557
# Integ Loss: 0.0532
#
#
# train, Regression Loss: 0.4410, Regression Loss 1h: 81.0052, Segmentation Loss:0.3626
# Train Confusion Matrix:
# [[1847967   40289]
#  [ 296903   80441]]
# Accuracy: 0.8512, CSI: 0.1926, Sensitivity: 0.2132, Specificity: 0.9787, False Alarm Ratio: 0.3337
# Integ Loss: 0.0521
#
#
# epoch duration : 99.12748575210571
# saving step
# epoch n° 298
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4414, Regression Loss 1h: 80.2203, Segmentation Loss:0.3591
# Train Confusion Matrix:
# [[3142304   67366]
#  [ 495682  134648]]
# Accuracy: 0.8534, CSI: 0.1930, Sensitivity: 0.2136, Specificity: 0.9790, False Alarm Ratio: 0.3335
# Integ Loss: 0.0526
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4414, Regression Loss 1h: 80.1965, Segmentation Loss:0.3581
# Train Confusion Matrix:
# [[3140982   68688]
#  [ 495473  134857]]
# Accuracy: 0.8531, CSI: 0.1929, Sensitivity: 0.2139, Specificity: 0.9786, False Alarm Ratio: 0.3375
# Integ Loss: 0.0526
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4415, Regression Loss 1h: 80.5165, Segmentation Loss:0.3684
# Train Confusion Matrix:
# [[3131705   77965]
#  [ 492506  137824]]
# Accuracy: 0.8514, CSI: 0.1946, Sensitivity: 0.2187, Specificity: 0.9757, False Alarm Ratio: 0.3613
# Integ Loss: 0.0549
#
#
# train, Regression Loss: 0.4402, Regression Loss 1h: 82.5977, Segmentation Loss:0.3610
# Train Confusion Matrix:
# [[1863774   39608]
#  [ 297523   83895]]
# Accuracy: 0.8524, CSI: 0.1993, Sensitivity: 0.2200, Specificity: 0.9792, False Alarm Ratio: 0.3207
# Integ Loss: 0.0527
#
#
# epoch duration : 99.26472020149231
# saving step
# epoch n° 299
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4335, Regression Loss 1h: 80.9120, Segmentation Loss:0.3590
# Train Confusion Matrix:
# [[3139555   64582]
#  [ 497870  137993]]
# Accuracy: 0.8535, CSI: 0.1970, Sensitivity: 0.2170, Specificity: 0.9798, False Alarm Ratio: 0.3188
# Integ Loss: 0.0521
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4335, Regression Loss 1h: 80.9290, Segmentation Loss:0.3575
# Train Confusion Matrix:
# [[3138471   65666]
#  [ 497808  138055]]
# Accuracy: 0.8533, CSI: 0.1968, Sensitivity: 0.2171, Specificity: 0.9795, False Alarm Ratio: 0.3223
# Integ Loss: 0.0518
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4335, Regression Loss 1h: 81.0811, Segmentation Loss:0.3678
# Train Confusion Matrix:
# [[3128997   75140]
#  [ 494389  141474]]
# Accuracy: 0.8517, CSI: 0.1990, Sensitivity: 0.2225, Specificity: 0.9765, False Alarm Ratio: 0.3469
# Integ Loss: 0.0536
#
#
# train, Regression Loss: 0.4333, Regression Loss 1h: 81.0686, Segmentation Loss:0.3593
# Train Confusion Matrix:
# [[1939676   42007]
#  [ 308190   87087]]
# Accuracy: 0.8527, CSI: 0.1992, Sensitivity: 0.2203, Specificity: 0.9788, False Alarm Ratio: 0.3254
# Integ Loss: 0.0524
#
#
# epoch duration : 98.70720481872559
# saving step
# epoch n° 300
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4375, Regression Loss 1h: 81.0410, Segmentation Loss:0.3614
# Train Confusion Matrix:
# [[3131058   70805]
#  [ 495647  142490]]
# Accuracy: 0.8525, CSI: 0.2010, Sensitivity: 0.2233, Specificity: 0.9779, False Alarm Ratio: 0.3320
# Integ Loss: 0.0527
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4376, Regression Loss 1h: 81.0869, Segmentation Loss:0.3586
# Train Confusion Matrix:
# [[3133517   68346]
#  [ 497954  140183]]
# Accuracy: 0.8525, CSI: 0.1984, Sensitivity: 0.2197, Specificity: 0.9787, False Alarm Ratio: 0.3278
# Integ Loss: 0.0522
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4375, Regression Loss 1h: 81.0408, Segmentation Loss:0.3641
# Train Confusion Matrix:
# [[3125357   76506]
#  [ 494848  143289]]
# Accuracy: 0.8512, CSI: 0.2005, Sensitivity: 0.2245, Specificity: 0.9761, False Alarm Ratio: 0.3481
# Integ Loss: 0.0528
#
#
# train, Regression Loss: 0.4374, Regression Loss 1h: 81.5308, Segmentation Loss:0.3605
# Train Confusion Matrix:
# [[1955799   42763]
#  [ 311498   86100]]
# Accuracy: 0.8522, CSI: 0.1955, Sensitivity: 0.2166, Specificity: 0.9786, False Alarm Ratio: 0.3318
# Integ Loss: 0.0521
#
#
# epoch duration : 98.49394822120667
# saving step
# epoch n° 301
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4358, Regression Loss 1h: 80.2869, Segmentation Loss:0.3611
# Train Confusion Matrix:
# [[3133407   66912]
#  [ 501503  138178]]
# Accuracy: 0.8520, CSI: 0.1956, Sensitivity: 0.2160, Specificity: 0.9791, False Alarm Ratio: 0.3263
# Integ Loss: 0.0529
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4358, Regression Loss 1h: 80.3421, Segmentation Loss:0.3604
# Train Confusion Matrix:
# [[3132050   68269]
#  [ 501138  138543]]
# Accuracy: 0.8517, CSI: 0.1957, Sensitivity: 0.2166, Specificity: 0.9787, False Alarm Ratio: 0.3301
# Integ Loss: 0.0529
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4357, Regression Loss 1h: 80.4552, Segmentation Loss:0.3690
# Train Confusion Matrix:
# [[3121356   78963]
#  [ 496557  143124]]
# Accuracy: 0.8501, CSI: 0.1992, Sensitivity: 0.2237, Specificity: 0.9753, False Alarm Ratio: 0.3555
# Integ Loss: 0.0542
#
#
# train, Regression Loss: 0.4368, Regression Loss 1h: 82.3399, Segmentation Loss:0.3609
# Train Confusion Matrix:
# [[1909696   39282]
#  [ 308748   84674]]
# Accuracy: 0.8514, CSI: 0.1957, Sensitivity: 0.2152, Specificity: 0.9798, False Alarm Ratio: 0.3169
# Integ Loss: 0.0519
#
#
# epoch duration : 99.02606463432312
# saving step
# epoch n° 302
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4372, Regression Loss 1h: 82.5461, Segmentation Loss:0.3615
# Train Confusion Matrix:
# [[3125529   69937]
#  [ 499495  145039]]
# Accuracy: 0.8517, CSI: 0.2030, Sensitivity: 0.2250, Specificity: 0.9781, False Alarm Ratio: 0.3253
# Integ Loss: 0.0537
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4373, Regression Loss 1h: 82.5784, Segmentation Loss:0.3594
# Train Confusion Matrix:
# [[3125087   70379]
#  [ 499926  144608]]
# Accuracy: 0.8515, CSI: 0.2023, Sensitivity: 0.2244, Specificity: 0.9780, False Alarm Ratio: 0.3274
# Integ Loss: 0.0532
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4369, Regression Loss 1h: 82.4073, Segmentation Loss:0.3641
# Train Confusion Matrix:
# [[3115248   80218]
#  [ 495156  149378]]
# Accuracy: 0.8502, CSI: 0.2061, Sensitivity: 0.2318, Specificity: 0.9749, False Alarm Ratio: 0.3494
# Integ Loss: 0.0536
#
#
# train, Regression Loss: 0.4395, Regression Loss 1h: 84.1398, Segmentation Loss:0.3585
# Train Confusion Matrix:
# [[1823954   41473]
#  [ 291394   85739]]
# Accuracy: 0.8516, CSI: 0.2048, Sensitivity: 0.2273, Specificity: 0.9778, False Alarm Ratio: 0.3260
# Integ Loss: 0.0524
#
#
# epoch duration : 98.7870683670044
# saving step
# epoch n° 303
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4325, Regression Loss 1h: 79.0886, Segmentation Loss:0.3604
# Train Confusion Matrix:
# [[3134435   69081]
#  [ 497174  139310]]
# Accuracy: 0.8525, CSI: 0.1974, Sensitivity: 0.2189, Specificity: 0.9784, False Alarm Ratio: 0.3315
# Integ Loss: 0.0525
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4326, Regression Loss 1h: 79.1785, Segmentation Loss:0.3589
# Train Confusion Matrix:
# [[3134458   69058]
#  [ 496566  139918]]
# Accuracy: 0.8527, CSI: 0.1983, Sensitivity: 0.2198, Specificity: 0.9784, False Alarm Ratio: 0.3305
# Integ Loss: 0.0535
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4337, Regression Loss 1h: 80.4627, Segmentation Loss:0.3741
# Train Confusion Matrix:
# [[3125173   78343]
#  [ 491544  144940]]
# Accuracy: 0.8516, CSI: 0.2028, Sensitivity: 0.2277, Specificity: 0.9755, False Alarm Ratio: 0.3509
# Integ Loss: 0.0581
#
#
# train, Regression Loss: 0.4351, Regression Loss 1h: 78.4241, Segmentation Loss:0.3602
# Train Confusion Matrix:
# [[1959288   40625]
#  [ 312818   83429]]
# Accuracy: 0.8525, CSI: 0.1910, Sensitivity: 0.2105, Specificity: 0.9797, False Alarm Ratio: 0.3275
# Integ Loss: 0.0519
#
#
# epoch duration : 98.93347501754761
# saving step
# epoch n° 304
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4372, Regression Loss 1h: 81.9552, Segmentation Loss:0.3593
# Train Confusion Matrix:
# [[3131718   69298]
#  [ 495333  143651]]
# Accuracy: 0.8530, CSI: 0.2028, Sensitivity: 0.2248, Specificity: 0.9784, False Alarm Ratio: 0.3254
# Integ Loss: 0.0529
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4376, Regression Loss 1h: 82.1932, Segmentation Loss:0.3622
# Train Confusion Matrix:
# [[3131838   69178]
#  [ 496334  142650]]
# Accuracy: 0.8527, CSI: 0.2014, Sensitivity: 0.2232, Specificity: 0.9784, False Alarm Ratio: 0.3266
# Integ Loss: 0.0525
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4386, Regression Loss 1h: 82.8768, Segmentation Loss:0.3746
# Train Confusion Matrix:
# [[3122179   78837]
#  [ 491233  147751]]
# Accuracy: 0.8515, CSI: 0.2058, Sensitivity: 0.2312, Specificity: 0.9754, False Alarm Ratio: 0.3479
# Integ Loss: 0.0541
#
#
# train, Regression Loss: 0.4410, Regression Loss 1h: 82.9611, Segmentation Loss:0.3576
# Train Confusion Matrix:
# [[1850925   41334]
#  [ 292941   84240]]
# Accuracy: 0.8527, CSI: 0.2013, Sensitivity: 0.2233, Specificity: 0.9782, False Alarm Ratio: 0.3292
# Integ Loss: 0.0525
#
#
# epoch duration : 99.34829306602478
# saving step
# epoch n° 305
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4375, Regression Loss 1h: 79.8856, Segmentation Loss:0.3584
# Train Confusion Matrix:
# [[3141282   64981]
#  [ 496849  136888]]
# Accuracy: 0.8537, CSI: 0.1959, Sensitivity: 0.2160, Specificity: 0.9797, False Alarm Ratio: 0.3219
# Integ Loss: 0.0528
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4372, Regression Loss 1h: 79.7465, Segmentation Loss:0.3581
# Train Confusion Matrix:
# [[3134015   72248]
#  [ 492680  141057]]
# Accuracy: 0.8529, CSI: 0.1998, Sensitivity: 0.2226, Specificity: 0.9775, False Alarm Ratio: 0.3387
# Integ Loss: 0.0526
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4368, Regression Loss 1h: 79.5670, Segmentation Loss:0.3644
# Train Confusion Matrix:
# [[3119233   87030]
#  [ 485315  148422]]
# Accuracy: 0.8510, CSI: 0.2059, Sensitivity: 0.2342, Specificity: 0.9729, False Alarm Ratio: 0.3696
# Integ Loss: 0.0542
#
#
# train, Regression Loss: 0.4379, Regression Loss 1h: 81.2559, Segmentation Loss:0.3583
# Train Confusion Matrix:
# [[1896296   40686]
#  [ 300500   81878]]
# Accuracy: 0.8529, CSI: 0.1935, Sensitivity: 0.2141, Specificity: 0.9790, False Alarm Ratio: 0.3320
# Integ Loss: 0.0521
#
#
# epoch duration : 98.2215850353241
# saving step
# epoch n° 306
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4374, Regression Loss 1h: 80.3838, Segmentation Loss:0.3600
# Train Confusion Matrix:
# [[3129935   71361]
#  [ 497434  141270]]
# Accuracy: 0.8519, CSI: 0.1990, Sensitivity: 0.2212, Specificity: 0.9777, False Alarm Ratio: 0.3356
# Integ Loss: 0.0535
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4374, Regression Loss 1h: 80.3727, Segmentation Loss:0.3577
# Train Confusion Matrix:
# [[3129984   71312]
#  [ 497801  140903]]
# Accuracy: 0.8518, CSI: 0.1985, Sensitivity: 0.2206, Specificity: 0.9777, False Alarm Ratio: 0.3360
# Integ Loss: 0.0531
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4372, Regression Loss 1h: 80.2605, Segmentation Loss:0.3612
# Train Confusion Matrix:
# [[3122104   79192]
#  [ 493645  145059]]
# Accuracy: 0.8508, CSI: 0.2021, Sensitivity: 0.2271, Specificity: 0.9753, False Alarm Ratio: 0.3531
# Integ Loss: 0.0533
#
#
# train, Regression Loss: 0.4372, Regression Loss 1h: 81.8802, Segmentation Loss:0.3587
# Train Confusion Matrix:
# [[1955645   42379]
#  [ 310410   87726]]
# Accuracy: 0.8528, CSI: 0.1991, Sensitivity: 0.2203, Specificity: 0.9788, False Alarm Ratio: 0.3257
# Integ Loss: 0.0526
#
#
# epoch duration : 100.31229329109192
# saving step
# epoch n° 307
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4352, Regression Loss 1h: 81.8468, Segmentation Loss:0.3610
# Train Confusion Matrix:
# [[3117257   76836]
#  [ 494709  151198]]
# Accuracy: 0.8512, CSI: 0.2092, Sensitivity: 0.2341, Specificity: 0.9759, False Alarm Ratio: 0.3369
# Integ Loss: 0.0536
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4353, Regression Loss 1h: 81.8814, Segmentation Loss:0.3587
# Train Confusion Matrix:
# [[3119331   74762]
#  [ 496552  149355]]
# Accuracy: 0.8512, CSI: 0.2072, Sensitivity: 0.2312, Specificity: 0.9766, False Alarm Ratio: 0.3336
# Integ Loss: 0.0531
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4352, Regression Loss 1h: 81.8330, Segmentation Loss:0.3638
# Train Confusion Matrix:
# [[3111152   82941]
#  [ 492879  153028]]
# Accuracy: 0.8500, CSI: 0.2100, Sensitivity: 0.2369, Specificity: 0.9740, False Alarm Ratio: 0.3515
# Integ Loss: 0.0537
#
#
# train, Regression Loss: 0.4382, Regression Loss 1h: 82.6927, Segmentation Loss:0.3583
# Train Confusion Matrix:
# [[2011582   44580]
#  [ 318732   94226]]
# Accuracy: 0.8529, CSI: 0.2059, Sensitivity: 0.2282, Specificity: 0.9783, False Alarm Ratio: 0.3212
# Integ Loss: 0.0528
#
#
# epoch duration : 99.10641241073608
# saving step
# epoch n° 308

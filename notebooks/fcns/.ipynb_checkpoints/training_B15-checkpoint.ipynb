# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B1.5 radar + gauges 1 min + cmls -> gauges 1 min [xrlg1_yg1]

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 1500
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B15_xrlg1_yg1.pt'
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 20
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 + 60
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn()

# %%
# Boucle avec 5 modes d'évaluation
val_steps = ['eval_opportunity_cost_spat',
             # 'eval_added_value_few_spat',
             # 'eval_added_value_half_spat',
             'eval_added_value_full_spat',
             # 'eval_added_value_full_id',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)

# %%
last_epoch
# Out:
# 1260

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}

  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    #Validation steps
    model.eval()
    with torch.no_grad():

      # splitting
      ng_val_inputs_few = 1
      ng_val_inputs_half = npoints//4  # 5
      ng_val_inputs_comp = npoints//2 - ng_val_inputs_half - ng_val_inputs_few  # 4
      ng_val_targets = npoints//2 # 10

      # val split
      split_val = [ng_val_inputs_few, ng_val_inputs_half, ng_val_inputs_comp, ng_val_targets]
      split_few, split_half, split_comp, split_targets = point_gt(images, npoints=npoints,
                                                                    use_fcn=use_fcn,
                                                                    split=split_val)
      _, point_measurements_fcn_eval_few, _ = split_few
      _, point_measurements_fcn_eval_half, _ = split_half
      _, point_measurements_fcn_eval_comp, _ = split_comp
      _, point_measurements_fcn_val_targets, _ = split_targets

      # 4 first val steps (10 last pluvios for testing generalization)
      targets = point_measurements_fcn_val_targets

      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          0 * point_measurements_fcn_eval_few - 0.1
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()

      # val step 2 : eval_added_value_few_spat
      # step = 'eval_added_value_few_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_few
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 3 : eval_added_value_half_spat
      # step = 'eval_added_value_half_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_half
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 4 : eval_added_value_full_spat
      step = 'eval_added_value_full_spat'

      point_measurements_fcn_eval_full = point_measurements_fcn_eval_few + \
                                          point_measurements_fcn_eval_half + \
                                          point_measurements_fcn_eval_comp

      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_few >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_half >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_comp >= 0)

      point_measurements_fcn_eval_full[point_measurements_fcn_eval_full<0] = -0.1

      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          point_measurements_fcn_eval_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, split_few, split_half, split_comp, split_targets
      torch.cuda.empty_cache()

      # last val step, on the 10 first pluvios : eval_added_value_full_id
      # step = 'eval_added_value_full_id'
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, point_measurements_fcn_eval_full) # inputs pluvios serve as targets
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      del point_measurements_fcn_eval_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    ng_train_inputs = torch.randint(1,9,(1,))
    ng_train_targets = npoints // 2 - ng_train_inputs
    split_train = [ng_train_inputs, ng_train_targets]


    # split  train
    split_inputs, split_targets = point_gt(images, npoints=npoints,
                                           use_fcn=use_fcn,
                                           split=split_train)

    _, point_measurements_fcn_train_inputs, _ = split_inputs
    _, point_measurements_fcn_train_targets, _ = split_targets

    inputs0 = torch.cat([noisy_images,
                        segment_measurements_fcn,
                        point_measurements_fcn_train_inputs
                        ], dim=1)
      
    inputs1 = torch.cat([noisy_images,
                        segment_measurements_fcn,
                        point_measurements_fcn_train_targets
                        ], dim=1)
      
    targets0 = point_measurements_fcn_train_targets
    targets1 = point_measurements_fcn_train_inputs
      
    optimizer.zero_grad()  # Zero the gradients
    outputs0 = model(inputs0)
    outputs1 = model(inputs1)      
    regression_loss, regression_loss_1h, segmentation_loss, loss0, batch_cm, _ = criterion(model.p, outputs0, targets0)
    _, _, _, loss1, _, _ = criterion(model.p, outputs1, targets1)
    loss = loss0 + loss1
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm

    del split_inputs, inputs0, inputs1, outputs0, outputs1, split_targets, loss0, loss1, loss, regression_loss, regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, segment_measurements_fcn
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step]))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 1260
#
# eval_opportunity_cost_spat, Regression Loss: 0.0229, Regression Loss 1h: 307.4009, Segmentation Loss:0.0829
# Train Confusion Matrix:
# [[3158664   54897]
#  [  69611  556828]]
# Accuracy: 0.9676, CSI: 0.8173, Sensitivity: 0.8889, Specificity: 0.9829, False Alarm Ratio: 0.0897
#
#
# eval_added_value_full_spat, Regression Loss: 0.0205, Regression Loss 1h: 315.6091, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3161010   52551]
#  [  63161  563278]]
# Accuracy: 0.9699, CSI: 0.8296, Sensitivity: 0.8992, Specificity: 0.9836, False Alarm Ratio: 0.0853
#
#
# train, Regression Loss: 0.0217, Regression Loss 1h: 325.4887, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[1786150   27770]
#  [  37954  317726]]
# Accuracy: 0.9697, CSI: 0.8286, Sensitivity: 0.8933, Specificity: 0.9847, False Alarm Ratio: 0.0804
#
#
# epoch duration : 110.55076360702515
# saving step
# epoch n° 1261
#
# eval_opportunity_cost_spat, Regression Loss: 0.0232, Regression Loss 1h: 288.2775, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[3143296   52727]
#  [  70346  573631]]
# Accuracy: 0.9679, CSI: 0.8233, Sensitivity: 0.8908, Specificity: 0.9835, False Alarm Ratio: 0.0842
#
#
# eval_added_value_full_spat, Regression Loss: 0.0207, Regression Loss 1h: 310.9138, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[3146967   49056]
#  [  65428  578549]]
# Accuracy: 0.9702, CSI: 0.8348, Sensitivity: 0.8984, Specificity: 0.9847, False Alarm Ratio: 0.0782
#
#
# train, Regression Loss: 0.0217, Regression Loss 1h: 322.3853, Segmentation Loss:0.0753
# Train Confusion Matrix:
# [[1632280   25913]
#  [  35052  303555]]
# Accuracy: 0.9695, CSI: 0.8328, Sensitivity: 0.8965, Specificity: 0.9844, False Alarm Ratio: 0.0787
#
#
# epoch duration : 111.13884854316711
# epoch n° 1262
#
# eval_opportunity_cost_spat, Regression Loss: 0.0226, Regression Loss 1h: 289.8312, Segmentation Loss:0.0824
# Train Confusion Matrix:
# [[3148919   54508]
#  [  69787  566786]]
# Accuracy: 0.9676, CSI: 0.8201, Sensitivity: 0.8904, Specificity: 0.9830, False Alarm Ratio: 0.0877
#
#
# eval_added_value_full_spat, Regression Loss: 0.0203, Regression Loss 1h: 315.0244, Segmentation Loss:0.0754
# Train Confusion Matrix:
# [[3152872   50555]
#  [  64838  571735]]
# Accuracy: 0.9699, CSI: 0.8321, Sensitivity: 0.8981, Specificity: 0.9842, False Alarm Ratio: 0.0812
#
#
# train, Regression Loss: 0.0214, Regression Loss 1h: 321.8819, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[1780838   27549]
#  [  38480  318893]]
# Accuracy: 0.9695, CSI: 0.8285, Sensitivity: 0.8923, Specificity: 0.9848, False Alarm Ratio: 0.0795
#
#
# epoch duration : 112.69664406776428
# epoch n° 1263
#
# eval_opportunity_cost_spat, Regression Loss: 0.0227, Regression Loss 1h: 323.5519, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[3154469   51972]
#  [  71780  561779]]
# Accuracy: 0.9678, CSI: 0.8195, Sensitivity: 0.8867, Specificity: 0.9838, False Alarm Ratio: 0.0847
#
#
# eval_added_value_full_spat, Regression Loss: 0.0203, Regression Loss 1h: 348.0200, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[3157317   49124]
#  [  66131  567428]]
# Accuracy: 0.9700, CSI: 0.8312, Sensitivity: 0.8956, Specificity: 0.9847, False Alarm Ratio: 0.0797
#
#
# train, Regression Loss: 0.0219, Regression Loss 1h: 347.5059, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[1863190   28811]
#  [  39942  329817]]
# Accuracy: 0.9696, CSI: 0.8275, Sensitivity: 0.8920, Specificity: 0.9848, False Alarm Ratio: 0.0803
#
#
# epoch duration : 112.61298298835754
# epoch n° 1264
#
# eval_opportunity_cost_spat, Regression Loss: 0.0224, Regression Loss 1h: 305.1946, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[3146482   51997]
#  [  70573  570948]]
# Accuracy: 0.9681, CSI: 0.8233, Sensitivity: 0.8900, Specificity: 0.9837, False Alarm Ratio: 0.0835
#
#
# eval_added_value_full_spat, Regression Loss: 0.0202, Regression Loss 1h: 322.7303, Segmentation Loss:0.0746
# Train Confusion Matrix:
# [[3149077   49402]
#  [  64307  577214]]
# Accuracy: 0.9704, CSI: 0.8354, Sensitivity: 0.8998, Specificity: 0.9846, False Alarm Ratio: 0.0788
#
#
# train, Regression Loss: 0.0217, Regression Loss 1h: 329.3325, Segmentation Loss:0.0769
# Train Confusion Matrix:
# [[1760960   27018]
#  [  38296  320286]]
# Accuracy: 0.9696, CSI: 0.8306, Sensitivity: 0.8932, Specificity: 0.9849, False Alarm Ratio: 0.0778
#
#
# epoch duration : 112.08354306221008
# epoch n° 1265
#
# eval_opportunity_cost_spat, Regression Loss: 0.0229, Regression Loss 1h: 315.4111, Segmentation Loss:0.0821
# Train Confusion Matrix:
# [[3146995   54333]
#  [  70002  568670]]
# Accuracy: 0.9676, CSI: 0.8206, Sensitivity: 0.8904, Specificity: 0.9830, False Alarm Ratio: 0.0872
#
#
# eval_added_value_full_spat, Regression Loss: 0.0206, Regression Loss 1h: 326.6643, Segmentation Loss:0.0756
# Train Confusion Matrix:
# [[3149414   51914]
#  [  63510  575162]]
# Accuracy: 0.9699, CSI: 0.8329, Sensitivity: 0.9006, Specificity: 0.9838, False Alarm Ratio: 0.0828
#
#
# train, Regression Loss: 0.0217, Regression Loss 1h: 338.9000, Segmentation Loss:0.0774
# Train Confusion Matrix:
# [[1755842   28258]
#  [  38747  323713]]
# Accuracy: 0.9688, CSI: 0.8285, Sensitivity: 0.8931, Specificity: 0.9842, False Alarm Ratio: 0.0803
#
#
# epoch duration : 115.14954471588135
# epoch n° 1266
#
# eval_opportunity_cost_spat, Regression Loss: 0.0231, Regression Loss 1h: 318.1062, Segmentation Loss:0.0829
# Train Confusion Matrix:
# [[3132493   56586]
#  [  69230  581691]]
# Accuracy: 0.9672, CSI: 0.8222, Sensitivity: 0.8936, Specificity: 0.9823, False Alarm Ratio: 0.0887
#
#
# eval_added_value_full_spat, Regression Loss: 0.0207, Regression Loss 1h: 337.9046, Segmentation Loss:0.0763
# Train Confusion Matrix:
# [[3136251   52828]
#  [  64228  586693]]
# Accuracy: 0.9695, CSI: 0.8337, Sensitivity: 0.9013, Specificity: 0.9834, False Alarm Ratio: 0.0826
#
#
# train, Regression Loss: 0.0215, Regression Loss 1h: 346.8851, Segmentation Loss:0.0766
# Train Confusion Matrix:
# [[1638504   25582]
#  [  36005  300549]]
# Accuracy: 0.9692, CSI: 0.8299, Sensitivity: 0.8930, Specificity: 0.9846, False Alarm Ratio: 0.0784
#
#
# epoch duration : 113.16551041603088
# epoch n° 1267
#
# eval_opportunity_cost_spat, Regression Loss: 0.0232, Regression Loss 1h: 300.1649, Segmentation Loss:0.0828
# Train Confusion Matrix:
# [[3141638   54593]
#  [  69588  574181]]
# Accuracy: 0.9677, CSI: 0.8222, Sensitivity: 0.8919, Specificity: 0.9829, False Alarm Ratio: 0.0868
#
#
# eval_added_value_full_spat, Regression Loss: 0.0207, Regression Loss 1h: 316.4761, Segmentation Loss:0.0760
# Train Confusion Matrix:
# [[3144869   51362]
#  [  63962  579807]]
# Accuracy: 0.9700, CSI: 0.8341, Sensitivity: 0.9006, Specificity: 0.9839, False Alarm Ratio: 0.0814
#
#
# train, Regression Loss: 0.0219, Regression Loss 1h: 322.4272, Segmentation Loss:0.0769
# Train Confusion Matrix:
# [[1868358   29293]
#  [  39990  339479]]
# Accuracy: 0.9696, CSI: 0.8305, Sensitivity: 0.8946, Specificity: 0.9846, False Alarm Ratio: 0.0794
#
#
# epoch duration : 116.01637935638428
# epoch n° 1268

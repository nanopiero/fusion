# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A1 radar + cmls -> rain gauges 1 min  [xrl_yg1]

# %%
# ! git clone https://github.com/nanopiero/fusion.git

# %%
import torch
import logging
logger = logging.getLogger("torch")
logger.setLevel(logging.ERROR)  # Show only errors, ignore warnings

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 1500
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_A1_xrl_yg1.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
ch_in = 72
ch_out = nsteps * 3
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
criterion = QPELoss_fcn()

# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
import warnings
warnings.filterwarnings("ignore")
model.train()
for epoch in range(last_epoch, num_epochs + 1):
  print('epoch n°', epoch)
  t = time.time()
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)  # Forward pass
    
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

      
    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()
    
    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 0
# Training, Regression Loss: 0.1172, Regression Loss 1h: 472.4958, Segmentation Loss:0.2707
# Train Confusion Matrix:
# [[3085217  116163]
#  [ 284667  353953]]
# Accuracy: 0.8956, CSI: 0.4689, Sensitivity: 0.5542, Specificity: 0.9637, False Alarm Ratio: 0.2471
#
#
# epoch duration : 61.15808725357056
# saving step
# epoch n° 1
# Training, Regression Loss: 0.0783, Regression Loss 1h: 270.5446, Segmentation Loss:0.2077
# Train Confusion Matrix:
# [[3106664   97548]
#  [ 190185  445603]]
# Accuracy: 0.9251, CSI: 0.6076, Sensitivity: 0.7009, Specificity: 0.9696, False Alarm Ratio: 0.1796
#
#
# epoch duration : 61.05767011642456
# epoch n° 2
# Training, Regression Loss: 0.0689, Regression Loss 1h: 245.9546, Segmentation Loss:0.1955
# Train Confusion Matrix:
# [[3107956   96280]
#  [ 177085  458679]]
# Accuracy: 0.9288, CSI: 0.6266, Sensitivity: 0.7215, Specificity: 0.9700, False Alarm Ratio: 0.1735
#
#
# epoch duration : 60.61017441749573
# epoch n° 3
# Training, Regression Loss: 0.0625, Regression Loss 1h: 225.6369, Segmentation Loss:0.2019
# Train Confusion Matrix:
# [[3108095   92625]
#  [ 187211  452069]]
# Accuracy: 0.9271, CSI: 0.6177, Sensitivity: 0.7072, Specificity: 0.9711, False Alarm Ratio: 0.1700
#
#
# epoch duration : 60.19250011444092
# epoch n° 4
# Training, Regression Loss: 0.0594, Regression Loss 1h: 223.5871, Segmentation Loss:0.1896
# Train Confusion Matrix:
# [[3104022   93643]
#  [ 174149  468186]]
# Accuracy: 0.9303, CSI: 0.6361, Sensitivity: 0.7289, Specificity: 0.9707, False Alarm Ratio: 0.1667
#
#
# epoch duration : 60.3466796875
# epoch n° 5
# Training, Regression Loss: 0.0598, Regression Loss 1h: 226.2200, Segmentation Loss:0.1844
# Train Confusion Matrix:
# [[3098115   91876]
#  [ 168759  481250]]
# Accuracy: 0.9321, CSI: 0.6487, Sensitivity: 0.7404, Specificity: 0.9712, False Alarm Ratio: 0.1603
#
#
# epoch duration : 61.17291450500488
# epoch n° 6
# Training, Regression Loss: 0.0550, Regression Loss 1h: 215.1447, Segmentation Loss:0.1791
# Train Confusion Matrix:
# [[3118723   88550]
#  [ 164604  468123]]
# Accuracy: 0.9341, CSI: 0.6490, Sensitivity: 0.7398, Specificity: 0.9724, False Alarm Ratio: 0.1591
#
#
# epoch duration : 60.72736954689026
# epoch n° 7
# Training, Regression Loss: 0.0540, Regression Loss 1h: 221.6557, Segmentation Loss:0.1778
# Train Confusion Matrix:
# [[3110186   88906]
#  [ 164693  476215]]
# Accuracy: 0.9340, CSI: 0.6525, Sensitivity: 0.7430, Specificity: 0.9722, False Alarm Ratio: 0.1573
#
#
# epoch duration : 62.889349937438965
# epoch n° 8
# Training, Regression Loss: 0.0540, Regression Loss 1h: 222.0127, Segmentation Loss:0.1674
# Train Confusion Matrix:
# [[3116551   88022]
#  [ 151647  483780]]
# Accuracy: 0.9376, CSI: 0.6687, Sensitivity: 0.7613, Specificity: 0.9725, False Alarm Ratio: 0.1539
#
#
# epoch duration : 63.615472078323364
# epoch n° 9
# Training, Regression Loss: 0.0523, Regression Loss 1h: 219.4207, Segmentation Loss:0.1659
# Train Confusion Matrix:
# [[3098472   91749]
#  [ 148657  501122]]
# Accuracy: 0.9374, CSI: 0.6758, Sensitivity: 0.7712, Specificity: 0.9712, False Alarm Ratio: 0.1548
#
#
# epoch duration : 64.25584602355957
# epoch n° 10
# Training, Regression Loss: 0.0523, Regression Loss 1h: 223.8039, Segmentation Loss:0.1690
# Train Confusion Matrix:
# [[3103896   89032]
#  [ 155632  491440]]
# Accuracy: 0.9363, CSI: 0.6676, Sensitivity: 0.7595, Specificity: 0.9721, False Alarm Ratio: 0.1534
#
#
# epoch duration : 64.80655908584595
# saving step
# epoch n° 11
# Training, Regression Loss: 0.0502, Regression Loss 1h: 206.4563, Segmentation Loss:0.1700
# Train Confusion Matrix:
# [[3110473   86943]
#  [ 157734  484850]]
# Accuracy: 0.9363, CSI: 0.6646, Sensitivity: 0.7545, Specificity: 0.9728, False Alarm Ratio: 0.1521
#
#
# epoch duration : 64.485342502594
# epoch n° 12
# Training, Regression Loss: 0.0511, Regression Loss 1h: 223.0641, Segmentation Loss:0.1605
# Train Confusion Matrix:
# [[3103496   88474]
#  [ 146130  501900]]
# Accuracy: 0.9389, CSI: 0.6815, Sensitivity: 0.7745, Specificity: 0.9723, False Alarm Ratio: 0.1499
#
#
# epoch duration : 65.1174635887146
# epoch n° 13
# Training, Regression Loss: 0.0493, Regression Loss 1h: 216.7980, Segmentation Loss:0.1640
# Train Confusion Matrix:
# [[3105115   87060]
#  [ 151733  496092]]
# Accuracy: 0.9378, CSI: 0.6751, Sensitivity: 0.7658, Specificity: 0.9727, False Alarm Ratio: 0.1493
#
#
# epoch duration : 64.99968481063843
# epoch n° 14
# Training, Regression Loss: 0.0493, Regression Loss 1h: 212.9151, Segmentation Loss:0.1617
# Train Confusion Matrix:
# [[3114869   86826]
#  [ 147913  490392]]
# Accuracy: 0.9389, CSI: 0.6763, Sensitivity: 0.7683, Specificity: 0.9729, False Alarm Ratio: 0.1504
#
#
# epoch duration : 65.90579223632812
# epoch n° 15
# Training, Regression Loss: 0.0485, Regression Loss 1h: 221.0365, Segmentation Loss:0.1622
# Train Confusion Matrix:
# [[3106249   88888]
#  [ 148924  495939]]
# Accuracy: 0.9381, CSI: 0.6759, Sensitivity: 0.7691, Specificity: 0.9722, False Alarm Ratio: 0.1520
#
#
# epoch duration : 64.60931706428528
# epoch n° 16
# Training, Regression Loss: 0.0482, Regression Loss 1h: 213.4790, Segmentation Loss:0.1592
# Train Confusion Matrix:
# [[3115295   85456]
#  [ 148073  491176]]
# Accuracy: 0.9392, CSI: 0.6778, Sensitivity: 0.7684, Specificity: 0.9733, False Alarm Ratio: 0.1482
#
#
# epoch duration : 65.12867140769958
# epoch n° 17
# Training, Regression Loss: 0.0477, Regression Loss 1h: 227.8246, Segmentation Loss:0.1549
# Train Confusion Matrix:
# [[3120054   86707]
#  [ 142092  491147]]
# Accuracy: 0.9404, CSI: 0.6822, Sensitivity: 0.7756, Specificity: 0.9730, False Alarm Ratio: 0.1501
#
#
# epoch duration : 65.63959264755249
# epoch n° 18
# Training, Regression Loss: 0.0470, Regression Loss 1h: 214.8146, Segmentation Loss:0.1537
# Train Confusion Matrix:
# [[3117128   86253]
#  [ 139586  497033]]
# Accuracy: 0.9412, CSI: 0.6876, Sensitivity: 0.7807, Specificity: 0.9731, False Alarm Ratio: 0.1479
#
#
# epoch duration : 65.7866952419281
# epoch n° 19
# Training, Regression Loss: 0.0471, Regression Loss 1h: 228.3347, Segmentation Loss:0.1552
# Train Confusion Matrix:
# [[3122181   85691]
#  [ 143532  488596]]
# Accuracy: 0.9403, CSI: 0.6807, Sensitivity: 0.7729, Specificity: 0.9733, False Alarm Ratio: 0.1492
#
#
# epoch duration : 64.44574451446533
# epoch n° 20
# Training, Regression Loss: 0.0464, Regression Loss 1h: 218.1674, Segmentation Loss:0.1580
# Train Confusion Matrix:
# [[3108178   86759]
#  [ 146734  498329]]
# Accuracy: 0.9392, CSI: 0.6809, Sensitivity: 0.7725, Specificity: 0.9728, False Alarm Ratio: 0.1483
#
#
# epoch duration : 66.44771957397461
# saving step
# epoch n° 21
# Training, Regression Loss: 0.0465, Regression Loss 1h: 212.9796, Segmentation Loss:0.1568
# Train Confusion Matrix:
# [[3108826   85474]
#  [ 144138  501562]]
# Accuracy: 0.9402, CSI: 0.6860, Sensitivity: 0.7768, Specificity: 0.9732, False Alarm Ratio: 0.1456
#
#
# epoch duration : 65.64245414733887
# epoch n° 22
# Training, Regression Loss: 0.0462, Regression Loss 1h: 222.4614, Segmentation Loss:0.1532
# Train Confusion Matrix:
# [[3112900   86127]
#  [ 140962  500011]]
# Accuracy: 0.9409, CSI: 0.6877, Sensitivity: 0.7801, Specificity: 0.9731, False Alarm Ratio: 0.1469
#
#
# epoch duration : 65.27300524711609
# epoch n° 23
# Training, Regression Loss: 0.0464, Regression Loss 1h: 217.9156, Segmentation Loss:0.1536
# Train Confusion Matrix:
# [[3116269   85868]
#  [ 140905  496958]]
# Accuracy: 0.9409, CSI: 0.6867, Sensitivity: 0.7791, Specificity: 0.9732, False Alarm Ratio: 0.1473
#
#
# epoch duration : 66.59725713729858
# epoch n° 24
# Training, Regression Loss: 0.0454, Regression Loss 1h: 210.9349, Segmentation Loss:0.1551
# Train Confusion Matrix:
# [[3114961   86160]
#  [ 144033  494846]]
# Accuracy: 0.9401, CSI: 0.6825, Sensitivity: 0.7746, Specificity: 0.9731, False Alarm Ratio: 0.1483
#
#
# epoch duration : 67.48117518424988
# epoch n° 25
# Training, Regression Loss: 0.0455, Regression Loss 1h: 215.8703, Segmentation Loss:0.1484
# Train Confusion Matrix:
# [[3123961   84960]
#  [ 135363  495716]]
# Accuracy: 0.9426, CSI: 0.6923, Sensitivity: 0.7855, Specificity: 0.9735, False Alarm Ratio: 0.1463
#
#
# epoch duration : 69.77647590637207
# epoch n° 26
# Training, Regression Loss: 0.0463, Regression Loss 1h: 216.2252, Segmentation Loss:0.1496
# Train Confusion Matrix:
# [[3112262   86450]
#  [ 136919  504369]]
# Accuracy: 0.9418, CSI: 0.6931, Sensitivity: 0.7865, Specificity: 0.9730, False Alarm Ratio: 0.1463
#
#
# epoch duration : 70.3435447216034
# epoch n° 27
# Training, Regression Loss: 0.0466, Regression Loss 1h: 218.2055, Segmentation Loss:0.1479
# Train Confusion Matrix:
# [[3104565   86428]
#  [ 134237  514770]]
# Accuracy: 0.9425, CSI: 0.7000, Sensitivity: 0.7932, Specificity: 0.9729, False Alarm Ratio: 0.1438
#
#
# epoch duration : 71.40060329437256
# epoch n° 28
# Training, Regression Loss: 0.0439, Regression Loss 1h: 217.0400, Segmentation Loss:0.1546
# Train Confusion Matrix:
# [[3106969   83780]
#  [ 145216  504035]]
# Accuracy: 0.9404, CSI: 0.6876, Sensitivity: 0.7763, Specificity: 0.9737, False Alarm Ratio: 0.1425
#
#
# epoch duration : 69.31528925895691
# epoch n° 29
# Training, Regression Loss: 0.0458, Regression Loss 1h: 223.3400, Segmentation Loss:0.1471
# Train Confusion Matrix:
# [[3122854   84052]
#  [ 135754  497340]]
# Accuracy: 0.9428, CSI: 0.6935, Sensitivity: 0.7856, Specificity: 0.9738, False Alarm Ratio: 0.1446
#
#
# epoch duration : 69.71677613258362
# epoch n° 30
# Training, Regression Loss: 0.0454, Regression Loss 1h: 221.7106, Segmentation Loss:0.1441
# Train Confusion Matrix:
# [[3108239   85989]
#  [ 130616  515156]]
# Accuracy: 0.9436, CSI: 0.7040, Sensitivity: 0.7977, Specificity: 0.9731, False Alarm Ratio: 0.1430
#
#
# epoch duration : 69.72797083854675
# saving step
# epoch n° 31
# Training, Regression Loss: 0.0451, Regression Loss 1h: 226.0076, Segmentation Loss:0.1475
# Train Confusion Matrix:
# [[3115598   83861]
#  [ 137148  503393]]
# Accuracy: 0.9424, CSI: 0.6949, Sensitivity: 0.7859, Specificity: 0.9738, False Alarm Ratio: 0.1428
#
#
# epoch duration : 70.51566696166992
# epoch n° 32
# Training, Regression Loss: 0.0433, Regression Loss 1h: 213.7865, Segmentation Loss:0.1469
# Train Confusion Matrix:
# [[3112579   83689]
#  [ 135228  508504]]
# Accuracy: 0.9430, CSI: 0.6991, Sensitivity: 0.7899, Specificity: 0.9738, False Alarm Ratio: 0.1413
#
#
# epoch duration : 70.14172410964966
# epoch n° 33
# Training, Regression Loss: 0.0447, Regression Loss 1h: 211.9455, Segmentation Loss:0.1434
# Train Confusion Matrix:
# [[3120053   82935]
#  [ 130852  506160]]
# Accuracy: 0.9443, CSI: 0.7031, Sensitivity: 0.7946, Specificity: 0.9741, False Alarm Ratio: 0.1408
#
#
# epoch duration : 68.96383595466614
# epoch n° 34
# Training, Regression Loss: 0.0433, Regression Loss 1h: 211.3304, Segmentation Loss:0.1464
# Train Confusion Matrix:
# [[3118605   83685]
#  [ 135110  502600]]
# Accuracy: 0.9430, CSI: 0.6967, Sensitivity: 0.7881, Specificity: 0.9739, False Alarm Ratio: 0.1427
#
#
# epoch duration : 70.30016255378723
# epoch n° 35
# Training, Regression Loss: 0.0433, Regression Loss 1h: 207.0233, Segmentation Loss:0.1479
# Train Confusion Matrix:
# [[3100723   85954]
#  [ 136273  517050]]
# Accuracy: 0.9421, CSI: 0.6994, Sensitivity: 0.7914, Specificity: 0.9730, False Alarm Ratio: 0.1425
#
#
# epoch duration : 69.14752244949341
# epoch n° 36
# Training, Regression Loss: 0.0444, Regression Loss 1h: 213.7900, Segmentation Loss:0.1472
# Train Confusion Matrix:
# [[3107293   83866]
#  [ 137082  511759]]
# Accuracy: 0.9425, CSI: 0.6984, Sensitivity: 0.7887, Specificity: 0.9737, False Alarm Ratio: 0.1408
#
#
# epoch duration : 72.06648755073547
# epoch n° 37
# Training, Regression Loss: 0.0436, Regression Loss 1h: 217.9250, Segmentation Loss:0.1470
# Train Confusion Matrix:
# [[3107937   84393]
#  [ 136699  510971]]
# Accuracy: 0.9424, CSI: 0.6980, Sensitivity: 0.7889, Specificity: 0.9736, False Alarm Ratio: 0.1418
#
#
# epoch duration : 70.20227861404419
# epoch n° 38
# Training, Regression Loss: 0.0443, Regression Loss 1h: 213.1320, Segmentation Loss:0.1441
# Train Confusion Matrix:
# [[3113019   83031]
#  [ 133068  510882]]
# Accuracy: 0.9437, CSI: 0.7027, Sensitivity: 0.7934, Specificity: 0.9740, False Alarm Ratio: 0.1398
#
#
# epoch duration : 70.30430769920349
# epoch n° 39
# Training, Regression Loss: 0.0443, Regression Loss 1h: 231.7352, Segmentation Loss:0.1405
# Train Confusion Matrix:
# [[3123685   82810]
#  [ 128375  505130]]
# Accuracy: 0.9450, CSI: 0.7052, Sensitivity: 0.7974, Specificity: 0.9742, False Alarm Ratio: 0.1408
#
#
# epoch duration : 69.42652440071106
# epoch n° 40
# Training, Regression Loss: 0.0435, Regression Loss 1h: 208.7774, Segmentation Loss:0.1462
# Train Confusion Matrix:
# [[3111853   82097]
#  [ 135784  510266]]
# Accuracy: 0.9433, CSI: 0.7008, Sensitivity: 0.7898, Specificity: 0.9743, False Alarm Ratio: 0.1386
#
#
# epoch duration : 70.68597960472107
# saving step
# epoch n° 41
# Training, Regression Loss: 0.0424, Regression Loss 1h: 210.9126, Segmentation Loss:0.1455
# Train Confusion Matrix:
# [[3116849   82741]
#  [ 135633  504777]]
# Accuracy: 0.9431, CSI: 0.6980, Sensitivity: 0.7882, Specificity: 0.9741, False Alarm Ratio: 0.1408
#
#
# epoch duration : 70.21126937866211
# epoch n° 42
# Training, Regression Loss: 0.0431, Regression Loss 1h: 217.7574, Segmentation Loss:0.1443
# Train Confusion Matrix:
# [[3108340   83229]
#  [ 133636  514795]]
# Accuracy: 0.9435, CSI: 0.7036, Sensitivity: 0.7939, Specificity: 0.9739, False Alarm Ratio: 0.1392
#
#
# epoch duration : 69.95798087120056
# epoch n° 43
# Training, Regression Loss: 0.0444, Regression Loss 1h: 218.6040, Segmentation Loss:0.1424
# Train Confusion Matrix:
# [[3119422   81411]
#  [ 132040  507127]]
# Accuracy: 0.9444, CSI: 0.7038, Sensitivity: 0.7934, Specificity: 0.9746, False Alarm Ratio: 0.1383
#
#
# epoch duration : 70.11879062652588
# epoch n° 44
# Training, Regression Loss: 0.0419, Regression Loss 1h: 213.8402, Segmentation Loss:0.1401
# Train Confusion Matrix:
# [[3118156   82669]
#  [ 128553  510622]]
# Accuracy: 0.9450, CSI: 0.7074, Sensitivity: 0.7989, Specificity: 0.9742, False Alarm Ratio: 0.1393
#
#
# epoch duration : 71.5792088508606
# epoch n° 45
# Training, Regression Loss: 0.0420, Regression Loss 1h: 214.8703, Segmentation Loss:0.1385
# Train Confusion Matrix:
# [[3118570   81132]
#  [ 127680  512618]]
# Accuracy: 0.9456, CSI: 0.7106, Sensitivity: 0.8006, Specificity: 0.9746, False Alarm Ratio: 0.1366
#
#
# epoch duration : 72.20374202728271
# epoch n° 46
# Training, Regression Loss: 0.0432, Regression Loss 1h: 224.6615, Segmentation Loss:0.1408
# Train Confusion Matrix:
# [[3112024   82496]
#  [ 130466  515014]]
# Accuracy: 0.9445, CSI: 0.7075, Sensitivity: 0.7979, Specificity: 0.9742, False Alarm Ratio: 0.1381
#
#
# epoch duration : 70.85417485237122
# epoch n° 47
# Training, Regression Loss: 0.0410, Regression Loss 1h: 213.2175, Segmentation Loss:0.1412
# Train Confusion Matrix:
# [[3122189   80394]
#  [ 131047  506370]]
# Accuracy: 0.9449, CSI: 0.7054, Sensitivity: 0.7944, Specificity: 0.9749, False Alarm Ratio: 0.1370
#
#
# epoch duration : 70.75429058074951
# epoch n° 48
# Training, Regression Loss: 0.0419, Regression Loss 1h: 212.3538, Segmentation Loss:0.1413
# Train Confusion Matrix:
# [[3126409   80484]
#  [ 131763  501344]]
# Accuracy: 0.9447, CSI: 0.7026, Sensitivity: 0.7919, Specificity: 0.9749, False Alarm Ratio: 0.1383
#
#
# epoch duration : 70.09968161582947
# epoch n° 49
# Training, Regression Loss: 0.0413, Regression Loss 1h: 222.4604, Segmentation Loss:0.1398
# Train Confusion Matrix:
# [[3122960   80644]
#  [ 129379  507017]]
# Accuracy: 0.9453, CSI: 0.7071, Sensitivity: 0.7967, Specificity: 0.9748, False Alarm Ratio: 0.1372
#
#
# epoch duration : 70.26928067207336
# epoch n° 50
# Training, Regression Loss: 0.0414, Regression Loss 1h: 229.1124, Segmentation Loss:0.1417
# Train Confusion Matrix:
# [[3111575   82136]
#  [ 131314  514975]]
# Accuracy: 0.9444, CSI: 0.7070, Sensitivity: 0.7968, Specificity: 0.9743, False Alarm Ratio: 0.1376
#
#
# epoch duration : 71.40685272216797
# saving step
# epoch n° 51
# Training, Regression Loss: 0.0425, Regression Loss 1h: 216.4905, Segmentation Loss:0.1374
# Train Confusion Matrix:
# [[3121287   79532]
#  [ 127112  512069]]
# Accuracy: 0.9462, CSI: 0.7125, Sensitivity: 0.8011, Specificity: 0.9752, False Alarm Ratio: 0.1344
#
#
# epoch duration : 69.65317034721375
# epoch n° 52
# Training, Regression Loss: 0.0400, Regression Loss 1h: 225.2932, Segmentation Loss:0.1428
# Train Confusion Matrix:
# [[3117697   81846]
#  [ 133537  506920]]
# Accuracy: 0.9439, CSI: 0.7018, Sensitivity: 0.7915, Specificity: 0.9744, False Alarm Ratio: 0.1390
#
#
# epoch duration : 69.92611718177795
# epoch n° 53
# Training, Regression Loss: 0.0393, Regression Loss 1h: 235.8148, Segmentation Loss:0.1401
# Train Confusion Matrix:
# [[3117667   82134]
#  [ 130386  509813]]
# Accuracy: 0.9447, CSI: 0.7058, Sensitivity: 0.7963, Specificity: 0.9743, False Alarm Ratio: 0.1388
#
#
# epoch duration : 69.95051002502441
# epoch n° 54
# Training, Regression Loss: 0.0408, Regression Loss 1h: 233.3383, Segmentation Loss:0.1368
# Train Confusion Matrix:
# [[3110056   82297]
#  [ 124587  523060]]
# Accuracy: 0.9461, CSI: 0.7166, Sensitivity: 0.8076, Specificity: 0.9742, False Alarm Ratio: 0.1359
#
#
# epoch duration : 70.78588080406189
# epoch n° 55
# Training, Regression Loss: 0.0398, Regression Loss 1h: 234.4126, Segmentation Loss:0.1399
# Train Confusion Matrix:
# [[3114654   81769]
#  [ 129796  513781]]
# Accuracy: 0.9449, CSI: 0.7083, Sensitivity: 0.7983, Specificity: 0.9744, False Alarm Ratio: 0.1373
#
#
# epoch duration : 71.42270708084106
# epoch n° 56
# Training, Regression Loss: 0.0400, Regression Loss 1h: 240.6404, Segmentation Loss:0.1384
# Train Confusion Matrix:
# [[3123906   80232]
#  [ 128595  507267]]
# Accuracy: 0.9456, CSI: 0.7084, Sensitivity: 0.7978, Specificity: 0.9750, False Alarm Ratio: 0.1366
#
#
# epoch duration : 71.07482266426086
# epoch n° 57
# Training, Regression Loss: 0.0388, Regression Loss 1h: 239.7765, Segmentation Loss:0.1375
# Train Confusion Matrix:
# [[3106138   82272]
#  [ 126691  524899]]
# Accuracy: 0.9456, CSI: 0.7153, Sensitivity: 0.8056, Specificity: 0.9742, False Alarm Ratio: 0.1355
#
#
# epoch duration : 70.78518152236938
# epoch n° 58

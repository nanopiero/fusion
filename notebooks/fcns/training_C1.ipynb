# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## C11 radar + cmls -> radar + rain gauges 1 min  [xrl_yrg1]
# 12 out channels are added
# At each loop's step:
#     - substep 1: segmentation step with the radar mask as target
#     - substep 2: regression step with raing gauge data as target

# %%
# ! git clone https://github.com/nanopiero/fusion.git

# %%
import torch
import logging
logger = logging.getLogger("torch")
logger.setLevel(logging.ERROR)  # Show only errors, ignore warnings

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_C11_xrl_yrg1.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
ch_in = 72
ch_out = nsteps * 3 + 2*12
size = nsteps * 3 

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
import torch.nn as nn
criterion = QPELoss_fcn()
criterion_segmentation = nn.CrossEntropyLoss()

# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")
model.train()
for epoch in range(last_epoch, num_epochs + 1):
  print('epoch n°', epoch)
  t = time.time()
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)
    bs = images.shape[0]
      
    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    optimizer.zero_grad()  # Zero the gradients
    # substep 1 : segmentation on radar targets
    inputs = torch.cat([0 * noisy_images, segment_measurements_fcn], dim=1)
    targets = noisy_images
      
    outputs = model(inputs)  # Forward pass
    segmentation_radar_output = torch.cat([outputs[:, -2*12:-12, ...].view(bs,1,12,-1),outputs[:, -12:, ...].view(bs,1,12,-1)], dim=1)
    loss = criterion_segmentation(segmentation_radar_output, targets.long().view(bs,12,-1))
    loss.backward()  # Backward pass
      
    loss_segmentation_radar = loss.item()

      
    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn

    outputs = model(inputs)  # Forward pass
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass

    # substep 2
    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn

    outputs = model(inputs)  # Forward pass
    
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

      
    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()
    
    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix, loss_segmentation_radar))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 0
# Training, Regression Loss: 0.1159, Regression Loss 1h: 473.1466, Segmentation Loss:0.2881
# Train Confusion Matrix:
# [[3081748  111818]
#  [ 325824  320610]]
# Accuracy: 0.8860, CSI: 0.4228, Sensitivity: 0.4960, Specificity: 0.9650, False Alarm Ratio: 0.2586
#
#
# epoch duration : 192.10221934318542
# saving step
# epoch n° 1
# Training, Regression Loss: 0.0768, Regression Loss 1h: 253.8390, Segmentation Loss:0.2114
# Train Confusion Matrix:
# [[3098768  101145]
#  [ 196603  443484]]
# Accuracy: 0.9225, CSI: 0.5983, Sensitivity: 0.6928, Specificity: 0.9684, False Alarm Ratio: 0.1857
#
#
# epoch duration : 188.20910620689392
# epoch n° 2
# Training, Regression Loss: 0.0650, Regression Loss 1h: 226.7098, Segmentation Loss:0.1957
# Train Confusion Matrix:
# [[3096573   97328]
#  [ 179088  467011]]
# Accuracy: 0.9280, CSI: 0.6282, Sensitivity: 0.7228, Specificity: 0.9695, False Alarm Ratio: 0.1725
#
#
# epoch duration : 185.92811179161072
# epoch n° 3
# Training, Regression Loss: 0.0608, Regression Loss 1h: 215.5366, Segmentation Loss:0.1883
# Train Confusion Matrix:
# [[3100010   95623]
#  [ 174676  469691]]
# Accuracy: 0.9296, CSI: 0.6347, Sensitivity: 0.7289, Specificity: 0.9701, False Alarm Ratio: 0.1692
#
#
# epoch duration : 182.49791431427002
# epoch n° 4
# Training, Regression Loss: 0.0569, Regression Loss 1h: 213.2261, Segmentation Loss:0.1851
# Train Confusion Matrix:
# [[3103924   92384]
#  [ 174417  469275]]
# Accuracy: 0.9305, CSI: 0.6375, Sensitivity: 0.7290, Specificity: 0.9711, False Alarm Ratio: 0.1645
#
#
# epoch duration : 188.33287596702576
# epoch n° 5
# Training, Regression Loss: 0.0562, Regression Loss 1h: 200.7198, Segmentation Loss:0.1728
# Train Confusion Matrix:
# [[3102747   94414]
#  [ 158064  484775]]
# Accuracy: 0.9343, CSI: 0.6575, Sensitivity: 0.7541, Specificity: 0.9705, False Alarm Ratio: 0.1630
#
#
# epoch duration : 185.6062695980072
# epoch n° 6
# Training, Regression Loss: 0.0557, Regression Loss 1h: 205.1066, Segmentation Loss:0.1716
# Train Confusion Matrix:
# [[3109300   93069]
#  [ 159198  478433]]
# Accuracy: 0.9343, CSI: 0.6548, Sensitivity: 0.7503, Specificity: 0.9709, False Alarm Ratio: 0.1628
#
#
# epoch duration : 187.9697027206421
# epoch n° 7
# Training, Regression Loss: 0.0540, Regression Loss 1h: 197.1873, Segmentation Loss:0.1715
# Train Confusion Matrix:
# [[3104181   92174]
#  [ 159211  484434]]
# Accuracy: 0.9345, CSI: 0.6584, Sensitivity: 0.7526, Specificity: 0.9712, False Alarm Ratio: 0.1599
#
#
# epoch duration : 189.34944534301758
# epoch n° 8
# Training, Regression Loss: 0.0524, Regression Loss 1h: 194.8817, Segmentation Loss:0.1682
# Train Confusion Matrix:
# [[3109365   90024]
#  [ 156408  484203]]
# Accuracy: 0.9358, CSI: 0.6627, Sensitivity: 0.7558, Specificity: 0.9719, False Alarm Ratio: 0.1568
#
#
# epoch duration : 188.45684432983398
# epoch n° 9
# Training, Regression Loss: 0.0498, Regression Loss 1h: 195.5942, Segmentation Loss:0.1641
# Train Confusion Matrix:
# [[3107281   90816]
#  [ 151111  490792]]
# Accuracy: 0.9370, CSI: 0.6698, Sensitivity: 0.7646, Specificity: 0.9716, False Alarm Ratio: 0.1561
#
#
# epoch duration : 188.47502946853638
# epoch n° 10
# Training, Regression Loss: 0.0506, Regression Loss 1h: 199.0551, Segmentation Loss:0.1610
# Train Confusion Matrix:
# [[3108664   90462]
#  [ 147837  493037]]
# Accuracy: 0.9379, CSI: 0.6742, Sensitivity: 0.7693, Specificity: 0.9717, False Alarm Ratio: 0.1550
#
#
# epoch duration : 189.73114681243896
# saving step
# epoch n° 11
# Training, Regression Loss: 0.0490, Regression Loss 1h: 197.2275, Segmentation Loss:0.1602
# Train Confusion Matrix:
# [[3106699   91113]
#  [ 146521  495667]]
# Accuracy: 0.9381, CSI: 0.6759, Sensitivity: 0.7718, Specificity: 0.9715, False Alarm Ratio: 0.1553
#
#
# epoch duration : 192.61534237861633
# epoch n° 12
# Training, Regression Loss: 0.0482, Regression Loss 1h: 207.1393, Segmentation Loss:0.1591
# Train Confusion Matrix:
# [[3107666   88677]
#  [ 147790  495867]]
# Accuracy: 0.9384, CSI: 0.6771, Sensitivity: 0.7704, Specificity: 0.9723, False Alarm Ratio: 0.1517
#
#
# epoch duration : 186.94229197502136
# epoch n° 13
# Training, Regression Loss: 0.0482, Regression Loss 1h: 208.0945, Segmentation Loss:0.1528
# Train Confusion Matrix:
# [[3115999   88158]
#  [ 138006  497837]]
# Accuracy: 0.9411, CSI: 0.6876, Sensitivity: 0.7830, Specificity: 0.9725, False Alarm Ratio: 0.1504
#
#
# epoch duration : 185.65679359436035
# epoch n° 14
# Training, Regression Loss: 0.0478, Regression Loss 1h: 197.5022, Segmentation Loss:0.1555
# Train Confusion Matrix:
# [[3104165   88933]
#  [ 142108  504794]]
# Accuracy: 0.9398, CSI: 0.6860, Sensitivity: 0.7803, Specificity: 0.9721, False Alarm Ratio: 0.1498
#
#
# epoch duration : 194.0823278427124
# epoch n° 15
# Training, Regression Loss: 0.0462, Regression Loss 1h: 215.1395, Segmentation Loss:0.1533
# Train Confusion Matrix:
# [[3105412   89345]
#  [ 138869  506374]]
# Accuracy: 0.9406, CSI: 0.6893, Sensitivity: 0.7848, Specificity: 0.9720, False Alarm Ratio: 0.1500
#
#
# epoch duration : 186.20036220550537
# epoch n° 16
# Training, Regression Loss: 0.0469, Regression Loss 1h: 216.6769, Segmentation Loss:0.1543
# Train Confusion Matrix:
# [[3102802   89366]
#  [ 142320  505512]]
# Accuracy: 0.9397, CSI: 0.6857, Sensitivity: 0.7803, Specificity: 0.9720, False Alarm Ratio: 0.1502
#
#
# epoch duration : 190.97727298736572
# epoch n° 17
# Training, Regression Loss: 0.0451, Regression Loss 1h: 222.4607, Segmentation Loss:0.1504
# Train Confusion Matrix:
# [[3108216   88911]
#  [ 137053  505820]]
# Accuracy: 0.9412, CSI: 0.6912, Sensitivity: 0.7868, Specificity: 0.9722, False Alarm Ratio: 0.1495
#
#
# epoch duration : 183.04552745819092
# epoch n° 18
# Training, Regression Loss: 0.0443, Regression Loss 1h: 212.3388, Segmentation Loss:0.1498
# Train Confusion Matrix:
# [[3098664   88458]
#  [ 136226  516652]]
# Accuracy: 0.9415, CSI: 0.6969, Sensitivity: 0.7913, Specificity: 0.9722, False Alarm Ratio: 0.1462
#
#
# epoch duration : 186.19509959220886
# epoch n° 19
# Training, Regression Loss: 0.0442, Regression Loss 1h: 213.5568, Segmentation Loss:0.1499
# Train Confusion Matrix:
# [[3112619   87991]
#  [ 137012  502378]]
# Accuracy: 0.9414, CSI: 0.6907, Sensitivity: 0.7857, Specificity: 0.9725, False Alarm Ratio: 0.1490
#
#
# epoch duration : 183.78361320495605
# epoch n° 20
# Training, Regression Loss: 0.0431, Regression Loss 1h: 202.9457, Segmentation Loss:0.1469
# Train Confusion Matrix:
# [[3116194   85592]
#  [ 133872  504342]]
# Accuracy: 0.9428, CSI: 0.6968, Sensitivity: 0.7902, Specificity: 0.9733, False Alarm Ratio: 0.1451
#
#
# epoch duration : 187.06706953048706
# saving step
# epoch n° 21
# Training, Regression Loss: 0.0446, Regression Loss 1h: 222.7438, Segmentation Loss:0.1444
# Train Confusion Matrix:
# [[3117495   85841]
#  [ 131588  505076]]
# Accuracy: 0.9434, CSI: 0.6991, Sensitivity: 0.7933, Specificity: 0.9732, False Alarm Ratio: 0.1453
#
#
# epoch duration : 185.72494530677795
# epoch n° 22
# Training, Regression Loss: 0.0428, Regression Loss 1h: 223.5300, Segmentation Loss:0.1456
# Train Confusion Matrix:
# [[3108255   86380]
#  [ 133135  512230]]
# Accuracy: 0.9428, CSI: 0.7000, Sensitivity: 0.7937, Specificity: 0.9730, False Alarm Ratio: 0.1443
#
#
# epoch duration : 183.97987532615662
# epoch n° 23
# Training, Regression Loss: 0.0422, Regression Loss 1h: 214.3221, Segmentation Loss:0.1439
# Train Confusion Matrix:
# [[3115244   86312]
#  [ 131311  507133]]
# Accuracy: 0.9433, CSI: 0.6997, Sensitivity: 0.7943, Specificity: 0.9730, False Alarm Ratio: 0.1454
#
#
# epoch duration : 181.39110016822815
# epoch n° 24
# Training, Regression Loss: 0.0422, Regression Loss 1h: 220.5922, Segmentation Loss:0.1444
# Train Confusion Matrix:
# [[3101591   86526]
#  [ 130575  521308]]
# Accuracy: 0.9435, CSI: 0.7060, Sensitivity: 0.7997, Specificity: 0.9729, False Alarm Ratio: 0.1424
#
#
# epoch duration : 182.4466688632965
# epoch n° 25
# Training, Regression Loss: 0.0419, Regression Loss 1h: 221.1305, Segmentation Loss:0.1430
# Train Confusion Matrix:
# [[3113033   84514]
#  [ 130020  512433]]
# Accuracy: 0.9441, CSI: 0.7049, Sensitivity: 0.7976, Specificity: 0.9736, False Alarm Ratio: 0.1416
#
#
# epoch duration : 190.2743058204651
# epoch n° 26
# Training, Regression Loss: 0.0419, Regression Loss 1h: 217.8446, Segmentation Loss:0.1422
# Train Confusion Matrix:
# [[3112903   87533]
#  [ 129110  510454]]
# Accuracy: 0.9436, CSI: 0.7020, Sensitivity: 0.7981, Specificity: 0.9726, False Alarm Ratio: 0.1464
#
#
# epoch duration : 188.9210102558136
# epoch n° 27
# Training, Regression Loss: 0.0417, Regression Loss 1h: 212.7599, Segmentation Loss:0.1429
# Train Confusion Matrix:
# [[3118089   84392]
#  [ 131165  506354]]
# Accuracy: 0.9439, CSI: 0.7014, Sensitivity: 0.7943, Specificity: 0.9736, False Alarm Ratio: 0.1429
#
#
# epoch duration : 183.2880551815033
# epoch n° 28
# Training, Regression Loss: 0.0410, Regression Loss 1h: 222.7285, Segmentation Loss:0.1382
# Train Confusion Matrix:
# [[3115984   84702]
#  [ 125728  513586]]
# Accuracy: 0.9452, CSI: 0.7094, Sensitivity: 0.8033, Specificity: 0.9735, False Alarm Ratio: 0.1416
#
#
# epoch duration : 184.1292359828949
# epoch n° 29
# Training, Regression Loss: 0.0410, Regression Loss 1h: 217.1294, Segmentation Loss:0.1436
# Train Confusion Matrix:
# [[3109029   85611]
#  [ 131964  513396]]
# Accuracy: 0.9433, CSI: 0.7023, Sensitivity: 0.7955, Specificity: 0.9732, False Alarm Ratio: 0.1429
#
#
# epoch duration : 189.25356364250183
# epoch n° 30
# Training, Regression Loss: 0.0409, Regression Loss 1h: 218.9839, Segmentation Loss:0.1392
# Train Confusion Matrix:
# [[3101157   84892]
#  [ 126731  527220]]
# Accuracy: 0.9449, CSI: 0.7136, Sensitivity: 0.8062, Specificity: 0.9734, False Alarm Ratio: 0.1387
#
#
# epoch duration : 182.76675581932068
# saving step
# epoch n° 31
# Training, Regression Loss: 0.0411, Regression Loss 1h: 220.9977, Segmentation Loss:0.1382
# Train Confusion Matrix:
# [[3121060   82150]
#  [ 127042  509748]]
# Accuracy: 0.9455, CSI: 0.7090, Sensitivity: 0.8005, Specificity: 0.9744, False Alarm Ratio: 0.1388
#
#
# epoch duration : 186.13291811943054
# epoch n° 32
# Training, Regression Loss: 0.0411, Regression Loss 1h: 213.1493, Segmentation Loss:0.1360
# Train Confusion Matrix:
# [[3110623   84434]
#  [ 122476  522467]]
# Accuracy: 0.9461, CSI: 0.7163, Sensitivity: 0.8101, Specificity: 0.9736, False Alarm Ratio: 0.1391
#
#
# epoch duration : 182.8939709663391
# epoch n° 33
# Training, Regression Loss: 0.0403, Regression Loss 1h: 212.9833, Segmentation Loss:0.1380
# Train Confusion Matrix:
# [[3118707   83433]
#  [ 126553  511307]]
# Accuracy: 0.9453, CSI: 0.7089, Sensitivity: 0.8016, Specificity: 0.9739, False Alarm Ratio: 0.1403
#
#
# epoch duration : 187.39915919303894
# epoch n° 34
# Training, Regression Loss: 0.0398, Regression Loss 1h: 215.8428, Segmentation Loss:0.1404
# Train Confusion Matrix:
# [[3112304   83781]
#  [ 130301  513614]]
# Accuracy: 0.9442, CSI: 0.7058, Sensitivity: 0.7976, Specificity: 0.9738, False Alarm Ratio: 0.1402
#
#
# epoch duration : 183.12350821495056
# epoch n° 35
# Training, Regression Loss: 0.0388, Regression Loss 1h: 208.5746, Segmentation Loss:0.1397
# Train Confusion Matrix:
# [[3113805   83837]
#  [ 129672  512686]]
# Accuracy: 0.9444, CSI: 0.7060, Sensitivity: 0.7981, Specificity: 0.9738, False Alarm Ratio: 0.1405
#
#
# epoch duration : 184.82443928718567
# epoch n° 36
# Training, Regression Loss: 0.0396, Regression Loss 1h: 215.7512, Segmentation Loss:0.1347
# Train Confusion Matrix:
# [[3119361   83983]
#  [ 122329  514327]]
# Accuracy: 0.9463, CSI: 0.7137, Sensitivity: 0.8079, Specificity: 0.9738, False Alarm Ratio: 0.1404
#
#
# epoch duration : 188.88243007659912
# epoch n° 37
# Training, Regression Loss: 0.0403, Regression Loss 1h: 225.0419, Segmentation Loss:0.1359
# Train Confusion Matrix:
# [[3109201   83135]
#  [ 124903  522761]]
# Accuracy: 0.9458, CSI: 0.7153, Sensitivity: 0.8071, Specificity: 0.9740, False Alarm Ratio: 0.1372
#
#
# epoch duration : 186.95291829109192
# epoch n° 38
# Training, Regression Loss: 0.0406, Regression Loss 1h: 227.2401, Segmentation Loss:0.1360
# Train Confusion Matrix:
# [[3112358   82675]
#  [ 124394  520573]]
# Accuracy: 0.9461, CSI: 0.7154, Sensitivity: 0.8071, Specificity: 0.9741, False Alarm Ratio: 0.1370
#
#
# epoch duration : 188.98188591003418
# epoch n° 39
# Training, Regression Loss: 0.0394, Regression Loss 1h: 206.0243, Segmentation Loss:0.1356
# Train Confusion Matrix:
# [[3114409   81931]
#  [ 124296  519364]]
# Accuracy: 0.9463, CSI: 0.7158, Sensitivity: 0.8069, Specificity: 0.9744, False Alarm Ratio: 0.1363
#
#
# epoch duration : 194.08328771591187
# epoch n° 40
# Training, Regression Loss: 0.0391, Regression Loss 1h: 224.7231, Segmentation Loss:0.1357
# Train Confusion Matrix:
# [[3117421   81375]
#  [ 125276  515928]]
# Accuracy: 0.9462, CSI: 0.7140, Sensitivity: 0.8046, Specificity: 0.9746, False Alarm Ratio: 0.1362
#
#
# epoch duration : 184.4243688583374
# saving step
# epoch n° 41
# Training, Regression Loss: 0.0397, Regression Loss 1h: 225.7760, Segmentation Loss:0.1341
# Train Confusion Matrix:
# [[3113289   82052]
#  [ 122827  521832]]
# Accuracy: 0.9466, CSI: 0.7181, Sensitivity: 0.8095, Specificity: 0.9743, False Alarm Ratio: 0.1359
#
#
# epoch duration : 192.1260735988617
# epoch n° 42
# Training, Regression Loss: 0.0394, Regression Loss 1h: 220.9559, Segmentation Loss:0.1343
# Train Confusion Matrix:
# [[3120917   82937]
#  [ 122908  513238]]
# Accuracy: 0.9464, CSI: 0.7137, Sensitivity: 0.8068, Specificity: 0.9741, False Alarm Ratio: 0.1391
#
#
# epoch duration : 192.50394368171692
# epoch n° 43
# Training, Regression Loss: 0.0388, Regression Loss 1h: 230.1245, Segmentation Loss:0.1316
# Train Confusion Matrix:
# [[3116573   81551]
#  [ 119368  522508]]
# Accuracy: 0.9477, CSI: 0.7223, Sensitivity: 0.8140, Specificity: 0.9745, False Alarm Ratio: 0.1350
#
#
# epoch duration : 194.52716755867004
# epoch n° 44
# Training, Regression Loss: 0.0385, Regression Loss 1h: 230.2093, Segmentation Loss:0.1324
# Train Confusion Matrix:
# [[3114642   81685]
#  [ 121318  522355]]
# Accuracy: 0.9471, CSI: 0.7201, Sensitivity: 0.8115, Specificity: 0.9744, False Alarm Ratio: 0.1352
#
#
# epoch duration : 193.42752051353455
# epoch n° 45
# Training, Regression Loss: 0.0381, Regression Loss 1h: 222.2508, Segmentation Loss:0.1345
# Train Confusion Matrix:
# [[3114603   80962]
#  [ 123985  520450]]
# Accuracy: 0.9466, CSI: 0.7175, Sensitivity: 0.8076, Specificity: 0.9747, False Alarm Ratio: 0.1346
#
#
# epoch duration : 195.86313772201538
# epoch n° 46
# Training, Regression Loss: 0.0390, Regression Loss 1h: 228.9584, Segmentation Loss:0.1285
# Train Confusion Matrix:
# [[3123254   80680]
#  [ 116518  519548]]
# Accuracy: 0.9486, CSI: 0.7249, Sensitivity: 0.8168, Specificity: 0.9748, False Alarm Ratio: 0.1344
#
#
# epoch duration : 196.92535758018494
# epoch n° 47
# Training, Regression Loss: 0.0381, Regression Loss 1h: 216.1241, Segmentation Loss:0.1320
# Train Confusion Matrix:
# [[3119148   81399]
#  [ 121275  518178]]
# Accuracy: 0.9472, CSI: 0.7188, Sensitivity: 0.8103, Specificity: 0.9746, False Alarm Ratio: 0.1358
#
#
# epoch duration : 193.55286121368408
# epoch n° 48
# Training, Regression Loss: 0.0392, Regression Loss 1h: 228.9218, Segmentation Loss:0.1311
# Train Confusion Matrix:
# [[3115377   81156]
#  [ 118614  524853]]
# Accuracy: 0.9480, CSI: 0.7243, Sensitivity: 0.8157, Specificity: 0.9746, False Alarm Ratio: 0.1339
#
#
# epoch duration : 197.90820407867432
# epoch n° 49
# Training, Regression Loss: 0.0375, Regression Loss 1h: 226.5061, Segmentation Loss:0.1332
# Train Confusion Matrix:
# [[3123081   79812]
#  [ 123394  513713]]
# Accuracy: 0.9471, CSI: 0.7166, Sensitivity: 0.8063, Specificity: 0.9751, False Alarm Ratio: 0.1345
#
#
# epoch duration : 197.13199090957642
# epoch n° 50
# Training, Regression Loss: 0.0384, Regression Loss 1h: 227.0190, Segmentation Loss:0.1326
# Train Confusion Matrix:
# [[3112930   82632]
#  [ 121171  523267]]
# Accuracy: 0.9469, CSI: 0.7197, Sensitivity: 0.8120, Specificity: 0.9741, False Alarm Ratio: 0.1364
#
#
# epoch duration : 206.8812289237976
# saving step
# epoch n° 51
# Training, Regression Loss: 0.0377, Regression Loss 1h: 229.5951, Segmentation Loss:0.1323
# Train Confusion Matrix:
# [[3117649   80140]
#  [ 122424  519787]]
# Accuracy: 0.9472, CSI: 0.7196, Sensitivity: 0.8094, Specificity: 0.9749, False Alarm Ratio: 0.1336
#
#
# epoch duration : 205.4991466999054
# epoch n° 52
# Training, Regression Loss: 0.0378, Regression Loss 1h: 223.6243, Segmentation Loss:0.1307
# Train Confusion Matrix:
# [[3114322   80415]
#  [ 119606  525657]]
# Accuracy: 0.9479, CSI: 0.7244, Sensitivity: 0.8146, Specificity: 0.9748, False Alarm Ratio: 0.1327
#
#
# epoch duration : 199.10487866401672
# epoch n° 53
# Training, Regression Loss: 0.0377, Regression Loss 1h: 228.1932, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3123948   79571]
#  [ 117707  518774]]
# Accuracy: 0.9486, CSI: 0.7245, Sensitivity: 0.8151, Specificity: 0.9752, False Alarm Ratio: 0.1330
#
#
# epoch duration : 199.32854223251343
# epoch n° 54
# Training, Regression Loss: 0.0382, Regression Loss 1h: 225.8850, Segmentation Loss:0.1288
# Train Confusion Matrix:
# [[3107250   80854]
#  [ 117369  534527]]
# Accuracy: 0.9484, CSI: 0.7295, Sensitivity: 0.8200, Specificity: 0.9746, False Alarm Ratio: 0.1314
#
#
# epoch duration : 192.64693355560303
# epoch n° 55
# Training, Regression Loss: 0.0376, Regression Loss 1h: 234.1668, Segmentation Loss:0.1284
# Train Confusion Matrix:
# [[3114694   79804]
#  [ 118437  527065]]
# Accuracy: 0.9484, CSI: 0.7267, Sensitivity: 0.8165, Specificity: 0.9750, False Alarm Ratio: 0.1315
#
#
# epoch duration : 193.16268849372864
# epoch n° 56
# Training, Regression Loss: 0.0377, Regression Loss 1h: 223.2772, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3120489   78037]
#  [ 113741  527733]]
# Accuracy: 0.9501, CSI: 0.7335, Sensitivity: 0.8227, Specificity: 0.9756, False Alarm Ratio: 0.1288
#
#
# epoch duration : 196.2403166294098
# epoch n° 58
# Training, Regression Loss: 0.0365, Regression Loss 1h: 221.4167, Segmentation Loss:0.1278
# Train Confusion Matrix:
# [[3121554   78768]
#  [ 117459  522219]]
# Accuracy: 0.9489, CSI: 0.7269, Sensitivity: 0.8164, Specificity: 0.9754, False Alarm Ratio: 0.1311
#
#
# epoch duration : 193.7959566116333
# epoch n° 59
# Training, Regression Loss: 0.0371, Regression Loss 1h: 232.8776, Segmentation Loss:0.1231
# Train Confusion Matrix:
# [[3116326   78388]
#  [ 111251  534035]]
# Accuracy: 0.9506, CSI: 0.7379, Sensitivity: 0.8276, Specificity: 0.9755, False Alarm Ratio: 0.1280
#
#
# epoch duration : 189.68894934654236
# saving step
# epoch n° 61
# Training, Regression Loss: 0.0359, Regression Loss 1h: 223.2145, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3116654   79166]
#  [ 117693  526487]]
# Accuracy: 0.9487, CSI: 0.7278, Sensitivity: 0.8173, Specificity: 0.9752, False Alarm Ratio: 0.1307
#
#
# epoch duration : 187.83149933815002
# epoch n° 62
# Training, Regression Loss: 0.0360, Regression Loss 1h: 239.8309, Segmentation Loss:0.1244
# Train Confusion Matrix:
# [[3111028   79427]
#  [ 113178  536367]]
# Accuracy: 0.9498, CSI: 0.7358, Sensitivity: 0.8258, Specificity: 0.9751, False Alarm Ratio: 0.1290
#
#
# epoch duration : 184.29679918289185
# epoch n° 63
# Training, Regression Loss: 0.0369, Regression Loss 1h: 236.4599, Segmentation Loss:0.1230
# Train Confusion Matrix:
# [[3126332   77942]
#  [ 112563  523163]]
# Accuracy: 0.9504, CSI: 0.7331, Sensitivity: 0.8229, Specificity: 0.9757, False Alarm Ratio: 0.1297
#
#
# epoch duration : 182.8811194896698
# epoch n° 64
# Training, Regression Loss: 0.0364, Regression Loss 1h: 234.0930, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3118377   77641]
#  [ 116052  527930]]
# Accuracy: 0.9496, CSI: 0.7316, Sensitivity: 0.8198, Specificity: 0.9757, False Alarm Ratio: 0.1282
#
#
# epoch duration : 181.5864953994751
# epoch n° 65
# Training, Regression Loss: 0.0357, Regression Loss 1h: 227.1985, Segmentation Loss:0.1244
# Train Confusion Matrix:
# [[3117624   78087]
#  [ 113884  530405]]
# Accuracy: 0.9500, CSI: 0.7343, Sensitivity: 0.8232, Specificity: 0.9756, False Alarm Ratio: 0.1283
#
#
# epoch duration : 192.984379529953
# epoch n° 66
# Training, Regression Loss: 0.0362, Regression Loss 1h: 237.0893, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3120286   77076]
#  [ 114923  527715]]
# Accuracy: 0.9500, CSI: 0.7332, Sensitivity: 0.8212, Specificity: 0.9759, False Alarm Ratio: 0.1274
#
#
# epoch duration : 186.67968678474426
# epoch n° 67
# Training, Regression Loss: 0.0351, Regression Loss 1h: 219.8164, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3126058   76669]
#  [ 115077  522196]]
# Accuracy: 0.9501, CSI: 0.7314, Sensitivity: 0.8194, Specificity: 0.9761, False Alarm Ratio: 0.1280
#
#
# epoch duration : 192.27836775779724
# epoch n° 69
# Training, Regression Loss: 0.0360, Regression Loss 1h: 229.4674, Segmentation Loss:0.1194
# Train Confusion Matrix:
# [[3127407   76009]
#  [ 107805  528779]]
# Accuracy: 0.9521, CSI: 0.7420, Sensitivity: 0.8307, Specificity: 0.9763, False Alarm Ratio: 0.1257
#
#
# epoch duration : 194.1786448955536
# epoch n° 70
# Training, Regression Loss: 0.0352, Regression Loss 1h: 225.4786, Segmentation Loss:0.1220
# Train Confusion Matrix:
# [[3107230   78159]
#  [ 110732  543879]]
# Accuracy: 0.9508, CSI: 0.7422, Sensitivity: 0.8308, Specificity: 0.9755, False Alarm Ratio: 0.1256
#
#
# epoch duration : 190.0348925590515
# saving step
# epoch n° 71
# Training, Regression Loss: 0.0344, Regression Loss 1h: 227.2368, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3123436   76346]
#  [ 114697  525521]]
# Accuracy: 0.9502, CSI: 0.7334, Sensitivity: 0.8208, Specificity: 0.9761, False Alarm Ratio: 0.1268
#
#
# epoch duration : 185.263188123703
# epoch n° 72
# Training, Regression Loss: 0.0344, Regression Loss 1h: 232.5746, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3128124   75925]
#  [ 115609  520342]]
# Accuracy: 0.9501, CSI: 0.7309, Sensitivity: 0.8182, Specificity: 0.9763, False Alarm Ratio: 0.1273
#
#
# epoch duration : 186.3808798789978
# epoch n° 73
# Training, Regression Loss: 0.0349, Regression Loss 1h: 224.5223, Segmentation Loss:0.1213
# Train Confusion Matrix:
# [[3116952   77988]
#  [ 109964  535096]]
# Accuracy: 0.9511, CSI: 0.7401, Sensitivity: 0.8295, Specificity: 0.9756, False Alarm Ratio: 0.1272
#
#
# epoch duration : 186.85121846199036
# epoch n° 74

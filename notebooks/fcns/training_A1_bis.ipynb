# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A1 radar + cmls -> rain gauges 1 min  [xrl_yg1]
# # Adam learning rate : 0.02

# %%
# ! git clone https://github.com/nanopiero/fusion.git

# %%
import torch
import logging
logger = logging.getLogger("torch")
logger.setLevel(logging.ERROR)  # Show only errors, ignore warnings

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_A1bis_xrl_yg1.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image = 64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
ch_in = 72
ch_out = nsteps * 3
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.02)

# %%
criterion = QPELoss_fcn()

# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")
model.train()
for epoch in range(last_epoch, num_epochs + 1):
  print('epoch n°', epoch)
  t = time.time()
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)  # Forward pass
    
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

      
    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()
    
    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 0
# Training, Regression Loss: 0.1716, Regression Loss 1h: 686.1680, Segmentation Loss:0.3677
# Train Confusion Matrix:
# [[3121878   85630]
#  [ 481624  150868]]
# Accuracy: 0.8523, CSI: 0.2101, Sensitivity: 0.2385, Specificity: 0.9733, False Alarm Ratio: 0.3621
#
#
# epoch duration : 87.55784058570862
# saving step
# epoch n° 1
# Training, Regression Loss: 0.0946, Regression Loss 1h: 388.1773, Segmentation Loss:0.2752
# Train Confusion Matrix:
# [[3081404  110158]
#  [ 291239  357199]]
# Accuracy: 0.8955, CSI: 0.4709, Sensitivity: 0.5509, Specificity: 0.9655, False Alarm Ratio: 0.2357
#
#
# epoch duration : 92.42314410209656
# epoch n° 2
# Training, Regression Loss: 0.0838, Regression Loss 1h: 309.5288, Segmentation Loss:0.2463
# Train Confusion Matrix:
# [[3089610  109927]
#  [ 239326  401137]]
# Accuracy: 0.9090, CSI: 0.5346, Sensitivity: 0.6263, Specificity: 0.9656, False Alarm Ratio: 0.2151
#
#
# epoch duration : 96.19173884391785
# epoch n° 3
# Training, Regression Loss: 0.0798, Regression Loss 1h: 261.6794, Segmentation Loss:0.2291
# Train Confusion Matrix:
# [[3084213  106127]
#  [ 220997  428663]]
# Accuracy: 0.9148, CSI: 0.5672, Sensitivity: 0.6598, Specificity: 0.9667, False Alarm Ratio: 0.1984
#
#
# epoch duration : 94.51203489303589
# epoch n° 4
# Training, Regression Loss: 0.0751, Regression Loss 1h: 251.9525, Segmentation Loss:0.2241
# Train Confusion Matrix:
# [[3101100   98562]
#  [ 217148  423190]]
# Accuracy: 0.9178, CSI: 0.5727, Sensitivity: 0.6609, Specificity: 0.9692, False Alarm Ratio: 0.1889
#
#
# epoch duration : 88.4761016368866
# epoch n° 5
# Training, Regression Loss: 0.0732, Regression Loss 1h: 248.6589, Segmentation Loss:0.2116
# Train Confusion Matrix:
# [[3104861   98460]
#  [ 202527  434152]]
# Accuracy: 0.9216, CSI: 0.5906, Sensitivity: 0.6819, Specificity: 0.9693, False Alarm Ratio: 0.1849
#
#
# epoch duration : 82.48572421073914
# epoch n° 6
# Training, Regression Loss: 0.0685, Regression Loss 1h: 235.1880, Segmentation Loss:0.2056
# Train Confusion Matrix:
# [[3100527   95201]
#  [ 191872  452400]]
# Accuracy: 0.9252, CSI: 0.6118, Sensitivity: 0.7022, Specificity: 0.9702, False Alarm Ratio: 0.1739
#
#
# epoch duration : 83.27916622161865
# epoch n° 7
# Training, Regression Loss: 0.0651, Regression Loss 1h: 227.7020, Segmentation Loss:0.1984
# Train Confusion Matrix:
# [[3111279   94072]
#  [ 181299  453350]]
# Accuracy: 0.9283, CSI: 0.6221, Sensitivity: 0.7143, Specificity: 0.9707, False Alarm Ratio: 0.1718
#
#
# epoch duration : 85.95885419845581
# epoch n° 8
# Training, Regression Loss: 0.0630, Regression Loss 1h: 228.3865, Segmentation Loss:0.1888
# Train Confusion Matrix:
# [[3111377   92185]
#  [ 171771  464667]]
# Accuracy: 0.9313, CSI: 0.6377, Sensitivity: 0.7301, Specificity: 0.9712, False Alarm Ratio: 0.1655
#
#
# epoch duration : 87.38394546508789
# epoch n° 9
# Training, Regression Loss: 0.0616, Regression Loss 1h: 233.9442, Segmentation Loss:0.1870
# Train Confusion Matrix:
# [[3099902   93853]
#  [ 168844  477401]]
# Accuracy: 0.9316, CSI: 0.6451, Sensitivity: 0.7387, Specificity: 0.9706, False Alarm Ratio: 0.1643
#
#
# epoch duration : 92.58454895019531
# epoch n° 10
# Training, Regression Loss: 0.0600, Regression Loss 1h: 217.9965, Segmentation Loss:0.1923
# Train Confusion Matrix:
# [[3106405   89287]
#  [ 178182  466126]]
# Accuracy: 0.9303, CSI: 0.6354, Sensitivity: 0.7235, Specificity: 0.9721, False Alarm Ratio: 0.1608
#
#
# epoch duration : 97.08349418640137
# saving step
# epoch n° 11
# Training, Regression Loss: 0.0565, Regression Loss 1h: 209.9097, Segmentation Loss:0.1857
# Train Confusion Matrix:
# [[3105845   90960]
#  [ 170434  472761]]
# Accuracy: 0.9319, CSI: 0.6440, Sensitivity: 0.7350, Specificity: 0.9715, False Alarm Ratio: 0.1614
#
#
# epoch duration : 96.40364933013916
# epoch n° 12
# Training, Regression Loss: 0.0557, Regression Loss 1h: 214.8357, Segmentation Loss:0.1834
# Train Confusion Matrix:
# [[3102197   91258]
#  [ 168515  478030]]
# Accuracy: 0.9324, CSI: 0.6479, Sensitivity: 0.7394, Specificity: 0.9714, False Alarm Ratio: 0.1603
#
#
# epoch duration : 88.89013814926147
# epoch n° 13
# Training, Regression Loss: 0.0554, Regression Loss 1h: 218.3937, Segmentation Loss:0.1795
# Train Confusion Matrix:
# [[3111380   90297]
#  [ 163898  474425]]
# Accuracy: 0.9338, CSI: 0.6511, Sensitivity: 0.7432, Specificity: 0.9718, False Alarm Ratio: 0.1599
#
#
# epoch duration : 85.3842523097992
# epoch n° 14
# Training, Regression Loss: 0.0520, Regression Loss 1h: 211.8975, Segmentation Loss:0.1787
# Train Confusion Matrix:
# [[3113921   88205]
#  [ 165214  472660]]
# Accuracy: 0.9340, CSI: 0.6510, Sensitivity: 0.7410, Specificity: 0.9725, False Alarm Ratio: 0.1573
#
#
# epoch duration : 84.36393404006958
# epoch n° 15
# Training, Regression Loss: 0.0538, Regression Loss 1h: 222.9875, Segmentation Loss:0.1816
# Train Confusion Matrix:
# [[3113504   88024]
#  [ 167825  470647]]
# Accuracy: 0.9334, CSI: 0.6478, Sensitivity: 0.7371, Specificity: 0.9725, False Alarm Ratio: 0.1576
#
#
# epoch duration : 83.81177973747253
# epoch n° 16
# Training, Regression Loss: 0.0564, Regression Loss 1h: 215.0474, Segmentation Loss:0.1767
# Train Confusion Matrix:
# [[3127283   86233]
#  [ 161564  464920]]
# Accuracy: 0.9355, CSI: 0.6523, Sensitivity: 0.7421, Specificity: 0.9732, False Alarm Ratio: 0.1565
#
#
# epoch duration : 86.74606919288635
# epoch n° 17
# Training, Regression Loss: 0.0551, Regression Loss 1h: 206.2849, Segmentation Loss:0.1823
# Train Confusion Matrix:
# [[3095102   90165]
#  [ 165573  489160]]
# Accuracy: 0.9334, CSI: 0.6567, Sensitivity: 0.7471, Specificity: 0.9717, False Alarm Ratio: 0.1556
#
#
# epoch duration : 92.28051447868347
# epoch n° 18
# Training, Regression Loss: 0.0532, Regression Loss 1h: 197.8176, Segmentation Loss:0.1816
# Train Confusion Matrix:
# [[3099767   89455]
#  [ 168617  482161]]
# Accuracy: 0.9328, CSI: 0.6514, Sensitivity: 0.7409, Specificity: 0.9720, False Alarm Ratio: 0.1565
#
#
# epoch duration : 95.90122246742249
# epoch n° 19
# Training, Regression Loss: 0.0511, Regression Loss 1h: 199.9156, Segmentation Loss:0.1806
# Train Confusion Matrix:
# [[3106264   86435]
#  [ 169061  478240]]
# Accuracy: 0.9335, CSI: 0.6518, Sensitivity: 0.7388, Specificity: 0.9729, False Alarm Ratio: 0.1531
#
#
# epoch duration : 95.31614446640015
# epoch n° 20
# Training, Regression Loss: 0.0521, Regression Loss 1h: 210.4926, Segmentation Loss:0.1709
# Train Confusion Matrix:
# [[3117849   86803]
#  [ 156760  478588]]
# Accuracy: 0.9366, CSI: 0.6627, Sensitivity: 0.7533, Specificity: 0.9729, False Alarm Ratio: 0.1535
#
#
# epoch duration : 89.00056266784668
# saving step
# epoch n° 21
# Training, Regression Loss: 0.0518, Regression Loss 1h: 203.2509, Segmentation Loss:0.1690
# Train Confusion Matrix:
# [[3108055   87167]
#  [ 155140  489638]]
# Accuracy: 0.9369, CSI: 0.6690, Sensitivity: 0.7594, Specificity: 0.9727, False Alarm Ratio: 0.1511
#
#
# epoch duration : 85.56953477859497
# epoch n° 22
# Training, Regression Loss: 0.0525, Regression Loss 1h: 218.8947, Segmentation Loss:0.1662
# Train Confusion Matrix:
# [[3113487   88257]
#  [ 151494  486762]]
# Accuracy: 0.9376, CSI: 0.6700, Sensitivity: 0.7626, Specificity: 0.9724, False Alarm Ratio: 0.1535
#
#
# epoch duration : 83.0186665058136
# epoch n° 23
# Training, Regression Loss: 0.0504, Regression Loss 1h: 211.8204, Segmentation Loss:0.1688
# Train Confusion Matrix:
# [[3111644   87413]
#  [ 155918  485025]]
# Accuracy: 0.9366, CSI: 0.6659, Sensitivity: 0.7567, Specificity: 0.9727, False Alarm Ratio: 0.1527
#
#
# epoch duration : 81.76257348060608
# epoch n° 24
# Training, Regression Loss: 0.0510, Regression Loss 1h: 209.5603, Segmentation Loss:0.1721
# Train Confusion Matrix:
# [[3102834   87863]
#  [ 159083  490220]]
# Accuracy: 0.9357, CSI: 0.6650, Sensitivity: 0.7550, Specificity: 0.9725, False Alarm Ratio: 0.1520
#
#
# epoch duration : 86.46017646789551
# epoch n° 25
# Training, Regression Loss: 0.0518, Regression Loss 1h: 198.6889, Segmentation Loss:0.1666
# Train Confusion Matrix:
# [[3116245   86516]
#  [ 152037  485202]]
# Accuracy: 0.9379, CSI: 0.6704, Sensitivity: 0.7614, Specificity: 0.9730, False Alarm Ratio: 0.1513
#
#
# epoch duration : 93.21847152709961
# epoch n° 26
# Training, Regression Loss: 0.0512, Regression Loss 1h: 205.4683, Segmentation Loss:0.1637
# Train Confusion Matrix:
# [[3105881   88769]
#  [ 148797  496553]]
# Accuracy: 0.9381, CSI: 0.6764, Sensitivity: 0.7694, Specificity: 0.9722, False Alarm Ratio: 0.1517
#
#
# epoch duration : 95.03553056716919
# epoch n° 27
# Training, Regression Loss: 0.0504, Regression Loss 1h: 224.5473, Segmentation Loss:0.1672
# Train Confusion Matrix:
# [[3105391   89110]
#  [ 154883  490616]]
# Accuracy: 0.9365, CSI: 0.6679, Sensitivity: 0.7601, Specificity: 0.9721, False Alarm Ratio: 0.1537
#
#
# epoch duration : 92.72231841087341
# epoch n° 28
# Training, Regression Loss: 0.0493, Regression Loss 1h: 210.9702, Segmentation Loss:0.1651
# Train Confusion Matrix:
# [[3105198   88471]
#  [ 151600  494731]]
# Accuracy: 0.9375, CSI: 0.6733, Sensitivity: 0.7654, Specificity: 0.9723, False Alarm Ratio: 0.1517
#
#
# epoch duration : 88.3077085018158
# epoch n° 29
# Training, Regression Loss: 0.0494, Regression Loss 1h: 223.9043, Segmentation Loss:0.1675
# Train Confusion Matrix:
# [[3113949   86178]
#  [ 153956  485917]]
# Accuracy: 0.9375, CSI: 0.6693, Sensitivity: 0.7594, Specificity: 0.9731, False Alarm Ratio: 0.1506
#
#
# epoch duration : 83.29443216323853
# epoch n° 30
# Training, Regression Loss: 0.0493, Regression Loss 1h: 212.1218, Segmentation Loss:0.1584
# Train Confusion Matrix:
# [[3122199   87102]
#  [ 143627  487072]]
# Accuracy: 0.9399, CSI: 0.6786, Sensitivity: 0.7723, Specificity: 0.9729, False Alarm Ratio: 0.1517
#
#
# epoch duration : 84.94433903694153
# saving step
# epoch n° 31
# Training, Regression Loss: 0.0470, Regression Loss 1h: 224.5878, Segmentation Loss:0.1630
# Train Confusion Matrix:
# [[3109886   87254]
#  [ 150345  492515]]
# Accuracy: 0.9381, CSI: 0.6746, Sensitivity: 0.7661, Specificity: 0.9727, False Alarm Ratio: 0.1505
#
#
# epoch duration : 85.22438764572144
# epoch n° 32
# Training, Regression Loss: 0.0492, Regression Loss 1h: 226.5647, Segmentation Loss:0.1600
# Train Confusion Matrix:
# [[3108444   86886]
#  [ 147295  497375]]
# Accuracy: 0.9390, CSI: 0.6799, Sensitivity: 0.7715, Specificity: 0.9728, False Alarm Ratio: 0.1487
#
#
# epoch duration : 87.12543654441833
# epoch n° 33
# Training, Regression Loss: 0.0502, Regression Loss 1h: 228.0458, Segmentation Loss:0.1621
# Train Confusion Matrix:
# [[3098934   88523]
#  [ 148857  503686]]
# Accuracy: 0.9382, CSI: 0.6797, Sensitivity: 0.7719, Specificity: 0.9722, False Alarm Ratio: 0.1495
#
#
# epoch duration : 92.89886546134949
# epoch n° 34
# Training, Regression Loss: 0.0548, Regression Loss 1h: 237.1868, Segmentation Loss:0.1668
# Train Confusion Matrix:
# [[3117877   87719]
#  [ 151789  482615]]
# Accuracy: 0.9376, CSI: 0.6683, Sensitivity: 0.7607, Specificity: 0.9726, False Alarm Ratio: 0.1538
#
#
# epoch duration : 94.94500851631165
# epoch n° 35
# Training, Regression Loss: 0.0770, Regression Loss 1h: 234.0051, Segmentation Loss:0.1937
# Train Confusion Matrix:
# [[3102112   91808]
#  [ 174287  471793]]
# Accuracy: 0.9307, CSI: 0.6394, Sensitivity: 0.7302, Specificity: 0.9713, False Alarm Ratio: 0.1629
#
#
# epoch duration : 91.66880869865417
# epoch n° 36
# Training, Regression Loss: 0.0613, Regression Loss 1h: 191.3500, Segmentation Loss:0.1806
# Train Confusion Matrix:
# [[3103156   90736]
#  [ 162026  484082]]
# Accuracy: 0.9342, CSI: 0.6570, Sensitivity: 0.7492, Specificity: 0.9716, False Alarm Ratio: 0.1579
#
#
# epoch duration : 85.08956956863403
# epoch n° 37
# Training, Regression Loss: 0.0571, Regression Loss 1h: 198.6116, Segmentation Loss:0.1756
# Train Confusion Matrix:
# [[3107234   87558]
#  [ 158323  486885]]
# Accuracy: 0.9360, CSI: 0.6644, Sensitivity: 0.7546, Specificity: 0.9726, False Alarm Ratio: 0.1524
#
#
# epoch duration : 83.78496837615967
# epoch n° 38
# Training, Regression Loss: 0.0556, Regression Loss 1h: 183.3584, Segmentation Loss:0.1706
# Train Confusion Matrix:
# [[3098288   89973]
#  [ 152508  499231]]
# Accuracy: 0.9369, CSI: 0.6731, Sensitivity: 0.7660, Specificity: 0.9718, False Alarm Ratio: 0.1527
#
#
# epoch duration : 84.32796669006348
# epoch n° 39
# Training, Regression Loss: 0.0524, Regression Loss 1h: 186.6699, Segmentation Loss:0.1728
# Train Confusion Matrix:
# [[3114803   88070]
#  [ 159451  477676]]
# Accuracy: 0.9355, CSI: 0.6587, Sensitivity: 0.7497, Specificity: 0.9725, False Alarm Ratio: 0.1557
#
#
# epoch duration : 84.79491305351257
# epoch n° 40
# Training, Regression Loss: 0.0522, Regression Loss 1h: 197.2247, Segmentation Loss:0.1713
# Train Confusion Matrix:
# [[3105878   88681]
#  [ 158481  486960]]
# Accuracy: 0.9356, CSI: 0.6633, Sensitivity: 0.7545, Specificity: 0.9722, False Alarm Ratio: 0.1541
#
#
# epoch duration : 90.74434757232666
# saving step
# epoch n° 41
# Training, Regression Loss: 0.0508, Regression Loss 1h: 192.2697, Segmentation Loss:0.1676
# Train Confusion Matrix:
# [[3103690   86781]
#  [ 155198  494331]]
# Accuracy: 0.9370, CSI: 0.6714, Sensitivity: 0.7611, Specificity: 0.9728, False Alarm Ratio: 0.1493
#
#
# epoch duration : 96.07226324081421
# epoch n° 42
# Training, Regression Loss: 0.0518, Regression Loss 1h: 199.1094, Segmentation Loss:0.1637
# Train Confusion Matrix:
# [[3104414   89736]
#  [ 149321  496529]]
# Accuracy: 0.9377, CSI: 0.6750, Sensitivity: 0.7688, Specificity: 0.9719, False Alarm Ratio: 0.1531
#
#
# epoch duration : 96.10431599617004
# epoch n° 43
# Training, Regression Loss: 0.0492, Regression Loss 1h: 200.2449, Segmentation Loss:0.1660
# Train Confusion Matrix:
# [[3107771   87061]
#  [ 154605  490563]]
# Accuracy: 0.9371, CSI: 0.6700, Sensitivity: 0.7604, Specificity: 0.9727, False Alarm Ratio: 0.1507
#
#
# epoch duration : 89.16459798812866
# epoch n° 44
# Training, Regression Loss: 0.0495, Regression Loss 1h: 201.7685, Segmentation Loss:0.1606
# Train Confusion Matrix:
# [[3118275   86601]
#  [ 146740  488384]]
# Accuracy: 0.9392, CSI: 0.6767, Sensitivity: 0.7690, Specificity: 0.9730, False Alarm Ratio: 0.1506
#
#
# epoch duration : 84.27784943580627
# epoch n° 45
# Training, Regression Loss: 0.0512, Regression Loss 1h: 204.6693, Segmentation Loss:0.1626
# Train Confusion Matrix:
# [[3103770   87196]
#  [ 149908  499126]]
# Accuracy: 0.9383, CSI: 0.6779, Sensitivity: 0.7690, Specificity: 0.9727, False Alarm Ratio: 0.1487
#
#
# epoch duration : 84.21319961547852
# epoch n° 46
# Training, Regression Loss: 0.0495, Regression Loss 1h: 210.5666, Segmentation Loss:0.1615
# Train Confusion Matrix:
# [[3117508   85998]
#  [ 149425  487069]]
# Accuracy: 0.9387, CSI: 0.6742, Sensitivity: 0.7652, Specificity: 0.9732, False Alarm Ratio: 0.1501
#
#
# epoch duration : 82.87068891525269
# epoch n° 47
# Training, Regression Loss: 0.0524, Regression Loss 1h: 203.9335, Segmentation Loss:0.1632
# Train Confusion Matrix:
# [[3112129   87334]
#  [ 149786  490751]]
# Accuracy: 0.9383, CSI: 0.6742, Sensitivity: 0.7662, Specificity: 0.9727, False Alarm Ratio: 0.1511
#
#
# epoch duration : 91.63516902923584
# epoch n° 48
# Training, Regression Loss: 0.0530, Regression Loss 1h: 181.5602, Segmentation Loss:0.1709
# Train Confusion Matrix:
# [[3107495   87057]
#  [ 158233  487215]]
# Accuracy: 0.9361, CSI: 0.6651, Sensitivity: 0.7548, Specificity: 0.9727, False Alarm Ratio: 0.1516
#
#
# epoch duration : 95.23665452003479
# epoch n° 49
# Training, Regression Loss: 0.0503, Regression Loss 1h: 188.0559, Segmentation Loss:0.1585
# Train Confusion Matrix:
# [[3115067   85383]
#  [ 145352  494198]]
# Accuracy: 0.9399, CSI: 0.6817, Sensitivity: 0.7727, Specificity: 0.9733, False Alarm Ratio: 0.1473
#
#
# epoch duration : 96.00861310958862
# epoch n° 50
# Training, Regression Loss: 0.0485, Regression Loss 1h: 189.9276, Segmentation Loss:0.1611
# Train Confusion Matrix:
# [[3120168   85982]
#  [ 148785  485065]]
# Accuracy: 0.9389, CSI: 0.6739, Sensitivity: 0.7653, Specificity: 0.9732, False Alarm Ratio: 0.1506
#
#
# epoch duration : 92.30070209503174
# saving step
# epoch n° 51
# Training, Regression Loss: 0.0488, Regression Loss 1h: 187.7534, Segmentation Loss:0.1624
# Train Confusion Matrix:
# [[3112660   86526]
#  [ 152200  488614]]
# Accuracy: 0.9378, CSI: 0.6718, Sensitivity: 0.7625, Specificity: 0.9730, False Alarm Ratio: 0.1504
#
#
# epoch duration : 86.78291296958923
# epoch n° 52
# Training, Regression Loss: 0.0499, Regression Loss 1h: 205.1858, Segmentation Loss:0.1563
# Train Confusion Matrix:
# [[3108594   86365]
#  [ 143314  501727]]
# Accuracy: 0.9402, CSI: 0.6860, Sensitivity: 0.7778, Specificity: 0.9730, False Alarm Ratio: 0.1469
#
#
# epoch duration : 84.04736113548279
# epoch n° 53
# Training, Regression Loss: 0.0498, Regression Loss 1h: 208.7724, Segmentation Loss:0.1537
# Train Confusion Matrix:
# [[3114061   86234]
#  [ 140442  499263]]
# Accuracy: 0.9410, CSI: 0.6877, Sensitivity: 0.7805, Specificity: 0.9731, False Alarm Ratio: 0.1473
#
#
# epoch duration : 86.43914270401001
# epoch n° 54
# Training, Regression Loss: 0.0469, Regression Loss 1h: 203.1479, Segmentation Loss:0.1544
# Train Confusion Matrix:
# [[3119309   85311]
#  [ 142217  493163]]
# Accuracy: 0.9407, CSI: 0.6843, Sensitivity: 0.7762, Specificity: 0.9734, False Alarm Ratio: 0.1475
#
#
# epoch duration : 86.06018137931824
# epoch n° 55
# Training, Regression Loss: 0.0473, Regression Loss 1h: 213.0709, Segmentation Loss:0.1520
# Train Confusion Matrix:
# [[3109689   86078]
#  [ 138436  505797]]
# Accuracy: 0.9415, CSI: 0.6926, Sensitivity: 0.7851, Specificity: 0.9731, False Alarm Ratio: 0.1454
#
#
# epoch duration : 92.48973846435547
# epoch n° 56
# Training, Regression Loss: 0.0473, Regression Loss 1h: 208.0863, Segmentation Loss:0.1527
# Train Confusion Matrix:
# [[3118586   84417]
#  [ 140885  496112]]
# Accuracy: 0.9413, CSI: 0.6877, Sensitivity: 0.7788, Specificity: 0.9736, False Alarm Ratio: 0.1454
#
#
# epoch duration : 95.08016443252563
# epoch n° 57
# Training, Regression Loss: 0.0475, Regression Loss 1h: 203.1398, Segmentation Loss:0.1569
# Train Confusion Matrix:
# [[3112152   86314]
#  [ 145512  496022]]
# Accuracy: 0.9396, CSI: 0.6815, Sensitivity: 0.7732, Specificity: 0.9730, False Alarm Ratio: 0.1482
#
#
# epoch duration : 96.83533024787903
# epoch n° 58
# Training, Regression Loss: 0.0478, Regression Loss 1h: 201.6609, Segmentation Loss:0.1547
# Train Confusion Matrix:
# [[3110544   84733]
#  [ 143353  501370]]
# Accuracy: 0.9406, CSI: 0.6873, Sensitivity: 0.7777, Specificity: 0.9735, False Alarm Ratio: 0.1446
#
#
# epoch duration : 91.12373232841492
# epoch n° 59
# Training, Regression Loss: 0.0475, Regression Loss 1h: 208.4710, Segmentation Loss:0.1490
# Train Confusion Matrix:
# [[3106924   85671]
#  [ 135506  511899]]
# Accuracy: 0.9424, CSI: 0.6983, Sensitivity: 0.7907, Specificity: 0.9732, False Alarm Ratio: 0.1434
#
#
# epoch duration : 86.51371717453003
# epoch n° 60
# Training, Regression Loss: 0.0473, Regression Loss 1h: 225.4573, Segmentation Loss:0.1518
# Train Confusion Matrix:
# [[3117926   86235]
#  [ 139491  496348]]
# Accuracy: 0.9412, CSI: 0.6874, Sensitivity: 0.7806, Specificity: 0.9731, False Alarm Ratio: 0.1480
#
#
# epoch duration : 84.79163932800293
# saving step
# epoch n° 61
# Training, Regression Loss: 0.0457, Regression Loss 1h: 212.5728, Segmentation Loss:0.1529
# Train Confusion Matrix:
# [[3117312   84114]
#  [ 143057  495517]]
# Accuracy: 0.9408, CSI: 0.6857, Sensitivity: 0.7760, Specificity: 0.9737, False Alarm Ratio: 0.1451
#
#
# epoch duration : 87.42895483970642
# epoch n° 62
# Training, Regression Loss: 0.0474, Regression Loss 1h: 189.9515, Segmentation Loss:0.1548
# Train Confusion Matrix:
# [[3106407   85390]
#  [ 142935  505268]]
# Accuracy: 0.9405, CSI: 0.6888, Sensitivity: 0.7795, Specificity: 0.9732, False Alarm Ratio: 0.1446
#
#
# epoch duration : 84.93833303451538
# epoch n° 63
# Training, Regression Loss: 0.0452, Regression Loss 1h: 206.2810, Segmentation Loss:0.1530
# Train Confusion Matrix:
# [[3119842   84746]
#  [ 142865  492547]]
# Accuracy: 0.9407, CSI: 0.6839, Sensitivity: 0.7752, Specificity: 0.9736, False Alarm Ratio: 0.1468
#
#
# epoch duration : 93.26486253738403
# epoch n° 64
# Training, Regression Loss: 0.0471, Regression Loss 1h: 204.4512, Segmentation Loss:0.1506
# Train Confusion Matrix:
# [[3110803   83963]
#  [ 138545  506689]]
# Accuracy: 0.9421, CSI: 0.6949, Sensitivity: 0.7853, Specificity: 0.9737, False Alarm Ratio: 0.1422
#
#
# epoch duration : 95.52141261100769
# epoch n° 65
# Training, Regression Loss: 0.0493, Regression Loss 1h: 197.5429, Segmentation Loss:0.1535
# Train Confusion Matrix:
# [[3116188   84111]
#  [ 139811  499890]]
# Accuracy: 0.9417, CSI: 0.6906, Sensitivity: 0.7814, Specificity: 0.9737, False Alarm Ratio: 0.1440
#
#
# epoch duration : 98.77104806900024
# epoch n° 66
# Training, Regression Loss: 0.0494, Regression Loss 1h: 184.9755, Segmentation Loss:0.1577
# Train Confusion Matrix:
# [[3109948   85253]
#  [ 144822  499977]]
# Accuracy: 0.9401, CSI: 0.6849, Sensitivity: 0.7754, Specificity: 0.9733, False Alarm Ratio: 0.1457
#
#
# epoch duration : 93.6468780040741
# epoch n° 67
# Training, Regression Loss: 0.0476, Regression Loss 1h: 193.5877, Segmentation Loss:0.1504
# Train Confusion Matrix:
# [[3100664   85794]
#  [ 137276  516266]]
# Accuracy: 0.9419, CSI: 0.6983, Sensitivity: 0.7900, Specificity: 0.9731, False Alarm Ratio: 0.1425
#
#
# epoch duration : 89.65360736846924
# epoch n° 68
# Training, Regression Loss: 0.0455, Regression Loss 1h: 210.7543, Segmentation Loss:0.1511
# Train Confusion Matrix:
# [[3112742   83291]
#  [ 140521  503446]]
# Accuracy: 0.9417, CSI: 0.6923, Sensitivity: 0.7818, Specificity: 0.9739, False Alarm Ratio: 0.1420
#
#
# epoch duration : 84.57324957847595
# epoch n° 69
# Training, Regression Loss: 0.0471, Regression Loss 1h: 212.9101, Segmentation Loss:0.1471
# Train Confusion Matrix:
# [[3120575   83627]
#  [ 135683  500115]]
# Accuracy: 0.9429, CSI: 0.6952, Sensitivity: 0.7866, Specificity: 0.9739, False Alarm Ratio: 0.1433
#
#
# epoch duration : 87.56797003746033
# epoch n° 70
# Training, Regression Loss: 0.0652, Regression Loss 1h: 216.0121, Segmentation Loss:0.1840
# Train Confusion Matrix:
# [[3106263   88882]
#  [ 167380  477475]]
# Accuracy: 0.9333, CSI: 0.6507, Sensitivity: 0.7404, Specificity: 0.9722, False Alarm Ratio: 0.1569
#
#
# epoch duration : 88.34909272193909
# saving step
# epoch n° 71
# Training, Regression Loss: 0.0586, Regression Loss 1h: 180.5533, Segmentation Loss:0.1825
# Train Confusion Matrix:
# [[3116365   87746]
#  [ 167342  468547]]
# Accuracy: 0.9336, CSI: 0.6475, Sensitivity: 0.7368, Specificity: 0.9726, False Alarm Ratio: 0.1577
#
#
# epoch duration : 94.99944257736206
# epoch n° 72
# Training, Regression Loss: 0.0544, Regression Loss 1h: 174.8623, Segmentation Loss:0.1749
# Train Confusion Matrix:
# [[3105617   85980]
#  [ 160503  487900]]
# Accuracy: 0.9358, CSI: 0.6644, Sensitivity: 0.7525, Specificity: 0.9731, False Alarm Ratio: 0.1498
#
#
# epoch duration : 96.5463297367096
# epoch n° 73
# Training, Regression Loss: 0.0529, Regression Loss 1h: 160.9354, Segmentation Loss:0.1713
# Train Confusion Matrix:
# [[3110691   85487]
#  [ 156806  487016]]
# Accuracy: 0.9369, CSI: 0.6678, Sensitivity: 0.7564, Specificity: 0.9733, False Alarm Ratio: 0.1493
#
#
# epoch duration : 101.10201978683472
# epoch n° 74
# Training, Regression Loss: 0.0520, Regression Loss 1h: 169.5327, Segmentation Loss:0.1726
# Train Confusion Matrix:
# [[3116862   82579]
#  [ 160984  479575]]
# Accuracy: 0.9366, CSI: 0.6632, Sensitivity: 0.7487, Specificity: 0.9742, False Alarm Ratio: 0.1469
#
#
# epoch duration : 92.58268857002258
# epoch n° 75
# Training, Regression Loss: 0.0518, Regression Loss 1h: 157.4095, Segmentation Loss:0.1664
# Train Confusion Matrix:
# [[3110616   85108]
#  [ 153712  490564]]
# Accuracy: 0.9378, CSI: 0.6726, Sensitivity: 0.7614, Specificity: 0.9734, False Alarm Ratio: 0.1478
#
#
# epoch duration : 90.20006108283997
# epoch n° 76
# Training, Regression Loss: 0.0512, Regression Loss 1h: 163.8546, Segmentation Loss:0.1614
# Train Confusion Matrix:
# [[3124044   83918]
#  [ 148364  483674]]
# Accuracy: 0.9395, CSI: 0.6756, Sensitivity: 0.7653, Specificity: 0.9738, False Alarm Ratio: 0.1478
#
#
# epoch duration : 88.87592625617981
# epoch n° 77
# Training, Regression Loss: 0.0509, Regression Loss 1h: 164.6786, Segmentation Loss:0.1688
# Train Confusion Matrix:
# [[3110309   84937]
#  [ 157192  487562]]
# Accuracy: 0.9369, CSI: 0.6682, Sensitivity: 0.7562, Specificity: 0.9734, False Alarm Ratio: 0.1484
#
#
# epoch duration : 95.17221093177795
# epoch n° 78
# Training, Regression Loss: 0.0498, Regression Loss 1h: 170.1987, Segmentation Loss:0.1627
# Train Confusion Matrix:
# [[3117660   83880]
#  [ 151593  486867]]
# Accuracy: 0.9387, CSI: 0.6740, Sensitivity: 0.7626, Specificity: 0.9738, False Alarm Ratio: 0.1470
#
#
# epoch duration : 86.53535318374634
# epoch n° 79
# Training, Regression Loss: 0.0508, Regression Loss 1h: 163.7278, Segmentation Loss:0.1654
# Train Confusion Matrix:
# [[3113741   84728]
#  [ 152519  489012]]
# Accuracy: 0.9382, CSI: 0.6733, Sensitivity: 0.7623, Specificity: 0.9735, False Alarm Ratio: 0.1477
#
#
# epoch duration : 98.43227934837341
# epoch n° 80
# Training, Regression Loss: 0.0486, Regression Loss 1h: 167.5464, Segmentation Loss:0.1653
# Train Confusion Matrix:
# [[3119215   84095]
#  [ 155070  481620]]
# Accuracy: 0.9377, CSI: 0.6682, Sensitivity: 0.7564, Specificity: 0.9737, False Alarm Ratio: 0.1487
#
#
# epoch duration : 98.56187272071838
# saving step
# epoch n° 81
# Training, Regression Loss: 0.0491, Regression Loss 1h: 165.0520, Segmentation Loss:0.1588
# Train Confusion Matrix:
# [[3118877   83335]
#  [ 147925  489863]]
# Accuracy: 0.9398, CSI: 0.6793, Sensitivity: 0.7681, Specificity: 0.9740, False Alarm Ratio: 0.1454
#
#
# epoch duration : 97.70999097824097
# epoch n° 82
# Training, Regression Loss: 0.0492, Regression Loss 1h: 166.4495, Segmentation Loss:0.1584
# Train Confusion Matrix:
# [[3113327   84750]
#  [ 147030  494893]]
# Accuracy: 0.9396, CSI: 0.6810, Sensitivity: 0.7710, Specificity: 0.9735, False Alarm Ratio: 0.1462
#
#
# epoch duration : 91.59093618392944
# epoch n° 83
# Training, Regression Loss: 0.0482, Regression Loss 1h: 183.7013, Segmentation Loss:0.1583
# Train Confusion Matrix:
# [[3121306   84499]
#  [ 146453  487742]]
# Accuracy: 0.9399, CSI: 0.6787, Sensitivity: 0.7691, Specificity: 0.9736, False Alarm Ratio: 0.1477
#
#
# epoch duration : 86.43104815483093
# epoch n° 84
# Training, Regression Loss: 0.0479, Regression Loss 1h: 170.1008, Segmentation Loss:0.1543
# Train Confusion Matrix:
# [[3119427   83190]
#  [ 142418  494965]]
# Accuracy: 0.9412, CSI: 0.6869, Sensitivity: 0.7766, Specificity: 0.9740, False Alarm Ratio: 0.1439
#
#
# epoch duration : 85.12603664398193
# epoch n° 85
# Training, Regression Loss: 0.0483, Regression Loss 1h: 188.6738, Segmentation Loss:0.1530
# Train Confusion Matrix:
# [[3104816   85682]
#  [ 139986  509516]]
# Accuracy: 0.9412, CSI: 0.6930, Sensitivity: 0.7845, Specificity: 0.9731, False Alarm Ratio: 0.1440
#
#
# epoch duration : 89.48776006698608
# epoch n° 86
# Training, Regression Loss: 0.0482, Regression Loss 1h: 176.6560, Segmentation Loss:0.1576
# Train Confusion Matrix:
# [[3111577   84172]
#  [ 147673  496578]]
# Accuracy: 0.9396, CSI: 0.6817, Sensitivity: 0.7708, Specificity: 0.9737, False Alarm Ratio: 0.1449
#
#
# epoch duration : 92.59455943107605
# epoch n° 87
# Training, Regression Loss: 0.0483, Regression Loss 1h: 182.7915, Segmentation Loss:0.1553
# Train Confusion Matrix:
# [[3118495   82815]
#  [ 146205  492485]]
# Accuracy: 0.9404, CSI: 0.6826, Sensitivity: 0.7711, Specificity: 0.9741, False Alarm Ratio: 0.1440
#
#
# epoch duration : 97.77371859550476
# epoch n° 88
# Training, Regression Loss: 0.0475, Regression Loss 1h: 177.2579, Segmentation Loss:0.1502
# Train Confusion Matrix:
# [[3106421   85675]
#  [ 137421  510483]]
# Accuracy: 0.9419, CSI: 0.6959, Sensitivity: 0.7879, Specificity: 0.9732, False Alarm Ratio: 0.1437
#
#
# epoch duration : 101.19679236412048
# epoch n° 89
# Training, Regression Loss: 0.0474, Regression Loss 1h: 189.0599, Segmentation Loss:0.1486
# Train Confusion Matrix:
# [[3117591   83038]
#  [ 138327  501044]]
# Accuracy: 0.9424, CSI: 0.6936, Sensitivity: 0.7837, Specificity: 0.9741, False Alarm Ratio: 0.1422
#
#
# epoch duration : 96.89593577384949
# epoch n° 90
# Training, Regression Loss: 0.0471, Regression Loss 1h: 199.1644, Segmentation Loss:0.1499
# Train Confusion Matrix:
# [[3119504   82681]
#  [ 139126  498689]]
# Accuracy: 0.9422, CSI: 0.6921, Sensitivity: 0.7819, Specificity: 0.9742, False Alarm Ratio: 0.1422
#
#
# epoch duration : 91.48610353469849
# saving step
# epoch n° 91
# Training, Regression Loss: 0.0494, Regression Loss 1h: 188.0503, Segmentation Loss:0.1626
# Train Confusion Matrix:
# [[3105927   85700]
#  [ 151795  496578]]
# Accuracy: 0.9382, CSI: 0.6765, Sensitivity: 0.7659, Specificity: 0.9731, False Alarm Ratio: 0.1472
#
#
# epoch duration : 86.07299065589905
# epoch n° 92
# Training, Regression Loss: 0.0554, Regression Loss 1h: 171.4585, Segmentation Loss:0.1720
# Train Confusion Matrix:
# [[3109992   83908]
#  [ 159381  486719]]
# Accuracy: 0.9366, CSI: 0.6667, Sensitivity: 0.7533, Specificity: 0.9737, False Alarm Ratio: 0.1470
#
#
# epoch duration : 90.78421258926392
# epoch n° 93
# Training, Regression Loss: 0.0506, Regression Loss 1h: 168.0552, Segmentation Loss:0.1610
# Train Confusion Matrix:
# [[3117471   83910]
#  [ 148724  489895]]
# Accuracy: 0.9394, CSI: 0.6780, Sensitivity: 0.7671, Specificity: 0.9738, False Alarm Ratio: 0.1462
#
#
# epoch duration : 85.94448351860046
# epoch n° 94
# Training, Regression Loss: 0.0496, Regression Loss 1h: 174.9637, Segmentation Loss:0.1611
# Train Confusion Matrix:
# [[3111154   83485]
#  [ 149986  495375]]
# Accuracy: 0.9392, CSI: 0.6797, Sensitivity: 0.7676, Specificity: 0.9739, False Alarm Ratio: 0.1442
#
#
# epoch duration : 92.84877133369446
# epoch n° 95
# Training, Regression Loss: 0.0535, Regression Loss 1h: 158.7136, Segmentation Loss:0.1587
# Train Confusion Matrix:
# [[3115566   83002]
#  [ 147310  494122]]
# Accuracy: 0.9400, CSI: 0.6821, Sensitivity: 0.7703, Specificity: 0.9741, False Alarm Ratio: 0.1438
#
#
# epoch duration : 97.40820717811584
# epoch n° 96
# Training, Regression Loss: 0.0503, Regression Loss 1h: 172.8107, Segmentation Loss:0.1542
# Train Confusion Matrix:
# [[3125007   83610]
#  [ 141330  490053]]
# Accuracy: 0.9414, CSI: 0.6854, Sensitivity: 0.7762, Specificity: 0.9739, False Alarm Ratio: 0.1457
#
#
# epoch duration : 98.85833787918091
# epoch n° 97
# Training, Regression Loss: 0.0487, Regression Loss 1h: 171.1797, Segmentation Loss:0.1557
# Train Confusion Matrix:
# [[3118932   84167]
#  [ 145356  491545]]
# Accuracy: 0.9402, CSI: 0.6817, Sensitivity: 0.7718, Specificity: 0.9737, False Alarm Ratio: 0.1462
#
#
# epoch duration : 96.09906125068665
# epoch n° 98
# Training, Regression Loss: 0.0464, Regression Loss 1h: 178.1892, Segmentation Loss:0.1537
# Train Confusion Matrix:
# [[3117801   82540]
#  [ 144730  494929]]
# Accuracy: 0.9408, CSI: 0.6853, Sensitivity: 0.7737, Specificity: 0.9742, False Alarm Ratio: 0.1429
#
#
# epoch duration : 96.55725741386414
# epoch n° 99
# Training, Regression Loss: 0.0462, Regression Loss 1h: 173.6888, Segmentation Loss:0.1530
# Train Confusion Matrix:
# [[3109273   83299]
#  [ 142506  504922]]
# Accuracy: 0.9412, CSI: 0.6910, Sensitivity: 0.7799, Specificity: 0.9739, False Alarm Ratio: 0.1416
#
#
# epoch duration : 86.29633092880249
# epoch n° 100
# Training, Regression Loss: 0.0482, Regression Loss 1h: 177.2136, Segmentation Loss:0.1496
# Train Confusion Matrix:
# [[3115185   83665]
#  [ 138228  502922]]
# Accuracy: 0.9422, CSI: 0.6939, Sensitivity: 0.7844, Specificity: 0.9738, False Alarm Ratio: 0.1426
#
#
# epoch duration : 90.34815859794617
# saving step
# epoch n° 101
# Training, Regression Loss: 0.0458, Regression Loss 1h: 164.5854, Segmentation Loss:0.1483
# Train Confusion Matrix:
# [[3127509   82245]
#  [ 137445  492801]]
# Accuracy: 0.9428, CSI: 0.6917, Sensitivity: 0.7819, Specificity: 0.9744, False Alarm Ratio: 0.1430
#
#
# epoch duration : 89.65879702568054
# epoch n° 102
# Training, Regression Loss: 0.0455, Regression Loss 1h: 181.3371, Segmentation Loss:0.1504
# Train Confusion Matrix:
# [[3118740   84159]
#  [ 140163  496938]]
# Accuracy: 0.9416, CSI: 0.6890, Sensitivity: 0.7800, Specificity: 0.9737, False Alarm Ratio: 0.1448
#
#
# epoch duration : 89.22492361068726
# epoch n° 103
# Training, Regression Loss: 0.0451, Regression Loss 1h: 187.8807, Segmentation Loss:0.1494
# Train Confusion Matrix:
# [[3122584   80787]
#  [ 141079  495550]]
# Accuracy: 0.9422, CSI: 0.6907, Sensitivity: 0.7784, Specificity: 0.9748, False Alarm Ratio: 0.1402
#
#
# epoch duration : 93.87470817565918
# epoch n° 104
# Training, Regression Loss: 0.0454, Regression Loss 1h: 189.8333, Segmentation Loss:0.1462
# Train Confusion Matrix:
# [[3124450   82316]
#  [ 135434  497800]]
# Accuracy: 0.9433, CSI: 0.6957, Sensitivity: 0.7861, Specificity: 0.9743, False Alarm Ratio: 0.1419
#
#
# epoch duration : 100.06964159011841
# epoch n° 105
# Training, Regression Loss: 0.0459, Regression Loss 1h: 191.9983, Segmentation Loss:0.1435
# Train Confusion Matrix:
# [[3114153   80933]
#  [ 132430  512484]]
# Accuracy: 0.9444, CSI: 0.7060, Sensitivity: 0.7947, Specificity: 0.9747, False Alarm Ratio: 0.1364
#
#
# epoch duration : 96.66571640968323
# epoch n° 106
# Training, Regression Loss: 0.0464, Regression Loss 1h: 196.2885, Segmentation Loss:0.1434
# Train Confusion Matrix:
# [[3127145   81746]
#  [ 132183  498926]]
# Accuracy: 0.9443, CSI: 0.6999, Sensitivity: 0.7906, Specificity: 0.9745, False Alarm Ratio: 0.1408
#
#
# epoch duration : 94.77306818962097
# epoch n° 107
# Training, Regression Loss: 0.0456, Regression Loss 1h: 199.1362, Segmentation Loss:0.1494
# Train Confusion Matrix:
# [[3109011   84106]
#  [ 139704  507179]]
# Accuracy: 0.9417, CSI: 0.6938, Sensitivity: 0.7840, Specificity: 0.9737, False Alarm Ratio: 0.1422
#
#
# epoch duration : 86.20492100715637
# epoch n° 108
# Training, Regression Loss: 0.0461, Regression Loss 1h: 186.9689, Segmentation Loss:0.1449
# Train Confusion Matrix:
# [[3108384   83544]
#  [ 133242  514830]]
# Accuracy: 0.9435, CSI: 0.7037, Sensitivity: 0.7944, Specificity: 0.9738, False Alarm Ratio: 0.1396
#
#
# epoch duration : 90.10236263275146
# epoch n° 109
# Training, Regression Loss: 0.0437, Regression Loss 1h: 197.2236, Segmentation Loss:0.1458
# Train Confusion Matrix:
# [[3113168   82612]
#  [ 135348  508872]]
# Accuracy: 0.9432, CSI: 0.7001, Sensitivity: 0.7899, Specificity: 0.9741, False Alarm Ratio: 0.1397
#
#
# epoch duration : 89.07911086082458
# epoch n° 110
# Training, Regression Loss: 0.0443, Regression Loss 1h: 199.8720, Segmentation Loss:0.1426
# Train Confusion Matrix:
# [[3111038   83007]
#  [ 130981  514974]]
# Accuracy: 0.9443, CSI: 0.7064, Sensitivity: 0.7972, Specificity: 0.9740, False Alarm Ratio: 0.1388
#
#
# epoch duration : 91.94653511047363
# saving step
# epoch n° 111
# Training, Regression Loss: 0.0431, Regression Loss 1h: 195.0686, Segmentation Loss:0.1506
# Train Confusion Matrix:
# [[3115477   81873]
#  [ 142705  499945]]
# Accuracy: 0.9415, CSI: 0.6900, Sensitivity: 0.7779, Specificity: 0.9744, False Alarm Ratio: 0.1407
#
#
# epoch duration : 95.8135392665863
# epoch n° 112
# Training, Regression Loss: 0.0445, Regression Loss 1h: 191.8187, Segmentation Loss:0.1464
# Train Confusion Matrix:
# [[3109588   84654]
#  [ 135564  510194]]
# Accuracy: 0.9427, CSI: 0.6985, Sensitivity: 0.7901, Specificity: 0.9735, False Alarm Ratio: 0.1423
#
#
# epoch duration : 99.91958737373352
# epoch n° 113
# Training, Regression Loss: 0.0437, Regression Loss 1h: 198.4945, Segmentation Loss:0.1426
# Train Confusion Matrix:
# [[3112113   83209]
#  [ 132096  512582]]
# Accuracy: 0.9439, CSI: 0.7042, Sensitivity: 0.7951, Specificity: 0.9740, False Alarm Ratio: 0.1397
#
#
# epoch duration : 101.43726301193237
# epoch n° 114
# Training, Regression Loss: 0.0452, Regression Loss 1h: 217.4999, Segmentation Loss:0.1402
# Train Confusion Matrix:
# [[3115750   82757]
#  [ 128546  512947]]
# Accuracy: 0.9450, CSI: 0.7082, Sensitivity: 0.7996, Specificity: 0.9741, False Alarm Ratio: 0.1389
#
#
# epoch duration : 92.71041417121887
# epoch n° 115
# Training, Regression Loss: 0.0431, Regression Loss 1h: 198.0344, Segmentation Loss:0.1419
# Train Confusion Matrix:
# [[3119026   81802]
#  [ 131699  507473]]
# Accuracy: 0.9444, CSI: 0.7039, Sensitivity: 0.7940, Specificity: 0.9744, False Alarm Ratio: 0.1388
#
#
# epoch duration : 91.4513680934906
# epoch n° 116
# Training, Regression Loss: 0.0443, Regression Loss 1h: 203.8255, Segmentation Loss:0.1440
# Train Confusion Matrix:
# [[3115541   82972]
#  [ 132922  508565]]
# Accuracy: 0.9438, CSI: 0.7020, Sensitivity: 0.7928, Specificity: 0.9741, False Alarm Ratio: 0.1403
#
#
# epoch duration : 88.01195454597473
# epoch n° 117
# Training, Regression Loss: 0.0449, Regression Loss 1h: 196.2138, Segmentation Loss:0.1417
# Train Confusion Matrix:
# [[3112629   82180]
#  [ 129899  515292]]
# Accuracy: 0.9448, CSI: 0.7084, Sensitivity: 0.7987, Specificity: 0.9743, False Alarm Ratio: 0.1375
#
#
# epoch duration : 90.53642129898071
# epoch n° 118
# Training, Regression Loss: 0.0428, Regression Loss 1h: 205.1823, Segmentation Loss:0.1486
# Train Confusion Matrix:
# [[3117317   83141]
#  [ 139651  499891]]
# Accuracy: 0.9420, CSI: 0.6917, Sensitivity: 0.7816, Specificity: 0.9740, False Alarm Ratio: 0.1426
#
#
# epoch duration : 86.15446281433105
# epoch n° 119
# Training, Regression Loss: 0.0432, Regression Loss 1h: 198.2290, Segmentation Loss:0.1427
# Train Confusion Matrix:
# [[3111494   82754]
#  [ 131520  514232]]
# Accuracy: 0.9442, CSI: 0.7059, Sensitivity: 0.7963, Specificity: 0.9741, False Alarm Ratio: 0.1386
#
#
# epoch duration : 96.56486368179321
# epoch n° 120
# Training, Regression Loss: 0.0424, Regression Loss 1h: 198.2278, Segmentation Loss:0.1420
# Train Confusion Matrix:
# [[3112256   83073]
#  [ 130660  514011]]
# Accuracy: 0.9443, CSI: 0.7063, Sensitivity: 0.7973, Specificity: 0.9740, False Alarm Ratio: 0.1391
#
#
# epoch duration : 96.83273386955261
# saving step
# epoch n° 121
# Training, Regression Loss: 0.0430, Regression Loss 1h: 209.5333, Segmentation Loss:0.1471
# Train Confusion Matrix:
# [[3127549   81062]
#  [ 136495  494894]]
# Accuracy: 0.9433, CSI: 0.6946, Sensitivity: 0.7838, Specificity: 0.9747, False Alarm Ratio: 0.1407
#
#
# epoch duration : 98.3820731639862
# epoch n° 122
# Training, Regression Loss: 0.0455, Regression Loss 1h: 191.5037, Segmentation Loss:0.1438
# Train Confusion Matrix:
# [[3123905   82171]
#  [ 132396  501528]]
# Accuracy: 0.9441, CSI: 0.7004, Sensitivity: 0.7911, Specificity: 0.9744, False Alarm Ratio: 0.1408
#
#
# epoch duration : 94.51950192451477
# epoch n° 123
# Training, Regression Loss: 0.0437, Regression Loss 1h: 202.0172, Segmentation Loss:0.1427
# Train Confusion Matrix:
# [[3111229   83830]
#  [ 131583  513358]]
# Accuracy: 0.9439, CSI: 0.7044, Sensitivity: 0.7960, Specificity: 0.9738, False Alarm Ratio: 0.1404
#
#
# epoch duration : 90.38553047180176
# epoch n° 124
# Training, Regression Loss: 0.0427, Regression Loss 1h: 204.2904, Segmentation Loss:0.1426
# Train Confusion Matrix:
# [[3119123   81632]
#  [ 132128  507117]]
# Accuracy: 0.9443, CSI: 0.7035, Sensitivity: 0.7933, Specificity: 0.9745, False Alarm Ratio: 0.1387
#
#
# epoch duration : 88.59499216079712
# epoch n° 125
# Training, Regression Loss: 0.0419, Regression Loss 1h: 206.2924, Segmentation Loss:0.1398
# Train Confusion Matrix:
# [[3106776   82140]
#  [ 128489  522595]]
# Accuracy: 0.9451, CSI: 0.7127, Sensitivity: 0.8027, Specificity: 0.9742, False Alarm Ratio: 0.1358
#
#
# epoch duration : 90.60778975486755
# epoch n° 126
# Training, Regression Loss: 0.0407, Regression Loss 1h: 207.3786, Segmentation Loss:0.1447
# Train Confusion Matrix:
# [[3108565   82090]
#  [ 135162  514183]]
# Accuracy: 0.9434, CSI: 0.7030, Sensitivity: 0.7918, Specificity: 0.9743, False Alarm Ratio: 0.1377
#
#
# epoch duration : 86.61526298522949
# epoch n° 127
# Training, Regression Loss: 0.0427, Regression Loss 1h: 204.5245, Segmentation Loss:0.1384
# Train Confusion Matrix:
# [[3114097   80944]
#  [ 126671  518288]]
# Accuracy: 0.9459, CSI: 0.7140, Sensitivity: 0.8036, Specificity: 0.9747, False Alarm Ratio: 0.1351
#
#
# epoch duration : 96.22812104225159
# epoch n° 128
# Training, Regression Loss: 0.0418, Regression Loss 1h: 204.9810, Segmentation Loss:0.1403
# Train Confusion Matrix:
# [[3115619   82160]
#  [ 129602  512619]]
# Accuracy: 0.9449, CSI: 0.7077, Sensitivity: 0.7982, Specificity: 0.9743, False Alarm Ratio: 0.1381
#
#
# epoch duration : 99.25689601898193
# epoch n° 129
# Training, Regression Loss: 0.0432, Regression Loss 1h: 212.2782, Segmentation Loss:0.1385
# Train Confusion Matrix:
# [[3118033   80219]
#  [ 128046  513702]]
# Accuracy: 0.9458, CSI: 0.7115, Sensitivity: 0.8005, Specificity: 0.9749, False Alarm Ratio: 0.1351
#
#
# epoch duration : 99.01811170578003
# epoch n° 130
# Training, Regression Loss: 0.0421, Regression Loss 1h: 205.4346, Segmentation Loss:0.1409
# Train Confusion Matrix:
# [[3113896   82273]
#  [ 129760  514071]]
# Accuracy: 0.9448, CSI: 0.7080, Sensitivity: 0.7985, Specificity: 0.9743, False Alarm Ratio: 0.1380
#
#
# epoch duration : 92.55534982681274
# saving step
# epoch n° 131
# Training, Regression Loss: 0.0407, Regression Loss 1h: 201.4307, Segmentation Loss:0.1485
# Train Confusion Matrix:
# [[3104798   84197]
#  [ 140050  510955]]
# Accuracy: 0.9416, CSI: 0.6950, Sensitivity: 0.7849, Specificity: 0.9736, False Alarm Ratio: 0.1415
#
#
# epoch duration : 93.85187673568726
# epoch n° 132
# Training, Regression Loss: 0.0421, Regression Loss 1h: 195.9475, Segmentation Loss:0.1428
# Train Confusion Matrix:
# [[3122884   81811]
#  [ 132383  502922]]
# Accuracy: 0.9442, CSI: 0.7013, Sensitivity: 0.7916, Specificity: 0.9745, False Alarm Ratio: 0.1399
#
#
# epoch duration : 85.08773279190063
# epoch n° 133
# Training, Regression Loss: 0.0422, Regression Loss 1h: 208.6783, Segmentation Loss:0.1363
# Train Confusion Matrix:
# [[3120607   80530]
#  [ 125333  513530]]
# Accuracy: 0.9464, CSI: 0.7138, Sensitivity: 0.8038, Specificity: 0.9748, False Alarm Ratio: 0.1356
#
#
# epoch duration : 93.02364611625671
# epoch n° 134
# Training, Regression Loss: 0.0421, Regression Loss 1h: 220.1192, Segmentation Loss:0.1384
# Train Confusion Matrix:
# [[3124725   81091]
#  [ 127262  506922]]
# Accuracy: 0.9457, CSI: 0.7087, Sensitivity: 0.7993, Specificity: 0.9747, False Alarm Ratio: 0.1379
#
#
# epoch duration : 87.54920554161072
# epoch n° 135
# Training, Regression Loss: 0.0419, Regression Loss 1h: 213.6617, Segmentation Loss:0.1379
# Train Confusion Matrix:
# [[3130243   80418]
#  [ 126498  502841]]
# Accuracy: 0.9461, CSI: 0.7085, Sensitivity: 0.7990, Specificity: 0.9750, False Alarm Ratio: 0.1379
#
#
# epoch duration : 95.68987369537354
# epoch n° 136
# Training, Regression Loss: 0.0407, Regression Loss 1h: 210.0296, Segmentation Loss:0.1417
# Train Confusion Matrix:
# [[3112866   80999]
#  [ 131460  514675]]
# Accuracy: 0.9447, CSI: 0.7078, Sensitivity: 0.7965, Specificity: 0.9746, False Alarm Ratio: 0.1360
#
#
# epoch duration : 97.81945967674255
# epoch n° 137
# Training, Regression Loss: 0.0404, Regression Loss 1h: 216.0224, Segmentation Loss:0.1373
# Train Confusion Matrix:
# [[3122118   79885]
#  [ 127221  510776]]
# Accuracy: 0.9461, CSI: 0.7115, Sensitivity: 0.8006, Specificity: 0.9751, False Alarm Ratio: 0.1352
#
#
# epoch duration : 98.32299017906189
# epoch n° 138
# Training, Regression Loss: 0.0592, Regression Loss 1h: 357.5823, Segmentation Loss:0.1710
# Train Confusion Matrix:
# [[3118110   86426]
#  [ 167119  468345]]
# Accuracy: 0.9340, CSI: 0.6488, Sensitivity: 0.7370, Specificity: 0.9730, False Alarm Ratio: 0.1558
#
#
# epoch duration : 89.9900255203247
# epoch n° 139
# Training, Regression Loss: 0.0581, Regression Loss 1h: 385.8291, Segmentation Loss:0.1770
# Train Confusion Matrix:
# [[3095119   99606]
#  [ 167761  477514]]
# Accuracy: 0.9304, CSI: 0.6411, Sensitivity: 0.7400, Specificity: 0.9688, False Alarm Ratio: 0.1726
#
#
# epoch duration : 86.85023283958435
# epoch n° 140
# Training, Regression Loss: 0.0492, Regression Loss 1h: 241.5627, Segmentation Loss:0.1502
# Train Confusion Matrix:
# [[3117805   85875]
#  [ 136853  499467]]
# Accuracy: 0.9420, CSI: 0.6916, Sensitivity: 0.7849, Specificity: 0.9732, False Alarm Ratio: 0.1467
#
#
# epoch duration : 87.91677451133728
# saving step
# epoch n° 141
# Training, Regression Loss: 0.0539, Regression Loss 1h: 241.4393, Segmentation Loss:0.1548
# Train Confusion Matrix:
# [[3109991   83180]
#  [ 143235  503594]]
# Accuracy: 0.9410, CSI: 0.6898, Sensitivity: 0.7786, Specificity: 0.9740, False Alarm Ratio: 0.1418
#
#
# epoch duration : 87.77435111999512
# epoch n° 142
# Training, Regression Loss: 0.0562, Regression Loss 1h: 231.5074, Segmentation Loss:0.1658
# Train Confusion Matrix:
# [[3104106   88723]
#  [ 150143  497028]]
# Accuracy: 0.9378, CSI: 0.6754, Sensitivity: 0.7680, Specificity: 0.9722, False Alarm Ratio: 0.1515
#
#
# epoch duration : 93.94709730148315
# epoch n° 143
# Training, Regression Loss: 0.0485, Regression Loss 1h: 209.5450, Segmentation Loss:0.1506
# Train Confusion Matrix:
# [[3108174   85808]
#  [ 137495  508523]]
# Accuracy: 0.9418, CSI: 0.6949, Sensitivity: 0.7872, Specificity: 0.9731, False Alarm Ratio: 0.1444
#
#
# epoch duration : 95.31090545654297
# epoch n° 144
# Training, Regression Loss: 0.0467, Regression Loss 1h: 217.5150, Segmentation Loss:0.1499
# Train Confusion Matrix:
# [[3113756   83741]
#  [ 139491  503012]]
# Accuracy: 0.9419, CSI: 0.6926, Sensitivity: 0.7829, Specificity: 0.9738, False Alarm Ratio: 0.1427
#
#
# epoch duration : 102.2362425327301
# epoch n° 145
# Training, Regression Loss: 0.0463, Regression Loss 1h: 223.8502, Segmentation Loss:0.1439
# Train Confusion Matrix:
# [[3106420   84972]
#  [ 130743  517865]]
# Accuracy: 0.9438, CSI: 0.7059, Sensitivity: 0.7984, Specificity: 0.9734, False Alarm Ratio: 0.1410
#
#
# epoch duration : 96.96183586120605
# epoch n° 146
# Training, Regression Loss: 0.0470, Regression Loss 1h: 237.1652, Segmentation Loss:0.1448
# Train Confusion Matrix:
# [[3112815   84904]
#  [ 133147  509134]]
# Accuracy: 0.9432, CSI: 0.7001, Sensitivity: 0.7927, Specificity: 0.9734, False Alarm Ratio: 0.1429
#
#
# epoch duration : 95.27723026275635
# epoch n° 147
# Training, Regression Loss: 0.0458, Regression Loss 1h: 249.2382, Segmentation Loss:0.1397
# Train Confusion Matrix:
# [[3124552   82653]
#  [ 127160  505635]]
# Accuracy: 0.9454, CSI: 0.7067, Sensitivity: 0.7991, Specificity: 0.9742, False Alarm Ratio: 0.1405
#
#
# epoch duration : 85.84304809570312
# epoch n° 148
# Training, Regression Loss: 0.0436, Regression Loss 1h: 257.6413, Segmentation Loss:0.1388
# Train Confusion Matrix:
# [[3117182   82159]
#  [ 126677  513982]]
# Accuracy: 0.9456, CSI: 0.7111, Sensitivity: 0.8023, Specificity: 0.9743, False Alarm Ratio: 0.1378
#
#
# epoch duration : 89.77633094787598
# epoch n° 149
# Training, Regression Loss: 0.0432, Regression Loss 1h: 251.4268, Segmentation Loss:0.1418
# Train Confusion Matrix:
# [[3111628   83302]
#  [ 129481  515589]]
# Accuracy: 0.9446, CSI: 0.7079, Sensitivity: 0.7993, Specificity: 0.9739, False Alarm Ratio: 0.1391
#
#
# epoch duration : 84.66298079490662
# epoch n° 150
# Training, Regression Loss: 0.0428, Regression Loss 1h: 261.9713, Segmentation Loss:0.1404
# Train Confusion Matrix:
# [[3119078   82539]
#  [ 129098  509285]]
# Accuracy: 0.9449, CSI: 0.7064, Sensitivity: 0.7978, Specificity: 0.9742, False Alarm Ratio: 0.1395
#
#
# epoch duration : 93.95912885665894
# saving step
# epoch n° 151
# Training, Regression Loss: 0.0427, Regression Loss 1h: 260.1259, Segmentation Loss:0.1405
# Train Confusion Matrix:
# [[3117843   83085]
#  [ 129789  509283]]
# Accuracy: 0.9446, CSI: 0.7052, Sensitivity: 0.7969, Specificity: 0.9740, False Alarm Ratio: 0.1403
#
#
# epoch duration : 95.01617336273193
# epoch n° 152
# Training, Regression Loss: 0.0415, Regression Loss 1h: 252.7393, Segmentation Loss:0.1392
# Train Confusion Matrix:
# [[3124183   81971]
#  [ 127264  506582]]
# Accuracy: 0.9455, CSI: 0.7077, Sensitivity: 0.7992, Specificity: 0.9744, False Alarm Ratio: 0.1393
#
#
# epoch duration : 100.1662187576294
# epoch n° 153
# Training, Regression Loss: 0.0423, Regression Loss 1h: 255.4483, Segmentation Loss:0.1432
# Train Confusion Matrix:
# [[3110605   83786]
#  [ 132569  513040]]
# Accuracy: 0.9437, CSI: 0.7034, Sensitivity: 0.7947, Specificity: 0.9738, False Alarm Ratio: 0.1404
#
#
# epoch duration : 95.30436325073242
# epoch n° 154
# Training, Regression Loss: 0.0529, Regression Loss 1h: 259.8603, Segmentation Loss:0.1582
# Train Confusion Matrix:
# [[3113312   84347]
#  [ 144892  497449]]
# Accuracy: 0.9403, CSI: 0.6845, Sensitivity: 0.7744, Specificity: 0.9736, False Alarm Ratio: 0.1450
#
#
# epoch duration : 90.61877989768982
# epoch n° 155
# Training, Regression Loss: 0.0457, Regression Loss 1h: 219.0993, Segmentation Loss:0.1483
# Train Confusion Matrix:
# [[3110226   83392]
#  [ 135843  510539]]
# Accuracy: 0.9429, CSI: 0.6996, Sensitivity: 0.7898, Specificity: 0.9739, False Alarm Ratio: 0.1404
#
#
# epoch duration : 86.11459851264954
# epoch n° 156
# Training, Regression Loss: 0.0433, Regression Loss 1h: 234.1282, Segmentation Loss:0.1436
# Train Confusion Matrix:
# [[3122865   83300]
#  [ 131930  501905]]
# Accuracy: 0.9440, CSI: 0.6999, Sensitivity: 0.7919, Specificity: 0.9740, False Alarm Ratio: 0.1423
#
#
# epoch duration : 88.63445258140564
# epoch n° 157
# Training, Regression Loss: 0.0424, Regression Loss 1h: 237.4534, Segmentation Loss:0.1448
# Train Confusion Matrix:
# [[3117919   83117]
#  [ 134064  504900]]
# Accuracy: 0.9434, CSI: 0.6992, Sensitivity: 0.7902, Specificity: 0.9740, False Alarm Ratio: 0.1414
#
#
# epoch duration : 86.87918472290039
# epoch n° 158
# Training, Regression Loss: 0.0432, Regression Loss 1h: 241.9904, Segmentation Loss:0.1377
# Train Confusion Matrix:
# [[3114346   82618]
#  [ 125482  517554]]
# Accuracy: 0.9458, CSI: 0.7132, Sensitivity: 0.8049, Specificity: 0.9742, False Alarm Ratio: 0.1377
#
#
# epoch duration : 91.38077783584595
# epoch n° 159
# Training, Regression Loss: 0.0419, Regression Loss 1h: 253.1256, Segmentation Loss:0.1398
# Train Confusion Matrix:
# [[3109880   83028]
#  [ 129300  517792]]
# Accuracy: 0.9447, CSI: 0.7092, Sensitivity: 0.8002, Specificity: 0.9740, False Alarm Ratio: 0.1382
#
#
# epoch duration : 99.13063549995422
# epoch n° 160
# Training, Regression Loss: 0.0412, Regression Loss 1h: 260.1882, Segmentation Loss:0.1413
# Train Confusion Matrix:
# [[3111341   84107]
#  [ 129342  515210]]
# Accuracy: 0.9444, CSI: 0.7071, Sensitivity: 0.7993, Specificity: 0.9737, False Alarm Ratio: 0.1403
#
#
# epoch duration : 98.70009970664978
# saving step
# epoch n° 161
# Training, Regression Loss: 0.0419, Regression Loss 1h: 253.9017, Segmentation Loss:0.1399
# Train Confusion Matrix:
# [[3113175   82654]
#  [ 128961  515210]]
# Accuracy: 0.9449, CSI: 0.7089, Sensitivity: 0.7998, Specificity: 0.9741, False Alarm Ratio: 0.1382
#
#
# epoch duration : 95.69360446929932
# epoch n° 162
# Training, Regression Loss: 0.0419, Regression Loss 1h: 262.0683, Segmentation Loss:0.1358
# Train Confusion Matrix:
# [[3114626   82680]
#  [ 123447  519247]]
# Accuracy: 0.9463, CSI: 0.7158, Sensitivity: 0.8079, Specificity: 0.9741, False Alarm Ratio: 0.1374
#
#
# epoch duration : 90.6853621006012
# epoch n° 163
# Training, Regression Loss: 0.0411, Regression Loss 1h: 254.8320, Segmentation Loss:0.1376
# Train Confusion Matrix:
# [[3111760   82498]
#  [ 126325  519417]]
# Accuracy: 0.9456, CSI: 0.7132, Sensitivity: 0.8044, Specificity: 0.9742, False Alarm Ratio: 0.1371
#
#
# epoch duration : 86.99826097488403
# epoch n° 164
# Training, Regression Loss: 0.0406, Regression Loss 1h: 269.9147, Segmentation Loss:0.1371
# Train Confusion Matrix:
# [[3109265   83051]
#  [ 124844  522840]]
# Accuracy: 0.9459, CSI: 0.7155, Sensitivity: 0.8072, Specificity: 0.9740, False Alarm Ratio: 0.1371
#
#
# epoch duration : 88.58544993400574
# epoch n° 165
# Training, Regression Loss: 0.0415, Regression Loss 1h: 256.7020, Segmentation Loss:0.1367
# Train Confusion Matrix:
# [[3115723   82413]
#  [ 124885  516979]]
# Accuracy: 0.9460, CSI: 0.7138, Sensitivity: 0.8054, Specificity: 0.9742, False Alarm Ratio: 0.1375
#
#
# epoch duration : 88.84108328819275
# epoch n° 166
# Training, Regression Loss: 0.0412, Regression Loss 1h: 262.8962, Segmentation Loss:0.1344
# Train Confusion Matrix:
# [[3116724   81827]
#  [ 122116  519333]]
# Accuracy: 0.9469, CSI: 0.7180, Sensitivity: 0.8096, Specificity: 0.9744, False Alarm Ratio: 0.1361
#
#
# epoch duration : 95.81249690055847
# epoch n° 167
# Training, Regression Loss: 0.0403, Regression Loss 1h: 256.5811, Segmentation Loss:0.1408
# Train Confusion Matrix:
# [[3107431   83628]
#  [ 129511  519430]]
# Accuracy: 0.9445, CSI: 0.7091, Sensitivity: 0.8004, Specificity: 0.9738, False Alarm Ratio: 0.1387
#
#
# epoch duration : 99.58488607406616
# epoch n° 168
# Training, Regression Loss: 0.0401, Regression Loss 1h: 259.8818, Segmentation Loss:0.1397
# Train Confusion Matrix:
# [[3118656   82233]
#  [ 129307  509804]]
# Accuracy: 0.9449, CSI: 0.7067, Sensitivity: 0.7977, Specificity: 0.9743, False Alarm Ratio: 0.1389
#
#
# epoch duration : 99.26811289787292
# epoch n° 169
# Training, Regression Loss: 0.0403, Regression Loss 1h: 256.4768, Segmentation Loss:0.1367
# Train Confusion Matrix:
# [[3129131   81291]
#  [ 125534  504044]]
# Accuracy: 0.9461, CSI: 0.7091, Sensitivity: 0.8006, Specificity: 0.9747, False Alarm Ratio: 0.1389
#
#
# epoch duration : 95.33608722686768
# epoch n° 170
# Training, Regression Loss: 0.0404, Regression Loss 1h: 257.1872, Segmentation Loss:0.1380
# Train Confusion Matrix:
# [[3108813   83381]
#  [ 126026  521780]]
# Accuracy: 0.9455, CSI: 0.7136, Sensitivity: 0.8055, Specificity: 0.9739, False Alarm Ratio: 0.1378
#
#
# epoch duration : 83.1303448677063
# epoch n° 173
# Training, Regression Loss: 0.0473, Regression Loss 1h: 258.3850, Segmentation Loss:0.1477
# Train Confusion Matrix:
# [[3110128   83347]
#  [ 136738  509787]]
# Accuracy: 0.9427, CSI: 0.6985, Sensitivity: 0.7885, Specificity: 0.9739, False Alarm Ratio: 0.1405
#
#
# epoch duration : 93.18217658996582
# epoch n° 174
# Training, Regression Loss: 0.0409, Regression Loss 1h: 251.2070, Segmentation Loss:0.1396
# Train Confusion Matrix:
# [[3112457   83317]
#  [ 127380  516846]]
# Accuracy: 0.9451, CSI: 0.7104, Sensitivity: 0.8023, Specificity: 0.9739, False Alarm Ratio: 0.1388
#
#
# epoch duration : 89.38738799095154
# epoch n° 175
# Training, Regression Loss: 0.0420, Regression Loss 1h: 262.8156, Segmentation Loss:0.1346
# Train Confusion Matrix:
# [[3111154   84171]
#  [ 120631  524044]]
# Accuracy: 0.9467, CSI: 0.7190, Sensitivity: 0.8129, Specificity: 0.9737, False Alarm Ratio: 0.1384
#
#
# epoch duration : 96.72183895111084
# epoch n° 176
# Training, Regression Loss: 0.0416, Regression Loss 1h: 266.4180, Segmentation Loss:0.1351
# Train Confusion Matrix:
# [[3117101   80870]
#  [ 123675  518354]]
# Accuracy: 0.9467, CSI: 0.7170, Sensitivity: 0.8074, Specificity: 0.9747, False Alarm Ratio: 0.1350
#
#
# epoch duration : 100.73758816719055
# epoch n° 177
# Training, Regression Loss: 0.0402, Regression Loss 1h: 269.3629, Segmentation Loss:0.1322
# Train Confusion Matrix:
# [[3123830   80348]
#  [ 120679  515143]]
# Accuracy: 0.9476, CSI: 0.7193, Sensitivity: 0.8102, Specificity: 0.9749, False Alarm Ratio: 0.1349
#
#
# epoch duration : 95.51228952407837
# epoch n° 179
# Training, Regression Loss: 0.0395, Regression Loss 1h: 275.1703, Segmentation Loss:0.1352
# Train Confusion Matrix:
# [[3114943   81818]
#  [ 123707  519532]]
# Accuracy: 0.9465, CSI: 0.7165, Sensitivity: 0.8077, Specificity: 0.9744, False Alarm Ratio: 0.1361
#
#
# epoch duration : 88.65262269973755
# epoch n° 180
# Training, Regression Loss: 0.0395, Regression Loss 1h: 269.2141, Segmentation Loss:0.1360
# Train Confusion Matrix:
# [[3112221   81253]
#  [ 124789  521737]]
# Accuracy: 0.9463, CSI: 0.7169, Sensitivity: 0.8070, Specificity: 0.9746, False Alarm Ratio: 0.1348
#
#
# epoch duration : 86.49327421188354
# saving step
# epoch n° 181
# Training, Regression Loss: 0.0399, Regression Loss 1h: 277.5160, Segmentation Loss:0.1373
# Train Confusion Matrix:
# [[3115471   82296]
#  [ 126144  516089]]
# Accuracy: 0.9457, CSI: 0.7123, Sensitivity: 0.8036, Specificity: 0.9743, False Alarm Ratio: 0.1375
#
#
# epoch duration : 85.92400574684143
# epoch n° 182
# Training, Regression Loss: 0.0394, Regression Loss 1h: 257.1050, Segmentation Loss:0.1338
# Train Confusion Matrix:
# [[3112277   81776]
#  [ 122088  523859]]
# Accuracy: 0.9469, CSI: 0.7199, Sensitivity: 0.8110, Specificity: 0.9744, False Alarm Ratio: 0.1350
#
#
# epoch duration : 90.94321823120117
# epoch n° 183
# Training, Regression Loss: 0.0397, Regression Loss 1h: 278.4583, Segmentation Loss:0.1330
# Train Confusion Matrix:
# [[3116850   81260]
#  [ 120981  520909]]
# Accuracy: 0.9473, CSI: 0.7203, Sensitivity: 0.8115, Specificity: 0.9746, False Alarm Ratio: 0.1349
#
#
# epoch duration : 94.2291944026947
# epoch n° 184
# Training, Regression Loss: 0.0393, Regression Loss 1h: 268.4083, Segmentation Loss:0.1376
# Train Confusion Matrix:
# [[3118113   81964]
#  [ 126781  513142]]
# Accuracy: 0.9456, CSI: 0.7108, Sensitivity: 0.8019, Specificity: 0.9744, False Alarm Ratio: 0.1377
#
#
# epoch duration : 100.89058756828308
# epoch n° 185
# Training, Regression Loss: 0.0390, Regression Loss 1h: 272.4244, Segmentation Loss:0.1336
# Train Confusion Matrix:
# [[3111923   82417]
#  [ 121689  523971]]
# Accuracy: 0.9468, CSI: 0.7197, Sensitivity: 0.8115, Specificity: 0.9742, False Alarm Ratio: 0.1359
#
#
# epoch duration : 97.35710620880127
# epoch n° 186
# Training, Regression Loss: 0.0401, Regression Loss 1h: 279.2503, Segmentation Loss:0.1322
# Train Confusion Matrix:
# [[3110373   81781]
#  [ 119469  528377]]
# Accuracy: 0.9476, CSI: 0.7242, Sensitivity: 0.8156, Specificity: 0.9744, False Alarm Ratio: 0.1340
#
#
# epoch duration : 92.46578335762024
# epoch n° 187
# Training, Regression Loss: 0.0382, Regression Loss 1h: 269.8514, Segmentation Loss:0.1360
# Train Confusion Matrix:
# [[3117515   81690]
#  [ 124605  516190]]
# Accuracy: 0.9463, CSI: 0.7145, Sensitivity: 0.8055, Specificity: 0.9745, False Alarm Ratio: 0.1366
#
#
# epoch duration : 88.88159704208374
# epoch n° 188
# Training, Regression Loss: 0.0388, Regression Loss 1h: 270.2673, Segmentation Loss:0.1375
# Train Confusion Matrix:
# [[3113627   83097]
#  [ 126502  516774]]
# Accuracy: 0.9454, CSI: 0.7114, Sensitivity: 0.8033, Specificity: 0.9740, False Alarm Ratio: 0.1385
#
#
# epoch duration : 89.39502048492432
# epoch n° 189
# Training, Regression Loss: 0.0395, Regression Loss 1h: 269.0470, Segmentation Loss:0.1324
# Train Confusion Matrix:
# [[3110301   81907]
#  [ 120180  527612]]
# Accuracy: 0.9474, CSI: 0.7231, Sensitivity: 0.8145, Specificity: 0.9743, False Alarm Ratio: 0.1344
#
#
# epoch duration : 92.50191259384155
# epoch n° 190
# Training, Regression Loss: 0.0393, Regression Loss 1h: 273.0021, Segmentation Loss:0.1315
# Train Confusion Matrix:
# [[3114353   80676]
#  [ 119266  525705]]
# Accuracy: 0.9479, CSI: 0.7245, Sensitivity: 0.8151, Specificity: 0.9747, False Alarm Ratio: 0.1330
#
#
# epoch duration : 89.92041015625
# saving step
# epoch n° 191
# Training, Regression Loss: 0.0382, Regression Loss 1h: 290.3817, Segmentation Loss:0.1306
# Train Confusion Matrix:
# [[3116646   80284]
#  [ 118609  524461]]
# Accuracy: 0.9482, CSI: 0.7250, Sensitivity: 0.8156, Specificity: 0.9749, False Alarm Ratio: 0.1328
#
#
# epoch duration : 94.3661003112793
# epoch n° 192
# Training, Regression Loss: 0.0382, Regression Loss 1h: 288.7530, Segmentation Loss:0.1330
# Train Confusion Matrix:
# [[3118074   80651]
#  [ 121742  519533]]
# Accuracy: 0.9473, CSI: 0.7196, Sensitivity: 0.8102, Specificity: 0.9748, False Alarm Ratio: 0.1344
#
#
# epoch duration : 100.1102843284607
# epoch n° 193
# Training, Regression Loss: 0.0495, Regression Loss 1h: 215.6348, Segmentation Loss:0.1680
# Train Confusion Matrix:
# [[3109069   85990]
#  [ 151675  493266]]
# Accuracy: 0.9381, CSI: 0.6748, Sensitivity: 0.7648, Specificity: 0.9731, False Alarm Ratio: 0.1484
#
#
# epoch duration : 99.07342982292175
# epoch n° 194
# Training, Regression Loss: 0.0461, Regression Loss 1h: 201.3819, Segmentation Loss:0.1507
# Train Confusion Matrix:
# [[3103382   85064]
#  [ 135990  515564]]
# Accuracy: 0.9424, CSI: 0.6999, Sensitivity: 0.7913, Specificity: 0.9733, False Alarm Ratio: 0.1416
#
#
# epoch duration : 93.50795674324036
# epoch n° 195
# Training, Regression Loss: 0.0431, Regression Loss 1h: 224.2489, Segmentation Loss:0.1403
# Train Confusion Matrix:
# [[3118163   82901]
#  [ 124541  514395]]
# Accuracy: 0.9460, CSI: 0.7126, Sensitivity: 0.8051, Specificity: 0.9741, False Alarm Ratio: 0.1388
#
#
# epoch duration : 87.17541027069092
# epoch n° 196
# Training, Regression Loss: 0.0418, Regression Loss 1h: 236.8162, Segmentation Loss:0.1418
# Train Confusion Matrix:
# [[3110107   84718]
#  [ 128095  517080]]
# Accuracy: 0.9446, CSI: 0.7084, Sensitivity: 0.8015, Specificity: 0.9735, False Alarm Ratio: 0.1408
#
#
# epoch duration : 89.47938108444214
# epoch n° 197
# Training, Regression Loss: 0.0416, Regression Loss 1h: 246.4241, Segmentation Loss:0.1417
# Train Confusion Matrix:
# [[3122966   83505]
#  [ 129442  504087]]
# Accuracy: 0.9445, CSI: 0.7030, Sensitivity: 0.7957, Specificity: 0.9740, False Alarm Ratio: 0.1421
#
#
# epoch duration : 87.23855328559875
# epoch n° 198
# Training, Regression Loss: 0.0429, Regression Loss 1h: 221.5595, Segmentation Loss:0.1418
# Train Confusion Matrix:
# [[3112530   82802]
#  [ 129121  515547]]
# Accuracy: 0.9448, CSI: 0.7087, Sensitivity: 0.7997, Specificity: 0.9741, False Alarm Ratio: 0.1384
#
#
# epoch duration : 92.29596018791199
# epoch n° 199
# Training, Regression Loss: 0.0420, Regression Loss 1h: 231.0384, Segmentation Loss:0.1378
# Train Confusion Matrix:
# [[3123845   81576]
#  [ 126154  508425]]
# Accuracy: 0.9459, CSI: 0.7099, Sensitivity: 0.8012, Specificity: 0.9746, False Alarm Ratio: 0.1383
#
#
# epoch duration : 94.17083168029785
# epoch n° 200
# Training, Regression Loss: 0.0419, Regression Loss 1h: 262.9619, Segmentation Loss:0.1353
# Train Confusion Matrix:
# [[3118683   82876]
#  [ 122693  515748]]
# Accuracy: 0.9465, CSI: 0.7150, Sensitivity: 0.8078, Specificity: 0.9741, False Alarm Ratio: 0.1384
#
#
# epoch duration : 102.55452990531921
# saving step
# epoch n° 201
# Training, Regression Loss: 0.0446, Regression Loss 1h: 241.2735, Segmentation Loss:0.1434
# Train Confusion Matrix:
# [[3122850   83028]
#  [ 129898  504224]]
# Accuracy: 0.9446, CSI: 0.7031, Sensitivity: 0.7952, Specificity: 0.9741, False Alarm Ratio: 0.1414
#
#
# epoch duration : 97.2454526424408
# epoch n° 202
# Training, Regression Loss: 0.0420, Regression Loss 1h: 248.7862, Segmentation Loss:0.1384
# Train Confusion Matrix:
# [[3121155   82140]
#  [ 126106  510599]]
# Accuracy: 0.9458, CSI: 0.7103, Sensitivity: 0.8019, Specificity: 0.9744, False Alarm Ratio: 0.1386
#
#
# epoch duration : 98.11458683013916
# epoch n° 203
# Training, Regression Loss: 0.0400, Regression Loss 1h: 250.0197, Segmentation Loss:0.1406
# Train Confusion Matrix:
# [[3110831   82407]
#  [ 129539  517223]]
# Accuracy: 0.9448, CSI: 0.7093, Sensitivity: 0.7997, Specificity: 0.9742, False Alarm Ratio: 0.1374
#
#
# epoch duration : 90.00681924819946
# epoch n° 204
# Training, Regression Loss: 0.0402, Regression Loss 1h: 254.3966, Segmentation Loss:0.1318
# Train Confusion Matrix:
# [[3118396   81114]
#  [ 119115  521375]]
# Accuracy: 0.9479, CSI: 0.7225, Sensitivity: 0.8140, Specificity: 0.9746, False Alarm Ratio: 0.1346
#
#
# epoch duration : 90.91158199310303
# epoch n° 205
# Training, Regression Loss: 0.0396, Regression Loss 1h: 265.4479, Segmentation Loss:0.1343
# Train Confusion Matrix:
# [[3125701   81790]
#  [ 122219  510290]]
# Accuracy: 0.9469, CSI: 0.7144, Sensitivity: 0.8068, Specificity: 0.9745, False Alarm Ratio: 0.1381
#
#
# epoch duration : 85.10011148452759
# epoch n° 206
# Training, Regression Loss: 0.0401, Regression Loss 1h: 260.0562, Segmentation Loss:0.1337
# Train Confusion Matrix:
# [[3115563   82671]
#  [ 120762  521004]]
# Accuracy: 0.9470, CSI: 0.7192, Sensitivity: 0.8118, Specificity: 0.9742, False Alarm Ratio: 0.1369
#
#
# epoch duration : 87.83609795570374
# epoch n° 207

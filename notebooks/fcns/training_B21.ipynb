# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B2 radar + cmls -> pluvios 1 min + cmls [xrlg1_yg1l]

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 1500
save_every = 1
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B21_xrl_yg1l.pt'
npairs = 40
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 10
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
# Boucle avec 5 modes d'évaluation
val_steps = ['eval_opportunity_cost_cml_spat',
             'eval_added_value_half_cml_spat',
             'eval_added_value_full_cml_spat',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
def segment_gt(images, pairs, filters, use_fcn=False, split=None, return_sampled_values_and_filters=False):
  """
  split : list of tuples (min link id, max link id + 1)) 
  """
    
  bs, nsteps, S, _ = images.shape
  _, nlinks, _, _ = filters.shape

  if split is None :
      filtered_images = images.unsqueeze(dim=2) * \
                    filters.unsqueeze(dim=1)     
      sampled_values = torch.sum(filtered_images,\
                        dim=(3,4))
      denom = torch.sum(filters.unsqueeze(dim=1),\
                        dim=(3,4))
      sampled_values /= denom 
      segment_measurements = torch.cat((pairs, sampled_values), dim=1)
        
    
      if not use_fcn:
        return segment_measurements, None
      else:
        sampled_values += 0.1
        filters = filters.unsqueeze(1) > 0
        filters = filters * sampled_values.view(bs, nsteps, nlinks, 1, 1)
        filters = filters.sum(dim=2)
        
      return segment_measurements, filters

  else :
      list_segments = []
      
      for (l0, l1) in split:
          partial_filters = filters[:,l0:l1,...]
          
          filtered_images = images.unsqueeze(dim=2) * \
                            partial_filters.unsqueeze(dim=1)     
          sampled_values = torch.sum(filtered_images,\
                            dim=(3,4))
          denom = torch.sum(partial_filters.unsqueeze(dim=1),\
                            dim=(3,4))
          sampled_values /= denom 
          segment_measurements = torch.cat((pairs[:,:,l0:l1], sampled_values), dim=1)
            
        
          if not use_fcn:
              if return_sampled_values_and_filters:
                list_segments.append((segment_measurements, None, sampled_values, partial_filters))
              else:
                list_segments.append((segment_measurements, None))
          else:
            sampled_values += 0.1
            link_inputs = partial_filters.unsqueeze(1) > 0 
            link_inputs = link_inputs * sampled_values.view(bs, nsteps, l1 - l0, 1, 1)
            link_inputs = link_inputs.sum(dim=2)

            if return_sampled_values_and_filters:
                list_segments.append((segment_measurements, link_inputs, sampled_values, partial_filters))
            else:
                list_segments.append((segment_measurements, link_inputs))
                
      return list_segments

# %%
import torch.nn as nn
from sklearn.metrics import confusion_matrix


class QPELoss_fcn(nn.Module):
    def __init__(self, eval_qpe_1h = False, eval_independent_qpe_1h=False, eval_segments=False):
        super(QPELoss_fcn, self).__init__()
        self.regression_loss = nn.MSELoss()
        self.segmentation_loss = nn.CrossEntropyLoss()
        self.eval_qpe_1h = eval_qpe_1h
        self.eval_independent_qpe_1h = eval_independent_qpe_1h
        self.eval_segments = eval_segments

    def forward(self, p, outputs, targets, sampled_values_and_filters=None):

      # sans supervision imparfaite, avec spatialisation
      bs, nsteps, S, _ = targets.shape
      targets = targets.view(bs, 1, nsteps, S**2)
      mask = (targets>=0)
      masked_targets = targets[mask]
      outputs_rnr0 = outputs[:, :nsteps, ...].view(bs, 1, nsteps, S**2)
      outputs_rnr1 = outputs[:, nsteps:2*nsteps, ...].view(bs, 1, nsteps, S**2)
      masked_outputs_rnr = torch.cat([outputs_rnr0[mask].view(bs, 1, -1), outputs_rnr1[mask].view(bs, 1, -1)], dim=1)
      masked_targets_rnr =  (masked_targets > 0).long().view(bs, -1)
      outputs_qpe = outputs[:, 2*nsteps:3*nsteps , ...]\
                                .view(bs, 1, nsteps, S**2)

      masked_outputs_qpe = outputs_qpe[mask][masked_targets > 0]
      masked_targets_qpe = masked_targets[masked_targets > 0]

      loss_rnr = self.segmentation_loss(masked_outputs_rnr, masked_targets_rnr)
      loss_qpe_1min = self.regression_loss(masked_outputs_qpe, masked_targets_qpe)
      loss = 1/(2*p[0]**2) * loss_qpe_1min + 1/(2*p[1]**2) * loss_rnr
      

      if self.eval_qpe_1h:
        loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])
        loss += 1/(2*p[2]**2) * loss_qpe_1h

      elif self.eval_independent_qpe_1h:
        outputs_qpe_1h = outputs[:, 3*nsteps, ...]\
                                .view(bs, 1, S**2)
          
        loss_qpe_1h = self.regression_loss(outputs_qpe_1h[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])   
        loss += 1/(2*p[2]**2) * loss_qpe_1h
      else:
        with torch.no_grad():
            loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                               targets.sum(dim=2)[mask[:, :, 0, ...]])
          
          
      if self.eval_segments:
          sampled_values, filters = sampled_values_and_filters
          #Pas très joli : on aurait aimé appler outputs_QPE, mais il a été applati
          filtered_outputs = outputs[:, 2*nsteps:3*nsteps, ...].unsqueeze(dim=2) * \
                             filters.unsqueeze(dim=1)
          sampled_pred_values = torch.sum(filtered_outputs,\
                            dim=(3,4))
          loss_segments = self.regression_loss(sampled_pred_values, sampled_values)
          loss += 1/(2*p[3]**2) * loss_segments
      else:
          loss_segments = 0.
      
      loss += torch.log(1 + p[0]**2 + p[1]**2 + self.eval_qpe_1h * p[2]**2 + self.eval_independent_qpe_1h * p[2]**2 + self.eval_segments * p[3]**2)

        
      with torch.no_grad():
        preds = masked_outputs_rnr.argmax(dim=1).flatten().cpu().numpy()
        targets = masked_targets_rnr.flatten().cpu().numpy()
        # Compute the confusion matrix
        cm = confusion_matrix(targets, preds, labels=np.arange(2))

      if self.eval_segments:
          return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr.item(), loss, cm, loss_segments.item()
      else:
          return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr.item(), loss, cm, loss_segments

criterion = QPELoss_fcn(eval_segments=True)

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 973

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}
  running_integ_loss = {step:0.0 for step in steps}
    
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)
      
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints, use_fcn=use_fcn)
    
    #Validation steps
    model.eval()
    with torch.no_grad():

      # 4 first val steps 
      # segment_measurements = segment_gt(images, pairs, filters)
      splitl_val = [(0,5),(0,10),(0,20),(20,40)]
      segment_measurements_fcn_val_few, segment_measurements_fcn_val_half, segment_measurements_fcn_val_full, sampled_values_and_filters_val_targets \
              = segment_gt(images, pairs, filters, use_fcn=use_fcn, split=splitl_val, return_sampled_values_and_filters=True)
      
      _, segment_measurements_fcn_val_few, _, _ = segment_measurements_fcn_val_few # 5 cmls
      _, segment_measurements_fcn_val_half, _, _ = segment_measurements_fcn_val_half # 10 cmls 
      _, segment_measurements_fcn_val_full, _, _ = segment_measurements_fcn_val_full # 20 cmls 
      sampled_values_and_filters_val_targets = sampled_values_and_filters_val_targets[2:]  #20 cmls
        
      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_cml_spat'

      inputs = torch.cat([noisy_images,
                          0*segment_measurements_fcn_val_half
                          ], dim=1)
      outputs = model(inputs)

      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
              criterion(model.p, outputs, point_measurements_fcn, sampled_values_and_filters=sampled_values_and_filters_val_targets)
                        
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss
        
      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()

      # val step 2 : eval_added_value_few_spat
      # step = 'eval_added_value_few_cml_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn_val_few,
      #                     point_measurements_fcn_val_full
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
      #         criterion(model.p, outputs, point_measurements_fcn_val_targets, sampled_values_and_filters=sampled_values_and_filters_val_targets)
              
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm
      # running_integ_loss[step] += integ_loss
        
      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_few
      # torch.cuda.empty_cache()

      # val step 3 : eval_added_value_half_spat
      step = 'eval_added_value_half_cml_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn_val_half
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
      criterion(model.p, outputs, point_measurements_fcn, sampled_values_and_filters=sampled_values_and_filters_val_targets)   
      
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_half
      torch.cuda.empty_cache()

      # val step 4 : eval_added_value_full_spat
      step = 'eval_added_value_full_cml_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn_val_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = \
              criterion(model.p, outputs, point_measurements_fcn, sampled_values_and_filters=sampled_values_and_filters_val_targets)  
              
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm
      running_integ_loss[step] += integ_loss

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, segment_measurements_fcn_val_full
      torch.cuda.empty_cache()

      # last val step, on the 10 first pluvios : eval_added_value_full_id
      # step = 'eval_added_value_full_id'
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = criterion(model.p, outputs, None,
      #                                                                                                segments=segment_measurements_fcn_eval_full) 
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm
      # running_integ_loss[step] += integ_loss

      # del outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, point_measurements_fcn_val_full, segment_measurements_fcn_val_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    nl_train_inputs = torch.randint(0,19,(1,))
    nl_train_targets = npairs - nl_train_inputs

    # split train cmls
    splitl_train = [(0, nl_train_inputs), (nl_train_inputs, 20)]
    segment_measurements_fcn_train_inputs, sampled_values_and_filters_train_targets \
          = segment_gt(images, pairs, filters, use_fcn=use_fcn, split=splitl_train, return_sampled_values_and_filters=True)
  
    _, segment_measurements_fcn_train_inputs, _, _ = segment_measurements_fcn_train_inputs
    sampled_values_and_filters_train_targets = sampled_values_and_filters_train_targets[2:]


      
    inputs = torch.cat([noisy_images,
                        segment_measurements_fcn_train_inputs
                        ], dim=1)


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, integ_loss = criterion(model.p, outputs, 
                                                                                                   point_measurements_fcn,
                                                                                                   sampled_values_and_filters=sampled_values_and_filters_train_targets)

    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm
    running_integ_loss[step] += integ_loss

    del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, point_measurements_fcn, \
        segment_measurements_fcn_train_inputs, sampled_values_and_filters_train_targets
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      integ_loss = running_integ_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step], integ_loss))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print(f'Integ Loss: {integ_loss:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 973
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4117, Regression Loss 1h: 79.4030, Segmentation Loss:0.1582
# Train Confusion Matrix:
# [[3143618   52929]
#  [ 128904  514549]]
# Accuracy: 0.9526, CSI: 0.7389, Sensitivity: 0.7997, Specificity: 0.9834, False Alarm Ratio: 0.0933
# Integ Loss: 0.0294
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4086, Regression Loss 1h: 78.9001, Segmentation Loss:0.1016
# Train Confusion Matrix:
# [[3140360   56187]
#  [  92410  551043]]
# Accuracy: 0.9613, CSI: 0.7876, Sensitivity: 0.8564, Specificity: 0.9824, False Alarm Ratio: 0.0925
# Integ Loss: 0.0238
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4075, Regression Loss 1h: 78.7335, Segmentation Loss:0.0924
# Train Confusion Matrix:
# [[3144516   52031]
#  [  85500  557953]]
# Accuracy: 0.9642, CSI: 0.8023, Sensitivity: 0.8671, Specificity: 0.9837, False Alarm Ratio: 0.0853
# Integ Loss: 0.0231
#
#
# train, Regression Loss: 0.4080, Regression Loss 1h: 78.7125, Segmentation Loss:0.1021
# Train Confusion Matrix:
# [[3143164   53383]
#  [  93802  549651]]
# Accuracy: 0.9617, CSI: 0.7888, Sensitivity: 0.8542, Specificity: 0.9833, False Alarm Ratio: 0.0885
# Integ Loss: 0.0245
#
#
# epoch duration : 98.83980917930603
# saving step
# epoch n° 974
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4108, Regression Loss 1h: 81.0318, Segmentation Loss:0.1611
# Train Confusion Matrix:
# [[3141883   50350]
#  [ 135475  512292]]
# Accuracy: 0.9516, CSI: 0.7338, Sensitivity: 0.7909, Specificity: 0.9842, False Alarm Ratio: 0.0895
# Integ Loss: 0.0291
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4077, Regression Loss 1h: 80.5178, Segmentation Loss:0.1026
# Train Confusion Matrix:
# [[3137272   54961]
#  [  94095  553672]]
# Accuracy: 0.9612, CSI: 0.7879, Sensitivity: 0.8547, Specificity: 0.9828, False Alarm Ratio: 0.0903
# Integ Loss: 0.0236
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4065, Regression Loss 1h: 80.3467, Segmentation Loss:0.0932
# Train Confusion Matrix:
# [[3141191   51042]
#  [  87001  560766]]
# Accuracy: 0.9641, CSI: 0.8025, Sensitivity: 0.8657, Specificity: 0.9840, False Alarm Ratio: 0.0834
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4063, Regression Loss 1h: 80.1413, Segmentation Loss:0.1038
# Train Confusion Matrix:
# [[3138512   53721]
#  [  94165  553602]]
# Accuracy: 0.9615, CSI: 0.7892, Sensitivity: 0.8546, Specificity: 0.9832, False Alarm Ratio: 0.0885
# Integ Loss: 0.0243
#
#
# epoch duration : 98.68724656105042
# saving step
# epoch n° 975
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4164, Regression Loss 1h: 80.1759, Segmentation Loss:0.1636
# Train Confusion Matrix:
# [[3151500   50744]
#  [ 138827  498929]]
# Accuracy: 0.9506, CSI: 0.7247, Sensitivity: 0.7823, Specificity: 0.9842, False Alarm Ratio: 0.0923
# Integ Loss: 0.0285
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4128, Regression Loss 1h: 79.5288, Segmentation Loss:0.1040
# Train Confusion Matrix:
# [[3146935   55309]
#  [  96708  541048]]
# Accuracy: 0.9604, CSI: 0.7807, Sensitivity: 0.8484, Specificity: 0.9827, False Alarm Ratio: 0.0927
# Integ Loss: 0.0233
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4116, Regression Loss 1h: 79.3353, Segmentation Loss:0.0943
# Train Confusion Matrix:
# [[3151830   50414]
#  [  90043  547713]]
# Accuracy: 0.9634, CSI: 0.7959, Sensitivity: 0.8588, Specificity: 0.9843, False Alarm Ratio: 0.0843
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4120, Regression Loss 1h: 79.3239, Segmentation Loss:0.1062
# Train Confusion Matrix:
# [[3148682   53562]
#  [  97847  539909]]
# Accuracy: 0.9606, CSI: 0.7810, Sensitivity: 0.8466, Specificity: 0.9833, False Alarm Ratio: 0.0903
# Integ Loss: 0.0242
#
#
# epoch duration : 98.42968535423279
# saving step
# epoch n° 976
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4065, Regression Loss 1h: 78.4175, Segmentation Loss:0.1544
# Train Confusion Matrix:
# [[3143309   55077]
#  [ 125810  515804]]
# Accuracy: 0.9529, CSI: 0.7404, Sensitivity: 0.8039, Specificity: 0.9828, False Alarm Ratio: 0.0965
# Integ Loss: 0.0284
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4034, Regression Loss 1h: 77.8224, Segmentation Loss:0.1002
# Train Confusion Matrix:
# [[3140727   57659]
#  [  89721  551893]]
# Accuracy: 0.9616, CSI: 0.7892, Sensitivity: 0.8602, Specificity: 0.9820, False Alarm Ratio: 0.0946
# Integ Loss: 0.0230
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4023, Regression Loss 1h: 77.6451, Segmentation Loss:0.0915
# Train Confusion Matrix:
# [[3144992   53394]
#  [  83252  558362]]
# Accuracy: 0.9644, CSI: 0.8034, Sensitivity: 0.8702, Specificity: 0.9833, False Alarm Ratio: 0.0873
# Integ Loss: 0.0224
#
#
# train, Regression Loss: 0.4025, Regression Loss 1h: 77.5888, Segmentation Loss:0.1026
# Train Confusion Matrix:
# [[3145597   52789]
#  [  93747  547867]]
# Accuracy: 0.9618, CSI: 0.7890, Sensitivity: 0.8539, Specificity: 0.9835, False Alarm Ratio: 0.0879
# Integ Loss: 0.0239
#
#
# epoch duration : 98.34464144706726
# saving step
# epoch n° 977
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4133, Regression Loss 1h: 79.0110, Segmentation Loss:0.1500
# Train Confusion Matrix:
# [[3148360   55475]
#  [ 121495  514670]]
# Accuracy: 0.9539, CSI: 0.7441, Sensitivity: 0.8090, Specificity: 0.9827, False Alarm Ratio: 0.0973
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4090, Regression Loss 1h: 78.1546, Segmentation Loss:0.0990
# Train Confusion Matrix:
# [[3149066   54769]
#  [  89832  546333]]
# Accuracy: 0.9623, CSI: 0.7907, Sensitivity: 0.8588, Specificity: 0.9829, False Alarm Ratio: 0.0911
# Integ Loss: 0.0234
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4078, Regression Loss 1h: 77.9526, Segmentation Loss:0.0907
# Train Confusion Matrix:
# [[3153554   50281]
#  [  85002  551163]]
# Accuracy: 0.9648, CSI: 0.8029, Sensitivity: 0.8664, Specificity: 0.9843, False Alarm Ratio: 0.0836
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4080, Regression Loss 1h: 77.8833, Segmentation Loss:0.1023
# Train Confusion Matrix:
# [[3151712   52123]
#  [  94029  542136]]
# Accuracy: 0.9619, CSI: 0.7877, Sensitivity: 0.8522, Specificity: 0.9837, False Alarm Ratio: 0.0877
# Integ Loss: 0.0247
#
#
# epoch duration : 98.94589161872864
# saving step
# epoch n° 978
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4204, Regression Loss 1h: 84.1739, Segmentation Loss:0.1633
# Train Confusion Matrix:
# [[3137023   53077]
#  [ 134999  514901]]
# Accuracy: 0.9510, CSI: 0.7325, Sensitivity: 0.7923, Specificity: 0.9834, False Alarm Ratio: 0.0934
# Integ Loss: 0.0301
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4164, Regression Loss 1h: 83.2655, Segmentation Loss:0.1027
# Train Confusion Matrix:
# [[3133597   56503]
#  [  93374  556526]]
# Accuracy: 0.9610, CSI: 0.7878, Sensitivity: 0.8563, Specificity: 0.9823, False Alarm Ratio: 0.0922
# Integ Loss: 0.0244
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4151, Regression Loss 1h: 82.9941, Segmentation Loss:0.0935
# Train Confusion Matrix:
# [[3136616   53484]
#  [  86147  563753]]
# Accuracy: 0.9636, CSI: 0.8015, Sensitivity: 0.8674, Specificity: 0.9832, False Alarm Ratio: 0.0867
# Integ Loss: 0.0238
#
#
# train, Regression Loss: 0.4158, Regression Loss 1h: 83.1140, Segmentation Loss:0.1054
# Train Confusion Matrix:
# [[3137059   53041]
#  [  97474  552426]]
# Accuracy: 0.9608, CSI: 0.7859, Sensitivity: 0.8500, Specificity: 0.9834, False Alarm Ratio: 0.0876
# Integ Loss: 0.0249
#
#
# epoch duration : 98.92700052261353
# saving step
# epoch n° 979
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4168, Regression Loss 1h: 82.0283, Segmentation Loss:0.1613
# Train Confusion Matrix:
# [[3140175   56174]
#  [ 131500  512151]]
# Accuracy: 0.9511, CSI: 0.7318, Sensitivity: 0.7957, Specificity: 0.9824, False Alarm Ratio: 0.0988
# Integ Loss: 0.0297
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4137, Regression Loss 1h: 81.4041, Segmentation Loss:0.1036
# Train Confusion Matrix:
# [[3137978   58371]
#  [  93465  550186]]
# Accuracy: 0.9605, CSI: 0.7837, Sensitivity: 0.8548, Specificity: 0.9817, False Alarm Ratio: 0.0959
# Integ Loss: 0.0237
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4126, Regression Loss 1h: 81.2360, Segmentation Loss:0.0946
# Train Confusion Matrix:
# [[3142481   53868]
#  [  87342  556309]]
# Accuracy: 0.9632, CSI: 0.7976, Sensitivity: 0.8643, Specificity: 0.9831, False Alarm Ratio: 0.0883
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4126, Regression Loss 1h: 81.1383, Segmentation Loss:0.1019
# Train Confusion Matrix:
# [[3141679   54670]
#  [  93003  550648]]
# Accuracy: 0.9615, CSI: 0.7885, Sensitivity: 0.8555, Specificity: 0.9829, False Alarm Ratio: 0.0903
# Integ Loss: 0.0241
#
#
# epoch duration : 97.86452794075012
# saving step
# epoch n° 980
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4142, Regression Loss 1h: 79.2628, Segmentation Loss:0.1592
# Train Confusion Matrix:
# [[3151048   52749]
#  [ 133215  502988]]
# Accuracy: 0.9516, CSI: 0.7301, Sensitivity: 0.7906, Specificity: 0.9835, False Alarm Ratio: 0.0949
# Integ Loss: 0.0286
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4111, Regression Loss 1h: 78.6911, Segmentation Loss:0.1037
# Train Confusion Matrix:
# [[3149912   53885]
#  [  97058  539145]]
# Accuracy: 0.9607, CSI: 0.7813, Sensitivity: 0.8474, Specificity: 0.9832, False Alarm Ratio: 0.0909
# Integ Loss: 0.0232
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4099, Regression Loss 1h: 78.4961, Segmentation Loss:0.0951
# Train Confusion Matrix:
# [[3153932   49865]
#  [  91744  544459]]
# Accuracy: 0.9631, CSI: 0.7936, Sensitivity: 0.8558, Specificity: 0.9844, False Alarm Ratio: 0.0839
# Integ Loss: 0.0225
#
#
# train, Regression Loss: 0.4100, Regression Loss 1h: 78.3752, Segmentation Loss:0.1081
# Train Confusion Matrix:
# [[3151091   52706]
#  [  99436  536767]]
# Accuracy: 0.9604, CSI: 0.7792, Sensitivity: 0.8437, Specificity: 0.9835, False Alarm Ratio: 0.0894
# Integ Loss: 0.0242
#
#
# epoch duration : 97.39847373962402
# saving step
# epoch n° 981
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4133, Regression Loss 1h: 80.6406, Segmentation Loss:0.1592
# Train Confusion Matrix:
# [[3147614   52210]
#  [ 131956  508220]]
# Accuracy: 0.9520, CSI: 0.7340, Sensitivity: 0.7939, Specificity: 0.9837, False Alarm Ratio: 0.0932
# Integ Loss: 0.0295
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4105, Regression Loss 1h: 80.0740, Segmentation Loss:0.1028
# Train Confusion Matrix:
# [[3144857   54967]
#  [  95836  544340]]
# Accuracy: 0.9607, CSI: 0.7831, Sensitivity: 0.8503, Specificity: 0.9828, False Alarm Ratio: 0.0917
# Integ Loss: 0.0237
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4094, Regression Loss 1h: 79.8955, Segmentation Loss:0.0940
# Train Confusion Matrix:
# [[3148138   51686]
#  [  89069  551107]]
# Accuracy: 0.9633, CSI: 0.7966, Sensitivity: 0.8609, Specificity: 0.9838, False Alarm Ratio: 0.0857
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4093, Regression Loss 1h: 79.7370, Segmentation Loss:0.1032
# Train Confusion Matrix:
# [[3146581   53243]
#  [  94937  545239]]
# Accuracy: 0.9614, CSI: 0.7863, Sensitivity: 0.8517, Specificity: 0.9834, False Alarm Ratio: 0.0890
# Integ Loss: 0.0241
#
#
# epoch duration : 98.9863588809967
# saving step
# epoch n° 982
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4234, Regression Loss 1h: 82.5173, Segmentation Loss:0.1543
# Train Confusion Matrix:
# [[3147006   53678]
#  [ 126222  513094]]
# Accuracy: 0.9532, CSI: 0.7404, Sensitivity: 0.8026, Specificity: 0.9832, False Alarm Ratio: 0.0947
# Integ Loss: 0.0298
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4205, Regression Loss 1h: 81.9605, Segmentation Loss:0.1022
# Train Confusion Matrix:
# [[3145538   55146]
#  [  93848  545468]]
# Accuracy: 0.9612, CSI: 0.7855, Sensitivity: 0.8532, Specificity: 0.9828, False Alarm Ratio: 0.0918
# Integ Loss: 0.0240
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4193, Regression Loss 1h: 81.7540, Segmentation Loss:0.0933
# Train Confusion Matrix:
# [[3149170   51514]
#  [  87546  551770]]
# Accuracy: 0.9638, CSI: 0.7987, Sensitivity: 0.8631, Specificity: 0.9839, False Alarm Ratio: 0.0854
# Integ Loss: 0.0234
#
#
# train, Regression Loss: 0.4195, Regression Loss 1h: 81.6910, Segmentation Loss:0.1060
# Train Confusion Matrix:
# [[3148516   52168]
#  [  97013  542303]]
# Accuracy: 0.9612, CSI: 0.7843, Sensitivity: 0.8483, Specificity: 0.9837, False Alarm Ratio: 0.0878
# Integ Loss: 0.0250
#
#
# epoch duration : 97.6361346244812
# saving step
# epoch n° 983
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4125, Regression Loss 1h: 80.1576, Segmentation Loss:0.1541
# Train Confusion Matrix:
# [[3149212   50343]
#  [ 130136  510309]]
# Accuracy: 0.9530, CSI: 0.7387, Sensitivity: 0.7968, Specificity: 0.9843, False Alarm Ratio: 0.0898
# Integ Loss: 0.0286
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4095, Regression Loss 1h: 79.4726, Segmentation Loss:0.1023
# Train Confusion Matrix:
# [[3143739   55816]
#  [  93075  547370]]
# Accuracy: 0.9612, CSI: 0.7862, Sensitivity: 0.8547, Specificity: 0.9826, False Alarm Ratio: 0.0925
# Integ Loss: 0.0233
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4083, Regression Loss 1h: 79.2434, Segmentation Loss:0.0935
# Train Confusion Matrix:
# [[3147171   52384]
#  [  86592  553853]]
# Accuracy: 0.9638, CSI: 0.7994, Sensitivity: 0.8648, Specificity: 0.9836, False Alarm Ratio: 0.0864
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4085, Regression Loss 1h: 79.2359, Segmentation Loss:0.1066
# Train Confusion Matrix:
# [[3147020   52535]
#  [  97129  543316]]
# Accuracy: 0.9610, CSI: 0.7840, Sensitivity: 0.8483, Specificity: 0.9836, False Alarm Ratio: 0.0882
# Integ Loss: 0.0241
#
#
# epoch duration : 98.8282642364502
# saving step
# epoch n° 984
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4187, Regression Loss 1h: 80.6771, Segmentation Loss:0.1539
# Train Confusion Matrix:
# [[3152383   51165]
#  [ 128785  507667]]
# Accuracy: 0.9531, CSI: 0.7383, Sensitivity: 0.7977, Specificity: 0.9840, False Alarm Ratio: 0.0916
# Integ Loss: 0.0285
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4160, Regression Loss 1h: 80.2277, Segmentation Loss:0.1005
# Train Confusion Matrix:
# [[3152501   51047]
#  [  95891  540561]]
# Accuracy: 0.9617, CSI: 0.7863, Sensitivity: 0.8493, Specificity: 0.9841, False Alarm Ratio: 0.0863
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4147, Regression Loss 1h: 80.0246, Segmentation Loss:0.0922
# Train Confusion Matrix:
# [[3156501   47047]
#  [  90382  546070]]
# Accuracy: 0.9642, CSI: 0.7989, Sensitivity: 0.8580, Specificity: 0.9853, False Alarm Ratio: 0.0793
# Integ Loss: 0.0225
#
#
# train, Regression Loss: 0.4146, Regression Loss 1h: 79.8761, Segmentation Loss:0.1036
# Train Confusion Matrix:
# [[3150922   52626]
#  [  95122  541330]]
# Accuracy: 0.9615, CSI: 0.7856, Sensitivity: 0.8505, Specificity: 0.9836, False Alarm Ratio: 0.0886
# Integ Loss: 0.0241
#
#
# epoch duration : 99.0167863368988
# saving step
# epoch n° 985
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4199, Regression Loss 1h: 81.3895, Segmentation Loss:0.1651
# Train Confusion Matrix:
# [[3144078   56501]
#  [ 134234  505187]]
# Accuracy: 0.9503, CSI: 0.7259, Sensitivity: 0.7901, Specificity: 0.9823, False Alarm Ratio: 0.1006
# Integ Loss: 0.0292
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4173, Regression Loss 1h: 80.9523, Segmentation Loss:0.1045
# Train Confusion Matrix:
# [[3143158   57421]
#  [  94972  544449]]
# Accuracy: 0.9603, CSI: 0.7813, Sensitivity: 0.8515, Specificity: 0.9821, False Alarm Ratio: 0.0954
# Integ Loss: 0.0234
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4161, Regression Loss 1h: 80.7535, Segmentation Loss:0.0946
# Train Confusion Matrix:
# [[3147945   52634]
#  [  87927  551494]]
# Accuracy: 0.9634, CSI: 0.7969, Sensitivity: 0.8625, Specificity: 0.9836, False Alarm Ratio: 0.0871
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4164, Regression Loss 1h: 80.7201, Segmentation Loss:0.1067
# Train Confusion Matrix:
# [[3147012   53567]
#  [  99214  540207]]
# Accuracy: 0.9602, CSI: 0.7795, Sensitivity: 0.8448, Specificity: 0.9833, False Alarm Ratio: 0.0902
# Integ Loss: 0.0239
#
#
# epoch duration : 98.6725263595581
# saving step
# epoch n° 986
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4065, Regression Loss 1h: 76.6845, Segmentation Loss:0.1672
# Train Confusion Matrix:
# [[3152394   53581]
#  [ 140946  493079]]
# Accuracy: 0.9493, CSI: 0.7171, Sensitivity: 0.7777, Specificity: 0.9833, False Alarm Ratio: 0.0980
# Integ Loss: 0.0282
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4026, Regression Loss 1h: 75.8674, Segmentation Loss:0.1067
# Train Confusion Matrix:
# [[3147338   58637]
#  [  96693  537332]]
# Accuracy: 0.9595, CSI: 0.7757, Sensitivity: 0.8475, Specificity: 0.9817, False Alarm Ratio: 0.0984
# Integ Loss: 0.0232
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4015, Regression Loss 1h: 75.6961, Segmentation Loss:0.0966
# Train Confusion Matrix:
# [[3152089   53886]
#  [  89332  544693]]
# Accuracy: 0.9627, CSI: 0.7918, Sensitivity: 0.8591, Specificity: 0.9832, False Alarm Ratio: 0.0900
# Integ Loss: 0.0226
#
#
# train, Regression Loss: 0.4020, Regression Loss 1h: 75.7456, Segmentation Loss:0.1144
# Train Confusion Matrix:
# [[3152579   53396]
#  [ 106463  527562]]
# Accuracy: 0.9584, CSI: 0.7675, Sensitivity: 0.8321, Specificity: 0.9833, False Alarm Ratio: 0.0919
# Integ Loss: 0.0240
#
#
# epoch duration : 97.68067002296448
# saving step
# epoch n° 987
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4203, Regression Loss 1h: 84.6991, Segmentation Loss:0.1538
# Train Confusion Matrix:
# [[3136065   54574]
#  [ 126840  522521]]
# Accuracy: 0.9528, CSI: 0.7423, Sensitivity: 0.8047, Specificity: 0.9829, False Alarm Ratio: 0.0946
# Integ Loss: 0.0302
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4166, Regression Loss 1h: 83.9525, Segmentation Loss:0.1019
# Train Confusion Matrix:
# [[3133902   56737]
#  [  91766  557595]]
# Accuracy: 0.9613, CSI: 0.7897, Sensitivity: 0.8587, Specificity: 0.9822, False Alarm Ratio: 0.0924
# Integ Loss: 0.0244
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4155, Regression Loss 1h: 83.7609, Segmentation Loss:0.0929
# Train Confusion Matrix:
# [[3136968   53671]
#  [  85179  564182]]
# Accuracy: 0.9638, CSI: 0.8025, Sensitivity: 0.8688, Specificity: 0.9832, False Alarm Ratio: 0.0869
# Integ Loss: 0.0237
#
#
# train, Regression Loss: 0.4162, Regression Loss 1h: 83.8872, Segmentation Loss:0.1043
# Train Confusion Matrix:
# [[3138503   52136]
#  [  95907  553454]]
# Accuracy: 0.9614, CSI: 0.7890, Sensitivity: 0.8523, Specificity: 0.9837, False Alarm Ratio: 0.0861
# Integ Loss: 0.0244
#
#
# epoch duration : 98.14655041694641
# saving step
# epoch n° 988
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4110, Regression Loss 1h: 80.3845, Segmentation Loss:0.1505
# Train Confusion Matrix:
# [[3150593   50925]
#  [ 125128  513354]]
# Accuracy: 0.9542, CSI: 0.7446, Sensitivity: 0.8040, Specificity: 0.9841, False Alarm Ratio: 0.0902
# Integ Loss: 0.0290
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4079, Regression Loss 1h: 79.8104, Segmentation Loss:0.0999
# Train Confusion Matrix:
# [[3148248   53270]
#  [  92001  546481]]
# Accuracy: 0.9622, CSI: 0.7900, Sensitivity: 0.8559, Specificity: 0.9834, False Alarm Ratio: 0.0888
# Integ Loss: 0.0233
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4067, Regression Loss 1h: 79.6304, Segmentation Loss:0.0914
# Train Confusion Matrix:
# [[3151926   49592]
#  [  86359  552123]]
# Accuracy: 0.9646, CSI: 0.8024, Sensitivity: 0.8647, Specificity: 0.9845, False Alarm Ratio: 0.0824
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4067, Regression Loss 1h: 79.4685, Segmentation Loss:0.1029
# Train Confusion Matrix:
# [[3149311   52207]
#  [  94306  544176]]
# Accuracy: 0.9618, CSI: 0.7879, Sensitivity: 0.8523, Specificity: 0.9837, False Alarm Ratio: 0.0875
# Integ Loss: 0.0242
#
#
# epoch duration : 98.65736413002014
# saving step
# epoch n° 989
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4162, Regression Loss 1h: 80.4109, Segmentation Loss:0.1505
# Train Confusion Matrix:
# [[3141422   56772]
#  [ 122207  519599]]
# Accuracy: 0.9534, CSI: 0.7438, Sensitivity: 0.8096, Specificity: 0.9822, False Alarm Ratio: 0.0985
# Integ Loss: 0.0299
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4121, Regression Loss 1h: 79.5523, Segmentation Loss:0.1011
# Train Confusion Matrix:
# [[3145153   53041]
#  [  95465  546341]]
# Accuracy: 0.9613, CSI: 0.7863, Sensitivity: 0.8513, Specificity: 0.9834, False Alarm Ratio: 0.0885
# Integ Loss: 0.0238
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4108, Regression Loss 1h: 79.3246, Segmentation Loss:0.0930
# Train Confusion Matrix:
# [[3150047   48147]
#  [  90956  550850]]
# Accuracy: 0.9638, CSI: 0.7984, Sensitivity: 0.8583, Specificity: 0.9849, False Alarm Ratio: 0.0804
# Integ Loss: 0.0231
#
#
# train, Regression Loss: 0.4106, Regression Loss 1h: 79.1326, Segmentation Loss:0.1032
# Train Confusion Matrix:
# [[3145520   52674]
#  [  93728  548078]]
# Accuracy: 0.9619, CSI: 0.7892, Sensitivity: 0.8540, Specificity: 0.9835, False Alarm Ratio: 0.0877
# Integ Loss: 0.0250
#
#
# epoch duration : 98.91339778900146
# saving step
# epoch n° 990
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4138, Regression Loss 1h: 79.8926, Segmentation Loss:0.1533
# Train Confusion Matrix:
# [[3138847   55274]
#  [ 125495  520384]]
# Accuracy: 0.9529, CSI: 0.7422, Sensitivity: 0.8057, Specificity: 0.9827, False Alarm Ratio: 0.0960
# Integ Loss: 0.0299
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4111, Regression Loss 1h: 79.4607, Segmentation Loss:0.1013
# Train Confusion Matrix:
# [[3139516   54605]
#  [  94182  551697]]
# Accuracy: 0.9613, CSI: 0.7876, Sensitivity: 0.8542, Specificity: 0.9829, False Alarm Ratio: 0.0901
# Integ Loss: 0.0239
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4100, Regression Loss 1h: 79.3349, Segmentation Loss:0.0931
# Train Confusion Matrix:
# [[3143474   50647]
#  [  88855  557024]]
# Accuracy: 0.9637, CSI: 0.7997, Sensitivity: 0.8624, Specificity: 0.9841, False Alarm Ratio: 0.0833
# Integ Loss: 0.0232
#
#
# train, Regression Loss: 0.4098, Regression Loss 1h: 79.1151, Segmentation Loss:0.1036
# Train Confusion Matrix:
# [[3140022   54099]
#  [  94586  551293]]
# Accuracy: 0.9613, CSI: 0.7876, Sensitivity: 0.8536, Specificity: 0.9831, False Alarm Ratio: 0.0894
# Integ Loss: 0.0247
#
#
# epoch duration : 98.82711124420166
# saving step
# epoch n° 991
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4065, Regression Loss 1h: 78.8858, Segmentation Loss:0.1591
# Train Confusion Matrix:
# [[3148391   54079]
#  [ 131589  505941]]
# Accuracy: 0.9516, CSI: 0.7315, Sensitivity: 0.7936, Specificity: 0.9831, False Alarm Ratio: 0.0966
# Integ Loss: 0.0293
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4040, Regression Loss 1h: 78.5021, Segmentation Loss:0.1022
# Train Confusion Matrix:
# [[3146417   56053]
#  [  93120  544410]]
# Accuracy: 0.9612, CSI: 0.7849, Sensitivity: 0.8539, Specificity: 0.9825, False Alarm Ratio: 0.0933
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4028, Regression Loss 1h: 78.3148, Segmentation Loss:0.0926
# Train Confusion Matrix:
# [[3150543   51927]
#  [  86431  551099]]
# Accuracy: 0.9640, CSI: 0.7993, Sensitivity: 0.8644, Specificity: 0.9838, False Alarm Ratio: 0.0861
# Integ Loss: 0.0224
#
#
# train, Regression Loss: 0.4032, Regression Loss 1h: 78.2894, Segmentation Loss:0.1035
# Train Confusion Matrix:
# [[3150157   52313]
#  [  95099  542431]]
# Accuracy: 0.9616, CSI: 0.7863, Sensitivity: 0.8508, Specificity: 0.9837, False Alarm Ratio: 0.0880
# Integ Loss: 0.0240
#
#
# epoch duration : 100.09391832351685
# saving step
# epoch n° 992
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4172, Regression Loss 1h: 81.0093, Segmentation Loss:0.1487
# Train Confusion Matrix:
# [[3146777   52822]
#  [ 121980  518421]]
# Accuracy: 0.9545, CSI: 0.7478, Sensitivity: 0.8095, Specificity: 0.9835, False Alarm Ratio: 0.0925
# Integ Loss: 0.0296
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4131, Regression Loss 1h: 80.1711, Segmentation Loss:0.0992
# Train Confusion Matrix:
# [[3148968   50631]
#  [  93721  546680]]
# Accuracy: 0.9624, CSI: 0.7911, Sensitivity: 0.8537, Specificity: 0.9842, False Alarm Ratio: 0.0848
# Integ Loss: 0.0237
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4123, Regression Loss 1h: 80.0551, Segmentation Loss:0.0909
# Train Confusion Matrix:
# [[3152644   46955]
#  [  88379  552022]]
# Accuracy: 0.9648, CSI: 0.8031, Sensitivity: 0.8620, Specificity: 0.9853, False Alarm Ratio: 0.0784
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4124, Regression Loss 1h: 79.9576, Segmentation Loss:0.1029
# Train Confusion Matrix:
# [[3147114   52485]
#  [  93918  546483]]
# Accuracy: 0.9619, CSI: 0.7887, Sensitivity: 0.8533, Specificity: 0.9836, False Alarm Ratio: 0.0876
# Integ Loss: 0.0241
#
#
# epoch duration : 98.46174168586731
# saving step
# epoch n° 993
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4152, Regression Loss 1h: 80.4735, Segmentation Loss:0.1570
# Train Confusion Matrix:
# [[3151700   50568]
#  [ 133220  504512]]
# Accuracy: 0.9521, CSI: 0.7330, Sensitivity: 0.7911, Specificity: 0.9842, False Alarm Ratio: 0.0911
# Integ Loss: 0.0284
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4114, Regression Loss 1h: 79.7525, Segmentation Loss:0.1028
# Train Confusion Matrix:
# [[3146876   55392]
#  [  94675  543057]]
# Accuracy: 0.9609, CSI: 0.7835, Sensitivity: 0.8515, Specificity: 0.9827, False Alarm Ratio: 0.0926
# Integ Loss: 0.0230
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4103, Regression Loss 1h: 79.5827, Segmentation Loss:0.0941
# Train Confusion Matrix:
# [[3151000   51268]
#  [  89171  548561]]
# Accuracy: 0.9634, CSI: 0.7962, Sensitivity: 0.8602, Specificity: 0.9840, False Alarm Ratio: 0.0855
# Integ Loss: 0.0223
#
#
# train, Regression Loss: 0.4102, Regression Loss 1h: 79.4249, Segmentation Loss:0.1098
# Train Confusion Matrix:
# [[3150254   52014]
#  [ 101024  536708]]
# Accuracy: 0.9601, CSI: 0.7781, Sensitivity: 0.8416, Specificity: 0.9838, False Alarm Ratio: 0.0884
# Integ Loss: 0.0247
#
#
# epoch duration : 99.7246675491333
# saving step
# epoch n° 994
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4166, Regression Loss 1h: 81.6665, Segmentation Loss:0.1526
# Train Confusion Matrix:
# [[3135384   58595]
#  [ 120747  525274]]
# Accuracy: 0.9533, CSI: 0.7455, Sensitivity: 0.8131, Specificity: 0.9817, False Alarm Ratio: 0.1004
# Integ Loss: 0.0298
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4136, Regression Loss 1h: 81.1769, Segmentation Loss:0.1001
# Train Confusion Matrix:
# [[3138900   55079]
#  [  90557  555464]]
# Accuracy: 0.9621, CSI: 0.7923, Sensitivity: 0.8598, Specificity: 0.9828, False Alarm Ratio: 0.0902
# Integ Loss: 0.0238
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4127, Regression Loss 1h: 81.0666, Segmentation Loss:0.0924
# Train Confusion Matrix:
# [[3143315   50664]
#  [  86548  559473]]
# Accuracy: 0.9643, CSI: 0.8031, Sensitivity: 0.8660, Specificity: 0.9841, False Alarm Ratio: 0.0830
# Integ Loss: 0.0231
#
#
# train, Regression Loss: 0.4123, Regression Loss 1h: 80.7930, Segmentation Loss:0.1026
# Train Confusion Matrix:
# [[3140684   53295]
#  [  92842  553179]]
# Accuracy: 0.9619, CSI: 0.7910, Sensitivity: 0.8563, Specificity: 0.9833, False Alarm Ratio: 0.0879
# Integ Loss: 0.0243
#
#
# epoch duration : 98.77152633666992
# saving step
# epoch n° 995
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4119, Regression Loss 1h: 79.9111, Segmentation Loss:0.1520
# Train Confusion Matrix:
# [[3145690   51613]
#  [ 126361  516336]]
# Accuracy: 0.9537, CSI: 0.7437, Sensitivity: 0.8034, Specificity: 0.9839, False Alarm Ratio: 0.0909
# Integ Loss: 0.0288
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4084, Regression Loss 1h: 79.2346, Segmentation Loss:0.0998
# Train Confusion Matrix:
# [[3144661   52642]
#  [  93269  549428]]
# Accuracy: 0.9620, CSI: 0.7902, Sensitivity: 0.8549, Specificity: 0.9835, False Alarm Ratio: 0.0874
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4075, Regression Loss 1h: 79.1563, Segmentation Loss:0.0920
# Train Confusion Matrix:
# [[3147748   49555]
#  [  87725  554972]]
# Accuracy: 0.9643, CSI: 0.8017, Sensitivity: 0.8635, Specificity: 0.9845, False Alarm Ratio: 0.0820
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4077, Regression Loss 1h: 79.0491, Segmentation Loss:0.1014
# Train Confusion Matrix:
# [[3144411   52892]
#  [  93196  549501]]
# Accuracy: 0.9620, CSI: 0.7900, Sensitivity: 0.8550, Specificity: 0.9835, False Alarm Ratio: 0.0878
# Integ Loss: 0.0239
#
#
# epoch duration : 98.72120475769043
# saving step
# epoch n° 996
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4150, Regression Loss 1h: 82.5543, Segmentation Loss:0.1551
# Train Confusion Matrix:
# [[3142247   51718]
#  [ 128202  517833]]
# Accuracy: 0.9531, CSI: 0.7421, Sensitivity: 0.8016, Specificity: 0.9838, False Alarm Ratio: 0.0908
# Integ Loss: 0.0298
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4112, Regression Loss 1h: 81.7594, Segmentation Loss:0.1015
# Train Confusion Matrix:
# [[3138277   55688]
#  [  92225  553810]]
# Accuracy: 0.9615, CSI: 0.7892, Sensitivity: 0.8572, Specificity: 0.9826, False Alarm Ratio: 0.0914
# Integ Loss: 0.0240
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4103, Regression Loss 1h: 81.6522, Segmentation Loss:0.0930
# Train Confusion Matrix:
# [[3141258   52707]
#  [  86172  559863]]
# Accuracy: 0.9638, CSI: 0.8012, Sensitivity: 0.8666, Specificity: 0.9835, False Alarm Ratio: 0.0860
# Integ Loss: 0.0233
#
#
# train, Regression Loss: 0.4104, Regression Loss 1h: 81.5513, Segmentation Loss:0.1064
# Train Confusion Matrix:
# [[3140662   53303]
#  [  96959  549076]]
# Accuracy: 0.9609, CSI: 0.7851, Sensitivity: 0.8499, Specificity: 0.9833, False Alarm Ratio: 0.0885
# Integ Loss: 0.0246
#
#
# epoch duration : 97.83055758476257
# saving step
# epoch n° 997
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4155, Regression Loss 1h: 80.7251, Segmentation Loss:0.1644
# Train Confusion Matrix:
# [[3147145   47848]
#  [ 142723  502284]]
# Accuracy: 0.9504, CSI: 0.7249, Sensitivity: 0.7787, Specificity: 0.9850, False Alarm Ratio: 0.0870
# Integ Loss: 0.0290
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4120, Regression Loss 1h: 80.0087, Segmentation Loss:0.1053
# Train Confusion Matrix:
# [[3140554   54439]
#  [  98509  546498]]
# Accuracy: 0.9602, CSI: 0.7813, Sensitivity: 0.8473, Specificity: 0.9830, False Alarm Ratio: 0.0906
# Integ Loss: 0.0237
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4110, Regression Loss 1h: 79.8608, Segmentation Loss:0.0953
# Train Confusion Matrix:
# [[3143534   51459]
#  [  90572  554435]]
# Accuracy: 0.9630, CSI: 0.7961, Sensitivity: 0.8596, Specificity: 0.9839, False Alarm Ratio: 0.0849
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4107, Regression Loss 1h: 79.6594, Segmentation Loss:0.1057
# Train Confusion Matrix:
# [[3141005   53988]
#  [  98046  546961]]
# Accuracy: 0.9604, CSI: 0.7825, Sensitivity: 0.8480, Specificity: 0.9831, False Alarm Ratio: 0.0898
# Integ Loss: 0.0247
#
#
# epoch duration : 99.57379865646362
# saving step
# epoch n° 998
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4178, Regression Loss 1h: 79.5489, Segmentation Loss:0.1553
# Train Confusion Matrix:
# [[3152591   50869]
#  [ 130041  506499]]
# Accuracy: 0.9529, CSI: 0.7368, Sensitivity: 0.7957, Specificity: 0.9841, False Alarm Ratio: 0.0913
# Integ Loss: 0.0288
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4135, Regression Loss 1h: 78.6180, Segmentation Loss:0.1018
# Train Confusion Matrix:
# [[3148773   54687]
#  [  93788  542752]]
# Accuracy: 0.9613, CSI: 0.7852, Sensitivity: 0.8527, Specificity: 0.9829, False Alarm Ratio: 0.0915
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4123, Regression Loss 1h: 78.4221, Segmentation Loss:0.0929
# Train Confusion Matrix:
# [[3152329   51131]
#  [  87144  549396]]
# Accuracy: 0.9640, CSI: 0.7989, Sensitivity: 0.8631, Specificity: 0.9840, False Alarm Ratio: 0.0851
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4125, Regression Loss 1h: 78.3486, Segmentation Loss:0.1017
# Train Confusion Matrix:
# [[3151129   52331]
#  [  93333  543207]]
# Accuracy: 0.9621, CSI: 0.7885, Sensitivity: 0.8534, Specificity: 0.9837, False Alarm Ratio: 0.0879
# Integ Loss: 0.0238
#
#
# epoch duration : 99.19107127189636
# saving step
# epoch n° 999
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4144, Regression Loss 1h: 80.6014, Segmentation Loss:0.1519
# Train Confusion Matrix:
# [[3148687   49555]
#  [ 126493  515265]]
# Accuracy: 0.9542, CSI: 0.7453, Sensitivity: 0.8029, Specificity: 0.9845, False Alarm Ratio: 0.0877
# Integ Loss: 0.0295
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4112, Regression Loss 1h: 79.9296, Segmentation Loss:0.0989
# Train Confusion Matrix:
# [[3142515   55727]
#  [  88770  552988]]
# Accuracy: 0.9624, CSI: 0.7928, Sensitivity: 0.8617, Specificity: 0.9826, False Alarm Ratio: 0.0915
# Integ Loss: 0.0236
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4100, Regression Loss 1h: 79.7483, Segmentation Loss:0.0906
# Train Confusion Matrix:
# [[3146071   52171]
#  [  82997  558761]]
# Accuracy: 0.9648, CSI: 0.8052, Sensitivity: 0.8707, Specificity: 0.9837, False Alarm Ratio: 0.0854
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4100, Regression Loss 1h: 79.6443, Segmentation Loss:0.1034
# Train Confusion Matrix:
# [[3146403   51839]
#  [  95096  546662]]
# Accuracy: 0.9617, CSI: 0.7882, Sensitivity: 0.8518, Specificity: 0.9838, False Alarm Ratio: 0.0866
# Integ Loss: 0.0244
#
#
# epoch duration : 98.29025959968567
# saving step
# epoch n° 1000
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4163, Regression Loss 1h: 81.1636, Segmentation Loss:0.1531
# Train Confusion Matrix:
# [[3145301   51417]
#  [ 127320  515962]]
# Accuracy: 0.9535, CSI: 0.7427, Sensitivity: 0.8021, Specificity: 0.9839, False Alarm Ratio: 0.0906
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4131, Regression Loss 1h: 80.5212, Segmentation Loss:0.1015
# Train Confusion Matrix:
# [[3141926   54792]
#  [  93791  549491]]
# Accuracy: 0.9613, CSI: 0.7872, Sensitivity: 0.8542, Specificity: 0.9829, False Alarm Ratio: 0.0907
# Integ Loss: 0.0233
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4119, Regression Loss 1h: 80.3441, Segmentation Loss:0.0927
# Train Confusion Matrix:
# [[3146235   50483]
#  [  87760  555522]]
# Accuracy: 0.9640, CSI: 0.8007, Sensitivity: 0.8636, Specificity: 0.9842, False Alarm Ratio: 0.0833
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4121, Regression Loss 1h: 80.2100, Segmentation Loss:0.1039
# Train Confusion Matrix:
# [[3143449   53269]
#  [  94635  548647]]
# Accuracy: 0.9615, CSI: 0.7877, Sensitivity: 0.8529, Specificity: 0.9833, False Alarm Ratio: 0.0885
# Integ Loss: 0.0241
#
#
# epoch duration : 99.25682187080383
# saving step
# epoch n° 1001
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4157, Regression Loss 1h: 81.5039, Segmentation Loss:0.1499
# Train Confusion Matrix:
# [[3151040   49464]
#  [ 126626  512870]]
# Accuracy: 0.9541, CSI: 0.7444, Sensitivity: 0.8020, Specificity: 0.9845, False Alarm Ratio: 0.0880
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4118, Regression Loss 1h: 80.6059, Segmentation Loss:0.0998
# Train Confusion Matrix:
# [[3147014   53490]
#  [  92320  547176]]
# Accuracy: 0.9620, CSI: 0.7896, Sensitivity: 0.8556, Specificity: 0.9833, False Alarm Ratio: 0.0891
# Integ Loss: 0.0236
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4108, Regression Loss 1h: 80.4701, Segmentation Loss:0.0915
# Train Confusion Matrix:
# [[3150082   50422]
#  [  86469  553027]]
# Accuracy: 0.9644, CSI: 0.8016, Sensitivity: 0.8648, Specificity: 0.9842, False Alarm Ratio: 0.0836
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4109, Regression Loss 1h: 80.3506, Segmentation Loss:0.1042
# Train Confusion Matrix:
# [[3147905   52599]
#  [  94909  544587]]
# Accuracy: 0.9616, CSI: 0.7869, Sensitivity: 0.8516, Specificity: 0.9836, False Alarm Ratio: 0.0881
# Integ Loss: 0.0243
#
#
# epoch duration : 99.56266164779663
# saving step
# epoch n° 1002
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4156, Regression Loss 1h: 79.4251, Segmentation Loss:0.1634
# Train Confusion Matrix:
# [[3152531   53931]
#  [ 134748  498790]]
# Accuracy: 0.9509, CSI: 0.7255, Sensitivity: 0.7873, Specificity: 0.9832, False Alarm Ratio: 0.0976
# Integ Loss: 0.0286
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4122, Regression Loss 1h: 78.7974, Segmentation Loss:0.1039
# Train Confusion Matrix:
# [[3150965   55497]
#  [  95500  538038]]
# Accuracy: 0.9607, CSI: 0.7809, Sensitivity: 0.8493, Specificity: 0.9827, False Alarm Ratio: 0.0935
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4112, Regression Loss 1h: 78.6773, Segmentation Loss:0.0941
# Train Confusion Matrix:
# [[3154928   51534]
#  [  88793  544745]]
# Accuracy: 0.9635, CSI: 0.7952, Sensitivity: 0.8598, Specificity: 0.9839, False Alarm Ratio: 0.0864
# Integ Loss: 0.0225
#
#
# train, Regression Loss: 0.4109, Regression Loss 1h: 78.4492, Segmentation Loss:0.1068
# Train Confusion Matrix:
# [[3153090   53372]
#  [  98758  534780]]
# Accuracy: 0.9604, CSI: 0.7785, Sensitivity: 0.8441, Specificity: 0.9834, False Alarm Ratio: 0.0907
# Integ Loss: 0.0237
#
#
# epoch duration : 99.39468693733215
# saving step
# epoch n° 1003
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4124, Regression Loss 1h: 82.0232, Segmentation Loss:0.1550
# Train Confusion Matrix:
# [[3135895   52861]
#  [ 127373  523871]]
# Accuracy: 0.9531, CSI: 0.7440, Sensitivity: 0.8044, Specificity: 0.9834, False Alarm Ratio: 0.0917
# Integ Loss: 0.0294
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4085, Regression Loss 1h: 81.1970, Segmentation Loss:0.0994
# Train Confusion Matrix:
# [[3132216   56540]
#  [  88606  562638]]
# Accuracy: 0.9622, CSI: 0.7949, Sensitivity: 0.8639, Specificity: 0.9823, False Alarm Ratio: 0.0913
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4075, Regression Loss 1h: 81.0402, Segmentation Loss:0.0912
# Train Confusion Matrix:
# [[3134808   53948]
#  [  82169  569075]]
# Accuracy: 0.9646, CSI: 0.8070, Sensitivity: 0.8738, Specificity: 0.9831, False Alarm Ratio: 0.0866
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4076, Regression Loss 1h: 80.9386, Segmentation Loss:0.1018
# Train Confusion Matrix:
# [[3135775   52981]
#  [  93074  558170]]
# Accuracy: 0.9620, CSI: 0.7926, Sensitivity: 0.8571, Specificity: 0.9834, False Alarm Ratio: 0.0867
# Integ Loss: 0.0247
#
#
# epoch duration : 98.60510230064392
# saving step
# epoch n° 1004
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4166, Regression Loss 1h: 82.0507, Segmentation Loss:0.1607
# Train Confusion Matrix:
# [[3147940   48075]
#  [ 138794  505191]]
# Accuracy: 0.9513, CSI: 0.7300, Sensitivity: 0.7845, Specificity: 0.9850, False Alarm Ratio: 0.0869
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4122, Regression Loss 1h: 81.0741, Segmentation Loss:0.1032
# Train Confusion Matrix:
# [[3139814   56201]
#  [  94702  549283]]
# Accuracy: 0.9607, CSI: 0.7845, Sensitivity: 0.8529, Specificity: 0.9824, False Alarm Ratio: 0.0928
# Integ Loss: 0.0237
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4113, Regression Loss 1h: 80.9548, Segmentation Loss:0.0939
# Train Confusion Matrix:
# [[3143007   53008]
#  [  87007  556978]]
# Accuracy: 0.9635, CSI: 0.7991, Sensitivity: 0.8649, Specificity: 0.9834, False Alarm Ratio: 0.0869
# Integ Loss: 0.0230
#
#
# train, Regression Loss: 0.4109, Regression Loss 1h: 80.7313, Segmentation Loss:0.1081
# Train Confusion Matrix:
# [[3142281   53734]
#  [  99801  544184]]
# Accuracy: 0.9600, CSI: 0.7799, Sensitivity: 0.8450, Specificity: 0.9832, False Alarm Ratio: 0.0899
# Integ Loss: 0.0244
#
#
# epoch duration : 98.16798067092896
# saving step
# epoch n° 1005
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4144, Regression Loss 1h: 80.5911, Segmentation Loss:0.1520
# Train Confusion Matrix:
# [[3147927   51113]
#  [ 128159  512801]]
# Accuracy: 0.9533, CSI: 0.7410, Sensitivity: 0.8001, Specificity: 0.9840, False Alarm Ratio: 0.0906
# Integ Loss: 0.0291
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4113, Regression Loss 1h: 80.0438, Segmentation Loss:0.1004
# Train Confusion Matrix:
# [[3142822   56218]
#  [  90801  550159]]
# Accuracy: 0.9617, CSI: 0.7891, Sensitivity: 0.8583, Specificity: 0.9824, False Alarm Ratio: 0.0927
# Integ Loss: 0.0236
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4104, Regression Loss 1h: 79.9401, Segmentation Loss:0.0915
# Train Confusion Matrix:
# [[3146484   52556]
#  [  84248  556712]]
# Accuracy: 0.9644, CSI: 0.8027, Sensitivity: 0.8686, Specificity: 0.9836, False Alarm Ratio: 0.0863
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4099, Regression Loss 1h: 79.6693, Segmentation Loss:0.1031
# Train Confusion Matrix:
# [[3146778   52262]
#  [  94266  546694]]
# Accuracy: 0.9618, CSI: 0.7886, Sensitivity: 0.8529, Specificity: 0.9837, False Alarm Ratio: 0.0873
# Integ Loss: 0.0244
#
#
# epoch duration : 97.8624095916748
# saving step
# epoch n° 1006
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4187, Regression Loss 1h: 83.0811, Segmentation Loss:0.1637
# Train Confusion Matrix:
# [[3147959   49966]
#  [ 139500  502575]]
# Accuracy: 0.9507, CSI: 0.7262, Sensitivity: 0.7827, Specificity: 0.9844, False Alarm Ratio: 0.0904
# Integ Loss: 0.0295
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4144, Regression Loss 1h: 82.1172, Segmentation Loss:0.1045
# Train Confusion Matrix:
# [[3144213   53712]
#  [  99484  542591]]
# Accuracy: 0.9601, CSI: 0.7798, Sensitivity: 0.8451, Specificity: 0.9832, False Alarm Ratio: 0.0901
# Integ Loss: 0.0240
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4135, Regression Loss 1h: 81.9997, Segmentation Loss:0.0947
# Train Confusion Matrix:
# [[3146954   50971]
#  [  90279  551796]]
# Accuracy: 0.9632, CSI: 0.7962, Sensitivity: 0.8594, Specificity: 0.9841, False Alarm Ratio: 0.0846
# Integ Loss: 0.0233
#
#
# train, Regression Loss: 0.4134, Regression Loss 1h: 81.8559, Segmentation Loss:0.1056
# Train Confusion Matrix:
# [[3144734   53191]
#  [  97450  544625]]
# Accuracy: 0.9608, CSI: 0.7833, Sensitivity: 0.8482, Specificity: 0.9834, False Alarm Ratio: 0.0890
# Integ Loss: 0.0249
#
#
# epoch duration : 98.5120780467987
# saving step
# epoch n° 1007
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4211, Regression Loss 1h: 82.2798, Segmentation Loss:0.1511
# Train Confusion Matrix:
# [[3144176   53249]
#  [ 124394  518181]]
# Accuracy: 0.9537, CSI: 0.7447, Sensitivity: 0.8064, Specificity: 0.9833, False Alarm Ratio: 0.0932
# Integ Loss: 0.0299
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4182, Regression Loss 1h: 81.7040, Segmentation Loss:0.1008
# Train Confusion Matrix:
# [[3140373   57052]
#  [  89883  552692]]
# Accuracy: 0.9617, CSI: 0.7900, Sensitivity: 0.8601, Specificity: 0.9822, False Alarm Ratio: 0.0936
# Integ Loss: 0.0241
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4173, Regression Loss 1h: 81.5931, Segmentation Loss:0.0923
# Train Confusion Matrix:
# [[3143063   54362]
#  [  82994  559581]]
# Accuracy: 0.9642, CSI: 0.8029, Sensitivity: 0.8708, Specificity: 0.9830, False Alarm Ratio: 0.0885
# Integ Loss: 0.0234
#
#
# train, Regression Loss: 0.4168, Regression Loss 1h: 81.3281, Segmentation Loss:0.1035
# Train Confusion Matrix:
# [[3145367   52058]
#  [  94936  547639]]
# Accuracy: 0.9617, CSI: 0.7884, Sensitivity: 0.8523, Specificity: 0.9837, False Alarm Ratio: 0.0868
# Integ Loss: 0.0250
#
#
# epoch duration : 98.12341737747192
# saving step
# epoch n° 1008
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4163, Regression Loss 1h: 78.0976, Segmentation Loss:0.1509
# Train Confusion Matrix:
# [[3156491   51371]
#  [ 125838  506300]]
# Accuracy: 0.9539, CSI: 0.7407, Sensitivity: 0.8009, Specificity: 0.9840, False Alarm Ratio: 0.0921
# Integ Loss: 0.0290
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4137, Regression Loss 1h: 77.6287, Segmentation Loss:0.1011
# Train Confusion Matrix:
# [[3154764   53098]
#  [  94562  537576]]
# Accuracy: 0.9615, CSI: 0.7845, Sensitivity: 0.8504, Specificity: 0.9834, False Alarm Ratio: 0.0899
# Integ Loss: 0.0232
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4129, Regression Loss 1h: 77.5189, Segmentation Loss:0.0927
# Train Confusion Matrix:
# [[3158112   49750]
#  [  87835  544303]]
# Accuracy: 0.9642, CSI: 0.7982, Sensitivity: 0.8611, Specificity: 0.9845, False Alarm Ratio: 0.0837
# Integ Loss: 0.0225
#
#
# train, Regression Loss: 0.4127, Regression Loss 1h: 77.3315, Segmentation Loss:0.1039
# Train Confusion Matrix:
# [[3155532   52330]
#  [  94894  537244]]
# Accuracy: 0.9617, CSI: 0.7849, Sensitivity: 0.8499, Specificity: 0.9837, False Alarm Ratio: 0.0888
# Integ Loss: 0.0245
#
#
# epoch duration : 99.56505274772644
# saving step
# epoch n° 1009
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4056, Regression Loss 1h: 77.9499, Segmentation Loss:0.1588
# Train Confusion Matrix:
# [[3146060   50043]
#  [ 134104  509793]]
# Accuracy: 0.9520, CSI: 0.7346, Sensitivity: 0.7917, Specificity: 0.9843, False Alarm Ratio: 0.0894
# Integ Loss: 0.0286
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4032, Regression Loss 1h: 77.5458, Segmentation Loss:0.1028
# Train Confusion Matrix:
# [[3138757   57346]
#  [  92525  551372]]
# Accuracy: 0.9610, CSI: 0.7863, Sensitivity: 0.8563, Specificity: 0.9821, False Alarm Ratio: 0.0942
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4022, Regression Loss 1h: 77.4181, Segmentation Loss:0.0940
# Train Confusion Matrix:
# [[3142059   54044]
#  [  85641  558256]]
# Accuracy: 0.9636, CSI: 0.7999, Sensitivity: 0.8670, Specificity: 0.9831, False Alarm Ratio: 0.0883
# Integ Loss: 0.0224
#
#
# train, Regression Loss: 0.4018, Regression Loss 1h: 77.1958, Segmentation Loss:0.1089
# Train Confusion Matrix:
# [[3142991   53112]
#  [ 100122  543775]]
# Accuracy: 0.9601, CSI: 0.7802, Sensitivity: 0.8445, Specificity: 0.9834, False Alarm Ratio: 0.0890
# Integ Loss: 0.0241
#
#
# epoch duration : 98.6462574005127
# saving step
# epoch n° 1010
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4171, Regression Loss 1h: 80.9136, Segmentation Loss:0.1529
# Train Confusion Matrix:
# [[3148069   50071]
#  [ 127149  514711]]
# Accuracy: 0.9538, CSI: 0.7439, Sensitivity: 0.8019, Specificity: 0.9843, False Alarm Ratio: 0.0887
# Integ Loss: 0.0288
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4143, Regression Loss 1h: 80.3868, Segmentation Loss:0.1007
# Train Confusion Matrix:
# [[3140899   57241]
#  [  89374  552486]]
# Accuracy: 0.9618, CSI: 0.7903, Sensitivity: 0.8608, Specificity: 0.9821, False Alarm Ratio: 0.0939
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4132, Regression Loss 1h: 80.2254, Segmentation Loss:0.0916
# Train Confusion Matrix:
# [[3143793   54347]
#  [  81692  560168]]
# Accuracy: 0.9646, CSI: 0.8046, Sensitivity: 0.8727, Specificity: 0.9830, False Alarm Ratio: 0.0884
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4127, Regression Loss 1h: 79.9797, Segmentation Loss:0.1031
# Train Confusion Matrix:
# [[3147025   51115]
#  [  94722  547138]]
# Accuracy: 0.9620, CSI: 0.7895, Sensitivity: 0.8524, Specificity: 0.9840, False Alarm Ratio: 0.0854
# Integ Loss: 0.0239
#
#
# epoch duration : 98.41731858253479
# saving step
# epoch n° 1011
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4186, Regression Loss 1h: 82.6159, Segmentation Loss:0.1630
# Train Confusion Matrix:
# [[3148026   50028]
#  [ 137947  503999]]
# Accuracy: 0.9510, CSI: 0.7283, Sensitivity: 0.7851, Specificity: 0.9844, False Alarm Ratio: 0.0903
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4156, Regression Loss 1h: 82.0397, Segmentation Loss:0.1043
# Train Confusion Matrix:
# [[3141512   56542]
#  [  96605  545341]]
# Accuracy: 0.9601, CSI: 0.7807, Sensitivity: 0.8495, Specificity: 0.9823, False Alarm Ratio: 0.0939
# Integ Loss: 0.0234
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4145, Regression Loss 1h: 81.8864, Segmentation Loss:0.0946
# Train Confusion Matrix:
# [[3144412   53642]
#  [  88022  553924]]
# Accuracy: 0.9631, CSI: 0.7963, Sensitivity: 0.8629, Specificity: 0.9832, False Alarm Ratio: 0.0883
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4146, Regression Loss 1h: 81.7720, Segmentation Loss:0.1059
# Train Confusion Matrix:
# [[3144890   53164]
#  [  97677  544269]]
# Accuracy: 0.9607, CSI: 0.7830, Sensitivity: 0.8478, Specificity: 0.9834, False Alarm Ratio: 0.0890
# Integ Loss: 0.0244
#
#
# epoch duration : 98.53874778747559
# saving step
# epoch n° 1012
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4212, Regression Loss 1h: 82.2614, Segmentation Loss:0.1417
# Train Confusion Matrix:
# [[3149260   51692]
#  [ 116143  522905]]
# Accuracy: 0.9563, CSI: 0.7570, Sensitivity: 0.8183, Specificity: 0.9839, False Alarm Ratio: 0.0900
# Integ Loss: 0.0294
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4177, Regression Loss 1h: 81.5598, Segmentation Loss:0.0956
# Train Confusion Matrix:
# [[3147744   53208]
#  [  86204  552844]]
# Accuracy: 0.9637, CSI: 0.7986, Sensitivity: 0.8651, Specificity: 0.9834, False Alarm Ratio: 0.0878
# Integ Loss: 0.0236
#
#
# ...
# [[3150277   51236]
#  [  95618  542869]]
# Accuracy: 0.9618, CSI: 0.7871, Sensitivity: 0.8502, Specificity: 0.9840, False Alarm Ratio: 0.0862
# Integ Loss: 0.0237
#
#
# epoch duration : 98.06965684890747
# saving step
# epoch n° 1305
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4158, Regression Loss 1h: 82.7427, Segmentation Loss:0.1552
# Train Confusion Matrix:
# [[3138906   51921]
#  [ 127933  521240]]
# Accuracy: 0.9532, CSI: 0.7435, Sensitivity: 0.8029, Specificity: 0.9837, False Alarm Ratio: 0.0906
# Integ Loss: 0.0294
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4119, Regression Loss 1h: 81.9558, Segmentation Loss:0.0984
# Train Confusion Matrix:
# [[3135739   55088]
#  [  88796  560377]]
# Accuracy: 0.9625, CSI: 0.7957, Sensitivity: 0.8632, Specificity: 0.9827, False Alarm Ratio: 0.0895
# Integ Loss: 0.0236
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4109, Regression Loss 1h: 81.8078, Segmentation Loss:0.0893
# Train Confusion Matrix:
# [[3139460   51367]
#  [  81700  567473]]
# Accuracy: 0.9653, CSI: 0.8101, Sensitivity: 0.8741, Specificity: 0.9839, False Alarm Ratio: 0.0830
# Integ Loss: 0.0229
#
#
# train, Regression Loss: 0.4107, Regression Loss 1h: 81.6204, Segmentation Loss:0.1008
# Train Confusion Matrix:
# [[3139634   51193]
#  [  90708  558465]]
# Accuracy: 0.9630, CSI: 0.7974, Sensitivity: 0.8603, Specificity: 0.9840, False Alarm Ratio: 0.0840
# Integ Loss: 0.0246
#
#
# epoch duration : 99.74287056922913
# saving step
# epoch n° 1306
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4210, Regression Loss 1h: 84.4791, Segmentation Loss:0.1586
# Train Confusion Matrix:
# [[3144707   51254]
#  [ 130517  513522]]
# Accuracy: 0.9527, CSI: 0.7386, Sensitivity: 0.7973, Specificity: 0.9840, False Alarm Ratio: 0.0908
# Integ Loss: 0.0292
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4159, Regression Loss 1h: 83.2594, Segmentation Loss:0.0984
# Train Confusion Matrix:
# [[3141837   54124]
#  [  89289  554750]]
# Accuracy: 0.9627, CSI: 0.7946, Sensitivity: 0.8614, Specificity: 0.9831, False Alarm Ratio: 0.0889
# Integ Loss: 0.0234
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4145, Regression Loss 1h: 82.9842, Segmentation Loss:0.0891
# Train Confusion Matrix:
# [[3145116   50845]
#  [  81787  562252]]
# Accuracy: 0.9655, CSI: 0.8091, Sensitivity: 0.8730, Specificity: 0.9841, False Alarm Ratio: 0.0829
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4142, Regression Loss 1h: 82.7989, Segmentation Loss:0.0986
# Train Confusion Matrix:
# [[3145123   50838]
#  [  90789  553250]]
# Accuracy: 0.9631, CSI: 0.7962, Sensitivity: 0.8590, Specificity: 0.9841, False Alarm Ratio: 0.0842
# Integ Loss: 0.0243
#
#
# epoch duration : 99.17922043800354
# saving step
# epoch n° 1307
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4258, Regression Loss 1h: 85.5057, Segmentation Loss:0.1360
# Train Confusion Matrix:
# [[3148802   48202]
#  [ 112707  530289]]
# Accuracy: 0.9581, CSI: 0.7672, Sensitivity: 0.8247, Specificity: 0.9849, False Alarm Ratio: 0.0833
# Integ Loss: 0.0298
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4224, Regression Loss 1h: 84.8680, Segmentation Loss:0.0923
# Train Confusion Matrix:
# [[3147515   49489]
#  [  85441  557555]]
# Accuracy: 0.9649, CSI: 0.8052, Sensitivity: 0.8671, Specificity: 0.9845, False Alarm Ratio: 0.0815
# Integ Loss: 0.0239
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4212, Regression Loss 1h: 84.6609, Segmentation Loss:0.0852
# Train Confusion Matrix:
# [[3151135   45869]
#  [  80787  562209]]
# Accuracy: 0.9670, CSI: 0.8161, Sensitivity: 0.8744, Specificity: 0.9857, False Alarm Ratio: 0.0754
# Integ Loss: 0.0232
#
#
# train, Regression Loss: 0.4211, Regression Loss 1h: 84.4725, Segmentation Loss:0.0946
# Train Confusion Matrix:
# [[3147252   49752]
#  [  84688  558308]]
# Accuracy: 0.9650, CSI: 0.8059, Sensitivity: 0.8683, Specificity: 0.9844, False Alarm Ratio: 0.0818
# Integ Loss: 0.0245
#
#
# epoch duration : 99.79485630989075
# saving step
# epoch n° 1308
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4150, Regression Loss 1h: 81.8134, Segmentation Loss:0.1634
# Train Confusion Matrix:
# [[3148448   49994]
#  [ 136527  505031]]
# Accuracy: 0.9514, CSI: 0.7303, Sensitivity: 0.7872, Specificity: 0.9844, False Alarm Ratio: 0.0901
# Integ Loss: 0.0283
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4110, Regression Loss 1h: 81.0264, Segmentation Loss:0.1019
# Train Confusion Matrix:
# [[3142973   55469]
#  [  93860  547698]]
# Accuracy: 0.9611, CSI: 0.7858, Sensitivity: 0.8537, Specificity: 0.9827, False Alarm Ratio: 0.0920
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4099, Regression Loss 1h: 80.8336, Segmentation Loss:0.0918
# Train Confusion Matrix:
# [[3147162   51280]
#  [  85807  555751]]
# Accuracy: 0.9643, CSI: 0.8021, Sensitivity: 0.8663, Specificity: 0.9840, False Alarm Ratio: 0.0845
# Integ Loss: 0.0226
#
#
# train, Regression Loss: 0.4103, Regression Loss 1h: 80.8236, Segmentation Loss:0.1051
# Train Confusion Matrix:
# [[3146339   52103]
#  [  97360  544198]]
# Accuracy: 0.9611, CSI: 0.7845, Sensitivity: 0.8482, Specificity: 0.9837, False Alarm Ratio: 0.0874
# Integ Loss: 0.0240
#
#
# epoch duration : 99.04810643196106
# saving step
# epoch n° 1309
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4167, Regression Loss 1h: 79.9795, Segmentation Loss:0.1519
# Train Confusion Matrix:
# [[3157564   46771]
#  [ 128600  507065]]
# Accuracy: 0.9543, CSI: 0.7430, Sensitivity: 0.7977, Specificity: 0.9854, False Alarm Ratio: 0.0844
# Integ Loss: 0.0282
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4137, Regression Loss 1h: 79.5046, Segmentation Loss:0.0952
# Train Confusion Matrix:
# [[3151306   53029]
#  [  86482  549183]]
# Accuracy: 0.9637, CSI: 0.7974, Sensitivity: 0.8640, Specificity: 0.9835, False Alarm Ratio: 0.0881
# Integ Loss: 0.0229
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4125, Regression Loss 1h: 79.3270, Segmentation Loss:0.0864
# Train Confusion Matrix:
# [[3155172   49163]
#  [  80164  555501]]
# Accuracy: 0.9663, CSI: 0.8112, Sensitivity: 0.8739, Specificity: 0.9847, False Alarm Ratio: 0.0813
# Integ Loss: 0.0222
#
#
# train, Regression Loss: 0.4120, Regression Loss 1h: 79.0781, Segmentation Loss:0.0965
# Train Confusion Matrix:
# [[3154236   50099]
#  [  87334  548331]]
# Accuracy: 0.9642, CSI: 0.7996, Sensitivity: 0.8626, Specificity: 0.9844, False Alarm Ratio: 0.0837
# Integ Loss: 0.0231
#
#
# epoch duration : 98.3389344215393
# saving step
# epoch n° 1310
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4200, Regression Loss 1h: 81.1466, Segmentation Loss:0.1482
# Train Confusion Matrix:
# [[3148570   51301]
#  [ 121369  518760]]
# Accuracy: 0.9550, CSI: 0.7503, Sensitivity: 0.8104, Specificity: 0.9840, False Alarm Ratio: 0.0900
# Integ Loss: 0.0289
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4172, Regression Loss 1h: 80.7183, Segmentation Loss:0.0957
# Train Confusion Matrix:
# [[3148708   51163]
#  [  88375  551754]]
# Accuracy: 0.9637, CSI: 0.7981, Sensitivity: 0.8619, Specificity: 0.9840, False Alarm Ratio: 0.0849
# Integ Loss: 0.0234
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4163, Regression Loss 1h: 80.5991, Segmentation Loss:0.0868
# Train Confusion Matrix:
# [[3152806   47065]
#  [  82094  558035]]
# Accuracy: 0.9664, CSI: 0.8120, Sensitivity: 0.8718, Specificity: 0.9853, False Alarm Ratio: 0.0778
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4159, Regression Loss 1h: 80.3563, Segmentation Loss:0.1011
# Train Confusion Matrix:
# [[3150303   49568]
#  [  92588  547541]]
# Accuracy: 0.9630, CSI: 0.7939, Sensitivity: 0.8554, Specificity: 0.9845, False Alarm Ratio: 0.0830
# Integ Loss: 0.0240
#
#
# epoch duration : 100.08219981193542
# saving step
# epoch n° 1311
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4182, Regression Loss 1h: 82.5935, Segmentation Loss:0.1531
# Train Confusion Matrix:
# [[3145006   49875]
#  [ 126589  518530]]
# Accuracy: 0.9540, CSI: 0.7461, Sensitivity: 0.8038, Specificity: 0.9844, False Alarm Ratio: 0.0877
# Integ Loss: 0.0292
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4147, Regression Loss 1h: 81.9567, Segmentation Loss:0.0964
# Train Confusion Matrix:
# [[3145058   49823]
#  [  90440  554679]]
# Accuracy: 0.9635, CSI: 0.7982, Sensitivity: 0.8598, Specificity: 0.9844, False Alarm Ratio: 0.0824
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4138, Regression Loss 1h: 81.8468, Segmentation Loss:0.0877
# Train Confusion Matrix:
# [[3148312   46569]
#  [  83527  561592]]
# Accuracy: 0.9661, CSI: 0.8119, Sensitivity: 0.8705, Specificity: 0.9854, False Alarm Ratio: 0.0766
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4136, Regression Loss 1h: 81.6267, Segmentation Loss:0.0992
# Train Confusion Matrix:
# [[3144989   49892]
#  [  90017  555102]]
# Accuracy: 0.9636, CSI: 0.7987, Sensitivity: 0.8605, Specificity: 0.9844, False Alarm Ratio: 0.0825
# Integ Loss: 0.0244
#
#
# epoch duration : 98.4636619091034
# saving step
# epoch n° 1312
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4122, Regression Loss 1h: 79.9623, Segmentation Loss:0.1557
# Train Confusion Matrix:
# [[3154154   47260]
#  [ 130523  508063]]
# Accuracy: 0.9537, CSI: 0.7408, Sensitivity: 0.7956, Specificity: 0.9852, False Alarm Ratio: 0.0851
# Integ Loss: 0.0283
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4087, Regression Loss 1h: 79.2966, Segmentation Loss:0.0967
# Train Confusion Matrix:
# [[3148654   52760]
#  [  88713  549873]]
# Accuracy: 0.9632, CSI: 0.7954, Sensitivity: 0.8611, Specificity: 0.9835, False Alarm Ratio: 0.0875
# Integ Loss: 0.0227
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4078, Regression Loss 1h: 79.1673, Segmentation Loss:0.0882
# Train Confusion Matrix:
# [[3152138   49276]
#  [  82214  556372]]
# Accuracy: 0.9658, CSI: 0.8088, Sensitivity: 0.8713, Specificity: 0.9846, False Alarm Ratio: 0.0814
# Integ Loss: 0.0220
#
#
# train, Regression Loss: 0.4075, Regression Loss 1h: 78.9547, Segmentation Loss:0.1000
# Train Confusion Matrix:
# [[3151126   50288]
#  [  91106  547480]]
# Accuracy: 0.9632, CSI: 0.7947, Sensitivity: 0.8573, Specificity: 0.9843, False Alarm Ratio: 0.0841
# Integ Loss: 0.0239
#
#
# epoch duration : 98.046560049057
# saving step
# epoch n° 1313
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4148, Regression Loss 1h: 79.7637, Segmentation Loss:0.1517
# Train Confusion Matrix:
# [[3153965   50896]
#  [ 123858  511281]]
# Accuracy: 0.9545, CSI: 0.7453, Sensitivity: 0.8050, Specificity: 0.9841, False Alarm Ratio: 0.0905
# Integ Loss: 0.0287
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4112, Regression Loss 1h: 79.0887, Segmentation Loss:0.0963
# Train Confusion Matrix:
# [[3153659   51202]
#  [  89592  545547]]
# Accuracy: 0.9633, CSI: 0.7949, Sensitivity: 0.8589, Specificity: 0.9840, False Alarm Ratio: 0.0858
# Integ Loss: 0.0231
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4101, Regression Loss 1h: 78.9547, Segmentation Loss:0.0871
# Train Confusion Matrix:
# [[3157863   46998]
#  [  83515  551624]]
# Accuracy: 0.9660, CSI: 0.8087, Sensitivity: 0.8685, Specificity: 0.9853, False Alarm Ratio: 0.0785
# Integ Loss: 0.0224
#
#
# train, Regression Loss: 0.4098, Regression Loss 1h: 78.7267, Segmentation Loss:0.0972
# Train Confusion Matrix:
# [[3154896   49965]
#  [  89216  545923]]
# Accuracy: 0.9638, CSI: 0.7968, Sensitivity: 0.8595, Specificity: 0.9844, False Alarm Ratio: 0.0838
# Integ Loss: 0.0238
#
#
# epoch duration : 98.1826536655426
# saving step
# epoch n° 1314
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4236, Regression Loss 1h: 83.5113, Segmentation Loss:0.1401
# Train Confusion Matrix:
# [[3143672   49884]
#  [ 115337  531107]]
# Accuracy: 0.9570, CSI: 0.7627, Sensitivity: 0.8216, Specificity: 0.9844, False Alarm Ratio: 0.0859
# Integ Loss: 0.0302
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4203, Regression Loss 1h: 82.9900, Segmentation Loss:0.0926
# Train Confusion Matrix:
# [[3140783   52773]
#  [  82528  563916]]
# Accuracy: 0.9648, CSI: 0.8065, Sensitivity: 0.8723, Specificity: 0.9835, False Alarm Ratio: 0.0856
# Integ Loss: 0.0239
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4191, Regression Loss 1h: 82.8066, Segmentation Loss:0.0847
# Train Confusion Matrix:
# [[3144806   48750]
#  [  76840  569604]]
# Accuracy: 0.9673, CSI: 0.8193, Sensitivity: 0.8811, Specificity: 0.9847, False Alarm Ratio: 0.0788
# Integ Loss: 0.0233
#
#
# train, Regression Loss: 0.4194, Regression Loss 1h: 82.7220, Segmentation Loss:0.0945
# Train Confusion Matrix:
# [[3144572   48984]
#  [  84725  561719]]
# Accuracy: 0.9652, CSI: 0.8077, Sensitivity: 0.8689, Specificity: 0.9847, False Alarm Ratio: 0.0802
# Integ Loss: 0.0248
#
#
# epoch duration : 97.96791195869446
# saving step
# epoch n° 1315
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4147, Regression Loss 1h: 81.2562, Segmentation Loss:0.1525
# Train Confusion Matrix:
# [[3147451   50051]
#  [ 124307  518191]]
# Accuracy: 0.9546, CSI: 0.7482, Sensitivity: 0.8065, Specificity: 0.9843, False Alarm Ratio: 0.0881
# Integ Loss: 0.0287
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4123, Regression Loss 1h: 80.9309, Segmentation Loss:0.0950
# Train Confusion Matrix:
# [[3144321   53181]
#  [  85821  556677]]
# Accuracy: 0.9638, CSI: 0.8002, Sensitivity: 0.8664, Specificity: 0.9834, False Alarm Ratio: 0.0872
# Integ Loss: 0.0228
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4113, Regression Loss 1h: 80.8193, Segmentation Loss:0.0862
# Train Confusion Matrix:
# [[3148208   49294]
#  [  78900  563598]]
# Accuracy: 0.9666, CSI: 0.8147, Sensitivity: 0.8772, Specificity: 0.9846, False Alarm Ratio: 0.0804
# Integ Loss: 0.0222
#
#
# train, Regression Loss: 0.4107, Regression Loss 1h: 80.5090, Segmentation Loss:0.0976
# Train Confusion Matrix:
# [[3147445   50057]
#  [  89369  553129]]
# Accuracy: 0.9637, CSI: 0.7987, Sensitivity: 0.8609, Specificity: 0.9843, False Alarm Ratio: 0.0830
# Integ Loss: 0.0234
#
#
# epoch duration : 97.7491865158081
# saving step
# epoch n° 1316
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4168, Regression Loss 1h: 82.5187, Segmentation Loss:0.1558
# Train Confusion Matrix:
# [[3143116   50665]
#  [ 130449  515770]]
# Accuracy: 0.9528, CSI: 0.7401, Sensitivity: 0.7981, Specificity: 0.9841, False Alarm Ratio: 0.0894
# Integ Loss: 0.0293
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4134, Regression Loss 1h: 81.8704, Segmentation Loss:0.0984
# Train Confusion Matrix:
# [[3142099   51682]
#  [  91622  554597]]
# Accuracy: 0.9627, CSI: 0.7947, Sensitivity: 0.8582, Specificity: 0.9838, False Alarm Ratio: 0.0852
# Integ Loss: 0.0233
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4126, Regression Loss 1h: 81.7585, Segmentation Loss:0.0893
# Train Confusion Matrix:
# [[3145744   48037]
#  [  84345  561874]]
# Accuracy: 0.9655, CSI: 0.8093, Sensitivity: 0.8695, Specificity: 0.9850, False Alarm Ratio: 0.0788
# Integ Loss: 0.0227
#
#
# train, Regression Loss: 0.4125, Regression Loss 1h: 81.6149, Segmentation Loss:0.1011
# Train Confusion Matrix:
# [[3143466   50315]
#  [  92167  554052]]
# Accuracy: 0.9629, CSI: 0.7954, Sensitivity: 0.8574, Specificity: 0.9842, False Alarm Ratio: 0.0833
# Integ Loss: 0.0244
#
#
# epoch duration : 98.48356676101685
# saving step
# epoch n° 1317
#
# eval_opportunity_cost_cml_spat, Regression Loss: 0.4181, Regression Loss 1h: 84.3308, Segmentation Loss:0.1475
# Train Confusion Matrix:
# [[3139484   52596]
#  [ 118646  529274]]
# Accuracy: 0.9554, CSI: 0.7555, Sensitivity: 0.8169, Specificity: 0.9835, False Alarm Ratio: 0.0904
# Integ Loss: 0.0297
#
#
# eval_added_value_half_cml_spat, Regression Loss: 0.4158, Regression Loss 1h: 84.0067, Segmentation Loss:0.0944
# Train Confusion Matrix:
# [[3139082   52998]
#  [  84907  563013]]
# Accuracy: 0.9641, CSI: 0.8033, Sensitivity: 0.8690, Specificity: 0.9834, False Alarm Ratio: 0.0860
# Integ Loss: 0.0235
#
#
# eval_added_value_full_cml_spat, Regression Loss: 0.4149, Regression Loss 1h: 83.8821, Segmentation Loss:0.0861
# Train Confusion Matrix:
# [[3143215   48865]
#  [  79576  568344]]
# Accuracy: 0.9666, CSI: 0.8157, Sensitivity: 0.8772, Specificity: 0.9847, False Alarm Ratio: 0.0792
# Integ Loss: 0.0228
#
#
# train, Regression Loss: 0.4142, Regression Loss 1h: 83.5969, Segmentation Loss:0.0939
# Train Confusion Matrix:
# [[3141554   50526]
#  [  85524  562396]]
# Accuracy: 0.9646, CSI: 0.8052, Sensitivity: 0.8680, Specificity: 0.9842, False Alarm Ratio: 0.0824
# Integ Loss: 0.0240
#
#
# epoch duration : 98.51032590866089
# saving step
# epoch n° 1318

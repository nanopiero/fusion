# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B1.6 radar + gauges 1 min + cmls -> gauges 1 min [xrlg1_yg1]
# # mode leave one gauge out

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 2000
save_every = 2
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B16_xrlg1_yg1.pt'
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 20
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 + 60
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn()

# %%
# Boucle avec 5 modes d'évaluation
val_steps = ['eval_opportunity_cost_spat',
             # 'eval_added_value_few_spat',
             # 'eval_added_value_half_spat',
             'eval_added_value_full_spat',
             # 'eval_added_value_full_id',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)

# %%
last_epoch
# Out:
# 54

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}

  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    #Validation steps
    model.eval()
    with torch.no_grad():

      # splitting
      np_val_inputs_few = 1
      np_val_inputs_half = npoints//4  # 5
      np_val_inputs_comp = npoints//2 - np_val_inputs_half - np_val_inputs_few  # 4
      np_val_targets = npoints//2 # 10

      # val split
      split_val = [np_val_inputs_few, np_val_inputs_half, np_val_inputs_comp, np_val_targets]
      split_few, split_half, split_comp, split_targets = point_gt(images, npoints=npoints,
                                                                    use_fcn=use_fcn,
                                                                    split=split_val)
      _, point_measurements_fcn_eval_few, _ = split_few
      _, point_measurements_fcn_eval_half, _ = split_half
      _, point_measurements_fcn_eval_comp, _ = split_comp
      _, point_measurements_fcn_val_targets, _ = split_targets

      # 4 first val steps (10 last pluvios for testing generalization)
      targets = point_measurements_fcn_val_targets

      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          0 * point_measurements_fcn_eval_few - 0.1
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()


      step = 'eval_added_value_full_spat'
      point_measurements_fcn_eval_full = point_measurements_fcn_eval_few + \
                                          point_measurements_fcn_eval_half + \
                                          point_measurements_fcn_eval_comp

      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_few >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_half >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_comp >= 0)

      point_measurements_fcn_eval_full[point_measurements_fcn_eval_full<0] = -0.1

      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          point_measurements_fcn_eval_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, split_few, split_half, split_comp, split_targets
      torch.cuda.empty_cache()

      del point_measurements_fcn_eval_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    optimizer.zero_grad()  # Zero the gradients
    # leave one gauge out :
    for k in range(0,10):
        if k == 0 : 
            ng_train_targets = 1
            ng_train_inputs = npoints // 2 - 1
            split_train = [ng_train_targets, ng_train_inputs]
            # split  train
            split_targets, split_inputs = point_gt(images, npoints=npoints,
                                                   use_fcn=use_fcn,
                                                   split=split_train)
        
            _, point_measurements_fcn_train_inputs, _ = split_inputs
            _, point_measurements_fcn_train_targets, _ = split_targets
            
        elif k == 9 : 
            ng_train_targets = 1
            ng_train_inputs = npoints // 2 - 1
            split_train = [ng_train_inputs, ng_train_targets]
            # split  train
            split_inputs, split_targets = point_gt(images, npoints=npoints,
                                                   use_fcn=use_fcn,
                                                   split=split_train)
        
            _, point_measurements_fcn_train_inputs, _ = split_inputs
            _, point_measurements_fcn_train_targets, _ = split_targets
        else : 
            ng_train_targets = 1
            ng_train_inputs0 = k - 1
            ng_train_inputs1 = npoints // 2 - k
            split_train = [ng_train_inputs0, ng_train_targets, ng_train_inputs1]
            
            # split  train
            split_inputs0, split_targets, split_inputs1 = point_gt(images, npoints=npoints,
                                                                    use_fcn=use_fcn,
                                                                    split=split_train)
            
            _, point_measurements_fcn_train_inputs0, _ = split_inputs0
            _, point_measurements_fcn_train_targets, _ = split_targets
            _, point_measurements_fcn_train_inputs1, _ = split_inputs1

            point_measurements_fcn_train_inputs = point_measurements_fcn_train_inputs0
            point_measurements_fcn_train_inputs[point_measurements_fcn_train_inputs1>=0] = \
                        point_measurements_fcn_train_inputs1[point_measurements_fcn_train_inputs1>=0]
      
        inputs0 = torch.cat([noisy_images,
                            segment_measurements_fcn,
                            point_measurements_fcn_train_inputs
                            ], dim=1)
          
        inputs1 = torch.cat([noisy_images,
                            segment_measurements_fcn,
                            point_measurements_fcn_train_targets
                            ], dim=1)
          
        targets0 = point_measurements_fcn_train_targets
        targets1 = point_measurements_fcn_train_inputs
          
 
        outputs0 = model(inputs0)
        outputs1 = model(inputs1)      
        regression_loss, regression_loss_1h, segmentation_loss, loss0, batch_cm, _ = criterion(model.p, outputs0, targets0)
        _, _, _, loss1, _, _ = criterion(model.p, outputs1, targets1)
        loss = loss0 + loss1
        loss.backward()  # Backward pass

    
        running_regression_loss[step] += regression_loss
        running_regression_loss_1h[step] += regression_loss_1h
        running_segmentation_loss[step] += segmentation_loss
        running_confusion_matrix[step] += batch_cm
        
    optimizer.step()  # Update the weights after the loop
    
    del inputs0, inputs1, outputs0, outputs1, split_targets, loss0, loss1, loss, regression_loss, 
    del regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, segment_measurements_fcn
    del point_measurements_fcn_train_targets
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step]))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 54
#
# eval_opportunity_cost_spat, Regression Loss: 0.0345, Regression Loss 1h: 260.9757, Segmentation Loss:0.1268
# Train Confusion Matrix:
# [[3116555   81305]
#  [ 111433  530707]]
# Accuracy: 0.9498, CSI: 0.7336, Sensitivity: 0.8265, Specificity: 0.9746, False Alarm Ratio: 0.1328
#
#
# eval_added_value_full_spat, Regression Loss: 0.0316, Regression Loss 1h: 264.1949, Segmentation Loss:0.1184
# Train Confusion Matrix:
# [[3120426   77434]
#  [ 104464  537676]]
# Accuracy: 0.9526, CSI: 0.7472, Sensitivity: 0.8373, Specificity: 0.9758, False Alarm Ratio: 0.1259
#
#
# train, Regression Loss: 0.3145, Regression Loss 1h: 2646.2965, Segmentation Loss:1.1649
# Train Confusion Matrix:
# [[3120604   73750]
#  [ 106130  539516]]
# Accuracy: 0.9532, CSI: 0.7500, Sensitivity: 0.8356, Specificity: 0.9769, False Alarm Ratio: 0.1203
#
#
# epoch duration : 1051.930097103119
# saving step
# epoch n° 55
#
# eval_opportunity_cost_spat, Regression Loss: 0.0342, Regression Loss 1h: 264.0845, Segmentation Loss:0.1251
# Train Confusion Matrix:
# [[3125070   78721]
#  [ 110057  526152]]
# Accuracy: 0.9508, CSI: 0.7359, Sensitivity: 0.8270, Specificity: 0.9754, False Alarm Ratio: 0.1301
#
#
# eval_added_value_full_spat, Regression Loss: 0.0314, Regression Loss 1h: 266.8423, Segmentation Loss:0.1175
# Train Confusion Matrix:
# [[3128732   75059]
#  [ 104367  531842]]
# Accuracy: 0.9533, CSI: 0.7477, Sensitivity: 0.8360, Specificity: 0.9766, False Alarm Ratio: 0.1237
#
#
# train, Regression Loss: 0.3116, Regression Loss 1h: 2711.2597, Segmentation Loss:1.1581
# Train Confusion Matrix:
# [[3127899   73598]
#  [ 104948  533555]]
# Accuracy: 0.9535, CSI: 0.7493, Sensitivity: 0.8356, Specificity: 0.9770, False Alarm Ratio: 0.1212
#
#
# epoch duration : 1061.582290172577
# epoch n° 56
#
# eval_opportunity_cost_spat, Regression Loss: 0.0344, Regression Loss 1h: 269.7449, Segmentation Loss:0.1233
# Train Confusion Matrix:
# [[3120299   79181]
#  [ 108809  531711]]
# Accuracy: 0.9510, CSI: 0.7388, Sensitivity: 0.8301, Specificity: 0.9753, False Alarm Ratio: 0.1296
#
#
# eval_added_value_full_spat, Regression Loss: 0.0316, Regression Loss 1h: 270.6540, Segmentation Loss:0.1156
# Train Confusion Matrix:
# [[3122580   76900]
#  [ 101070  539450]]
# Accuracy: 0.9537, CSI: 0.7519, Sensitivity: 0.8422, Specificity: 0.9760, False Alarm Ratio: 0.1248
#
#
# train, Regression Loss: 0.3113, Regression Loss 1h: 2746.3490, Segmentation Loss:1.1203
# Train Confusion Matrix:
# [[3133508   72294]
#  [ 101744  532454]]
# Accuracy: 0.9547, CSI: 0.7537, Sensitivity: 0.8396, Specificity: 0.9774, False Alarm Ratio: 0.1195
#
#
# epoch duration : 1059.311232805252
# saving step
# epoch n° 57
#
# eval_opportunity_cost_spat, Regression Loss: 0.0350, Regression Loss 1h: 259.8967, Segmentation Loss:0.1254
# Train Confusion Matrix:
# [[3117919   79836]
#  [ 111302  530943]]
# Accuracy: 0.9502, CSI: 0.7353, Sensitivity: 0.8267, Specificity: 0.9750, False Alarm Ratio: 0.1307
#
#
# eval_added_value_full_spat, Regression Loss: 0.0320, Regression Loss 1h: 263.2850, Segmentation Loss:0.1173
# Train Confusion Matrix:
# [[3121476   76279]
#  [ 103864  538381]]
# Accuracy: 0.9531, CSI: 0.7493, Sensitivity: 0.8383, Specificity: 0.9761, False Alarm Ratio: 0.1241
#
#
# train, Regression Loss: 0.3134, Regression Loss 1h: 2676.3303, Segmentation Loss:1.1351
# Train Confusion Matrix:
# [[3127279   72981]
#  [ 102830  536910]]
# Accuracy: 0.9542, CSI: 0.7533, Sensitivity: 0.8393, Specificity: 0.9772, False Alarm Ratio: 0.1197
#
#
# epoch duration : 1052.6991345882416
# epoch n° 58
#
# eval_opportunity_cost_spat, Regression Loss: 0.0336, Regression Loss 1h: 261.2285, Segmentation Loss:0.1226
# Train Confusion Matrix:
# [[3118661   79075]
#  [ 107888  534376]]
# Accuracy: 0.9513, CSI: 0.7408, Sensitivity: 0.8320, Specificity: 0.9753, False Alarm Ratio: 0.1289
#
#
# eval_added_value_full_spat, Regression Loss: 0.0310, Regression Loss 1h: 261.8990, Segmentation Loss:0.1153
# Train Confusion Matrix:
# [[3120703   77033]
#  [ 100114  542150]]
# Accuracy: 0.9539, CSI: 0.7537, Sensitivity: 0.8441, Specificity: 0.9759, False Alarm Ratio: 0.1244
#
#
# train, Regression Loss: 0.3168, Regression Loss 1h: 2685.6066, Segmentation Loss:1.1394
# Train Confusion Matrix:
# [[3120007   74456]
#  [ 102167  543370]]
# Accuracy: 0.9540, CSI: 0.7547, Sensitivity: 0.8417, Specificity: 0.9767, False Alarm Ratio: 0.1205
#
#
# epoch duration : 1048.438137292862
# saving step
# epoch n° 59
#
# eval_opportunity_cost_spat, Regression Loss: 0.0337, Regression Loss 1h: 263.4449, Segmentation Loss:0.1206
# Train Confusion Matrix:
# [[3119450   78165]
#  [ 104939  537446]]
# Accuracy: 0.9523, CSI: 0.7459, Sensitivity: 0.8366, Specificity: 0.9756, False Alarm Ratio: 0.1270
#
#
# eval_added_value_full_spat, Regression Loss: 0.0307, Regression Loss 1h: 263.0188, Segmentation Loss:0.1131
# Train Confusion Matrix:
# [[3122783   74832]
#  [  98400  543985]]
# Accuracy: 0.9549, CSI: 0.7585, Sensitivity: 0.8468, Specificity: 0.9766, False Alarm Ratio: 0.1209
#
#
# train, Regression Loss: 0.3062, Regression Loss 1h: 2676.6333, Segmentation Loss:1.1260
# Train Confusion Matrix:
# [[3125776   72175]
#  [ 101472  540577]]
# Accuracy: 0.9548, CSI: 0.7569, Sensitivity: 0.8420, Specificity: 0.9774, False Alarm Ratio: 0.1178
#
#
# epoch duration : 1045.1087231636047
# epoch n° 60
#
# eval_opportunity_cost_spat, Regression Loss: 0.0328, Regression Loss 1h: 263.0845, Segmentation Loss:0.1244
# Train Confusion Matrix:
# [[3124551   78068]
#  [ 110724  526657]]
# Accuracy: 0.9508, CSI: 0.7361, Sensitivity: 0.8263, Specificity: 0.9756, False Alarm Ratio: 0.1291
#
#
# eval_added_value_full_spat, Regression Loss: 0.0301, Regression Loss 1h: 267.3653, Segmentation Loss:0.1165
# Train Confusion Matrix:
# [[3127287   75332]
#  [ 103537  533844]]
# Accuracy: 0.9534, CSI: 0.7490, Sensitivity: 0.8376, Specificity: 0.9765, False Alarm Ratio: 0.1237
#
#
# train, Regression Loss: 0.3028, Regression Loss 1h: 2665.3365, Segmentation Loss:1.1501
# Train Confusion Matrix:
# [[3126504   73428]
#  [ 105118  534950]]
# Accuracy: 0.9535, CSI: 0.7498, Sensitivity: 0.8358, Specificity: 0.9771, False Alarm Ratio: 0.1207
#
#
# epoch duration : 1040.7489776611328
# saving step
# epoch n° 61
#
# eval_opportunity_cost_spat, Regression Loss: 0.0342, Regression Loss 1h: 268.5083, Segmentation Loss:0.1254
# Train Confusion Matrix:
# [[3110987   82090]
#  [ 108849  538074]]
# Accuracy: 0.9503, CSI: 0.7381, Sensitivity: 0.8317, Specificity: 0.9743, False Alarm Ratio: 0.1324
#
#
# eval_added_value_full_spat, Regression Loss: 0.0312, Regression Loss 1h: 268.2865, Segmentation Loss:0.1165
# Train Confusion Matrix:
# [[3113804   79273]
#  [ 100023  546900]]
# Accuracy: 0.9533, CSI: 0.7531, Sensitivity: 0.8454, Specificity: 0.9752, False Alarm Ratio: 0.1266
#
#
# train, Regression Loss: 0.3108, Regression Loss 1h: 2725.4031, Segmentation Loss:1.1470
# Train Confusion Matrix:
# [[3113199   73359]
#  [ 103342  550100]]
# Accuracy: 0.9540, CSI: 0.7569, Sensitivity: 0.8418, Specificity: 0.9770, False Alarm Ratio: 0.1177
#
#
# epoch duration : 1042.5510835647583
# epoch n° 62
#
# eval_opportunity_cost_spat, Regression Loss: 0.0335, Regression Loss 1h: 266.4253, Segmentation Loss:0.1239
# Train Confusion Matrix:
# [[3116196   80525]
#  [ 109019  534260]]
# Accuracy: 0.9506, CSI: 0.7381, Sensitivity: 0.8305, Specificity: 0.9748, False Alarm Ratio: 0.1310
#
#
# eval_added_value_full_spat, Regression Loss: 0.0309, Regression Loss 1h: 269.9198, Segmentation Loss:0.1157
# Train Confusion Matrix:
# [[3119018   77703]
#  [ 101001  542278]]
# Accuracy: 0.9535, CSI: 0.7521, Sensitivity: 0.8430, Specificity: 0.9757, False Alarm Ratio: 0.1253
#
#
# train, Regression Loss: 0.3062, Regression Loss 1h: 2692.3927, Segmentation Loss:1.1491
# Train Confusion Matrix:
# [[3119937   73458]
#  [ 104867  541738]]
# Accuracy: 0.9536, CSI: 0.7523, Sensitivity: 0.8378, Specificity: 0.9770, False Alarm Ratio: 0.1194
#
#
# epoch duration : 1037.815599679947
# saving step
# epoch n° 63
#
# eval_opportunity_cost_spat, Regression Loss: 0.0331, Regression Loss 1h: 270.9871, Segmentation Loss:0.1228
# Train Confusion Matrix:
# [[3119623   77851]
#  [ 107735  534791]]
# Accuracy: 0.9517, CSI: 0.7424, Sensitivity: 0.8323, Specificity: 0.9757, False Alarm Ratio: 0.1271
#
#
# eval_added_value_full_spat, Regression Loss: 0.0303, Regression Loss 1h: 272.6438, Segmentation Loss:0.1142
# Train Confusion Matrix:
# [[3122643   74831]
#  [ 100124  542402]]
# Accuracy: 0.9544, CSI: 0.7561, Sensitivity: 0.8442, Specificity: 0.9766, False Alarm Ratio: 0.1212
#
#
# train, Regression Loss: 0.3011, Regression Loss 1h: 2751.1090, Segmentation Loss:1.1086
# Train Confusion Matrix:
# [[3128362   72603]
#  [  99899  539136]]
# Accuracy: 0.9551, CSI: 0.7576, Sensitivity: 0.8437, Specificity: 0.9773, False Alarm Ratio: 0.1187
#
#
# epoch duration : 1040.3191168308258
# epoch n° 64
#
# eval_opportunity_cost_spat, Regression Loss: 0.0328, Regression Loss 1h: 269.9457, Segmentation Loss:0.1215
# Train Confusion Matrix:
# [[3111690   79095]
#  [ 106455  542760]]
# Accuracy: 0.9517, CSI: 0.7452, Sensitivity: 0.8360, Specificity: 0.9752, False Alarm Ratio: 0.1272
#
#
# eval_added_value_full_spat, Regression Loss: 0.0300, Regression Loss 1h: 271.5511, Segmentation Loss:0.1141
# Train Confusion Matrix:
# [[3114684   76101]
#  [  99636  549579]]
# Accuracy: 0.9542, CSI: 0.7577, Sensitivity: 0.8465, Specificity: 0.9761, False Alarm Ratio: 0.1216
#
#
# train, Regression Loss: 0.3035, Regression Loss 1h: 2725.4874, Segmentation Loss:1.1161
# Train Confusion Matrix:
# [[3118869   71785]
#  [ 100737  548609]]
# Accuracy: 0.9551, CSI: 0.7608, Sensitivity: 0.8449, Specificity: 0.9775, False Alarm Ratio: 0.1157
#
#
# epoch duration : 1042.1970994472504
# saving step
# epoch n° 65
#
# eval_opportunity_cost_spat, Regression Loss: 0.0326, Regression Loss 1h: 271.6508, Segmentation Loss:0.1206
# Train Confusion Matrix:
# [[3122418   78447]
#  [ 106003  533132]]
# Accuracy: 0.9520, CSI: 0.7430, Sensitivity: 0.8341, Specificity: 0.9755, False Alarm Ratio: 0.1283
#
#
# eval_added_value_full_spat, Regression Loss: 0.0298, Regression Loss 1h: 275.6152, Segmentation Loss:0.1128
# Train Confusion Matrix:
# [[3125908   74957]
#  [  98778  540357]]
# Accuracy: 0.9548, CSI: 0.7567, Sensitivity: 0.8455, Specificity: 0.9766, False Alarm Ratio: 0.1218
#
#
# train, Regression Loss: 0.2918, Regression Loss 1h: 2770.0873, Segmentation Loss:1.1239
# Train Confusion Matrix:
# [[3124797   72856]
#  [ 102021  540326]]
# Accuracy: 0.9545, CSI: 0.7555, Sensitivity: 0.8412, Specificity: 0.9772, False Alarm Ratio: 0.1188
#
#
# epoch duration : 1041.9579193592072
# epoch n° 66
#
# eval_opportunity_cost_spat, Regression Loss: 0.0339, Regression Loss 1h: 266.0475, Segmentation Loss:0.1183
# Train Confusion Matrix:
# [[3120269   79625]
#  [ 101651  538455]]
# Accuracy: 0.9528, CSI: 0.7481, Sensitivity: 0.8412, Specificity: 0.9751, False Alarm Ratio: 0.1288
#
#
# eval_added_value_full_spat, Regression Loss: 0.0309, Regression Loss 1h: 268.8801, Segmentation Loss:0.1110
# Train Confusion Matrix:
# [[3123555   76339]
#  [  95081  545025]]
# Accuracy: 0.9554, CSI: 0.7607, Sensitivity: 0.8515, Specificity: 0.9761, False Alarm Ratio: 0.1229
#
#
# train, Regression Loss: 0.3146, Regression Loss 1h: 2744.8147, Segmentation Loss:1.0907
# Train Confusion Matrix:
# [[3120331   71630]
#  [  97271  550768]]
# Accuracy: 0.9560, CSI: 0.7653, Sensitivity: 0.8499, Specificity: 0.9776, False Alarm Ratio: 0.1151
#
#
# epoch duration : 1043.1724762916565
# saving step
# epoch n° 67
#
# eval_opportunity_cost_spat, Regression Loss: 0.0326, Regression Loss 1h: 276.8932, Segmentation Loss:0.1217
# Train Confusion Matrix:
# [[3110385   80775]
#  [ 105661  543179]]
# Accuracy: 0.9514, CSI: 0.7445, Sensitivity: 0.8372, Specificity: 0.9747, False Alarm Ratio: 0.1295
#
#
# eval_added_value_full_spat, Regression Loss: 0.0295, Regression Loss 1h: 281.3811, Segmentation Loss:0.1139
# Train Confusion Matrix:
# [[3114792   76368]
#  [  99178  549662]]
# Accuracy: 0.9543, CSI: 0.7579, Sensitivity: 0.8471, Specificity: 0.9761, False Alarm Ratio: 0.1220
#
#
# train, Regression Loss: 0.3003, Regression Loss 1h: 2816.3343, Segmentation Loss:1.1131
# Train Confusion Matrix:
# [[3119810   72711]
#  [ 100405  547074]]
# Accuracy: 0.9549, CSI: 0.7596, Sensitivity: 0.8449, Specificity: 0.9772, False Alarm Ratio: 0.1173
#
#
# epoch duration : 1041.8950436115265
# epoch n° 68
#
# eval_opportunity_cost_spat, Regression Loss: 0.0318, Regression Loss 1h: 271.8333, Segmentation Loss:0.1225
# Train Confusion Matrix:
# [[3117510   79664]
#  [ 106931  535895]]
# Accuracy: 0.9514, CSI: 0.7417, Sensitivity: 0.8337, Specificity: 0.9751, False Alarm Ratio: 0.1294
#
#
# eval_added_value_full_spat, Regression Loss: 0.0290, Regression Loss 1h: 276.7470, Segmentation Loss:0.1140
# Train Confusion Matrix:
# [[3121627   75547]
#  [  99720  543106]]
# Accuracy: 0.9544, CSI: 0.7560, Sensitivity: 0.8449, Specificity: 0.9764, False Alarm Ratio: 0.1221
#
#
# train, Regression Loss: 0.2861, Regression Loss 1h: 2801.2254, Segmentation Loss:1.1205
# Train Confusion Matrix:
# [[3123291   72046]
#  [ 101820  542843]]
# Accuracy: 0.9547, CSI: 0.7574, Sensitivity: 0.8421, Specificity: 0.9775, False Alarm Ratio: 0.1172
#
#
# epoch duration : 1040.7517728805542
# saving step
# epoch n° 69
#
# eval_opportunity_cost_spat, Regression Loss: 0.0346, Regression Loss 1h: 264.7695, Segmentation Loss:0.1200
# Train Confusion Matrix:
# [[3115533   79318]
#  [ 104020  541129]]
# Accuracy: 0.9523, CSI: 0.7469, Sensitivity: 0.8388, Specificity: 0.9752, False Alarm Ratio: 0.1278
#
#
# eval_added_value_full_spat, Regression Loss: 0.0315, Regression Loss 1h: 270.2103, Segmentation Loss:0.1126
# Train Confusion Matrix:
# [[3119339   75512]
#  [  98340  546809]]
# Accuracy: 0.9547, CSI: 0.7588, Sensitivity: 0.8476, Specificity: 0.9764, False Alarm Ratio: 0.1213
#
#
# train, Regression Loss: 0.3096, Regression Loss 1h: 2696.0660, Segmentation Loss:1.0969
# Train Confusion Matrix:
# [[3125808   70749]
#  [  98830  544613]]
# Accuracy: 0.9558, CSI: 0.7626, Sensitivity: 0.8464, Specificity: 0.9779, False Alarm Ratio: 0.1150
#
#
# epoch duration : 1046.4394762516022
# epoch n° 70
#
# eval_opportunity_cost_spat, Regression Loss: 0.0332, Regression Loss 1h: 273.6116, Segmentation Loss:0.1207
# Train Confusion Matrix:
# [[3119995   79101]
#  [ 105366  535538]]
# Accuracy: 0.9520, CSI: 0.7438, Sensitivity: 0.8356, Specificity: 0.9753, False Alarm Ratio: 0.1287
#
#
# eval_added_value_full_spat, Regression Loss: 0.0302, Regression Loss 1h: 275.3694, Segmentation Loss:0.1129
# Train Confusion Matrix:
# [[3124065   75031]
#  [  98820  542084]]
# Accuracy: 0.9547, CSI: 0.7572, Sensitivity: 0.8458, Specificity: 0.9765, False Alarm Ratio: 0.1216
#
#
# train, Regression Loss: 0.2991, Regression Loss 1h: 2796.3074, Segmentation Loss:1.1133
# Train Confusion Matrix:
# [[3126416   71942]
#  [ 100411  541231]]
# Accuracy: 0.9551, CSI: 0.7585, Sensitivity: 0.8435, Specificity: 0.9775, False Alarm Ratio: 0.1173
#
#
# epoch duration : 1040.169916152954
# saving step
# epoch n° 71

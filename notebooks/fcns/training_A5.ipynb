# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A5 radar + cmls -> rain gauges 1 min  [xrl_yg1]

# %%
# ! git clone https://github.com/nanopiero/fusion.git

# %%
import torch
import logging
logger = logging.getLogger("torch")
logger.setLevel(logging.ERROR)  # Show only errors, ignore warnings

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_A5_xrl_yg1.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
ch_in = 72
ch_out = nsteps 
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

# %%
import torch
import torch.nn as nn
from sklearn.metrics import confusion_matrix
class QPELoss_fcn_train_A5(nn.Module):

    def __init__(self, eval_qpe_1h = False, eval_independent_qpe_1h=False, eval_segments=False):
        super(QPELoss_fcn_train_A5, self).__init__()
        self.regression_loss = nn.MSELoss()
        self.segmentation_loss = nn.CrossEntropyLoss()
        self.eval_qpe_1h = eval_qpe_1h
        self.eval_independent_qpe_1h = eval_independent_qpe_1h
        self.eval_segments = eval_segments

    def forward(self, p, outputs, targets, sampled_values_and_filters=None):

      # sans supervision imparfaite, avec spatialisation
      bs, nsteps, S, _ = targets.shape
      targets = targets.view(bs, 1, nsteps, S**2)
      mask = (targets>=0)
      masked_targets = targets[mask]
      outputs_qpe = outputs[:, : , ...]\
                                .view(bs, 1, nsteps, S**2)

      masked_outputs_qpe = outputs_qpe[mask]
      masked_targets_qpe = masked_targets

      loss_rnr = 0.
      loss_qpe_1min = self.regression_loss(masked_outputs_qpe, masked_targets_qpe)
      loss = 1/(2*p[0]**2) * loss_qpe_1min 
      

      if self.eval_qpe_1h:
        loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])
        loss += 1/(2*p[2]**2) * loss_qpe_1h

      elif self.eval_independent_qpe_1h:
        outputs_qpe_1h = outputs[:, 3*nsteps, ...]\
                                .view(bs, 1, S**2)
          
        loss_qpe_1h = self.regression_loss(outputs_qpe_1h[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])   
        loss += 1/(2*p[2]**2) * loss_qpe_1h
      else:
        with torch.no_grad():
            loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                               targets.sum(dim=2)[mask[:, :, 0, ...]])
          
          
      if self.eval_segments:
          sampled_values, filters = sampled_values_and_filters
          #Pas très joli : on aurait aimé appler outputs_QPE, mais il a été applati
          filtered_outputs = outputs[:, 2*nsteps:3*nsteps , ...].unsqueeze(dim=2) * \
                             filters.unsqueeze(dim=1)
          sampled_pred_values = torch.sum(filtered_outputs,\
                            dim=(3,4))
          loss_segments = self.regression_loss(sampled_pred_values, sampled_values)
          loss += 1/(2*p[3]**2) * loss_segments
      else:
          loss_segments = 0.

      loss += torch.log(1 + p[0]**2 + self.eval_qpe_1h * p[2]**2 + self.eval_independent_qpe_1h * p[2]**2 + self.eval_segments * p[3]**2)
      cm = np.zeros((2, 2), dtype=int)
      return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr, loss, cm, loss_segments


class QPELoss_fcn_val_A5(nn.Module):

    def __init__(self, eval_qpe_1h = False, eval_independent_qpe_1h=False, eval_segments=False):
        super(QPELoss_fcn_val_A5, self).__init__()
        self.regression_loss = nn.MSELoss()
        self.segmentation_loss = nn.CrossEntropyLoss()
        self.eval_qpe_1h = eval_qpe_1h
        self.eval_independent_qpe_1h = eval_independent_qpe_1h
        self.eval_segments = eval_segments

    def forward(self, p, outputs, targets, sampled_values_and_filters=None):

      # sans supervision imparfaite, avec spatialisation
      bs, nsteps, S, _ = targets.shape
      targets = targets.view(bs, 1, nsteps, S**2)

      mask = (targets>=0)
      masked_targets = targets[mask]

      outputs_qpe = outputs[:, :, ...]\
                                .view(bs, 1, nsteps, S**2)
      masked_outputs_qpe = outputs_qpe[mask][masked_targets > 0]
      masked_targets_qpe = masked_targets[masked_targets > 0]

        
      loss_rnr = 0.
      loss_qpe_1min = self.regression_loss(masked_outputs_qpe, masked_targets_qpe)
      loss = 1/(2*p[0]**2) * loss_qpe_1min 
      

      if self.eval_qpe_1h:
        loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])
        loss += 1/(2*p[2]**2) * loss_qpe_1h

      elif self.eval_independent_qpe_1h:
        outputs_qpe_1h = outputs[:, 3*nsteps, ...]\
                                .view(bs, 1, S**2)
          
        loss_qpe_1h = self.regression_loss(outputs_qpe_1h[mask[:, :, 0, ...]],
                                           targets.sum(dim=2)[mask[:, :, 0, ...]])   
        loss += 1/(2*p[2]**2) * loss_qpe_1h
      else:
        with torch.no_grad():
            loss_qpe_1h = self.regression_loss(outputs_qpe.sum(dim=2)[mask[:, :, 0, ...]],
                                               targets.sum(dim=2)[mask[:, :, 0, ...]])
          
          
      if self.eval_segments:
          sampled_values, filters = sampled_values_and_filters
          #Pas très joli : on aurait aimé appler outputs_QPE, mais il a été applati
          filtered_outputs = outputs[:, 2*nsteps:3*nsteps , ...].unsqueeze(dim=2) * \
                             filters.unsqueeze(dim=1)
          sampled_pred_values = torch.sum(filtered_outputs,\
                            dim=(3,4))
          loss_segments = self.regression_loss(sampled_pred_values, sampled_values)
          loss += 1/(2*p[3]**2) * loss_segments
      else:
          loss_segments = 0.

      loss += torch.log(1 + p[0]**2 + self.eval_qpe_1h * p[2]**2 + self.eval_independent_qpe_1h * p[2]**2 + self.eval_segments * p[3]**2)
      cm = np.zeros((2, 2), dtype=int)
      return loss_qpe_1min.item(), loss_qpe_1h.item(), loss_rnr, loss, cm, loss_segments

# %%
criterion_train = QPELoss_fcn_train_A5()
criterion_val = QPELoss_fcn_val_A5()
# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
# Boucle avec 5 modes d'évaluation
val_steps = ['val'
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 0

# %%
import warnings
warnings.filterwarnings("ignore")
model.train()
for epoch in range(last_epoch, num_epochs + 1):
  print('epoch n°', epoch)
  t = time.time()
  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}
    
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn

    # phase val
    step = 'val'
    model.eval()
    with torch.no_grad():
        outputs = model(inputs)
        regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion_val(model.p, outputs, targets)
        
    del outputs, loss
    torch.cuda.empty_cache()
      
    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm
      
    # phase train
    step = 'train'
    model.train()
    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)  # Forward pass

    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion_train(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

      
    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()
    
    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm


  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step]))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)


  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 0
# epoch duration : 72.39930200576782
# saving step
# epoch n° 1
# val, Regression Loss: 2.1942, Regression Loss 1h: 843.1961, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0307, Regression Loss 1h: 15.4082, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.97777557373047
# epoch n° 2
# val, Regression Loss: 0.1154, Regression Loss 1h: 13.6391, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0252, Regression Loss 1h: 11.7686, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.48209595680237
# epoch n° 3
# val, Regression Loss: 0.1001, Regression Loss 1h: 10.3756, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 9.4672, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.75485968589783
# epoch n° 4
# val, Regression Loss: 0.0971, Regression Loss 1h: 9.6029, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 8.6280, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.52770948410034
# epoch n° 5
# val, Regression Loss: 0.0970, Regression Loss 1h: 9.9734, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0218, Regression Loss 1h: 8.9724, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.00513458251953
# epoch n° 6
# val, Regression Loss: 0.0890, Regression Loss 1h: 8.3104, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0208, Regression Loss 1h: 7.9220, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.91939425468445
# epoch n° 7
# val, Regression Loss: 0.0908, Regression Loss 1h: 8.1388, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0206, Regression Loss 1h: 7.4564, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.66451930999756
# epoch n° 8
# val, Regression Loss: 0.0867, Regression Loss 1h: 7.7864, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0201, Regression Loss 1h: 7.0735, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.45446014404297
# epoch n° 9
# val, Regression Loss: 0.0864, Regression Loss 1h: 7.3319, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0200, Regression Loss 1h: 7.2364, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.36582517623901
# epoch n° 10
# val, Regression Loss: 0.0837, Regression Loss 1h: 7.3873, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0198, Regression Loss 1h: 6.8925, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.48358988761902
# saving step
# epoch n° 11
# val, Regression Loss: 0.0852, Regression Loss 1h: 6.7140, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0195, Regression Loss 1h: 6.3352, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.71273875236511
# epoch n° 12
# val, Regression Loss: 0.0827, Regression Loss 1h: 7.3359, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0196, Regression Loss 1h: 7.0345, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.8725757598877
# epoch n° 13
# val, Regression Loss: 0.0827, Regression Loss 1h: 6.8951, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0192, Regression Loss 1h: 6.4432, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.80420112609863
# epoch n° 14
# val, Regression Loss: 0.0840, Regression Loss 1h: 7.3673, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0196, Regression Loss 1h: 6.6309, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.83511233329773
# epoch n° 15
# val, Regression Loss: 0.0835, Regression Loss 1h: 7.1815, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0194, Regression Loss 1h: 7.1481, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.72825264930725
# epoch n° 16
# val, Regression Loss: 0.0804, Regression Loss 1h: 7.3707, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0192, Regression Loss 1h: 6.5805, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.11365532875061
# epoch n° 17
# val, Regression Loss: 0.0787, Regression Loss 1h: 5.7030, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0188, Regression Loss 1h: 5.8766, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.11215209960938
# epoch n° 18
# val, Regression Loss: 0.0829, Regression Loss 1h: 6.8251, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0191, Regression Loss 1h: 6.3872, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 73.72941613197327
# epoch n° 19
# val, Regression Loss: 0.0792, Regression Loss 1h: 6.4793, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0188, Regression Loss 1h: 6.0608, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.3575873374939
# epoch n° 20
# val, Regression Loss: 0.0776, Regression Loss 1h: 6.1404, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0189, Regression Loss 1h: 6.2274, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.54960632324219
# saving step
# epoch n° 21
# val, Regression Loss: 0.0799, Regression Loss 1h: 6.1688, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0186, Regression Loss 1h: 6.0375, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 73.43489742279053
# epoch n° 22
# val, Regression Loss: 0.0778, Regression Loss 1h: 5.7700, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0185, Regression Loss 1h: 5.8260, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.39959526062012
# epoch n° 23
# val, Regression Loss: 0.0767, Regression Loss 1h: 5.9704, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0181, Regression Loss 1h: 5.5974, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.9238760471344
# epoch n° 24
# val, Regression Loss: 0.0791, Regression Loss 1h: 5.4246, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0185, Regression Loss 1h: 5.5316, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.63227891921997
# epoch n° 25
# val, Regression Loss: 0.0769, Regression Loss 1h: 5.9062, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0183, Regression Loss 1h: 5.7263, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.25693202018738
# epoch n° 26
# val, Regression Loss: 0.0782, Regression Loss 1h: 5.6696, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0183, Regression Loss 1h: 5.7767, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.0650429725647
# epoch n° 27
# val, Regression Loss: 0.0796, Regression Loss 1h: 6.0228, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0184, Regression Loss 1h: 5.6794, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 73.20453476905823
# epoch n° 28
# val, Regression Loss: 0.0782, Regression Loss 1h: 5.7771, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0182, Regression Loss 1h: 5.3755, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.68775057792664
# epoch n° 29
# val, Regression Loss: 0.0821, Regression Loss 1h: 6.6690, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0184, Regression Loss 1h: 5.9048, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.57587623596191
# epoch n° 30
# val, Regression Loss: 0.0781, Regression Loss 1h: 5.7852, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0179, Regression Loss 1h: 5.5271, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 70.52221250534058
# saving step
# epoch n° 31
# val, Regression Loss: 0.0766, Regression Loss 1h: 5.7133, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0179, Regression Loss 1h: 5.4272, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.5774974822998
# epoch n° 32
# val, Regression Loss: 0.0772, Regression Loss 1h: 5.2020, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0180, Regression Loss 1h: 5.0613, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 70.8205087184906
# epoch n° 33
# val, Regression Loss: 0.0761, Regression Loss 1h: 5.5686, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0180, Regression Loss 1h: 5.3845, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.08979368209839
# epoch n° 34
# val, Regression Loss: 0.0762, Regression Loss 1h: 5.3240, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0177, Regression Loss 1h: 5.1870, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.36936736106873
# epoch n° 35
# val, Regression Loss: 0.0763, Regression Loss 1h: 5.3181, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0178, Regression Loss 1h: 5.2584, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 70.18408632278442
# epoch n° 36
# val, Regression Loss: 0.0748, Regression Loss 1h: 5.3124, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0179, Regression Loss 1h: 5.1805, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 68.44308948516846
# epoch n° 37
# val, Regression Loss: 0.0752, Regression Loss 1h: 5.5032, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0177, Regression Loss 1h: 5.3219, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.92497038841248
# epoch n° 38
# val, Regression Loss: 0.0752, Regression Loss 1h: 5.2928, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0179, Regression Loss 1h: 5.2635, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.69763112068176
# epoch n° 39
# val, Regression Loss: 0.0763, Regression Loss 1h: 5.0314, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0177, Regression Loss 1h: 5.1345, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.10667252540588
# epoch n° 40
# val, Regression Loss: 0.0736, Regression Loss 1h: 5.1585, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0174, Regression Loss 1h: 5.0672, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.78432869911194
# saving step
# epoch n° 41
# val, Regression Loss: 0.0739, Regression Loss 1h: 5.4777, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0174, Regression Loss 1h: 5.3526, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.19085001945496
# epoch n° 42
# val, Regression Loss: 0.0776, Regression Loss 1h: 6.6053, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0180, Regression Loss 1h: 5.6355, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.27778339385986
# epoch n° 43
# val, Regression Loss: 0.0808, Regression Loss 1h: 6.3663, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0188, Regression Loss 1h: 6.2144, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.94145035743713
# epoch n° 44
# val, Regression Loss: 0.0786, Regression Loss 1h: 5.7508, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0179, Regression Loss 1h: 5.5617, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.8810076713562
# epoch n° 45
# val, Regression Loss: 0.0750, Regression Loss 1h: 5.3456, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0175, Regression Loss 1h: 5.0065, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.8284502029419
# epoch n° 46
# val, Regression Loss: 0.0750, Regression Loss 1h: 5.0852, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0176, Regression Loss 1h: 5.5277, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.31341433525085
# epoch n° 47
# val, Regression Loss: 0.0745, Regression Loss 1h: 5.1992, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0176, Regression Loss 1h: 5.0158, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 72.24867081642151
# epoch n° 48
# val, Regression Loss: 0.0733, Regression Loss 1h: 4.9697, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0172, Regression Loss 1h: 5.0787, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 73.3485221862793
# epoch n° 49
# val, Regression Loss: 0.0756, Regression Loss 1h: 5.2140, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0175, Regression Loss 1h: 5.2174, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.31952500343323
# epoch n° 50
# val, Regression Loss: 0.0728, Regression Loss 1h: 5.1389, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0173, Regression Loss 1h: 5.1745, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.48483538627625
# saving step
# epoch n° 51
# val, Regression Loss: 0.0735, Regression Loss 1h: 5.0986, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0173, Regression Loss 1h: 4.8581, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.3516616821289
# epoch n° 52
# val, Regression Loss: 0.0742, Regression Loss 1h: 5.0516, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0174, Regression Loss 1h: 5.0778, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.66886734962463
# epoch n° 53
# val, Regression Loss: 0.0721, Regression Loss 1h: 4.7029, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0171, Regression Loss 1h: 4.7282, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.95492839813232
# epoch n° 54
# val, Regression Loss: 0.0739, Regression Loss 1h: 5.2644, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0171, Regression Loss 1h: 5.0338, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.63713359832764
# epoch n° 55
# val, Regression Loss: 0.0717, Regression Loss 1h: 4.5810, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0168, Regression Loss 1h: 4.5509, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.92334985733032
# epoch n° 56
# val, Regression Loss: 0.0732, Regression Loss 1h: 4.6045, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0172, Regression Loss 1h: 4.6698, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.70614552497864
# epoch n° 57
# val, Regression Loss: 0.0729, Regression Loss 1h: 4.9124, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# train, Regression Loss: 0.0170, Regression Loss 1h: 4.7731, Segmentation Loss:0.0000
# Train Confusion Matrix:
# [[0 0]
#  [0 0]]
# Accuracy: nan, CSI: 0.0000, Sensitivity: 0.0000, Specificity: 0.0000, False Alarm Ratio: 0.0000
#
#
# epoch duration : 71.42637968063354
# epoch n° 58

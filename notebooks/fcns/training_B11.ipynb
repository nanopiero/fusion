# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_B11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## B1.1 radar + gauges 1 min + cmls -> gauges 1 min [xrlg1_yg1]

# %%
! git clone https://github.com/nanopiero/fusion.git

# %%
! pwd
# Out:
# /home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/notebooks/fcns

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Config
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_exp_B11_xrlg1_yg1.pt'
npairs = 20
nsteps = 60
ndiscs = 5
size_image=64
length_dataset = 6400
device = torch.device('cuda:0')

# Entraînement
npoints = 20
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=4)

# %%
# Tiny UNet V1. 60 new channels for input time series of rain gauges measurements
use_fcn = True
ch_in = 72 + 60
ch_out = nsteps * 3 + 1
size = nsteps * 3

model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn()

# %%
# Boucle avec 5 modes d'évaluation
val_steps = ['eval_opportunity_cost_spat',
             # 'eval_added_value_few_spat',
             # 'eval_added_value_half_spat',
             'eval_added_value_full_spat',
             # 'eval_added_value_full_id',
             ]
steps = val_steps + ['train']
losses = {step:[] for step in steps}
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)

# %%
last_epoch
# Out:
# 1480

# %%
model.train()

for epoch in range(last_epoch, num_epochs + 1):
  t = time.time()
  print('epoch n°', epoch, '\n')

  running_regression_loss = {step:0.0 for step in steps}
  running_regression_loss_1h = {step:0.0 for step in steps}
  running_segmentation_loss = {step:0.0 for step in steps}
  running_confusion_matrix = {step: np.zeros((2, 2), dtype=int) for step in steps}

  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo radar
    noisy_images = make_noisy_images(images)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    #Validation steps
    model.eval()
    with torch.no_grad():

      # splitting
      np_val_inputs_few = 1
      np_val_inputs_half = npoints//4  # 5
      np_val_inputs_comp = npoints//2 - np_val_inputs_half - np_val_inputs_few  # 4
      np_val_targets = npoints//2 # 10

      # val split
      split_val = [np_val_inputs_few, np_val_inputs_half, np_val_inputs_comp, np_val_targets]
      split_few, split_half, split_comp, split_targets = point_gt(images, npoints=npoints,
                                                                    use_fcn=use_fcn,
                                                                    split=split_val)
      _, point_measurements_fcn_eval_few, _ = split_few
      _, point_measurements_fcn_eval_half, _ = split_half
      _, point_measurements_fcn_eval_comp, _ = split_comp
      _, point_measurements_fcn_val_targets, _ = split_targets

      # 4 first val steps (10 last pluvios for testing generalization)
      targets = point_measurements_fcn_val_targets

      # val step 1 : eval_opportunity_cost_spat
      step = 'eval_opportunity_cost_spat'
      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          0 * point_measurements_fcn_eval_few - 0.1
                          ], dim=1)
      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      torch.cuda.empty_cache()

      # val step 2 : eval_added_value_few_spat
      # step = 'eval_added_value_few_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_few
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 3 : eval_added_value_half_spat
      # step = 'eval_added_value_half_spat'
      # inputs = torch.cat([noisy_images,
      #                     segment_measurements_fcn,
      #                     point_measurements_fcn_eval_half
      #                     ], dim=1)
      # outputs = model(inputs)
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, targets)
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del inputs, outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      # torch.cuda.empty_cache()

      # val step 4 : eval_added_value_full_spat
      step = 'eval_added_value_full_spat'

      point_measurements_fcn_eval_full = point_measurements_fcn_eval_few + \
                                          point_measurements_fcn_eval_half + \
                                          point_measurements_fcn_eval_comp

      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_few >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_half >= 0)
      point_measurements_fcn_eval_full += 2 * 0.1 * (point_measurements_fcn_eval_comp >= 0)

      point_measurements_fcn_eval_full[point_measurements_fcn_eval_full<0] = -0.1

      inputs = torch.cat([noisy_images,
                          segment_measurements_fcn,
                          point_measurements_fcn_eval_full
                          ], dim=1)

      outputs = model(inputs)
      regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
      running_regression_loss[step] += regression_loss
      running_regression_loss_1h[step] += regression_loss_1h
      running_segmentation_loss[step] += segmentation_loss
      running_confusion_matrix[step] += batch_cm

      del inputs, loss, regression_loss, regression_loss_1h, segmentation_loss, split_few, split_half, split_comp, split_targets
      torch.cuda.empty_cache()

      # last val step, on the 10 first pluvios : eval_added_value_full_id
      # step = 'eval_added_value_full_id'
      # regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm = criterion(model.p, outputs, point_measurements_fcn_eval_full) # inputs pluvios serve as targets
      # running_regression_loss[step] += regression_loss
      # running_regression_loss_1h[step] += regression_loss_1h
      # running_segmentation_loss[step] += segmentation_loss
      # running_confusion_matrix[step] += batch_cm

      # del outputs, loss, regression_loss, regression_loss_1h, segmentation_loss
      del point_measurements_fcn_eval_full
      torch.cuda.empty_cache()

    # train step
    model.train()
    step = 'train'
    np_train_inputs = torch.randint(0,9,(1,))
    np_train_targets = npoints // 2 - np_train_inputs
    split_train = [np_train_inputs, np_train_targets]


    # split  train
    split_inputs, split_targets = point_gt(images, npoints=npoints,
                                           use_fcn=use_fcn,
                                           split=split_train)

    _, point_measurements_fcn_train_inputs, _ = split_inputs
    _, point_measurements_fcn_train_targets, _ = split_targets

    inputs = torch.cat([noisy_images,
                        segment_measurements_fcn,
                        point_measurements_fcn_train_inputs
                        ], dim=1)
    targets = point_measurements_fcn_train_targets

    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)
    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)

    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    running_regression_loss[step] += regression_loss
    running_regression_loss_1h[step] += regression_loss_1h
    running_segmentation_loss[step] += segmentation_loss
    running_confusion_matrix[step] += batch_cm

    del split_inputs, inputs, outputs, split_targets, loss, regression_loss, regression_loss_1h, segmentation_loss, noisy_images, images, pairs, filters, segment_measurements_fcn
    torch.cuda.empty_cache()

  if epoch > 0:
    for step in steps:
      regression_loss = running_regression_loss[step] / len(loader)
      regression_loss_1h = running_regression_loss_1h[step] / len(loader)
      segmentation_loss = running_segmentation_loss[step] / len(loader)
      losses[step].append((epoch, regression_loss, regression_loss_1h, segmentation_loss, running_confusion_matrix[step]))

      print(f'{step}, Regression Loss: {regression_loss:.4f}, Regression Loss 1h: {regression_loss_1h:.4f}, Segmentation Loss:{segmentation_loss:.4f}' )
      print("Train Confusion Matrix:")
      print(running_confusion_matrix[step])
      accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(running_confusion_matrix[step])
      print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
      print('\n')
  print('epoch duration :', time.time() - t)

  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 1480
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 312.5298, Segmentation Loss:0.0832
# Train Confusion Matrix:
# [[3147964   55100]
#  [  70878  566058]]
# Accuracy: 0.9672, CSI: 0.8180, Sensitivity: 0.8887, Specificity: 0.9828, False Alarm Ratio: 0.0887
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 313.7808, Segmentation Loss:0.0771
# Train Confusion Matrix:
# [[3149613   53451]
#  [  64781  572155]]
# Accuracy: 0.9692, CSI: 0.8287, Sensitivity: 0.8983, Specificity: 0.9833, False Alarm Ratio: 0.0854
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 324.2335, Segmentation Loss:0.0779
# Train Confusion Matrix:
# [[1960818   31507]
#  [  43222  356773]]
# Accuracy: 0.9688, CSI: 0.8268, Sensitivity: 0.8919, Specificity: 0.9842, False Alarm Ratio: 0.0811
#
#
# epoch duration : 79.96184134483337
# saving step
# epoch n° 1481
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 301.9496, Segmentation Loss:0.0894
# Train Confusion Matrix:
# [[3151630   53263]
#  [  82125  552982]]
# Accuracy: 0.9647, CSI: 0.8033, Sensitivity: 0.8707, Specificity: 0.9834, False Alarm Ratio: 0.0879
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 305.5290, Segmentation Loss:0.0828
# Train Confusion Matrix:
# [[3153884   51009]
#  [  75730  559377]]
# Accuracy: 0.9670, CSI: 0.8153, Sensitivity: 0.8808, Specificity: 0.9841, False Alarm Ratio: 0.0836
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 325.6619, Segmentation Loss:0.0838
# Train Confusion Matrix:
# [[1930947   32163]
#  [  45742  341228]]
# Accuracy: 0.9669, CSI: 0.8141, Sensitivity: 0.8818, Specificity: 0.9836, False Alarm Ratio: 0.0861
#
#
# epoch duration : 83.73343968391418
# epoch n° 1482
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 304.8040, Segmentation Loss:0.0865
# Train Confusion Matrix:
# [[3149534   53832]
#  [  77157  559477]]
# Accuracy: 0.9659, CSI: 0.8103, Sensitivity: 0.8788, Specificity: 0.9832, False Alarm Ratio: 0.0878
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 313.9267, Segmentation Loss:0.0801
# Train Confusion Matrix:
# [[3151301   52065]
#  [  70529  566105]]
# Accuracy: 0.9681, CSI: 0.8220, Sensitivity: 0.8892, Specificity: 0.9837, False Alarm Ratio: 0.0842
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 323.3442, Segmentation Loss:0.0812
# Train Confusion Matrix:
# [[2061615   34540]
#  [  47583  367622]]
# Accuracy: 0.9673, CSI: 0.8174, Sensitivity: 0.8854, Specificity: 0.9835, False Alarm Ratio: 0.0859
#
#
# epoch duration : 84.89936828613281
# epoch n° 1483
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 300.9427, Segmentation Loss:0.0885
# Train Confusion Matrix:
# [[3145126   57353]
#  [  76421  561100]]
# Accuracy: 0.9652, CSI: 0.8075, Sensitivity: 0.8801, Specificity: 0.9821, False Alarm Ratio: 0.0927
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 319.7256, Segmentation Loss:0.0819
# Train Confusion Matrix:
# [[3148065   54414]
#  [  70915  566606]]
# Accuracy: 0.9674, CSI: 0.8189, Sensitivity: 0.8888, Specificity: 0.9830, False Alarm Ratio: 0.0876
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 330.4315, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[1856286   30735]
#  [  43440  331299]]
# Accuracy: 0.9672, CSI: 0.8171, Sensitivity: 0.8841, Specificity: 0.9837, False Alarm Ratio: 0.0849
#
#
# epoch duration : 84.95354104042053
# epoch n° 1484
#
# eval_opportunity_cost_spat, Regression Loss: 0.0249, Regression Loss 1h: 321.0488, Segmentation Loss:0.0868
# Train Confusion Matrix:
# [[3153890   54380]
#  [  76809  554921]]
# Accuracy: 0.9658, CSI: 0.8088, Sensitivity: 0.8784, Specificity: 0.9831, False Alarm Ratio: 0.0892
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 324.6139, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3156023   52247]
#  [  70562  561168]]
# Accuracy: 0.9680, CSI: 0.8204, Sensitivity: 0.8883, Specificity: 0.9837, False Alarm Ratio: 0.0852
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 340.3151, Segmentation Loss:0.0828
# Train Confusion Matrix:
# [[1794558   30017]
#  [  41842  322383]]
# Accuracy: 0.9672, CSI: 0.8177, Sensitivity: 0.8851, Specificity: 0.9835, False Alarm Ratio: 0.0852
#
#
# epoch duration : 82.73036336898804
# epoch n° 1485
#
# eval_opportunity_cost_spat, Regression Loss: 0.0255, Regression Loss 1h: 343.1513, Segmentation Loss:0.0876
# Train Confusion Matrix:
# [[3147922   54401]
#  [  76806  560871]]
# Accuracy: 0.9658, CSI: 0.8104, Sensitivity: 0.8796, Specificity: 0.9830, False Alarm Ratio: 0.0884
#
#
# eval_added_value_full_spat, Regression Loss: 0.0229, Regression Loss 1h: 368.5676, Segmentation Loss:0.0809
# Train Confusion Matrix:
# [[3151374   50949]
#  [  71631  566046]]
# Accuracy: 0.9681, CSI: 0.8220, Sensitivity: 0.8877, Specificity: 0.9841, False Alarm Ratio: 0.0826
#
#
# train, Regression Loss: 0.0235, Regression Loss 1h: 329.9282, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[1855069   30258]
#  [  42542  333891]]
# Accuracy: 0.9678, CSI: 0.8210, Sensitivity: 0.8870, Specificity: 0.9840, False Alarm Ratio: 0.0831
#
#
# epoch duration : 83.3678457736969
# epoch n° 1486
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 308.0272, Segmentation Loss:0.0854
# Train Confusion Matrix:
# [[3152148   54305]
#  [  75046  558501]]
# Accuracy: 0.9663, CSI: 0.8119, Sensitivity: 0.8815, Specificity: 0.9831, False Alarm Ratio: 0.0886
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 318.8759, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[3154783   51670]
#  [  69442  564105]]
# Accuracy: 0.9685, CSI: 0.8233, Sensitivity: 0.8904, Specificity: 0.9839, False Alarm Ratio: 0.0839
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 322.1290, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[1972029   32038]
#  [  43671  352262]]
# Accuracy: 0.9685, CSI: 0.8231, Sensitivity: 0.8897, Specificity: 0.9840, False Alarm Ratio: 0.0834
#
#
# epoch duration : 84.3589038848877
# epoch n° 1487
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 301.9353, Segmentation Loss:0.0877
# Train Confusion Matrix:
# [[3138092   54165]
#  [  78064  569679]]
# Accuracy: 0.9656, CSI: 0.8116, Sensitivity: 0.8795, Specificity: 0.9830, False Alarm Ratio: 0.0868
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 309.8429, Segmentation Loss:0.0812
# Train Confusion Matrix:
# [[3140160   52097]
#  [  71922  575821]]
# Accuracy: 0.9677, CSI: 0.8228, Sensitivity: 0.8890, Specificity: 0.9837, False Alarm Ratio: 0.0830
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 327.6362, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[1813277   29954]
#  [  41758  330691]]
# Accuracy: 0.9676, CSI: 0.8218, Sensitivity: 0.8879, Specificity: 0.9837, False Alarm Ratio: 0.0831
#
#
# epoch duration : 84.40958642959595
# epoch n° 1488
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 299.1081, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3142465   52263]
#  [  79294  565978]]
# Accuracy: 0.9657, CSI: 0.8114, Sensitivity: 0.8771, Specificity: 0.9836, False Alarm Ratio: 0.0845
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 310.1157, Segmentation Loss:0.0803
# Train Confusion Matrix:
# [[3143534   51194]
#  [  71517  573755]]
# Accuracy: 0.9680, CSI: 0.8238, Sensitivity: 0.8892, Specificity: 0.9840, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 328.6028, Segmentation Loss:0.0818
# Train Confusion Matrix:
# [[1896487   31528]
#  [  43375  347970]]
# Accuracy: 0.9677, CSI: 0.8229, Sensitivity: 0.8892, Specificity: 0.9836, False Alarm Ratio: 0.0831
#
#
# epoch duration : 84.44220280647278
# epoch n° 1489
#
# eval_opportunity_cost_spat, Regression Loss: 0.0249, Regression Loss 1h: 302.8810, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3141817   54298]
#  [  75526  568359]]
# Accuracy: 0.9662, CSI: 0.8141, Sensitivity: 0.8827, Specificity: 0.9830, False Alarm Ratio: 0.0872
#
#
# eval_added_value_full_spat, Regression Loss: 0.0227, Regression Loss 1h: 313.6941, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[3144097   52018]
#  [  69596  574289]]
# Accuracy: 0.9683, CSI: 0.8252, Sensitivity: 0.8919, Specificity: 0.9837, False Alarm Ratio: 0.0831
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 327.2434, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[2015975   33185]
#  [  46216  369904]]
# Accuracy: 0.9678, CSI: 0.8233, Sensitivity: 0.8889, Specificity: 0.9838, False Alarm Ratio: 0.0823
#
#
# epoch duration : 84.39180254936218
# epoch n° 1490
#
# eval_opportunity_cost_spat, Regression Loss: 0.0248, Regression Loss 1h: 312.6381, Segmentation Loss:0.0871
# Train Confusion Matrix:
# [[3149237   52995]
#  [  79096  558672]]
# Accuracy: 0.9656, CSI: 0.8088, Sensitivity: 0.8760, Specificity: 0.9835, False Alarm Ratio: 0.0866
#
#
# eval_added_value_full_spat, Regression Loss: 0.0225, Regression Loss 1h: 334.8390, Segmentation Loss:0.0806
# Train Confusion Matrix:
# [[3153305   48927]
#  [  74605  563163]]
# Accuracy: 0.9678, CSI: 0.8201, Sensitivity: 0.8830, Specificity: 0.9847, False Alarm Ratio: 0.0799
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 314.4337, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[2013275   32811]
#  [  45684  358150]]
# Accuracy: 0.9680, CSI: 0.8202, Sensitivity: 0.8869, Specificity: 0.9840, False Alarm Ratio: 0.0839
#
#
# epoch duration : 85.44224953651428
# saving step
# epoch n° 1491
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 297.8599, Segmentation Loss:0.0868
# Train Confusion Matrix:
# [[3142015   54825]
#  [  76521  566639]]
# Accuracy: 0.9658, CSI: 0.8118, Sensitivity: 0.8810, Specificity: 0.9829, False Alarm Ratio: 0.0882
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 304.5478, Segmentation Loss:0.0802
# Train Confusion Matrix:
# [[3143557   53283]
#  [  69537  573623]]
# Accuracy: 0.9680, CSI: 0.8236, Sensitivity: 0.8919, Specificity: 0.9833, False Alarm Ratio: 0.0850
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 322.2858, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[1814418   29824]
#  [  41194  330244]]
# Accuracy: 0.9679, CSI: 0.8230, Sensitivity: 0.8891, Specificity: 0.9838, False Alarm Ratio: 0.0828
#
#
# epoch duration : 83.2067506313324
# epoch n° 1492
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 299.0667, Segmentation Loss:0.0864
# Train Confusion Matrix:
# [[3143880   53842]
#  [  76640  565638]]
# Accuracy: 0.9660, CSI: 0.8126, Sensitivity: 0.8807, Specificity: 0.9832, False Alarm Ratio: 0.0869
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 322.6959, Segmentation Loss:0.0798
# Train Confusion Matrix:
# [[3146998   50724]
#  [  71022  571256]]
# Accuracy: 0.9683, CSI: 0.8243, Sensitivity: 0.8894, Specificity: 0.9841, False Alarm Ratio: 0.0816
#
#
# train, Regression Loss: 0.0235, Regression Loss 1h: 316.6879, Segmentation Loss:0.0811
# Train Confusion Matrix:
# [[2002346   33047]
#  [  46053  364634]]
# Accuracy: 0.9677, CSI: 0.8217, Sensitivity: 0.8879, Specificity: 0.9838, False Alarm Ratio: 0.0831
#
#
# epoch duration : 83.17223048210144
# epoch n° 1493
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 341.2308, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3146481   53512]
#  [  77926  562081]]
# Accuracy: 0.9658, CSI: 0.8105, Sensitivity: 0.8782, Specificity: 0.9833, False Alarm Ratio: 0.0869
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 375.1518, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3148572   51421]
#  [  71240  568767]]
# Accuracy: 0.9681, CSI: 0.8226, Sensitivity: 0.8887, Specificity: 0.9839, False Alarm Ratio: 0.0829
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 322.5453, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[1999977   32951]
#  [  46607  355025]]
# Accuracy: 0.9673, CSI: 0.8169, Sensitivity: 0.8840, Specificity: 0.9838, False Alarm Ratio: 0.0849
#
#
# epoch duration : 84.45086145401001
# epoch n° 1494
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 289.6920, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3147688   52813]
#  [  79019  560480]]
# Accuracy: 0.9657, CSI: 0.8096, Sensitivity: 0.8764, Specificity: 0.9835, False Alarm Ratio: 0.0861
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 308.8172, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[3150868   49633]
#  [  73282  566217]]
# Accuracy: 0.9680, CSI: 0.8216, Sensitivity: 0.8854, Specificity: 0.9845, False Alarm Ratio: 0.0806
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 330.9357, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[1836124   30082]
#  [  43102  329412]]
# Accuracy: 0.9673, CSI: 0.8182, Sensitivity: 0.8843, Specificity: 0.9839, False Alarm Ratio: 0.0837
#
#
# epoch duration : 84.80352258682251
# epoch n° 1495
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 315.1140, Segmentation Loss:0.0855
# Train Confusion Matrix:
# [[3144271   54118]
#  [  75172  566439]]
# Accuracy: 0.9663, CSI: 0.8142, Sensitivity: 0.8828, Specificity: 0.9831, False Alarm Ratio: 0.0872
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 326.2138, Segmentation Loss:0.0791
# Train Confusion Matrix:
# [[3147497   50892]
#  [  69908  571703]]
# Accuracy: 0.9685, CSI: 0.8256, Sensitivity: 0.8910, Specificity: 0.9841, False Alarm Ratio: 0.0817
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 336.2452, Segmentation Loss:0.0802
# Train Confusion Matrix:
# [[1992059   32847]
#  [  45582  360232]]
# Accuracy: 0.9677, CSI: 0.8212, Sensitivity: 0.8877, Specificity: 0.9838, False Alarm Ratio: 0.0836
#
#
# epoch duration : 84.06546068191528
# epoch n° 1496
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 335.8176, Segmentation Loss:0.0881
# Train Confusion Matrix:
# [[3145764   53526]
#  [  79336  561374]]
# Accuracy: 0.9654, CSI: 0.8086, Sensitivity: 0.8762, Specificity: 0.9833, False Alarm Ratio: 0.0870
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 351.5684, Segmentation Loss:0.0813
# Train Confusion Matrix:
# [[3147714   51576]
#  [  72497  568213]]
# Accuracy: 0.9677, CSI: 0.8208, Sensitivity: 0.8868, Specificity: 0.9839, False Alarm Ratio: 0.0832
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 331.3693, Segmentation Loss:0.0825
# Train Confusion Matrix:
# [[1917739   31875]
#  [  44672  340434]]
# Accuracy: 0.9672, CSI: 0.8164, Sensitivity: 0.8840, Specificity: 0.9837, False Alarm Ratio: 0.0856
#
#
# epoch duration : 83.50215721130371
# epoch n° 1497
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 288.2085, Segmentation Loss:0.0899
# Train Confusion Matrix:
# [[3151723   51450]
#  [  83548  553279]]
# Accuracy: 0.9648, CSI: 0.8039, Sensitivity: 0.8688, Specificity: 0.9839, False Alarm Ratio: 0.0851
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 302.1765, Segmentation Loss:0.0825
# Train Confusion Matrix:
# [[3155044   48129]
#  [  77212  559615]]
# Accuracy: 0.9674, CSI: 0.8170, Sensitivity: 0.8788, Specificity: 0.9850, False Alarm Ratio: 0.0792
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 336.1812, Segmentation Loss:0.0837
# Train Confusion Matrix:
# [[1825954   30417]
#  [  44493  326336]]
# Accuracy: 0.9664, CSI: 0.8133, Sensitivity: 0.8800, Specificity: 0.9836, False Alarm Ratio: 0.0853
#
#
# epoch duration : 83.4851062297821
# epoch n° 1498
#
# eval_opportunity_cost_spat, Regression Loss: 0.0250, Regression Loss 1h: 316.1383, Segmentation Loss:0.0841
# Train Confusion Matrix:
# [[3141102   53474]
#  [  74220  571204]]
# Accuracy: 0.9667, CSI: 0.8173, Sensitivity: 0.8850, Specificity: 0.9833, False Alarm Ratio: 0.0856
#
#
# eval_added_value_full_spat, Regression Loss: 0.0228, Regression Loss 1h: 331.8277, Segmentation Loss:0.0785
# Train Confusion Matrix:
# [[3143506   51070]
#  [  68914  576510]]
# Accuracy: 0.9688, CSI: 0.8277, Sensitivity: 0.8932, Specificity: 0.9840, False Alarm Ratio: 0.0814
#
#
# train, Regression Loss: 0.0235, Regression Loss 1h: 330.6553, Segmentation Loss:0.0789
# Train Confusion Matrix:
# [[1928930   31447]
#  [  42986  350557]]
# Accuracy: 0.9684, CSI: 0.8249, Sensitivity: 0.8908, Specificity: 0.9840, False Alarm Ratio: 0.0823
#
#
# epoch duration : 83.48839497566223
# epoch n° 1499
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 341.2602, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3144888   54810]
#  [  76699  563603]]
# Accuracy: 0.9658, CSI: 0.8108, Sensitivity: 0.8802, Specificity: 0.9829, False Alarm Ratio: 0.0886
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 355.6761, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3147902   51796]
#  [  70953  569349]]
# Accuracy: 0.9680, CSI: 0.8226, Sensitivity: 0.8892, Specificity: 0.9838, False Alarm Ratio: 0.0834
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 335.4287, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[1788138   29520]
#  [  41141  326161]]
# Accuracy: 0.9677, CSI: 0.8219, Sensitivity: 0.8880, Specificity: 0.9838, False Alarm Ratio: 0.0830
#
#
# epoch duration : 84.73833799362183
# epoch n° 1500
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 317.6991, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3151179   53900]
#  [  76972  557949]]
# Accuracy: 0.9659, CSI: 0.8100, Sensitivity: 0.8788, Specificity: 0.9832, False Alarm Ratio: 0.0881
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 330.1285, Segmentation Loss:0.0803
# Train Confusion Matrix:
# [[3153619   51460]
#  [  70648  564273]]
# Accuracy: 0.9682, CSI: 0.8221, Sensitivity: 0.8887, Specificity: 0.9839, False Alarm Ratio: 0.0836
#
#
# train, Regression Loss: 0.0225, Regression Loss 1h: 336.0994, Segmentation Loss:0.0810
# Train Confusion Matrix:
# [[1951685   32610]
#  [  45030  355315]]
# Accuracy: 0.9674, CSI: 0.8207, Sensitivity: 0.8875, Specificity: 0.9836, False Alarm Ratio: 0.0841
#
#
# epoch duration : 84.089430809021
# saving step
# epoch n° 1501
#
# eval_opportunity_cost_spat, Regression Loss: 0.0251, Regression Loss 1h: 315.4108, Segmentation Loss:0.0878
# Train Confusion Matrix:
# [[3126224   55018]
#  [  77681  581077]]
# Accuracy: 0.9654, CSI: 0.8141, Sensitivity: 0.8821, Specificity: 0.9827, False Alarm Ratio: 0.0865
#
#
# eval_added_value_full_spat, Regression Loss: 0.0228, Regression Loss 1h: 328.3974, Segmentation Loss:0.0813
# Train Confusion Matrix:
# [[3129486   51756]
#  [  72087  586671]]
# Accuracy: 0.9677, CSI: 0.8257, Sensitivity: 0.8906, Specificity: 0.9837, False Alarm Ratio: 0.0811
#
#
# train, Regression Loss: 0.0236, Regression Loss 1h: 318.0959, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[1741228   29440]
#  [  40266  327946]]
# Accuracy: 0.9674, CSI: 0.8247, Sensitivity: 0.8906, Specificity: 0.9834, False Alarm Ratio: 0.0824
#
#
# epoch duration : 83.77732467651367
# epoch n° 1502
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 294.6785, Segmentation Loss:0.0859
# Train Confusion Matrix:
# [[3143996   53629]
#  [  76819  565556]]
# Accuracy: 0.9660, CSI: 0.8126, Sensitivity: 0.8804, Specificity: 0.9832, False Alarm Ratio: 0.0866
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 306.0647, Segmentation Loss:0.0792
# Train Confusion Matrix:
# [[3147106   50519]
#  [  71262  571113]]
# Accuracy: 0.9683, CSI: 0.8242, Sensitivity: 0.8891, Specificity: 0.9842, False Alarm Ratio: 0.0813
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 327.5497, Segmentation Loss:0.0802
# Train Confusion Matrix:
# [[1813151   29825]
#  [  41008  324016]]
# Accuracy: 0.9679, CSI: 0.8206, Sensitivity: 0.8877, Specificity: 0.9838, False Alarm Ratio: 0.0843
#
#
# epoch duration : 85.02345418930054
# epoch n° 1503
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 313.9543, Segmentation Loss:0.0883
# Train Confusion Matrix:
# [[3137736   52598]
#  [  80235  569431]]
# Accuracy: 0.9654, CSI: 0.8109, Sensitivity: 0.8765, Specificity: 0.9835, False Alarm Ratio: 0.0846
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 314.6541, Segmentation Loss:0.0815
# Train Confusion Matrix:
# [[3139335   50999]
#  [  73142  576524]]
# Accuracy: 0.9677, CSI: 0.8228, Sensitivity: 0.8874, Specificity: 0.9840, False Alarm Ratio: 0.0813
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 312.4949, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[1965391   32933]
#  [  45754  359762]]
# Accuracy: 0.9673, CSI: 0.8205, Sensitivity: 0.8872, Specificity: 0.9835, False Alarm Ratio: 0.0839
#
#
# epoch duration : 83.26768851280212
# epoch n° 1504
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 308.6778, Segmentation Loss:0.0864
# Train Confusion Matrix:
# [[3152343   52774]
#  [  77475  557408]]
# Accuracy: 0.9661, CSI: 0.8106, Sensitivity: 0.8780, Specificity: 0.9835, False Alarm Ratio: 0.0865
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 320.1643, Segmentation Loss:0.0800
# Train Confusion Matrix:
# [[3155991   49126]
#  [  72663  562220]]
# Accuracy: 0.9683, CSI: 0.8219, Sensitivity: 0.8855, Specificity: 0.9847, False Alarm Ratio: 0.0804
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 316.6314, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[1903337   31040]
#  [  43484  337659]]
# Accuracy: 0.9678, CSI: 0.8192, Sensitivity: 0.8859, Specificity: 0.9840, False Alarm Ratio: 0.0842
#
#
# epoch duration : 83.46916937828064
# epoch n° 1505
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 318.9107, Segmentation Loss:0.0865
# Train Confusion Matrix:
# [[3147283   54983]
#  [  75728  562006]]
# Accuracy: 0.9660, CSI: 0.8113, Sensitivity: 0.8813, Specificity: 0.9828, False Alarm Ratio: 0.0891
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 333.4050, Segmentation Loss:0.0801
# Train Confusion Matrix:
# [[3150530   51736]
#  [  70611  567123]]
# Accuracy: 0.9681, CSI: 0.8225, Sensitivity: 0.8893, Specificity: 0.9838, False Alarm Ratio: 0.0836
#
#
# train, Regression Loss: 0.0228, Regression Loss 1h: 346.8002, Segmentation Loss:0.0813
# Train Confusion Matrix:
# [[1856338   30359]
#  [  43295  327928]]
# Accuracy: 0.9674, CSI: 0.8166, Sensitivity: 0.8834, Specificity: 0.9839, False Alarm Ratio: 0.0847
#
#
# epoch duration : 83.49060297012329
# epoch n° 1506
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 298.9247, Segmentation Loss:0.0858
# Train Confusion Matrix:
# [[3139425   55390]
#  [  74269  570916]]
# Accuracy: 0.9662, CSI: 0.8149, Sensitivity: 0.8849, Specificity: 0.9827, False Alarm Ratio: 0.0884
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 311.0276, Segmentation Loss:0.0796
# Train Confusion Matrix:
# [[3142303   52512]
#  [  69146  576039]]
# Accuracy: 0.9683, CSI: 0.8256, Sensitivity: 0.8928, Specificity: 0.9836, False Alarm Ratio: 0.0835
#
#
# train, Regression Loss: 0.0233, Regression Loss 1h: 323.2794, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[1834726   30594]
#  [  42383  334857]]
# Accuracy: 0.9675, CSI: 0.8211, Sensitivity: 0.8876, Specificity: 0.9836, False Alarm Ratio: 0.0837
#
#
# epoch duration : 84.58685612678528
# epoch n° 1507
#
# eval_opportunity_cost_spat, Regression Loss: 0.0242, Regression Loss 1h: 285.7084, Segmentation Loss:0.0873
# Train Confusion Matrix:
# [[3144443   53147]
#  [  78288  564122]]
# Accuracy: 0.9658, CSI: 0.8110, Sensitivity: 0.8781, Specificity: 0.9834, False Alarm Ratio: 0.0861
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 302.3092, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3147494   50096]
#  [  72865  569545]]
# Accuracy: 0.9680, CSI: 0.8224, Sensitivity: 0.8866, Specificity: 0.9843, False Alarm Ratio: 0.0808
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 318.9311, Segmentation Loss:0.0814
# Train Confusion Matrix:
# [[1847741   30759]
#  [  42175  337245]]
# Accuracy: 0.9677, CSI: 0.8222, Sensitivity: 0.8888, Specificity: 0.9836, False Alarm Ratio: 0.0836
#
#
# epoch duration : 82.8711884021759
# epoch n° 1508
#
# eval_opportunity_cost_spat, Regression Loss: 0.0252, Regression Loss 1h: 354.5676, Segmentation Loss:0.0889
# Train Confusion Matrix:
# [[3130598   52527]
#  [  81162  575713]]
# Accuracy: 0.9652, CSI: 0.8115, Sensitivity: 0.8764, Specificity: 0.9835, False Alarm Ratio: 0.0836
#
#
# eval_added_value_full_spat, Regression Loss: 0.0229, Regression Loss 1h: 364.7391, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[3133115   50010]
#  [  74900  581975]]
# Accuracy: 0.9675, CSI: 0.8233, Sensitivity: 0.8860, Specificity: 0.9843, False Alarm Ratio: 0.0791
#
#
# train, Regression Loss: 0.0238, Regression Loss 1h: 335.5281, Segmentation Loss:0.0828
# Train Confusion Matrix:
# [[2048538   33693]
#  [  48557  376732]]
# Accuracy: 0.9672, CSI: 0.8208, Sensitivity: 0.8858, Specificity: 0.9838, False Alarm Ratio: 0.0821
#
#
# epoch duration : 84.52343535423279
# epoch n° 1509
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 308.7459, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3148211   54172]
#  [  76010  561607]]
# Accuracy: 0.9661, CSI: 0.8118, Sensitivity: 0.8808, Specificity: 0.9831, False Alarm Ratio: 0.0880
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 316.5061, Segmentation Loss:0.0791
# Train Confusion Matrix:
# [[3150335   52048]
#  [  69308  568309]]
# Accuracy: 0.9684, CSI: 0.8240, Sensitivity: 0.8913, Specificity: 0.9837, False Alarm Ratio: 0.0839
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 333.8020, Segmentation Loss:0.0794
# Train Confusion Matrix:
# [[1868164   30416]
#  [  42122  336418]]
# Accuracy: 0.9681, CSI: 0.8226, Sensitivity: 0.8887, Specificity: 0.9840, False Alarm Ratio: 0.0829
#
#
# epoch duration : 85.0317873954773
# epoch n° 1510
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 286.5903, Segmentation Loss:0.0881
# Train Confusion Matrix:
# [[3141899   56758]
#  [  76205  565138]]
# Accuracy: 0.9654, CSI: 0.8095, Sensitivity: 0.8812, Specificity: 0.9823, False Alarm Ratio: 0.0913
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 301.0765, Segmentation Loss:0.0814
# Train Confusion Matrix:
# [[3145798   52859]
#  [  71070  570273]]
# Accuracy: 0.9677, CSI: 0.8215, Sensitivity: 0.8892, Specificity: 0.9835, False Alarm Ratio: 0.0848
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 312.2508, Segmentation Loss:0.0822
# Train Confusion Matrix:
# [[1877679   30785]
#  [  44086  336090]]
# Accuracy: 0.9673, CSI: 0.8178, Sensitivity: 0.8840, Specificity: 0.9839, False Alarm Ratio: 0.0839
#
#
# epoch duration : 84.51772785186768
# saving step
# epoch n° 1511
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 291.2580, Segmentation Loss:0.0901
# Train Confusion Matrix:
# [[3146319   51976]
#  [  84262  557443]]
# Accuracy: 0.9645, CSI: 0.8036, Sensitivity: 0.8687, Specificity: 0.9837, False Alarm Ratio: 0.0853
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 308.2918, Segmentation Loss:0.0828
# Train Confusion Matrix:
# [[3148549   49746]
#  [  76653  565052]]
# Accuracy: 0.9671, CSI: 0.8172, Sensitivity: 0.8805, Specificity: 0.9844, False Alarm Ratio: 0.0809
#
#
# train, Regression Loss: 0.0221, Regression Loss 1h: 307.3409, Segmentation Loss:0.0830
# Train Confusion Matrix:
# [[1975950   33170]
#  [  46976  355424]]
# Accuracy: 0.9668, CSI: 0.8160, Sensitivity: 0.8833, Specificity: 0.9835, False Alarm Ratio: 0.0854
#
#
# epoch duration : 83.41217637062073
# epoch n° 1512
#
# eval_opportunity_cost_spat, Regression Loss: 0.0247, Regression Loss 1h: 294.9731, Segmentation Loss:0.0880
# Train Confusion Matrix:
# [[3132274   57043]
#  [  76430  574253]]
# Accuracy: 0.9652, CSI: 0.8114, Sensitivity: 0.8825, Specificity: 0.9821, False Alarm Ratio: 0.0904
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 306.5020, Segmentation Loss:0.0814
# Train Confusion Matrix:
# [[3135427   53890]
#  [  70712  579971]]
# Accuracy: 0.9676, CSI: 0.8232, Sensitivity: 0.8913, Specificity: 0.9831, False Alarm Ratio: 0.0850
#
#
# train, Regression Loss: 0.0228, Regression Loss 1h: 301.2960, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[1938881   32145]
#  [  44269  353985]]
# Accuracy: 0.9677, CSI: 0.8225, Sensitivity: 0.8888, Specificity: 0.9837, False Alarm Ratio: 0.0832
#
#
# epoch duration : 84.05284810066223
# epoch n° 1513
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 290.9998, Segmentation Loss:0.0872
# Train Confusion Matrix:
# [[3146155   54079]
#  [  78409  561357]]
# Accuracy: 0.9655, CSI: 0.8091, Sensitivity: 0.8774, Specificity: 0.9831, False Alarm Ratio: 0.0879
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 300.9367, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[3148953   51281]
#  [  72360  567406]]
# Accuracy: 0.9678, CSI: 0.8211, Sensitivity: 0.8869, Specificity: 0.9840, False Alarm Ratio: 0.0829
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 314.3884, Segmentation Loss:0.0819
# Train Confusion Matrix:
# [[1897609   31278]
#  [  44809  341824]]
# Accuracy: 0.9671, CSI: 0.8179, Sensitivity: 0.8841, Specificity: 0.9838, False Alarm Ratio: 0.0838
#
#
# epoch duration : 83.84952807426453
# epoch n° 1514
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 309.9185, Segmentation Loss:0.0875
# Train Confusion Matrix:
# [[3145298   53721]
#  [  78555  562426]]
# Accuracy: 0.9656, CSI: 0.8096, Sensitivity: 0.8774, Specificity: 0.9832, False Alarm Ratio: 0.0872
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 312.3991, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3148102   50917]
#  [  72120  568861]]
# Accuracy: 0.9680, CSI: 0.8222, Sensitivity: 0.8875, Specificity: 0.9841, False Alarm Ratio: 0.0822
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 319.1515, Segmentation Loss:0.0824
# Train Confusion Matrix:
# [[1619476   27459]
#  [  38357  296148]]
# Accuracy: 0.9668, CSI: 0.8182, Sensitivity: 0.8853, Specificity: 0.9833, False Alarm Ratio: 0.0849
#
#
# epoch duration : 83.75354886054993
# epoch n° 1515
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 305.5867, Segmentation Loss:0.0863
# Train Confusion Matrix:
# [[3147346   51270]
#  [  78603  562781]]
# Accuracy: 0.9662, CSI: 0.8125, Sensitivity: 0.8774, Specificity: 0.9840, False Alarm Ratio: 0.0835
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 310.5911, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[3149444   49172]
#  [  72427  568957]]
# Accuracy: 0.9683, CSI: 0.8239, Sensitivity: 0.8871, Specificity: 0.9846, False Alarm Ratio: 0.0795
#
#
# train, Regression Loss: 0.0234, Regression Loss 1h: 320.6037, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[1959448   32468]
#  [  45424  354980]]
# Accuracy: 0.9674, CSI: 0.8201, Sensitivity: 0.8866, Specificity: 0.9837, False Alarm Ratio: 0.0838
#
#
# epoch duration : 83.826908826828
# epoch n° 1516
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 314.5235, Segmentation Loss:0.0889
# Train Confusion Matrix:
# [[3139505   56015]
#  [  78044  566436]]
# Accuracy: 0.9651, CSI: 0.8086, Sensitivity: 0.8789, Specificity: 0.9825, False Alarm Ratio: 0.0900
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 323.8105, Segmentation Loss:0.0820
# Train Confusion Matrix:
# [[3141794   53726]
#  [  71346  573134]]
# Accuracy: 0.9674, CSI: 0.8209, Sensitivity: 0.8893, Specificity: 0.9832, False Alarm Ratio: 0.0857
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 318.9337, Segmentation Loss:0.0837
# Train Confusion Matrix:
# [[1923492   31678]
#  [  46223  344847]]
# Accuracy: 0.9668, CSI: 0.8157, Sensitivity: 0.8818, Specificity: 0.9838, False Alarm Ratio: 0.0841
#
#
# epoch duration : 84.54040837287903
# epoch n° 1517
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 300.4213, Segmentation Loss:0.0840
# Train Confusion Matrix:
# [[3142704   52995]
#  [  74054  570247]]
# Accuracy: 0.9669, CSI: 0.8178, Sensitivity: 0.8851, Specificity: 0.9834, False Alarm Ratio: 0.0850
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 309.2496, Segmentation Loss:0.0781
# Train Confusion Matrix:
# [[3145635   50064]
#  [  69175  575126]]
# Accuracy: 0.9689, CSI: 0.8283, Sensitivity: 0.8926, Specificity: 0.9843, False Alarm Ratio: 0.0801
#
#
# train, Regression Loss: 0.0228, Regression Loss 1h: 307.3364, Segmentation Loss:0.0795
# Train Confusion Matrix:
# [[1871203   30211]
#  [  42907  336639]]
# Accuracy: 0.9679, CSI: 0.8216, Sensitivity: 0.8870, Specificity: 0.9841, False Alarm Ratio: 0.0824
#
#
# epoch duration : 85.15949273109436
# epoch n° 1518
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 285.3797, Segmentation Loss:0.0867
# Train Confusion Matrix:
# [[3137385   51408]
#  [  79905  571302]]
# Accuracy: 0.9658, CSI: 0.8131, Sensitivity: 0.8773, Specificity: 0.9839, False Alarm Ratio: 0.0826
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 289.2643, Segmentation Loss:0.0803
# Train Confusion Matrix:
# [[3138712   50081]
#  [  72741  578466]]
# Accuracy: 0.9680, CSI: 0.8249, Sensitivity: 0.8883, Specificity: 0.9843, False Alarm Ratio: 0.0797
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 310.0015, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[1798575   30238]
#  [  41422  330085]]
# Accuracy: 0.9674, CSI: 0.8216, Sensitivity: 0.8885, Specificity: 0.9835, False Alarm Ratio: 0.0839
#
#
# epoch duration : 84.24024271965027
# epoch n° 1519
#
# eval_opportunity_cost_spat, Regression Loss: 0.0249, Regression Loss 1h: 329.4041, Segmentation Loss:0.0883
# Train Confusion Matrix:
# [[3148834   52733]
#  [  79941  558492]]
# Accuracy: 0.9654, CSI: 0.8080, Sensitivity: 0.8748, Specificity: 0.9835, False Alarm Ratio: 0.0863
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 341.2459, Segmentation Loss:0.0811
# Train Confusion Matrix:
# [[3150882   50685]
#  [  72913  565520]]
# Accuracy: 0.9678, CSI: 0.8206, Sensitivity: 0.8858, Specificity: 0.9842, False Alarm Ratio: 0.0823
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 322.1849, Segmentation Loss:0.0811
# Train Confusion Matrix:
# [[1709440   27817]
#  [  39715  311988]]
# Accuracy: 0.9677, CSI: 0.8221, Sensitivity: 0.8871, Specificity: 0.9840, False Alarm Ratio: 0.0819
#
#
# epoch duration : 84.19651794433594
# epoch n° 1520
#
# eval_opportunity_cost_spat, Regression Loss: 0.0254, Regression Loss 1h: 288.8475, Segmentation Loss:0.0845
# Train Confusion Matrix:
# [[3153938   51933]
#  [  75610  558519]]
# Accuracy: 0.9668, CSI: 0.8141, Sensitivity: 0.8808, Specificity: 0.9838, False Alarm Ratio: 0.0851
#
#
# eval_added_value_full_spat, Regression Loss: 0.0229, Regression Loss 1h: 289.8821, Segmentation Loss:0.0786
# Train Confusion Matrix:
# [[3155554   50317]
#  [  70048  564081]]
# Accuracy: 0.9687, CSI: 0.8241, Sensitivity: 0.8895, Specificity: 0.9843, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0238, Regression Loss 1h: 307.6954, Segmentation Loss:0.0792
# Train Confusion Matrix:
# [[1889322   30314]
#  [  42476  338048]]
# Accuracy: 0.9684, CSI: 0.8228, Sensitivity: 0.8884, Specificity: 0.9842, False Alarm Ratio: 0.0823
#
#
# epoch duration : 84.5795304775238
# saving step
# epoch n° 1521
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 304.8145, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3155020   51610]
#  [  78193  555177]]
# Accuracy: 0.9662, CSI: 0.8105, Sensitivity: 0.8765, Specificity: 0.9839, False Alarm Ratio: 0.0851
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 310.6121, Segmentation Loss:0.0792
# Train Confusion Matrix:
# [[3157202   49428]
#  [  71868  561502]]
# Accuracy: 0.9684, CSI: 0.8224, Sensitivity: 0.8865, Specificity: 0.9846, False Alarm Ratio: 0.0809
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 318.6523, Segmentation Loss:0.0811
# Train Confusion Matrix:
# [[2077919   33702]
#  [  47898  363361]]
# Accuracy: 0.9677, CSI: 0.8166, Sensitivity: 0.8835, Specificity: 0.9840, False Alarm Ratio: 0.0849
#
#
# epoch duration : 83.62587356567383
# epoch n° 1522
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 309.3908, Segmentation Loss:0.0835
# Train Confusion Matrix:
# [[3138289   57176]
#  [  69461  575074]]
# Accuracy: 0.9670, CSI: 0.8195, Sensitivity: 0.8922, Specificity: 0.9821, False Alarm Ratio: 0.0904
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 324.3870, Segmentation Loss:0.0774
# Train Confusion Matrix:
# [[3142465   53000]
#  [  66035  578500]]
# Accuracy: 0.9690, CSI: 0.8293, Sensitivity: 0.8975, Specificity: 0.9834, False Alarm Ratio: 0.0839
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 301.3613, Segmentation Loss:0.0789
# Train Confusion Matrix:
# [[1954596   31913]
#  [  44187  353944]]
# Accuracy: 0.9681, CSI: 0.8230, Sensitivity: 0.8890, Specificity: 0.9839, False Alarm Ratio: 0.0827
#
#
# epoch duration : 84.37560725212097
# epoch n° 1523
#
# eval_opportunity_cost_spat, Regression Loss: 0.0249, Regression Loss 1h: 304.2784, Segmentation Loss:0.0876
# Train Confusion Matrix:
# [[3143140   52537]
#  [  78854  565469]]
# Accuracy: 0.9658, CSI: 0.8115, Sensitivity: 0.8776, Specificity: 0.9836, False Alarm Ratio: 0.0850
#
#
# eval_added_value_full_spat, Regression Loss: 0.0224, Regression Loss 1h: 309.2985, Segmentation Loss:0.0808
# Train Confusion Matrix:
# [[3146347   49330]
#  [  73635  570688]]
# Accuracy: 0.9680, CSI: 0.8227, Sensitivity: 0.8857, Specificity: 0.9846, False Alarm Ratio: 0.0796
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 315.3524, Segmentation Loss:0.0807
# Train Confusion Matrix:
# [[1962095   31505]
#  [  44811  357749]]
# Accuracy: 0.9682, CSI: 0.8242, Sensitivity: 0.8887, Specificity: 0.9842, False Alarm Ratio: 0.0809
#
#
# epoch duration : 84.554447889328
# epoch n° 1524
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 299.7807, Segmentation Loss:0.0851
# Train Confusion Matrix:
# [[3145517   53630]
#  [  75836  565017]]
# Accuracy: 0.9663, CSI: 0.8136, Sensitivity: 0.8817, Specificity: 0.9832, False Alarm Ratio: 0.0867
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 306.2568, Segmentation Loss:0.0784
# Train Confusion Matrix:
# [[3148207   50940]
#  [  69472  571381]]
# Accuracy: 0.9686, CSI: 0.8259, Sensitivity: 0.8916, Specificity: 0.9841, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0225, Regression Loss 1h: 313.8678, Segmentation Loss:0.0806
# Train Confusion Matrix:
# [[1934860   31676]
#  [  44028  347196]]
# Accuracy: 0.9679, CSI: 0.8210, Sensitivity: 0.8875, Specificity: 0.9839, False Alarm Ratio: 0.0836
#
#
# epoch duration : 83.46746563911438
# epoch n° 1525
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 293.2334, Segmentation Loss:0.0852
# Train Confusion Matrix:
# [[3143408   55934]
#  [  73230  567428]]
# Accuracy: 0.9664, CSI: 0.8146, Sensitivity: 0.8857, Specificity: 0.9825, False Alarm Ratio: 0.0897
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 298.1485, Segmentation Loss:0.0788
# Train Confusion Matrix:
# [[3145852   53490]
#  [  67543  573115]]
# Accuracy: 0.9685, CSI: 0.8256, Sensitivity: 0.8946, Specificity: 0.9833, False Alarm Ratio: 0.0854
#
#
# train, Regression Loss: 0.0234, Regression Loss 1h: 315.5764, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[1839504   30382]
#  [  40952  331722]]
# Accuracy: 0.9682, CSI: 0.8230, Sensitivity: 0.8901, Specificity: 0.9838, False Alarm Ratio: 0.0839
#
#
# epoch duration : 84.7448422908783
# epoch n° 1526
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 316.6079, Segmentation Loss:0.0847
# Train Confusion Matrix:
# [[3149269   53012]
#  [  74827  562892]]
# Accuracy: 0.9667, CSI: 0.8149, Sensitivity: 0.8827, Specificity: 0.9834, False Alarm Ratio: 0.0861
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 328.3470, Segmentation Loss:0.0784
# Train Confusion Matrix:
# [[3152279   50002]
#  [  69461  568258]]
# Accuracy: 0.9689, CSI: 0.8263, Sensitivity: 0.8911, Specificity: 0.9844, False Alarm Ratio: 0.0809
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 322.7847, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[2001007   32393]
#  [  45087  359913]]
# Accuracy: 0.9682, CSI: 0.8229, Sensitivity: 0.8887, Specificity: 0.9841, False Alarm Ratio: 0.0826
#
#
# epoch duration : 84.96067476272583
# epoch n° 1527
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 296.7760, Segmentation Loss:0.0864
# Train Confusion Matrix:
# [[3148837   54163]
#  [  76624  560376]]
# Accuracy: 0.9659, CSI: 0.8108, Sensitivity: 0.8797, Specificity: 0.9831, False Alarm Ratio: 0.0881
#
#
# eval_added_value_full_spat, Regression Loss: 0.0221, Regression Loss 1h: 312.4726, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[3152154   50846]
#  [  71610  565390]]
# Accuracy: 0.9681, CSI: 0.8220, Sensitivity: 0.8876, Specificity: 0.9841, False Alarm Ratio: 0.0825
#
#
# train, Regression Loss: 0.0235, Regression Loss 1h: 318.3769, Segmentation Loss:0.0803
# Train Confusion Matrix:
# [[1954342   31919]
#  [  44620  353759]]
# Accuracy: 0.9679, CSI: 0.8221, Sensitivity: 0.8880, Specificity: 0.9839, False Alarm Ratio: 0.0828
#
#
# epoch duration : 84.17939615249634
# epoch n° 1528
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 309.0235, Segmentation Loss:0.0844
# Train Confusion Matrix:
# [[3145455   54360]
#  [  72765  567420]]
# Accuracy: 0.9669, CSI: 0.8170, Sensitivity: 0.8863, Specificity: 0.9830, False Alarm Ratio: 0.0874
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 319.6910, Segmentation Loss:0.0783
# Train Confusion Matrix:
# [[3149015   50800]
#  [  68336  571849]]
# Accuracy: 0.9690, CSI: 0.8276, Sensitivity: 0.8933, Specificity: 0.9841, False Alarm Ratio: 0.0816
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 321.8777, Segmentation Loss:0.0783
# Train Confusion Matrix:
# [[1871250   30083]
#  [  41193  338434]]
# Accuracy: 0.9688, CSI: 0.8260, Sensitivity: 0.8915, Specificity: 0.9842, False Alarm Ratio: 0.0816
#
#
# epoch duration : 84.44141006469727
# epoch n° 1529
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 284.3153, Segmentation Loss:0.0853
# Train Confusion Matrix:
# [[3144634   52984]
#  [  75457  566925]]
# Accuracy: 0.9666, CSI: 0.8153, Sensitivity: 0.8825, Specificity: 0.9834, False Alarm Ratio: 0.0855
#
#
# eval_added_value_full_spat, Regression Loss: 0.0217, Regression Loss 1h: 286.8071, Segmentation Loss:0.0789
# Train Confusion Matrix:
# [[3145983   51635]
#  [  68800  573582]]
# Accuracy: 0.9686, CSI: 0.8265, Sensitivity: 0.8929, Specificity: 0.9839, False Alarm Ratio: 0.0826
#
#
# train, Regression Loss: 0.0233, Regression Loss 1h: 304.4482, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[1907471   30989]
#  [  43588  344992]]
# Accuracy: 0.9680, CSI: 0.8223, Sensitivity: 0.8878, Specificity: 0.9840, False Alarm Ratio: 0.0824
#
#
# epoch duration : 83.30693912506104
# epoch n° 1530
#
# eval_opportunity_cost_spat, Regression Loss: 0.0246, Regression Loss 1h: 303.6266, Segmentation Loss:0.0862
# Train Confusion Matrix:
# [[3156004   50916]
#  [  79226  553854]]
# Accuracy: 0.9661, CSI: 0.8097, Sensitivity: 0.8749, Specificity: 0.9841, False Alarm Ratio: 0.0842
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 317.6465, Segmentation Loss:0.0798
# Train Confusion Matrix:
# [[3159288   47632]
#  [  73851  559229]]
# Accuracy: 0.9684, CSI: 0.8215, Sensitivity: 0.8833, Specificity: 0.9851, False Alarm Ratio: 0.0785
#
#
# train, Regression Loss: 0.0237, Regression Loss 1h: 314.6420, Segmentation Loss:0.0796
# Train Confusion Matrix:
# [[2005819   32505]
#  [  44414  355662]]
# Accuracy: 0.9685, CSI: 0.8222, Sensitivity: 0.8890, Specificity: 0.9841, False Alarm Ratio: 0.0837
#
#
# epoch duration : 83.37880897521973
# saving step
# epoch n° 1531
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 303.3335, Segmentation Loss:0.0897
# Train Confusion Matrix:
# [[3144772   54542]
#  [  80229  560457]]
# Accuracy: 0.9649, CSI: 0.8061, Sensitivity: 0.8748, Specificity: 0.9830, False Alarm Ratio: 0.0887
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 311.1635, Segmentation Loss:0.0821
# Train Confusion Matrix:
# [[3147668   51646]
#  [  73786  566900]]
# Accuracy: 0.9673, CSI: 0.8188, Sensitivity: 0.8848, Specificity: 0.9839, False Alarm Ratio: 0.0835
#
#
# train, Regression Loss: 0.0231, Regression Loss 1h: 325.6263, Segmentation Loss:0.0824
# Train Confusion Matrix:
# [[1915777   31733]
#  [  45565  345485]]
# Accuracy: 0.9669, CSI: 0.8172, Sensitivity: 0.8835, Specificity: 0.9837, False Alarm Ratio: 0.0841
#
#
# epoch duration : 83.49763917922974
# epoch n° 1532
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 323.7683, Segmentation Loss:0.0856
# Train Confusion Matrix:
# [[3149239   53828]
#  [  74978  561955]]
# Accuracy: 0.9665, CSI: 0.8135, Sensitivity: 0.8823, Specificity: 0.9832, False Alarm Ratio: 0.0874
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 324.9760, Segmentation Loss:0.0790
# Train Confusion Matrix:
# [[3151702   51365]
#  [  69514  567419]]
# Accuracy: 0.9685, CSI: 0.8244, Sensitivity: 0.8909, Specificity: 0.9840, False Alarm Ratio: 0.0830
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 322.1864, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[1924666   31714]
#  [  42994  350706]]
# Accuracy: 0.9682, CSI: 0.8244, Sensitivity: 0.8908, Specificity: 0.9838, False Alarm Ratio: 0.0829
#
#
# epoch duration : 83.85504293441772
# epoch n° 1533
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 318.7558, Segmentation Loss:0.0862
# Train Confusion Matrix:
# [[3140216   53611]
#  [  76837  569336]]
# Accuracy: 0.9660, CSI: 0.8136, Sensitivity: 0.8811, Specificity: 0.9832, False Alarm Ratio: 0.0861
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 326.8372, Segmentation Loss:0.0796
# Train Confusion Matrix:
# [[3142481   51346]
#  [  70320  575853]]
# Accuracy: 0.9683, CSI: 0.8256, Sensitivity: 0.8912, Specificity: 0.9839, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0229, Regression Loss 1h: 323.5984, Segmentation Loss:0.0804
# Train Confusion Matrix:
# [[1909168   31608]
#  [  43288  350656]]
# Accuracy: 0.9679, CSI: 0.8240, Sensitivity: 0.8901, Specificity: 0.9837, False Alarm Ratio: 0.0827
#
#
# epoch duration : 83.77587294578552
# epoch n° 1534
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 304.5732, Segmentation Loss:0.0874
# Train Confusion Matrix:
# [[3151297   53381]
#  [  77549  557773]]
# Accuracy: 0.9659, CSI: 0.8099, Sensitivity: 0.8779, Specificity: 0.9833, False Alarm Ratio: 0.0873
#
#
# eval_added_value_full_spat, Regression Loss: 0.0223, Regression Loss 1h: 313.8330, Segmentation Loss:0.0805
# Train Confusion Matrix:
# [[3153615   51063]
#  [  71381  563941]]
# Accuracy: 0.9681, CSI: 0.8216, Sensitivity: 0.8876, Specificity: 0.9841, False Alarm Ratio: 0.0830
#
#
# train, Regression Loss: 0.0230, Regression Loss 1h: 325.1010, Segmentation Loss:0.0802
# Train Confusion Matrix:
# [[1844434   29710]
#  [  41900  330356]]
# Accuracy: 0.9681, CSI: 0.8219, Sensitivity: 0.8874, Specificity: 0.9841, False Alarm Ratio: 0.0825
#
#
# epoch duration : 83.21713972091675
# epoch n° 1535
#
# eval_opportunity_cost_spat, Regression Loss: 0.0241, Regression Loss 1h: 308.5476, Segmentation Loss:0.0862
# Train Confusion Matrix:
# [[3143493   56773]
#  [  73418  566316]]
# Accuracy: 0.9661, CSI: 0.8131, Sensitivity: 0.8852, Specificity: 0.9823, False Alarm Ratio: 0.0911
#
#
# eval_added_value_full_spat, Regression Loss: 0.0218, Regression Loss 1h: 315.9001, Segmentation Loss:0.0799
# Train Confusion Matrix:
# [[3146016   54250]
#  [  67942  571792]]
# Accuracy: 0.9682, CSI: 0.8239, Sensitivity: 0.8938, Specificity: 0.9830, False Alarm Ratio: 0.0867
#
#
# train, Regression Loss: 0.0232, Regression Loss 1h: 328.6546, Segmentation Loss:0.0793
# Train Confusion Matrix:
# [[1896028   31477]
#  [  42641  345374]]
# Accuracy: 0.9680, CSI: 0.8233, Sensitivity: 0.8901, Specificity: 0.9837, False Alarm Ratio: 0.0835
#
#
# epoch duration : 83.28413581848145
# epoch n° 1536
#
# eval_opportunity_cost_spat, Regression Loss: 0.0245, Regression Loss 1h: 320.7034, Segmentation Loss:0.0846
# Train Confusion Matrix:
# [[3153730   49755]
#  [  77677  558838]]
# Accuracy: 0.9668, CSI: 0.8143, Sensitivity: 0.8780, Specificity: 0.9845, False Alarm Ratio: 0.0818
#
#
# eval_added_value_full_spat, Regression Loss: 0.0222, Regression Loss 1h: 337.4671, Segmentation Loss:0.0785
# Train Confusion Matrix:
# [[3156791   46694]
#  [  72690  563825]]
# Accuracy: 0.9689, CSI: 0.8253, Sensitivity: 0.8858, Specificity: 0.9854, False Alarm Ratio: 0.0765
#
#
# ...
# Train Confusion Matrix:
# [[3141496   54924]
#  [  71512  572068]]
# Accuracy: 0.9671, CSI: 0.8190, Sensitivity: 0.8889, Specificity: 0.9828, False Alarm Ratio: 0.0876
#
#
# eval_added_value_full_spat, Regression Loss: 0.0210, Regression Loss 1h: 315.6570, Segmentation Loss:0.0772
# Train Confusion Matrix:
# [[3144043   52377]
#  [  65785  577795]]
# Accuracy: 0.9692, CSI: 0.8302, Sensitivity: 0.8978, Specificity: 0.9836, False Alarm Ratio: 0.0831
#
#
# train, Regression Loss: 0.0223, Regression Loss 1h: 315.1162, Segmentation Loss:0.0782
# Train Confusion Matrix:
# [[1909504   30523]
#  [  42395  352298]]
# Accuracy: 0.9688, CSI: 0.8285, Sensitivity: 0.8926, Specificity: 0.9843, False Alarm Ratio: 0.0797
#
#
# epoch duration : 83.94507646560669
# epoch n° 1877
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 313.6431, Segmentation Loss:0.0820
# Train Confusion Matrix:
# [[3144361   50204]
#  [  73986  571449]]
# Accuracy: 0.9677, CSI: 0.8215, Sensitivity: 0.8854, Specificity: 0.9843, False Alarm Ratio: 0.0808
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 327.0408, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[3146155   48410]
#  [  67754  577681]]
# Accuracy: 0.9697, CSI: 0.8326, Sensitivity: 0.8950, Specificity: 0.9848, False Alarm Ratio: 0.0773
#
#
# train, Regression Loss: 0.0223, Regression Loss 1h: 317.7286, Segmentation Loss:0.0765
# Train Confusion Matrix:
# [[1965885   31062]
#  [  43177  363716]]
# Accuracy: 0.9691, CSI: 0.8305, Sensitivity: 0.8939, Specificity: 0.9844, False Alarm Ratio: 0.0787
#
#
# epoch duration : 84.85851502418518
# epoch n° 1878
#
# eval_opportunity_cost_spat, Regression Loss: 0.0243, Regression Loss 1h: 293.0781, Segmentation Loss:0.0857
# Train Confusion Matrix:
# [[3144048   51992]
#  [  76046  567914]]
# Accuracy: 0.9667, CSI: 0.8160, Sensitivity: 0.8819, Specificity: 0.9837, False Alarm Ratio: 0.0839
#
#
# eval_added_value_full_spat, Regression Loss: 0.0219, Regression Loss 1h: 294.6154, Segmentation Loss:0.0790
# Train Confusion Matrix:
# [[3144719   51321]
#  [  68711  575249]]
# Accuracy: 0.9687, CSI: 0.8274, Sensitivity: 0.8933, Specificity: 0.9839, False Alarm Ratio: 0.0819
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 321.8750, Segmentation Loss:0.0779
# Train Confusion Matrix:
# [[1639991   26314]
#  [  36254  298081]]
# Accuracy: 0.9687, CSI: 0.8265, Sensitivity: 0.8916, Specificity: 0.9842, False Alarm Ratio: 0.0811
#
#
# epoch duration : 83.92435240745544
# epoch n° 1879
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 307.3288, Segmentation Loss:0.0854
# Train Confusion Matrix:
# [[3147338   51160]
#  [  77287  564215]]
# Accuracy: 0.9666, CSI: 0.8146, Sensitivity: 0.8795, Specificity: 0.9840, False Alarm Ratio: 0.0831
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 318.7453, Segmentation Loss:0.0782
# Train Confusion Matrix:
# [[3150309   48189]
#  [  71003  570499]]
# Accuracy: 0.9690, CSI: 0.8272, Sensitivity: 0.8893, Specificity: 0.9849, False Alarm Ratio: 0.0779
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 319.2505, Segmentation Loss:0.0791
# Train Confusion Matrix:
# [[2023264   32127]
#  [  45146  368583]]
# Accuracy: 0.9687, CSI: 0.8267, Sensitivity: 0.8909, Specificity: 0.9844, False Alarm Ratio: 0.0802
#
#
# epoch duration : 84.26774883270264
# epoch n° 1880
#
# eval_opportunity_cost_spat, Regression Loss: 0.0234, Regression Loss 1h: 308.1010, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[3153718   50129]
#  [  73112  563041]]
# Accuracy: 0.9679, CSI: 0.8204, Sensitivity: 0.8851, Specificity: 0.9844, False Alarm Ratio: 0.0818
#
#
# eval_added_value_full_spat, Regression Loss: 0.0212, Regression Loss 1h: 318.1378, Segmentation Loss:0.0752
# Train Confusion Matrix:
# [[3156252   47595]
#  [  67431  568722]]
# Accuracy: 0.9700, CSI: 0.8318, Sensitivity: 0.8940, Specificity: 0.9851, False Alarm Ratio: 0.0772
#
#
# train, Regression Loss: 0.0220, Regression Loss 1h: 322.3582, Segmentation Loss:0.0766
# Train Confusion Matrix:
# [[2006057   30890]
#  [  43372  361921]]
# Accuracy: 0.9696, CSI: 0.8297, Sensitivity: 0.8930, Specificity: 0.9848, False Alarm Ratio: 0.0786
#
#
# epoch duration : 83.70003294944763
# saving step
# epoch n° 1881
#
# eval_opportunity_cost_spat, Regression Loss: 0.0234, Regression Loss 1h: 295.8084, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3140093   52969]
#  [  70414  576524]]
# Accuracy: 0.9679, CSI: 0.8237, Sensitivity: 0.8912, Specificity: 0.9834, False Alarm Ratio: 0.0841
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 321.7883, Segmentation Loss:0.0755
# Train Confusion Matrix:
# [[3143340   49722]
#  [  65414  581524]]
# Accuracy: 0.9700, CSI: 0.8347, Sensitivity: 0.8989, Specificity: 0.9844, False Alarm Ratio: 0.0788
#
#
# train, Regression Loss: 0.0221, Regression Loss 1h: 315.4896, Segmentation Loss:0.0774
# Train Confusion Matrix:
# [[1976936   31251]
#  [  43619  359714]]
# Accuracy: 0.9690, CSI: 0.8277, Sensitivity: 0.8919, Specificity: 0.9844, False Alarm Ratio: 0.0799
#
#
# epoch duration : 84.29829740524292
# epoch n° 1882
#
# eval_opportunity_cost_spat, Regression Loss: 0.0244, Regression Loss 1h: 295.0834, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3150823   49163]
#  [  73998  566016]]
# Accuracy: 0.9679, CSI: 0.8213, Sensitivity: 0.8844, Specificity: 0.9846, False Alarm Ratio: 0.0799
#
#
# eval_added_value_full_spat, Regression Loss: 0.0220, Regression Loss 1h: 308.8559, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[3153034   46952]
#  [  68857  571157]]
# Accuracy: 0.9698, CSI: 0.8314, Sensitivity: 0.8924, Specificity: 0.9853, False Alarm Ratio: 0.0760
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 303.0116, Segmentation Loss:0.0757
# Train Confusion Matrix:
# [[1753798   27377]
#  [  36451  321254]]
# Accuracy: 0.9702, CSI: 0.8342, Sensitivity: 0.8981, Specificity: 0.9846, False Alarm Ratio: 0.0785
#
#
# epoch duration : 84.13189268112183
# epoch n° 1883
#
# eval_opportunity_cost_spat, Regression Loss: 0.0234, Regression Loss 1h: 311.6276, Segmentation Loss:0.0827
# Train Confusion Matrix:
# [[3150261   51780]
#  [  72833  565126]]
# Accuracy: 0.9675, CSI: 0.8193, Sensitivity: 0.8858, Specificity: 0.9838, False Alarm Ratio: 0.0839
#
#
# eval_added_value_full_spat, Regression Loss: 0.0211, Regression Loss 1h: 329.1089, Segmentation Loss:0.0765
# Train Confusion Matrix:
# [[3153542   48499]
#  [  68267  569692]]
# Accuracy: 0.9696, CSI: 0.8299, Sensitivity: 0.8930, Specificity: 0.9849, False Alarm Ratio: 0.0785
#
#
# train, Regression Loss: 0.0226, Regression Loss 1h: 311.9352, Segmentation Loss:0.0772
# Train Confusion Matrix:
# [[1890940   29554]
#  [  41731  345615]]
# Accuracy: 0.9691, CSI: 0.8290, Sensitivity: 0.8923, Specificity: 0.9846, False Alarm Ratio: 0.0788
#
#
# epoch duration : 84.44397711753845
# epoch n° 1884
#
# eval_opportunity_cost_spat, Regression Loss: 0.0240, Regression Loss 1h: 306.8282, Segmentation Loss:0.0840
# Train Confusion Matrix:
# [[3147855   50767]
#  [  75844  565534]]
# Accuracy: 0.9670, CSI: 0.8171, Sensitivity: 0.8817, Specificity: 0.9841, False Alarm Ratio: 0.0824
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 316.4968, Segmentation Loss:0.0774
# Train Confusion Matrix:
# [[3151174   47448]
#  [  70316  571062]]
# Accuracy: 0.9693, CSI: 0.8290, Sensitivity: 0.8904, Specificity: 0.9852, False Alarm Ratio: 0.0767
#
#
# train, Regression Loss: 0.0217, Regression Loss 1h: 314.5246, Segmentation Loss:0.0768
# Train Confusion Matrix:
# [[1782203   27755]
#  [  38967  320675]]
# Accuracy: 0.9692, CSI: 0.8278, Sensitivity: 0.8917, Specificity: 0.9847, False Alarm Ratio: 0.0797
#
#
# epoch duration : 83.83997440338135
# epoch n° 1885
#
# eval_opportunity_cost_spat, Regression Loss: 0.0234, Regression Loss 1h: 299.6862, Segmentation Loss:0.0852
# Train Confusion Matrix:
# [[3145755   55862]
#  [  72742  565641]]
# Accuracy: 0.9665, CSI: 0.8148, Sensitivity: 0.8861, Specificity: 0.9826, False Alarm Ratio: 0.0899
#
#
# eval_added_value_full_spat, Regression Loss: 0.0210, Regression Loss 1h: 311.1088, Segmentation Loss:0.0783
# Train Confusion Matrix:
# [[3149031   52586]
#  [  66840  571543]]
# Accuracy: 0.9689, CSI: 0.8272, Sensitivity: 0.8953, Specificity: 0.9836, False Alarm Ratio: 0.0843
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 328.7214, Segmentation Loss:0.0794
# Train Confusion Matrix:
# [[1889178   30204]
#  [  42749  338029]]
# Accuracy: 0.9683, CSI: 0.8225, Sensitivity: 0.8877, Specificity: 0.9843, False Alarm Ratio: 0.0820
#
#
# epoch duration : 83.64715337753296
# epoch n° 1886
#
# eval_opportunity_cost_spat, Regression Loss: 0.0238, Regression Loss 1h: 283.8576, Segmentation Loss:0.0837
# Train Confusion Matrix:
# [[3146407   52737]
#  [  74194  566662]]
# Accuracy: 0.9669, CSI: 0.8170, Sensitivity: 0.8842, Specificity: 0.9835, False Alarm Ratio: 0.0851
#
#
# eval_added_value_full_spat, Regression Loss: 0.0216, Regression Loss 1h: 303.7041, Segmentation Loss:0.0771
# Train Confusion Matrix:
# [[3149599   49545]
#  [  68536  572320]]
# Accuracy: 0.9692, CSI: 0.8290, Sensitivity: 0.8931, Specificity: 0.9845, False Alarm Ratio: 0.0797
#
#
# train, Regression Loss: 0.0228, Regression Loss 1h: 310.2986, Segmentation Loss:0.0774
# Train Confusion Matrix:
# [[2013802   32045]
#  [  45101  366652]]
# Accuracy: 0.9686, CSI: 0.8262, Sensitivity: 0.8905, Specificity: 0.9843, False Alarm Ratio: 0.0804
#
#
# epoch duration : 83.80746555328369
# epoch n° 1887
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 297.9550, Segmentation Loss:0.0839
# Train Confusion Matrix:
# [[3135590   52848]
#  [  74622  576940]]
# Accuracy: 0.9668, CSI: 0.8190, Sensitivity: 0.8855, Specificity: 0.9834, False Alarm Ratio: 0.0839
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 315.4342, Segmentation Loss:0.0772
# Train Confusion Matrix:
# [[3139366   49072]
#  [  69027  582535]]
# Accuracy: 0.9692, CSI: 0.8314, Sensitivity: 0.8941, Specificity: 0.9846, False Alarm Ratio: 0.0777
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 306.5311, Segmentation Loss:0.0778
# Train Confusion Matrix:
# [[1825559   28990]
#  [  41025  339306]]
# Accuracy: 0.9687, CSI: 0.8289, Sensitivity: 0.8921, Specificity: 0.9844, False Alarm Ratio: 0.0787
#
#
# epoch duration : 82.99168610572815
# epoch n° 1888
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 305.3288, Segmentation Loss:0.0846
# Train Confusion Matrix:
# [[3145471   49158]
#  [  78003  567368]]
# Accuracy: 0.9669, CSI: 0.8169, Sensitivity: 0.8791, Specificity: 0.9846, False Alarm Ratio: 0.0797
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 316.7475, Segmentation Loss:0.0777
# Train Confusion Matrix:
# [[3148515   46114]
#  [  72288  573083]]
# Accuracy: 0.9692, CSI: 0.8288, Sensitivity: 0.8880, Specificity: 0.9856, False Alarm Ratio: 0.0745
#
#
# train, Regression Loss: 0.0222, Regression Loss 1h: 312.8138, Segmentation Loss:0.0775
# Train Confusion Matrix:
# [[1970728   31285]
#  [  43345  358482]]
# Accuracy: 0.9690, CSI: 0.8277, Sensitivity: 0.8921, Specificity: 0.9844, False Alarm Ratio: 0.0803
#
#
# epoch duration : 82.77958512306213
# epoch n° 1889
#
# eval_opportunity_cost_spat, Regression Loss: 0.0231, Regression Loss 1h: 294.6837, Segmentation Loss:0.0848
# Train Confusion Matrix:
# [[3152416   51315]
#  [  76264  560005]]
# Accuracy: 0.9668, CSI: 0.8145, Sensitivity: 0.8801, Specificity: 0.9840, False Alarm Ratio: 0.0839
#
#
# eval_added_value_full_spat, Regression Loss: 0.0210, Regression Loss 1h: 302.3657, Segmentation Loss:0.0784
# Train Confusion Matrix:
# [[3155026   48705]
#  [  70728  565541]]
# Accuracy: 0.9689, CSI: 0.8256, Sensitivity: 0.8888, Specificity: 0.9848, False Alarm Ratio: 0.0793
#
#
# train, Regression Loss: 0.0213, Regression Loss 1h: 309.3879, Segmentation Loss:0.0773
# Train Confusion Matrix:
# [[1940749   29890]
#  [  42509  348452]]
# Accuracy: 0.9693, CSI: 0.8280, Sensitivity: 0.8913, Specificity: 0.9848, False Alarm Ratio: 0.0790
#
#
# epoch duration : 83.99108028411865
# epoch n° 1890
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 289.1789, Segmentation Loss:0.0838
# Train Confusion Matrix:
# [[3153997   51286]
#  [  75330  559387]]
# Accuracy: 0.9670, CSI: 0.8154, Sensitivity: 0.8813, Specificity: 0.9840, False Alarm Ratio: 0.0840
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 295.7677, Segmentation Loss:0.0770
# Train Confusion Matrix:
# [[3155934   49349]
#  [  68908  565809]]
# Accuracy: 0.9692, CSI: 0.8271, Sensitivity: 0.8914, Specificity: 0.9846, False Alarm Ratio: 0.0802
#
#
# train, Regression Loss: 0.0221, Regression Loss 1h: 309.6507, Segmentation Loss:0.0760
# Train Confusion Matrix:
# [[1862531   29427]
#  [  40030  333612]]
# Accuracy: 0.9693, CSI: 0.8277, Sensitivity: 0.8929, Specificity: 0.9844, False Alarm Ratio: 0.0811
#
#
# epoch duration : 83.45611810684204
# saving step
# epoch n° 1891
#
# eval_opportunity_cost_spat, Regression Loss: 0.0235, Regression Loss 1h: 303.2728, Segmentation Loss:0.0859
# Train Confusion Matrix:
# [[3140659   53671]
#  [  75175  570495]]
# Accuracy: 0.9664, CSI: 0.8158, Sensitivity: 0.8836, Specificity: 0.9832, False Alarm Ratio: 0.0860
#
#
# eval_added_value_full_spat, Regression Loss: 0.0212, Regression Loss 1h: 308.6383, Segmentation Loss:0.0792
# Train Confusion Matrix:
# [[3143038   51292]
#  [  68805  576865]]
# Accuracy: 0.9687, CSI: 0.8277, Sensitivity: 0.8934, Specificity: 0.9839, False Alarm Ratio: 0.0817
#
#
# train, Regression Loss: 0.0219, Regression Loss 1h: 309.8690, Segmentation Loss:0.0794
# Train Confusion Matrix:
# [[1697444   27405]
#  [  38300  314291]]
# Accuracy: 0.9684, CSI: 0.8271, Sensitivity: 0.8914, Specificity: 0.9841, False Alarm Ratio: 0.0802
#
#
# epoch duration : 83.05450987815857
# epoch n° 1892
#
# eval_opportunity_cost_spat, Regression Loss: 0.0237, Regression Loss 1h: 323.4670, Segmentation Loss:0.0817
# Train Confusion Matrix:
# [[3152073   51168]
#  [  72276  564483]]
# Accuracy: 0.9679, CSI: 0.8206, Sensitivity: 0.8865, Specificity: 0.9840, False Alarm Ratio: 0.0831
#
#
# eval_added_value_full_spat, Regression Loss: 0.0215, Regression Loss 1h: 331.8213, Segmentation Loss:0.0759
# Train Confusion Matrix:
# [[3154921   48320]
#  [  67457  569302]]
# Accuracy: 0.9698, CSI: 0.8310, Sensitivity: 0.8941, Specificity: 0.9849, False Alarm Ratio: 0.0782
#
#
# train, Regression Loss: 0.0224, Regression Loss 1h: 315.3928, Segmentation Loss:0.0771
# Train Confusion Matrix:
# [[1996942   31207]
#  [  43252  359319]]
# Accuracy: 0.9694, CSI: 0.8283, Sensitivity: 0.8926, Specificity: 0.9846, False Alarm Ratio: 0.0799
#
#
# epoch duration : 83.35920453071594
# epoch n° 1893
#
# eval_opportunity_cost_spat, Regression Loss: 0.0235, Regression Loss 1h: 304.7743, Segmentation Loss:0.0826
# Train Confusion Matrix:
# [[3148504   49676]
#  [  74929  566891]]
# Accuracy: 0.9676, CSI: 0.8198, Sensitivity: 0.8833, Specificity: 0.9845, False Alarm Ratio: 0.0806
#
#
# eval_added_value_full_spat, Regression Loss: 0.0214, Regression Loss 1h: 311.5215, Segmentation Loss:0.0763
# Train Confusion Matrix:
# [[3150885   47295]
#  [  68917  572903]]
# Accuracy: 0.9697, CSI: 0.8314, Sensitivity: 0.8926, Specificity: 0.9852, False Alarm Ratio: 0.0763
#
#
# train, Regression Loss: 0.0228, Regression Loss 1h: 323.9715, Segmentation Loss:0.0771
# Train Confusion Matrix:
# [[1855158   28244]
#  [  40848  333670]]
# Accuracy: 0.9694, CSI: 0.8285, Sensitivity: 0.8909, Specificity: 0.9850, False Alarm Ratio: 0.0780
#
#
# epoch duration : 84.79502534866333
# epoch n° 1894
#
# eval_opportunity_cost_spat, Regression Loss: 0.0236, Regression Loss 1h: 292.4953, Segmentation Loss:0.0816
# Train Confusion Matrix:
# [[3155215   51527]
#  [  71796  561462]]
# Accuracy: 0.9679, CSI: 0.8199, Sensitivity: 0.8866, Specificity: 0.9839, False Alarm Ratio: 0.0841
#
#
# eval_added_value_full_spat, Regression Loss: 0.0213, Regression Loss 1h: 292.2425, Segmentation Loss:0.0758
# Train Confusion Matrix:
# [[3157341   49401]
#  [  66040  567218]]
# Accuracy: 0.9699, CSI: 0.8309, Sensitivity: 0.8957, Specificity: 0.9846, False Alarm Ratio: 0.0801
#
#
# train, Regression Loss: 0.0227, Regression Loss 1h: 298.4950, Segmentation Loss:0.0775
# Train Confusion Matrix:
# [[1935039   30383]
#  [  43038  345460]]
# Accuracy: 0.9688, CSI: 0.8247, Sensitivity: 0.8892, Specificity: 0.9845, False Alarm Ratio: 0.0808
#
#
# epoch duration : 84.75106930732727
# epoch n° 1895

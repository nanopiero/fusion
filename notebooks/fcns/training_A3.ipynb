# %% [markdown]
# <a href="https://colab.research.google.com/github/nanopiero/fusion/blob/main/notebooks/fcns/training_A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## A3.radar + cmls -> rain gauges 1 min + rain gauges 60 min (champ indépendant) [xrl_yg1g60i]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import sys
sys.path.append('/home/mdso/lepetitp/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation')

from fusion.utils.datasets import spatialized_gt, create_cmls_filter, FusionDataset
from fusion.utils.datasets import indices_to_sampled_values, get_point_measurements, point_gt, segment_gt, make_noisy_images
from torch.utils.data import DataLoader
from fusion.utils.fcn import UNet
from fusion.utils.cost_functions import QPELoss_fcn, compute_metrics
from fusion.utils.viz import set_tensor_values2, plot_images, plot_images_10pts_20seg, plot_results_10pts_20seg

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# config de base (change en B.):
num_epochs = 2000
save_every = 10
path = r'/scratch/mdso/lepetitp/ppc/RAINCELL/models/simulation/checkpoint_fcn_A3_xrl_yg1g60i.pt'
npoints = 10
npairs = 20
nsteps = 60
ndiscs = 5
size_image = 64
length_dataset = 6400
device = torch.device('cuda:0')

# %%
# Dataset, DataLoader
dataset = FusionDataset(length_dataset=length_dataset,
                        npairs=npairs,
                        nsteps=nsteps,
                        ndiscs=ndiscs, size_image=size_image)


loader = DataLoader(dataset, batch_size=64, num_workers=8)

# %%
# Petit UNet
ch_in = 72
ch_out = nsteps * 3 + 1
size = nsteps * 3
device = torch.device('cuda:0')
model = UNet(ch_in, ch_out, size, nb_additional_parameters=16).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = QPELoss_fcn(eval_independent_qpe_1h=True)

# %%
# Baseline with a FCN
use_fcn = True

best_loss = [float('inf'), float('inf')]  # Initialize best validation loss to a very high value
losses = []
last_epoch = 0

# %%
checkpoint = torch.load(path, \
                            map_location=device)
last_epoch = checkpoint['epoch']
losses = checkpoint['train_losses']
# best_loss = checkpoint['best_loss']
model_weights = checkpoint['model']
optimizer_state_dict = checkpoint['optimizer']
# scheduler_state_dict = checkpoint['scheduler']
model.load_state_dict(model_weights)
optimizer.load_state_dict(optimizer_state_dict)
# scheduler.load_state_dict(scheduler_state_dict)
del checkpoint, model_weights, optimizer_state_dict

# %%
last_epoch
# Out:
# 1420

# %%
model.train()
for epoch in range(last_epoch, num_epochs):
  print('epoch n°', epoch)
  running_regression_loss = 0.0
  running_regression_loss_1h = 0.0
  running_segmentation_loss = 0.0
  train_confusion_matrix = np.zeros((2, 2), dtype=int)
  for i, (images, pairs, filters) in enumerate(loader):

    # ground truth (not usable)
    images = images.clone().detach().float().to(device)

    # pseudo CMLs
    pairs = pairs.clone().detach().float().to(device)
    filters = filters.clone().float().detach().to(device)

    # for transformers :
    # segment_measurements = segment_gt(images, pairs, filters)
    _, segment_measurements_fcn = segment_gt(images, pairs, filters,
                                             use_fcn=use_fcn)

    # pseudo pluvios
    _, point_measurements_fcn, _ = point_gt(images, npoints=npoints,
                                            use_fcn=use_fcn)


    # pseudo radar
    noisy_images = make_noisy_images(images)

    # prepare inputs and targets
    inputs = torch.cat([noisy_images, segment_measurements_fcn], dim=1)
    targets = point_measurements_fcn


    optimizer.zero_grad()  # Zero the gradients
    outputs = model(inputs)  # Forward pass

    regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
    loss.backward()  # Backward pass
    optimizer.step()  # Update the weights

    del inputs, targets, outputs, loss, noisy_images, images, pairs, filters
    torch.cuda.empty_cache()

    running_regression_loss += regression_loss
    running_regression_loss_1h += regression_loss_1h
    running_segmentation_loss += segmentation_loss
    train_confusion_matrix += batch_cm

  # Calculating average training loss
  train_regression_loss = running_regression_loss / len(loader)
  train_regression_loss_1h = running_regression_loss_1h / len(loader)
  train_segmentation_loss = running_segmentation_loss / len(loader)
  losses.append((epoch, train_regression_loss, train_regression_loss_1h, train_segmentation_loss, train_confusion_matrix))
  print(f'Training, Regression Loss: {train_regression_loss:.4f}, Regression Loss 1h: {train_regression_loss_1h:.4f}, Segmentation Loss:{train_segmentation_loss:.4f}' )
  print("Train Confusion Matrix:")
  print(train_confusion_matrix)
  accuracy, csi, sensitivity, specificity, false_alarm_ratio = compute_metrics(train_confusion_matrix)
  print(f'Accuracy: {accuracy:.4f}, CSI: {csi:.4f}, Sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, False Alarm Ratio: {false_alarm_ratio:.4f}')
  print('\n')
    
  if (epoch % save_every == 0 or \
    epoch == last_epoch):
    print("saving step")
    checkpoint = { 
        'epoch': epoch,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        # 'scheduler': scheduler.state_dict(),
        'train_losses': losses,
        }
    torch.save(checkpoint, path)
# Out:
# epoch n° 1420
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4553, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3121959   71399]
#  [ 120556  526086]]
# Accuracy: 0.9500, CSI: 0.7327, Sensitivity: 0.8136, Specificity: 0.9776, False Alarm Ratio: 0.1195
#
#
# saving step
# epoch n° 1421
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4414, Segmentation Loss:0.1237
# Train Confusion Matrix:
# [[3125104   70058]
#  [ 114332  530506]]
# Accuracy: 0.9520, CSI: 0.7421, Sensitivity: 0.8227, Specificity: 0.9781, False Alarm Ratio: 0.1167
#
#
# epoch n° 1422
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.4889, Segmentation Loss:0.1306
# Train Confusion Matrix:
# [[3133655   70220]
#  [ 122080  514045]]
# Accuracy: 0.9499, CSI: 0.7278, Sensitivity: 0.8081, Specificity: 0.9781, False Alarm Ratio: 0.1202
#
#
# epoch n° 1423
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4030, Segmentation Loss:0.1289
# Train Confusion Matrix:
# [[3120600   70308]
#  [ 120969  528123]]
# Accuracy: 0.9502, CSI: 0.7341, Sensitivity: 0.8136, Specificity: 0.9780, False Alarm Ratio: 0.1175
#
#
# epoch n° 1424
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3165, Segmentation Loss:0.1275
# Train Confusion Matrix:
# [[3138360   69371]
#  [ 119144  513125]]
# Accuracy: 0.9509, CSI: 0.7313, Sensitivity: 0.8116, Specificity: 0.9784, False Alarm Ratio: 0.1191
#
#
# epoch n° 1425
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4208, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3133813   69125]
#  [ 117533  519529]]
# Accuracy: 0.9514, CSI: 0.7357, Sensitivity: 0.8155, Specificity: 0.9784, False Alarm Ratio: 0.1174
#
#
# epoch n° 1426
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.4552, Segmentation Loss:0.1325
# Train Confusion Matrix:
# [[3122789   70220]
#  [ 125832  521159]]
# Accuracy: 0.9489, CSI: 0.7266, Sensitivity: 0.8055, Specificity: 0.9780, False Alarm Ratio: 0.1187
#
#
# epoch n° 1427
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3918, Segmentation Loss:0.1236
# Train Confusion Matrix:
# [[3130339   70292]
#  [ 113778  525591]]
# Accuracy: 0.9521, CSI: 0.7406, Sensitivity: 0.8220, Specificity: 0.9780, False Alarm Ratio: 0.1180
#
#
# epoch n° 1428
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4746, Segmentation Loss:0.1283
# Train Confusion Matrix:
# [[3133893   70374]
#  [ 120244  515489]]
# Accuracy: 0.9504, CSI: 0.7300, Sensitivity: 0.8109, Specificity: 0.9780, False Alarm Ratio: 0.1201
#
#
# epoch n° 1429
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.5127, Segmentation Loss:0.1284
# Train Confusion Matrix:
# [[3118524   69927]
#  [ 120427  531122]]
# Accuracy: 0.9504, CSI: 0.7362, Sensitivity: 0.8152, Specificity: 0.9781, False Alarm Ratio: 0.1163
#
#
# epoch n° 1430
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3880, Segmentation Loss:0.1288
# Train Confusion Matrix:
# [[3132846   70451]
#  [ 121340  515363]]
# Accuracy: 0.9501, CSI: 0.7288, Sensitivity: 0.8094, Specificity: 0.9780, False Alarm Ratio: 0.1203
#
#
# saving step
# epoch n° 1431
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3811, Segmentation Loss:0.1300
# Train Confusion Matrix:
# [[3139231   69639]
#  [ 123523  507607]]
# Accuracy: 0.9497, CSI: 0.7244, Sensitivity: 0.8043, Specificity: 0.9783, False Alarm Ratio: 0.1206
#
#
# epoch n° 1432
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4005, Segmentation Loss:0.1293
# Train Confusion Matrix:
# [[3129870   70289]
#  [ 121416  518425]]
# Accuracy: 0.9501, CSI: 0.7300, Sensitivity: 0.8102, Specificity: 0.9780, False Alarm Ratio: 0.1194
#
#
# epoch n° 1433
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.5334, Segmentation Loss:0.1298
# Train Confusion Matrix:
# [[3117420   70811]
#  [ 121608  530161]]
# Accuracy: 0.9499, CSI: 0.7337, Sensitivity: 0.8134, Specificity: 0.9778, False Alarm Ratio: 0.1178
#
#
# epoch n° 1434
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4044, Segmentation Loss:0.1270
# Train Confusion Matrix:
# [[3129277   69501]
#  [ 118421  522801]]
# Accuracy: 0.9511, CSI: 0.7356, Sensitivity: 0.8153, Specificity: 0.9783, False Alarm Ratio: 0.1173
#
#
# epoch n° 1436
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.5137, Segmentation Loss:0.1225
# Train Confusion Matrix:
# [[3128026   70464]
#  [ 113051  528459]]
# Accuracy: 0.9522, CSI: 0.7422, Sensitivity: 0.8238, Specificity: 0.9780, False Alarm Ratio: 0.1177
#
#
# epoch n° 1437
# Training, Regression Loss: 0.0365, Regression Loss 1h: 1.4302, Segmentation Loss:0.1252
# Train Confusion Matrix:
# [[3124584   69439]
#  [ 116755  529222]]
# Accuracy: 0.9515, CSI: 0.7397, Sensitivity: 0.8193, Specificity: 0.9783, False Alarm Ratio: 0.1160
#
#
# epoch n° 1438
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4723, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3125353   70519]
#  [ 114975  529153]]
# Accuracy: 0.9517, CSI: 0.7404, Sensitivity: 0.8215, Specificity: 0.9779, False Alarm Ratio: 0.1176
#
#
# epoch n° 1439
# Training, Regression Loss: 0.0367, Regression Loss 1h: 1.5172, Segmentation Loss:0.1287
# Train Confusion Matrix:
# [[3125838   70489]
#  [ 120675  522998]]
# Accuracy: 0.9502, CSI: 0.7323, Sensitivity: 0.8125, Specificity: 0.9779, False Alarm Ratio: 0.1188
#
#
# epoch n° 1440
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4509, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3131885   69566]
#  [ 115667  522882]]
# Accuracy: 0.9518, CSI: 0.7384, Sensitivity: 0.8189, Specificity: 0.9783, False Alarm Ratio: 0.1174
#
#
# saving step
# epoch n° 1441
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4460, Segmentation Loss:0.1253
# Train Confusion Matrix:
# [[3128246   70066]
#  [ 116383  525305]]
# Accuracy: 0.9514, CSI: 0.7380, Sensitivity: 0.8186, Specificity: 0.9781, False Alarm Ratio: 0.1177
#
#
# epoch n° 1442
# Training, Regression Loss: 0.0367, Regression Loss 1h: 1.4272, Segmentation Loss:0.1262
# Train Confusion Matrix:
# [[3131101   68914]
#  [ 118072  521913]]
# Accuracy: 0.9513, CSI: 0.7362, Sensitivity: 0.8155, Specificity: 0.9785, False Alarm Ratio: 0.1166
#
#
# epoch n° 1443
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.4706, Segmentation Loss:0.1299
# Train Confusion Matrix:
# [[3130788   69274]
#  [ 122506  517432]]
# Accuracy: 0.9501, CSI: 0.7296, Sensitivity: 0.8086, Specificity: 0.9784, False Alarm Ratio: 0.1181
#
#
# epoch n° 1444
# Training, Regression Loss: 0.0372, Regression Loss 1h: 1.4830, Segmentation Loss:0.1267
# Train Confusion Matrix:
# [[3126279   70750]
#  [ 117167  525804]]
# Accuracy: 0.9511, CSI: 0.7367, Sensitivity: 0.8178, Specificity: 0.9779, False Alarm Ratio: 0.1186
#
#
# epoch n° 1445
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4837, Segmentation Loss:0.1266
# Train Confusion Matrix:
# [[3126772   69833]
#  [ 117905  525490]]
# Accuracy: 0.9511, CSI: 0.7368, Sensitivity: 0.8167, Specificity: 0.9782, False Alarm Ratio: 0.1173
#
#
# epoch n° 1446
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4217, Segmentation Loss:0.1257
# Train Confusion Matrix:
# [[3131996   68686]
#  [ 117035  522283]]
# Accuracy: 0.9516, CSI: 0.7377, Sensitivity: 0.8169, Specificity: 0.9785, False Alarm Ratio: 0.1162
#
#
# epoch n° 1447
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.4379, Segmentation Loss:0.1272
# Train Confusion Matrix:
# [[3126143   69629]
#  [ 119309  524919]]
# Accuracy: 0.9508, CSI: 0.7353, Sensitivity: 0.8148, Specificity: 0.9782, False Alarm Ratio: 0.1171
#
#
# epoch n° 1448
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4086, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3127191   69562]
#  [ 115257  527990]]
# Accuracy: 0.9519, CSI: 0.7407, Sensitivity: 0.8208, Specificity: 0.9782, False Alarm Ratio: 0.1164
#
#
# epoch n° 1449
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.5127, Segmentation Loss:0.1276
# Train Confusion Matrix:
# [[3131833   69554]
#  [ 120095  518518]]
# Accuracy: 0.9506, CSI: 0.7322, Sensitivity: 0.8119, Specificity: 0.9783, False Alarm Ratio: 0.1183
#
#
# epoch n° 1450
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.3771, Segmentation Loss:0.1299
# Train Confusion Matrix:
# [[3128417   71260]
#  [ 122199  518124]]
# Accuracy: 0.9496, CSI: 0.7281, Sensitivity: 0.8092, Specificity: 0.9777, False Alarm Ratio: 0.1209
#
#
# saving step
# epoch n° 1451
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3659, Segmentation Loss:0.1297
# Train Confusion Matrix:
# [[3122132   69196]
#  [ 122618  526054]]
# Accuracy: 0.9500, CSI: 0.7328, Sensitivity: 0.8110, Specificity: 0.9783, False Alarm Ratio: 0.1162
#
#
# epoch n° 1452
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4177, Segmentation Loss:0.1215
# Train Confusion Matrix:
# [[3127821   69410]
#  [ 112240  530529]]
# Accuracy: 0.9527, CSI: 0.7449, Sensitivity: 0.8254, Specificity: 0.9783, False Alarm Ratio: 0.1157
#
#
# epoch n° 1453
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4925, Segmentation Loss:0.1292
# Train Confusion Matrix:
# [[3122910   71028]
#  [ 120800  525262]]
# Accuracy: 0.9500, CSI: 0.7325, Sensitivity: 0.8130, Specificity: 0.9778, False Alarm Ratio: 0.1191
#
#
# epoch n° 1454
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3442, Segmentation Loss:0.1296
# Train Confusion Matrix:
# [[3135604   68734]
#  [ 122453  513209]]
# Accuracy: 0.9502, CSI: 0.7286, Sensitivity: 0.8074, Specificity: 0.9785, False Alarm Ratio: 0.1181
#
#
# epoch n° 1455
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.4433, Segmentation Loss:0.1302
# Train Confusion Matrix:
# [[3130380   70374]
#  [ 122310  516936]]
# Accuracy: 0.9498, CSI: 0.7285, Sensitivity: 0.8087, Specificity: 0.9780, False Alarm Ratio: 0.1198
#
#
# epoch n° 1456
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3918, Segmentation Loss:0.1245
# Train Confusion Matrix:
# [[3125699   69445]
#  [ 115657  529199]]
# Accuracy: 0.9518, CSI: 0.7409, Sensitivity: 0.8206, Specificity: 0.9783, False Alarm Ratio: 0.1160
#
#
# epoch n° 1457
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.3624, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3125758   69399]
#  [ 114562  530281]]
# Accuracy: 0.9521, CSI: 0.7424, Sensitivity: 0.8223, Specificity: 0.9783, False Alarm Ratio: 0.1157
#
#
# epoch n° 1458
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4126, Segmentation Loss:0.1296
# Train Confusion Matrix:
# [[3119527   70465]
#  [ 121280  528728]]
# Accuracy: 0.9501, CSI: 0.7339, Sensitivity: 0.8134, Specificity: 0.9779, False Alarm Ratio: 0.1176
#
#
# epoch n° 1459
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.4514, Segmentation Loss:0.1287
# Train Confusion Matrix:
# [[3130217   69853]
#  [ 120713  519217]]
# Accuracy: 0.9504, CSI: 0.7315, Sensitivity: 0.8114, Specificity: 0.9782, False Alarm Ratio: 0.1186
#
#
# epoch n° 1460
# Training, Regression Loss: 0.0365, Regression Loss 1h: 1.4650, Segmentation Loss:0.1263
# Train Confusion Matrix:
# [[3129761   69897]
#  [ 118150  522192]]
# Accuracy: 0.9510, CSI: 0.7352, Sensitivity: 0.8155, Specificity: 0.9782, False Alarm Ratio: 0.1181
#
#
# saving step
# epoch n° 1461
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4187, Segmentation Loss:0.1247
# Train Confusion Matrix:
# [[3131053   69545]
#  [ 116471  522931]]
# Accuracy: 0.9516, CSI: 0.7376, Sensitivity: 0.8178, Specificity: 0.9783, False Alarm Ratio: 0.1174
#
#
# epoch n° 1462
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.3927, Segmentation Loss:0.1233
# Train Confusion Matrix:
# [[3127673   69728]
#  [ 113896  528703]]
# Accuracy: 0.9522, CSI: 0.7422, Sensitivity: 0.8228, Specificity: 0.9782, False Alarm Ratio: 0.1165
#
#
# epoch n° 1463
# Training, Regression Loss: 0.0369, Regression Loss 1h: 1.4328, Segmentation Loss:0.1261
# Train Confusion Matrix:
# [[3126365   70486]
#  [ 117123  526026]]
# Accuracy: 0.9511, CSI: 0.7371, Sensitivity: 0.8179, Specificity: 0.9780, False Alarm Ratio: 0.1182
#
#
# epoch n° 1464
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3947, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3130000   70097]
#  [ 117427  522476]]
# Accuracy: 0.9512, CSI: 0.7359, Sensitivity: 0.8165, Specificity: 0.9781, False Alarm Ratio: 0.1183
#
#
# epoch n° 1465
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.4417, Segmentation Loss:0.1285
# Train Confusion Matrix:
# [[3126715   71162]
#  [ 120213  521910]]
# Accuracy: 0.9502, CSI: 0.7317, Sensitivity: 0.8128, Specificity: 0.9777, False Alarm Ratio: 0.1200
#
#
# epoch n° 1466
# Training, Regression Loss: 0.0365, Regression Loss 1h: 1.4567, Segmentation Loss:0.1262
# Train Confusion Matrix:
# [[3125004   70560]
#  [ 116852  527584]]
# Accuracy: 0.9512, CSI: 0.7379, Sensitivity: 0.8187, Specificity: 0.9779, False Alarm Ratio: 0.1180
#
#
# epoch n° 1467
# Training, Regression Loss: 0.0369, Regression Loss 1h: 1.4277, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3136372   68565]
#  [ 117233  517830]]
# Accuracy: 0.9516, CSI: 0.7359, Sensitivity: 0.8154, Specificity: 0.9786, False Alarm Ratio: 0.1169
#
#
# epoch n° 1468
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4374, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3128437   68935]
#  [ 115013  527615]]
# Accuracy: 0.9521, CSI: 0.7415, Sensitivity: 0.8210, Specificity: 0.9784, False Alarm Ratio: 0.1156
#
#
# epoch n° 1469
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4173, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3125364   70064]
#  [ 117446  527126]]
# Accuracy: 0.9512, CSI: 0.7376, Sensitivity: 0.8178, Specificity: 0.9781, False Alarm Ratio: 0.1173
#
#
# epoch n° 1470
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3616, Segmentation Loss:0.1266
# Train Confusion Matrix:
# [[3127730   69097]
#  [ 118079  525094]]
# Accuracy: 0.9513, CSI: 0.7372, Sensitivity: 0.8164, Specificity: 0.9784, False Alarm Ratio: 0.1163
#
#
# saving step
# epoch n° 1471
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4198, Segmentation Loss:0.1290
# Train Confusion Matrix:
# [[3132220   69083]
#  [ 121288  517409]]
# Accuracy: 0.9504, CSI: 0.7310, Sensitivity: 0.8101, Specificity: 0.9784, False Alarm Ratio: 0.1178
#
#
# epoch n° 1472
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3601, Segmentation Loss:0.1274
# Train Confusion Matrix:
# [[3137399   68833]
#  [ 120509  513259]]
# Accuracy: 0.9507, CSI: 0.7305, Sensitivity: 0.8099, Specificity: 0.9785, False Alarm Ratio: 0.1183
#
#
# epoch n° 1473
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4182, Segmentation Loss:0.1235
# Train Confusion Matrix:
# [[3127072   69648]
#  [ 113930  529350]]
# Accuracy: 0.9522, CSI: 0.7425, Sensitivity: 0.8229, Specificity: 0.9782, False Alarm Ratio: 0.1163
#
#
# epoch n° 1474
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3803, Segmentation Loss:0.1243
# Train Confusion Matrix:
# [[3117305   69800]
#  [ 115283  537612]]
# Accuracy: 0.9518, CSI: 0.7439, Sensitivity: 0.8234, Specificity: 0.9781, False Alarm Ratio: 0.1149
#
#
# epoch n° 1475
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3999, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3126499   69918]
#  [ 120764  522819]]
# Accuracy: 0.9503, CSI: 0.7328, Sensitivity: 0.8124, Specificity: 0.9781, False Alarm Ratio: 0.1180
#
#
# epoch n° 1476
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4887, Segmentation Loss:0.1258
# Train Confusion Matrix:
# [[3119895   71282]
#  [ 116619  532204]]
# Accuracy: 0.9511, CSI: 0.7391, Sensitivity: 0.8203, Specificity: 0.9777, False Alarm Ratio: 0.1181
#
#
# epoch n° 1477
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3703, Segmentation Loss:0.1276
# Train Confusion Matrix:
# [[3133325   69805]
#  [ 119679  517191]]
# Accuracy: 0.9507, CSI: 0.7319, Sensitivity: 0.8121, Specificity: 0.9782, False Alarm Ratio: 0.1189
#
#
# epoch n° 1478
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4137, Segmentation Loss:0.1319
# Train Confusion Matrix:
# [[3120823   70631]
#  [ 124726  523820]]
# Accuracy: 0.9491, CSI: 0.7284, Sensitivity: 0.8077, Specificity: 0.9779, False Alarm Ratio: 0.1188
#
#
# epoch n° 1479
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3915, Segmentation Loss:0.1312
# Train Confusion Matrix:
# [[3130797   70388]
#  [ 124119  514696]]
# Accuracy: 0.9493, CSI: 0.7257, Sensitivity: 0.8057, Specificity: 0.9780, False Alarm Ratio: 0.1203
#
#
# epoch n° 1480
# Training, Regression Loss: 0.0373, Regression Loss 1h: 1.4412, Segmentation Loss:0.1253
# Train Confusion Matrix:
# [[3130918   70183]
#  [ 116264  522635]]
# Accuracy: 0.9514, CSI: 0.7371, Sensitivity: 0.8180, Specificity: 0.9781, False Alarm Ratio: 0.1184
#
#
# saving step
# epoch n° 1481
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.4058, Segmentation Loss:0.1281
# Train Confusion Matrix:
# [[3128024   69711]
#  [ 120393  521872]]
# Accuracy: 0.9505, CSI: 0.7330, Sensitivity: 0.8125, Specificity: 0.9782, False Alarm Ratio: 0.1178
#
#
# epoch n° 1482
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3619, Segmentation Loss:0.1261
# Train Confusion Matrix:
# [[3139168   69136]
#  [ 117355  514341]]
# Accuracy: 0.9514, CSI: 0.7339, Sensitivity: 0.8142, Specificity: 0.9785, False Alarm Ratio: 0.1185
#
#
# epoch n° 1483
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4315, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3132189   69985]
#  [ 115954  521872]]
# Accuracy: 0.9516, CSI: 0.7373, Sensitivity: 0.8182, Specificity: 0.9781, False Alarm Ratio: 0.1182
#
#
# epoch n° 1484
# Training, Regression Loss: 0.0369, Regression Loss 1h: 1.4293, Segmentation Loss:0.1270
# Train Confusion Matrix:
# [[3119908   71600]
#  [ 118581  529911]]
# Accuracy: 0.9505, CSI: 0.7359, Sensitivity: 0.8171, Specificity: 0.9776, False Alarm Ratio: 0.1190
#
#
# epoch n° 1485
# Training, Regression Loss: 0.0365, Regression Loss 1h: 1.4302, Segmentation Loss:0.1230
# Train Confusion Matrix:
# [[3126299   69703]
#  [ 113885  530113]]
# Accuracy: 0.9522, CSI: 0.7428, Sensitivity: 0.8232, Specificity: 0.9782, False Alarm Ratio: 0.1162
#
#
# epoch n° 1486
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.3398, Segmentation Loss:0.1261
# Train Confusion Matrix:
# [[3125886   69243]
#  [ 118215  526656]]
# Accuracy: 0.9512, CSI: 0.7375, Sensitivity: 0.8167, Specificity: 0.9783, False Alarm Ratio: 0.1162
#
#
# epoch n° 1487
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.4859, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3114981   71652]
#  [ 116799  536568]]
# Accuracy: 0.9509, CSI: 0.7401, Sensitivity: 0.8212, Specificity: 0.9775, False Alarm Ratio: 0.1178
#
#
# epoch n° 1488
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4198, Segmentation Loss:0.1278
# Train Confusion Matrix:
# [[3137134   68693]
#  [ 120498  513675]]
# Accuracy: 0.9507, CSI: 0.7308, Sensitivity: 0.8100, Specificity: 0.9786, False Alarm Ratio: 0.1180
#
#
# epoch n° 1489
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4053, Segmentation Loss:0.1282
# Train Confusion Matrix:
# [[3124286   70080]
#  [ 119465  526169]]
# Accuracy: 0.9506, CSI: 0.7352, Sensitivity: 0.8150, Specificity: 0.9781, False Alarm Ratio: 0.1175
#
#
# epoch n° 1490
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3536, Segmentation Loss:0.1308
# Train Confusion Matrix:
# [[3126035   70556]
#  [ 122468  520941]]
# Accuracy: 0.9497, CSI: 0.7296, Sensitivity: 0.8097, Specificity: 0.9779, False Alarm Ratio: 0.1193
#
#
# saving step
# epoch n° 1491
# Training, Regression Loss: 0.0374, Regression Loss 1h: 1.4041, Segmentation Loss:0.1237
# Train Confusion Matrix:
# [[3140478   68443]
#  [ 115017  516062]]
# Accuracy: 0.9522, CSI: 0.7377, Sensitivity: 0.8177, Specificity: 0.9787, False Alarm Ratio: 0.1171
#
#
# epoch n° 1492
# Training, Regression Loss: 0.0374, Regression Loss 1h: 1.5363, Segmentation Loss:0.1224
# Train Confusion Matrix:
# [[3134955   69265]
#  [ 112465  523315]]
# Accuracy: 0.9527, CSI: 0.7422, Sensitivity: 0.8231, Specificity: 0.9784, False Alarm Ratio: 0.1169
#
#
# epoch n° 1493
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4122, Segmentation Loss:0.1227
# Train Confusion Matrix:
# [[3123710   68795]
#  [ 113223  534272]]
# Accuracy: 0.9526, CSI: 0.7459, Sensitivity: 0.8251, Specificity: 0.9785, False Alarm Ratio: 0.1141
#
#
# epoch n° 1494
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4618, Segmentation Loss:0.1276
# Train Confusion Matrix:
# [[3128859   71072]
#  [ 119377  520692]]
# Accuracy: 0.9504, CSI: 0.7322, Sensitivity: 0.8135, Specificity: 0.9778, False Alarm Ratio: 0.1201
#
#
# epoch n° 1495
# Training, Regression Loss: 0.0347, Regression Loss 1h: 1.3477, Segmentation Loss:0.1269
# Train Confusion Matrix:
# [[3131538   69025]
#  [ 118963  520474]]
# Accuracy: 0.9510, CSI: 0.7347, Sensitivity: 0.8140, Specificity: 0.9784, False Alarm Ratio: 0.1171
#
#
# epoch n° 1496
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3684, Segmentation Loss:0.1267
# Train Confusion Matrix:
# [[3130438   70123]
#  [ 118173  521266]]
# Accuracy: 0.9510, CSI: 0.7346, Sensitivity: 0.8152, Specificity: 0.9781, False Alarm Ratio: 0.1186
#
#
# epoch n° 1497
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.3844, Segmentation Loss:0.1265
# Train Confusion Matrix:
# [[3128965   69075]
#  [ 119590  522370]]
# Accuracy: 0.9509, CSI: 0.7347, Sensitivity: 0.8137, Specificity: 0.9784, False Alarm Ratio: 0.1168
#
#
# epoch n° 1498
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3463, Segmentation Loss:0.1276
# Train Confusion Matrix:
# [[3130282   69693]
#  [ 119851  520174]]
# Accuracy: 0.9506, CSI: 0.7329, Sensitivity: 0.8127, Specificity: 0.9782, False Alarm Ratio: 0.1182
#
#
# epoch n° 1499
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.3672, Segmentation Loss:0.1275
# Train Confusion Matrix:
# [[3122728   70432]
#  [ 117675  529165]]
# Accuracy: 0.9510, CSI: 0.7377, Sensitivity: 0.8181, Specificity: 0.9779, False Alarm Ratio: 0.1175
#
#
# epoch n° 1500
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3167, Segmentation Loss:0.1266
# Train Confusion Matrix:
# [[3138790   68360]
#  [ 118991  513859]]
# Accuracy: 0.9512, CSI: 0.7328, Sensitivity: 0.8120, Specificity: 0.9787, False Alarm Ratio: 0.1174
#
#
# saving step
# epoch n° 1501
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.4174, Segmentation Loss:0.1256
# Train Confusion Matrix:
# [[3122655   70472]
#  [ 116438  530435]]
# Accuracy: 0.9513, CSI: 0.7394, Sensitivity: 0.8200, Specificity: 0.9779, False Alarm Ratio: 0.1173
#
#
# epoch n° 1502
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.4228, Segmentation Loss:0.1244
# Train Confusion Matrix:
# [[3133851   69960]
#  [ 115461  520728]]
# Accuracy: 0.9517, CSI: 0.7374, Sensitivity: 0.8185, Specificity: 0.9782, False Alarm Ratio: 0.1184
#
#
# epoch n° 1503
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.3780, Segmentation Loss:0.1258
# Train Confusion Matrix:
# [[3134439   68620]
#  [ 117880  519061]]
# Accuracy: 0.9514, CSI: 0.7357, Sensitivity: 0.8149, Specificity: 0.9786, False Alarm Ratio: 0.1168
#
#
# epoch n° 1504
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3921, Segmentation Loss:0.1313
# Train Confusion Matrix:
# [[3125713   71746]
#  [ 123569  518972]]
# Accuracy: 0.9491, CSI: 0.7266, Sensitivity: 0.8077, Specificity: 0.9776, False Alarm Ratio: 0.1215
#
#
# epoch n° 1505
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3785, Segmentation Loss:0.1252
# Train Confusion Matrix:
# [[3126537   69572]
#  [ 116602  527289]]
# Accuracy: 0.9515, CSI: 0.7391, Sensitivity: 0.8189, Specificity: 0.9782, False Alarm Ratio: 0.1166
#
#
# epoch n° 1506
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3879, Segmentation Loss:0.1249
# Train Confusion Matrix:
# [[3141689   68660]
#  [ 116126  513525]]
# Accuracy: 0.9519, CSI: 0.7354, Sensitivity: 0.8156, Specificity: 0.9786, False Alarm Ratio: 0.1179
#
#
# epoch n° 1507
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3664, Segmentation Loss:0.1256
# Train Confusion Matrix:
# [[3134452   69380]
#  [ 116890  519278]]
# Accuracy: 0.9515, CSI: 0.7360, Sensitivity: 0.8163, Specificity: 0.9783, False Alarm Ratio: 0.1179
#
#
# epoch n° 1508
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.4252, Segmentation Loss:0.1223
# Train Confusion Matrix:
# [[3128834   69395]
#  [ 112721  529050]]
# Accuracy: 0.9526, CSI: 0.7439, Sensitivity: 0.8244, Specificity: 0.9783, False Alarm Ratio: 0.1160
#
#
# epoch n° 1509
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4401, Segmentation Loss:0.1251
# Train Confusion Matrix:
# [[3132759   69404]
#  [ 116408  521429]]
# Accuracy: 0.9516, CSI: 0.7373, Sensitivity: 0.8175, Specificity: 0.9783, False Alarm Ratio: 0.1175
#
#
# epoch n° 1510
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4106, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3129902   69413]
#  [ 117107  523578]]
# Accuracy: 0.9514, CSI: 0.7373, Sensitivity: 0.8172, Specificity: 0.9783, False Alarm Ratio: 0.1171
#
#
# saving step
# epoch n° 1511
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4136, Segmentation Loss:0.1222
# Train Confusion Matrix:
# [[3126385   70079]
#  [ 111973  531563]]
# Accuracy: 0.9526, CSI: 0.7449, Sensitivity: 0.8260, Specificity: 0.9781, False Alarm Ratio: 0.1165
#
#
# epoch n° 1512
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4390, Segmentation Loss:0.1256
# Train Confusion Matrix:
# [[3125756   70102]
#  [ 117500  526642]]
# Accuracy: 0.9511, CSI: 0.7373, Sensitivity: 0.8176, Specificity: 0.9781, False Alarm Ratio: 0.1175
#
#
# epoch n° 1513
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.4010, Segmentation Loss:0.1316
# Train Confusion Matrix:
# [[3116077   71047]
#  [ 124423  528453]]
# Accuracy: 0.9491, CSI: 0.7300, Sensitivity: 0.8094, Specificity: 0.9777, False Alarm Ratio: 0.1185
#
#
# epoch n° 1514
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4877, Segmentation Loss:0.1288
# Train Confusion Matrix:
# [[3122318   70328]
#  [ 120796  526558]]
# Accuracy: 0.9502, CSI: 0.7337, Sensitivity: 0.8134, Specificity: 0.9780, False Alarm Ratio: 0.1178
#
#
# epoch n° 1515
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4805, Segmentation Loss:0.1243
# Train Confusion Matrix:
# [[3126143   68817]
#  [ 115490  529550]]
# Accuracy: 0.9520, CSI: 0.7418, Sensitivity: 0.8210, Specificity: 0.9785, False Alarm Ratio: 0.1150
#
#
# epoch n° 1516
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.4982, Segmentation Loss:0.1299
# Train Confusion Matrix:
# [[3126242   69757]
#  [ 122208  521793]]
# Accuracy: 0.9500, CSI: 0.7311, Sensitivity: 0.8102, Specificity: 0.9782, False Alarm Ratio: 0.1179
#
#
# epoch n° 1517
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.5210, Segmentation Loss:0.1291
# Train Confusion Matrix:
# [[3121466   71097]
#  [ 120220  527217]]
# Accuracy: 0.9502, CSI: 0.7337, Sensitivity: 0.8143, Specificity: 0.9777, False Alarm Ratio: 0.1188
#
#
# epoch n° 1518
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3249, Segmentation Loss:0.1254
# Train Confusion Matrix:
# [[3138145   69432]
#  [ 116629  515794]]
# Accuracy: 0.9515, CSI: 0.7349, Sensitivity: 0.8156, Specificity: 0.9784, False Alarm Ratio: 0.1186
#
#
# epoch n° 1519
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.4285, Segmentation Loss:0.1272
# Train Confusion Matrix:
# [[3125292   69336]
#  [ 118874  526498]]
# Accuracy: 0.9510, CSI: 0.7367, Sensitivity: 0.8158, Specificity: 0.9783, False Alarm Ratio: 0.1164
#
#
# epoch n° 1520
# Training, Regression Loss: 0.0374, Regression Loss 1h: 1.4538, Segmentation Loss:0.1234
# Train Confusion Matrix:
# [[3110653   70890]
#  [ 113733  544724]]
# Accuracy: 0.9519, CSI: 0.7469, Sensitivity: 0.8273, Specificity: 0.9777, False Alarm Ratio: 0.1152
#
#
# saving step
# epoch n° 1521
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3930, Segmentation Loss:0.1279
# Train Confusion Matrix:
# [[3126835   70655]
#  [ 118835  523675]]
# Accuracy: 0.9507, CSI: 0.7343, Sensitivity: 0.8150, Specificity: 0.9779, False Alarm Ratio: 0.1189
#
#
# epoch n° 1522
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.3462, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3120644   69361]
#  [ 117853  532142]]
# Accuracy: 0.9512, CSI: 0.7397, Sensitivity: 0.8187, Specificity: 0.9783, False Alarm Ratio: 0.1153
#
#
# epoch n° 1523
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.3849, Segmentation Loss:0.1232
# Train Confusion Matrix:
# [[3143833   68402]
#  [ 113635  514130]]
# Accuracy: 0.9526, CSI: 0.7385, Sensitivity: 0.8190, Specificity: 0.9787, False Alarm Ratio: 0.1174
#
#
# epoch n° 1524
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.3542, Segmentation Loss:0.1257
# Train Confusion Matrix:
# [[3133128   68951]
#  [ 118384  519537]]
# Accuracy: 0.9512, CSI: 0.7350, Sensitivity: 0.8144, Specificity: 0.9785, False Alarm Ratio: 0.1172
#
#
# epoch n° 1525
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3472, Segmentation Loss:0.1263
# Train Confusion Matrix:
# [[3126315   70013]
#  [ 117993  525679]]
# Accuracy: 0.9510, CSI: 0.7366, Sensitivity: 0.8167, Specificity: 0.9781, False Alarm Ratio: 0.1175
#
#
# epoch n° 1526
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.3504, Segmentation Loss:0.1288
# Train Confusion Matrix:
# [[3130842   70167]
#  [ 120694  518297]]
# Accuracy: 0.9503, CSI: 0.7309, Sensitivity: 0.8111, Specificity: 0.9781, False Alarm Ratio: 0.1192
#
#
# epoch n° 1527
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3571, Segmentation Loss:0.1267
# Train Confusion Matrix:
# [[3122026   70179]
#  [ 118190  529605]]
# Accuracy: 0.9509, CSI: 0.7376, Sensitivity: 0.8176, Specificity: 0.9780, False Alarm Ratio: 0.1170
#
#
# epoch n° 1528
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.3827, Segmentation Loss:0.1279
# Train Confusion Matrix:
# [[3127450   70367]
#  [ 120613  521570]]
# Accuracy: 0.9503, CSI: 0.7320, Sensitivity: 0.8122, Specificity: 0.9780, False Alarm Ratio: 0.1189
#
#
# epoch n° 1529
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4443, Segmentation Loss:0.1247
# Train Confusion Matrix:
# [[3132910   69039]
#  [ 115913  522138]]
# Accuracy: 0.9518, CSI: 0.7384, Sensitivity: 0.8183, Specificity: 0.9784, False Alarm Ratio: 0.1168
#
#
# epoch n° 1530
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4584, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3128023   70720]
#  [ 113995  527262]]
# Accuracy: 0.9519, CSI: 0.7406, Sensitivity: 0.8222, Specificity: 0.9779, False Alarm Ratio: 0.1183
#
#
# saving step
# epoch n° 1531
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4845, Segmentation Loss:0.1262
# Train Confusion Matrix:
# [[3132015   70228]
#  [ 117385  520372]]
# Accuracy: 0.9511, CSI: 0.7350, Sensitivity: 0.8159, Specificity: 0.9781, False Alarm Ratio: 0.1189
#
#
# epoch n° 1532
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.4008, Segmentation Loss:0.1258
# Train Confusion Matrix:
# [[3135236   68856]
#  [ 117377  518531]]
# Accuracy: 0.9515, CSI: 0.7358, Sensitivity: 0.8154, Specificity: 0.9785, False Alarm Ratio: 0.1172
#
#
# epoch n° 1533
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3395, Segmentation Loss:0.1299
# Train Confusion Matrix:
# [[3121069   70967]
#  [ 121412  526552]]
# Accuracy: 0.9499, CSI: 0.7324, Sensitivity: 0.8126, Specificity: 0.9778, False Alarm Ratio: 0.1188
#
#
# epoch n° 1534
# Training, Regression Loss: 0.0356, Regression Loss 1h: 1.4310, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3126459   70484]
#  [ 118054  525003]]
# Accuracy: 0.9509, CSI: 0.7358, Sensitivity: 0.8164, Specificity: 0.9780, False Alarm Ratio: 0.1184
#
#
# epoch n° 1535
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.5636, Segmentation Loss:0.1239
# Train Confusion Matrix:
# [[3124465   69808]
#  [ 115005  530722]]
# Accuracy: 0.9519, CSI: 0.7417, Sensitivity: 0.8219, Specificity: 0.9781, False Alarm Ratio: 0.1162
#
#
# epoch n° 1536
# Training, Regression Loss: 0.0364, Regression Loss 1h: 1.4331, Segmentation Loss:0.1236
# Train Confusion Matrix:
# [[3126335   69115]
#  [ 114275  530275]]
# Accuracy: 0.9522, CSI: 0.7430, Sensitivity: 0.8227, Specificity: 0.9784, False Alarm Ratio: 0.1153
#
#
# epoch n° 1537
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4460, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3121955   70081]
#  [ 115224  532740]]
# Accuracy: 0.9517, CSI: 0.7419, Sensitivity: 0.8222, Specificity: 0.9780, False Alarm Ratio: 0.1163
#
#
# epoch n° 1538
# Training, Regression Loss: 0.0354, Regression Loss 1h: 1.4439, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3140063   68956]
#  [ 120894  510087]]
# Accuracy: 0.9506, CSI: 0.7288, Sensitivity: 0.8084, Specificity: 0.9785, False Alarm Ratio: 0.1191
#
#
# epoch n° 1539
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3758, Segmentation Loss:0.1249
# Train Confusion Matrix:
# [[3129826   69570]
#  [ 115792  524812]]
# Accuracy: 0.9517, CSI: 0.7390, Sensitivity: 0.8192, Specificity: 0.9783, False Alarm Ratio: 0.1170
#
#
# epoch n° 1540
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3626, Segmentation Loss:0.1265
# Train Confusion Matrix:
# [[3131531   69895]
#  [ 118272  520302]]
# Accuracy: 0.9510, CSI: 0.7344, Sensitivity: 0.8148, Specificity: 0.9782, False Alarm Ratio: 0.1184
#
#
# saving step
# epoch n° 1541
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3525, Segmentation Loss:0.1263
# Train Confusion Matrix:
# [[3142995   68738]
#  [ 118217  510050]]
# Accuracy: 0.9513, CSI: 0.7318, Sensitivity: 0.8118, Specificity: 0.9786, False Alarm Ratio: 0.1188
#
#
# epoch n° 1542
# Training, Regression Loss: 0.0367, Regression Loss 1h: 1.4123, Segmentation Loss:0.1247
# Train Confusion Matrix:
# [[3131498   68660]
#  [ 116117  523725]]
# Accuracy: 0.9519, CSI: 0.7392, Sensitivity: 0.8185, Specificity: 0.9785, False Alarm Ratio: 0.1159
#
#
# epoch n° 1543
# Training, Regression Loss: 0.0372, Regression Loss 1h: 1.4755, Segmentation Loss:0.1251
# Train Confusion Matrix:
# [[3129993   69139]
#  [ 116348  524520]]
# Accuracy: 0.9517, CSI: 0.7388, Sensitivity: 0.8185, Specificity: 0.9784, False Alarm Ratio: 0.1165
#
#
# epoch n° 1544
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4031, Segmentation Loss:0.1276
# Train Confusion Matrix:
# [[3125728   70405]
#  [ 119621  524246]]
# Accuracy: 0.9505, CSI: 0.7340, Sensitivity: 0.8142, Specificity: 0.9780, False Alarm Ratio: 0.1184
#
#
# epoch n° 1545
# Training, Regression Loss: 0.0371, Regression Loss 1h: 1.4719, Segmentation Loss:0.1215
# Train Confusion Matrix:
# [[3135453   68793]
#  [ 112644  523110]]
# Accuracy: 0.9528, CSI: 0.7425, Sensitivity: 0.8228, Specificity: 0.9785, False Alarm Ratio: 0.1162
#
#
# epoch n° 1546
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.4022, Segmentation Loss:0.1274
# Train Confusion Matrix:
# [[3128753   69552]
#  [ 119266  522429]]
# Accuracy: 0.9508, CSI: 0.7345, Sensitivity: 0.8141, Specificity: 0.9783, False Alarm Ratio: 0.1175
#
#
# epoch n° 1547
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3572, Segmentation Loss:0.1245
# Train Confusion Matrix:
# [[3130591   68173]
#  [ 115225  526011]]
# Accuracy: 0.9522, CSI: 0.7415, Sensitivity: 0.8203, Specificity: 0.9787, False Alarm Ratio: 0.1147
#
#
# epoch n° 1548
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4286, Segmentation Loss:0.1256
# Train Confusion Matrix:
# [[3132008   69641]
#  [ 116977  521374]]
# Accuracy: 0.9514, CSI: 0.7364, Sensitivity: 0.8168, Specificity: 0.9782, False Alarm Ratio: 0.1178
#
#
# epoch n° 1549
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3417, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3133494   69285]
#  [ 118237  518984]]
# Accuracy: 0.9512, CSI: 0.7346, Sensitivity: 0.8144, Specificity: 0.9784, False Alarm Ratio: 0.1178
#
#
# epoch n° 1550
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3958, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3139100   68915]
#  [ 116081  515904]]
# Accuracy: 0.9518, CSI: 0.7361, Sensitivity: 0.8163, Specificity: 0.9785, False Alarm Ratio: 0.1178
#
#
# saving step
# epoch n° 1551
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3510, Segmentation Loss:0.1275
# Train Confusion Matrix:
# [[3131284   69866]
#  [ 119573  519277]]
# Accuracy: 0.9507, CSI: 0.7327, Sensitivity: 0.8128, Specificity: 0.9782, False Alarm Ratio: 0.1186
#
#
# epoch n° 1552
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3903, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3122043   69749]
#  [ 117413  530795]]
# Accuracy: 0.9513, CSI: 0.7393, Sensitivity: 0.8189, Specificity: 0.9781, False Alarm Ratio: 0.1161
#
#
# epoch n° 1553
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.4164, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3131373   69823]
#  [ 116992  521812]]
# Accuracy: 0.9514, CSI: 0.7364, Sensitivity: 0.8169, Specificity: 0.9782, False Alarm Ratio: 0.1180
#
#
# epoch n° 1554
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3840, Segmentation Loss:0.1295
# Train Confusion Matrix:
# [[3133142   69102]
#  [ 121911  515845]]
# Accuracy: 0.9503, CSI: 0.7298, Sensitivity: 0.8088, Specificity: 0.9784, False Alarm Ratio: 0.1181
#
#
# epoch n° 1555
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3838, Segmentation Loss:0.1294
# Train Confusion Matrix:
# [[3126102   69075]
#  [ 122152  522671]]
# Accuracy: 0.9502, CSI: 0.7321, Sensitivity: 0.8106, Specificity: 0.9784, False Alarm Ratio: 0.1167
#
#
# epoch n° 1556
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3729, Segmentation Loss:0.1267
# Train Confusion Matrix:
# [[3130141   69487]
#  [ 118772  521600]]
# Accuracy: 0.9510, CSI: 0.7348, Sensitivity: 0.8145, Specificity: 0.9783, False Alarm Ratio: 0.1176
#
#
# epoch n° 1557
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.3841, Segmentation Loss:0.1261
# Train Confusion Matrix:
# [[3124726   70502]
#  [ 116649  528123]]
# Accuracy: 0.9513, CSI: 0.7384, Sensitivity: 0.8191, Specificity: 0.9779, False Alarm Ratio: 0.1178
#
#
# epoch n° 1558
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3979, Segmentation Loss:0.1297
# Train Confusion Matrix:
# [[3126078   69023]
#  [ 122247  522652]]
# Accuracy: 0.9502, CSI: 0.7321, Sensitivity: 0.8104, Specificity: 0.9784, False Alarm Ratio: 0.1167
#
#
# epoch n° 1559
# Training, Regression Loss: 0.0342, Regression Loss 1h: 1.2680, Segmentation Loss:0.1292
# Train Confusion Matrix:
# [[3129392   69000]
#  [ 122199  519409]]
# Accuracy: 0.9502, CSI: 0.7309, Sensitivity: 0.8095, Specificity: 0.9784, False Alarm Ratio: 0.1173
#
#
# epoch n° 1560
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.4138, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3133661   68317]
#  [ 115249  522773]]
# Accuracy: 0.9522, CSI: 0.7401, Sensitivity: 0.8194, Specificity: 0.9787, False Alarm Ratio: 0.1156
#
#
# saving step
# epoch n° 1561
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3935, Segmentation Loss:0.1218
# Train Confusion Matrix:
# [[3132424   68817]
#  [ 112974  525785]]
# Accuracy: 0.9527, CSI: 0.7431, Sensitivity: 0.8231, Specificity: 0.9785, False Alarm Ratio: 0.1157
#
#
# epoch n° 1562
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4319, Segmentation Loss:0.1239
# Train Confusion Matrix:
# [[3137738   69131]
#  [ 114964  518167]]
# Accuracy: 0.9521, CSI: 0.7379, Sensitivity: 0.8184, Specificity: 0.9784, False Alarm Ratio: 0.1177
#
#
# epoch n° 1563
# Training, Regression Loss: 0.0366, Regression Loss 1h: 1.4824, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3120015   70386]
#  [ 114505  535094]]
# Accuracy: 0.9519, CSI: 0.7432, Sensitivity: 0.8237, Specificity: 0.9779, False Alarm Ratio: 0.1162
#
#
# epoch n° 1564
# Training, Regression Loss: 0.0354, Regression Loss 1h: 1.3238, Segmentation Loss:0.1229
# Train Confusion Matrix:
# [[3132868   68732]
#  [ 113764  524636]]
# Accuracy: 0.9525, CSI: 0.7419, Sensitivity: 0.8218, Specificity: 0.9785, False Alarm Ratio: 0.1158
#
#
# epoch n° 1565
# Training, Regression Loss: 0.0369, Regression Loss 1h: 1.4002, Segmentation Loss:0.1234
# Train Confusion Matrix:
# [[3121422   69473]
#  [ 113859  535246]]
# Accuracy: 0.9523, CSI: 0.7449, Sensitivity: 0.8246, Specificity: 0.9782, False Alarm Ratio: 0.1149
#
#
# epoch n° 1566
# Training, Regression Loss: 0.0365, Regression Loss 1h: 1.4040, Segmentation Loss:0.1262
# Train Confusion Matrix:
# [[3125565   69533]
#  [ 118450  526452]]
# Accuracy: 0.9510, CSI: 0.7369, Sensitivity: 0.8163, Specificity: 0.9782, False Alarm Ratio: 0.1167
#
#
# epoch n° 1567
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.4068, Segmentation Loss:0.1279
# Train Confusion Matrix:
# [[3130479   70316]
#  [ 120075  519130]]
# Accuracy: 0.9504, CSI: 0.7317, Sensitivity: 0.8121, Specificity: 0.9780, False Alarm Ratio: 0.1193
#
#
# epoch n° 1568
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.3279, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3133929   68642]
#  [ 115580  521849]]
# Accuracy: 0.9520, CSI: 0.7391, Sensitivity: 0.8187, Specificity: 0.9786, False Alarm Ratio: 0.1162
#
#
# epoch n° 1569
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3986, Segmentation Loss:0.1258
# Train Confusion Matrix:
# [[3132577   69439]
#  [ 116901  521083]]
# Accuracy: 0.9515, CSI: 0.7366, Sensitivity: 0.8168, Specificity: 0.9783, False Alarm Ratio: 0.1176
#
#
# epoch n° 1570
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3239, Segmentation Loss:0.1281
# Train Confusion Matrix:
# [[3129077   70048]
#  [ 119482  521393]]
# Accuracy: 0.9506, CSI: 0.7334, Sensitivity: 0.8136, Specificity: 0.9781, False Alarm Ratio: 0.1184
#
#
# saving step
# epoch n° 1571
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.4536, Segmentation Loss:0.1275
# Train Confusion Matrix:
# [[3126553   69256]
#  [ 120400  523791]]
# Accuracy: 0.9506, CSI: 0.7342, Sensitivity: 0.8131, Specificity: 0.9783, False Alarm Ratio: 0.1168
#
#
# epoch n° 1572
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.3438, Segmentation Loss:0.1269
# Train Confusion Matrix:
# [[3127605   68848]
#  [ 118962  524585]]
# Accuracy: 0.9511, CSI: 0.7364, Sensitivity: 0.8151, Specificity: 0.9785, False Alarm Ratio: 0.1160
#
#
# epoch n° 1573
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.4448, Segmentation Loss:0.1279
# Train Confusion Matrix:
# [[3124767   69865]
#  [ 118898  526470]]
# Accuracy: 0.9508, CSI: 0.7361, Sensitivity: 0.8158, Specificity: 0.9781, False Alarm Ratio: 0.1172
#
#
# epoch n° 1574
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3388, Segmentation Loss:0.1245
# Train Confusion Matrix:
# [[3134089   69805]
#  [ 115742  520364]]
# Accuracy: 0.9517, CSI: 0.7372, Sensitivity: 0.8180, Specificity: 0.9782, False Alarm Ratio: 0.1183
#
#
# epoch n° 1575
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3254, Segmentation Loss:0.1305
# Train Confusion Matrix:
# [[3130375   69763]
#  [ 123338  516524]]
# Accuracy: 0.9497, CSI: 0.7279, Sensitivity: 0.8072, Specificity: 0.9782, False Alarm Ratio: 0.1190
#
#
# epoch n° 1576
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.3171, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3126713   68958]
#  [ 115610  528719]]
# Accuracy: 0.9519, CSI: 0.7412, Sensitivity: 0.8206, Specificity: 0.9784, False Alarm Ratio: 0.1154
#
#
# epoch n° 1577
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4250, Segmentation Loss:0.1221
# Train Confusion Matrix:
# [[3119140   70217]
#  [ 111547  539096]]
# Accuracy: 0.9527, CSI: 0.7479, Sensitivity: 0.8286, Specificity: 0.9780, False Alarm Ratio: 0.1152
#
#
# epoch n° 1578
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3428, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3131175   68989]
#  [ 117267  522569]]
# Accuracy: 0.9515, CSI: 0.7372, Sensitivity: 0.8167, Specificity: 0.9784, False Alarm Ratio: 0.1166
#
#
# epoch n° 1579
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3978, Segmentation Loss:0.1269
# Train Confusion Matrix:
# [[3126359   69580]
#  [ 118995  525066]]
# Accuracy: 0.9509, CSI: 0.7358, Sensitivity: 0.8152, Specificity: 0.9782, False Alarm Ratio: 0.1170
#
#
# epoch n° 1580
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4247, Segmentation Loss:0.1283
# Train Confusion Matrix:
# [[3132431   69870]
#  [ 121058  516641]]
# Accuracy: 0.9503, CSI: 0.7302, Sensitivity: 0.8102, Specificity: 0.9782, False Alarm Ratio: 0.1191
#
#
# saving step
# epoch n° 1581
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3435, Segmentation Loss:0.1279
# Train Confusion Matrix:
# [[3123909   70241]
#  [ 120868  524982]]
# Accuracy: 0.9502, CSI: 0.7331, Sensitivity: 0.8129, Specificity: 0.9780, False Alarm Ratio: 0.1180
#
#
# epoch n° 1582
# Training, Regression Loss: 0.0354, Regression Loss 1h: 1.3411, Segmentation Loss:0.1293
# Train Confusion Matrix:
# [[3135455   69602]
#  [ 121822  513121]]
# Accuracy: 0.9502, CSI: 0.7283, Sensitivity: 0.8081, Specificity: 0.9783, False Alarm Ratio: 0.1194
#
#
# epoch n° 1583
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3579, Segmentation Loss:0.1271
# Train Confusion Matrix:
# [[3128235   68759]
#  [ 119715  523291]]
# Accuracy: 0.9509, CSI: 0.7352, Sensitivity: 0.8138, Specificity: 0.9785, False Alarm Ratio: 0.1161
#
#
# epoch n° 1584
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3665, Segmentation Loss:0.1234
# Train Confusion Matrix:
# [[3120180   70139]
#  [ 113743  535938]]
# Accuracy: 0.9521, CSI: 0.7445, Sensitivity: 0.8249, Specificity: 0.9780, False Alarm Ratio: 0.1157
#
#
# epoch n° 1585
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3936, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3121841   69575]
#  [ 116841  531743]]
# Accuracy: 0.9515, CSI: 0.7404, Sensitivity: 0.8199, Specificity: 0.9782, False Alarm Ratio: 0.1157
#
#
# epoch n° 1586
# Training, Regression Loss: 0.0359, Regression Loss 1h: 1.4443, Segmentation Loss:0.1263
# Train Confusion Matrix:
# [[3127739   69500]
#  [ 118014  524747]]
# Accuracy: 0.9512, CSI: 0.7367, Sensitivity: 0.8164, Specificity: 0.9783, False Alarm Ratio: 0.1170
#
#
# epoch n° 1587
# Training, Regression Loss: 0.0361, Regression Loss 1h: 1.3933, Segmentation Loss:0.1229
# Train Confusion Matrix:
# [[3132794   69190]
#  [ 114778  523238]]
# Accuracy: 0.9521, CSI: 0.7399, Sensitivity: 0.8201, Specificity: 0.9784, False Alarm Ratio: 0.1168
#
#
# epoch n° 1588
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.4113, Segmentation Loss:0.1264
# Train Confusion Matrix:
# [[3123111   70801]
#  [ 118007  528081]]
# Accuracy: 0.9508, CSI: 0.7366, Sensitivity: 0.8174, Specificity: 0.9778, False Alarm Ratio: 0.1182
#
#
# epoch n° 1589
# Training, Regression Loss: 0.0368, Regression Loss 1h: 1.3759, Segmentation Loss:0.1222
# Train Confusion Matrix:
# [[3129680   70083]
#  [ 112454  527783]]
# Accuracy: 0.9525, CSI: 0.7430, Sensitivity: 0.8244, Specificity: 0.9781, False Alarm Ratio: 0.1172
#
#
# epoch n° 1590
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.5608, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3127771   69235]
#  [ 117677  525317]]
# Accuracy: 0.9513, CSI: 0.7376, Sensitivity: 0.8170, Specificity: 0.9783, False Alarm Ratio: 0.1164
#
#
# saving step
# epoch n° 1591
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4146, Segmentation Loss:0.1220
# Train Confusion Matrix:
# [[3137766   68353]
#  [ 113143  520738]]
# Accuracy: 0.9527, CSI: 0.7415, Sensitivity: 0.8215, Specificity: 0.9787, False Alarm Ratio: 0.1160
#
#
# epoch n° 1592
# Training, Regression Loss: 0.0357, Regression Loss 1h: 1.3656, Segmentation Loss:0.1256
# Train Confusion Matrix:
# [[3137337   69048]
#  [ 117487  516128]]
# Accuracy: 0.9514, CSI: 0.7345, Sensitivity: 0.8146, Specificity: 0.9785, False Alarm Ratio: 0.1180
#
#
# epoch n° 1593
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4250, Segmentation Loss:0.1258
# Train Confusion Matrix:
# [[3123578   69776]
#  [ 117180  529466]]
# Accuracy: 0.9513, CSI: 0.7390, Sensitivity: 0.8188, Specificity: 0.9781, False Alarm Ratio: 0.1164
#
#
# epoch n° 1594
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.4232, Segmentation Loss:0.1270
# Train Confusion Matrix:
# [[3123064   70448]
#  [ 117706  528782]]
# Accuracy: 0.9510, CSI: 0.7376, Sensitivity: 0.8179, Specificity: 0.9779, False Alarm Ratio: 0.1176
#
#
# epoch n° 1595
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.3830, Segmentation Loss:0.1285
# Train Confusion Matrix:
# [[3128246   70420]
#  [ 120751  520583]]
# Accuracy: 0.9502, CSI: 0.7314, Sensitivity: 0.8117, Specificity: 0.9780, False Alarm Ratio: 0.1192
#
#
# epoch n° 1596
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3822, Segmentation Loss:0.1251
# Train Confusion Matrix:
# [[3139224   68365]
#  [ 116602  515809]]
# Accuracy: 0.9518, CSI: 0.7361, Sensitivity: 0.8156, Specificity: 0.9787, False Alarm Ratio: 0.1170
#
#
# epoch n° 1597
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3434, Segmentation Loss:0.1242
# Train Confusion Matrix:
# [[3128577   70099]
#  [ 115021  526303]]
# Accuracy: 0.9518, CSI: 0.7398, Sensitivity: 0.8207, Specificity: 0.9781, False Alarm Ratio: 0.1175
#
#
# epoch n° 1598
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3713, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3136905   69316]
#  [ 117966  515813]]
# Accuracy: 0.9512, CSI: 0.7336, Sensitivity: 0.8139, Specificity: 0.9784, False Alarm Ratio: 0.1185
#
#
# epoch n° 1599
# Training, Regression Loss: 0.0360, Regression Loss 1h: 1.3538, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3129551   69342]
#  [ 115606  525501]]
# Accuracy: 0.9518, CSI: 0.7397, Sensitivity: 0.8197, Specificity: 0.9783, False Alarm Ratio: 0.1166
#
#
# epoch n° 1600
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3602, Segmentation Loss:0.1262
# Train Confusion Matrix:
# [[3135708   69080]
#  [ 117881  517331]]
# ...
# Train Confusion Matrix:
# [[3127794   68644]
#  [ 118694  524868]]
# Accuracy: 0.9512, CSI: 0.7370, Sensitivity: 0.8156, Specificity: 0.9785, False Alarm Ratio: 0.1157
#
#
# epoch n° 1815
# Training, Regression Loss: 0.0354, Regression Loss 1h: 1.3766, Segmentation Loss:0.1232
# Train Confusion Matrix:
# [[3127908   69119]
#  [ 114112  528861]]
# Accuracy: 0.9523, CSI: 0.7427, Sensitivity: 0.8225, Specificity: 0.9784, False Alarm Ratio: 0.1156
#
#
# epoch n° 1816
# Training, Regression Loss: 0.0343, Regression Loss 1h: 1.2698, Segmentation Loss:0.1259
# Train Confusion Matrix:
# [[3132420   68324]
#  [ 118302  520954]]
# Accuracy: 0.9514, CSI: 0.7362, Sensitivity: 0.8149, Specificity: 0.9787, False Alarm Ratio: 0.1159
#
#
# epoch n° 1817
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3254, Segmentation Loss:0.1236
# Train Confusion Matrix:
# [[3133181   69558]
#  [ 114978  522283]]
# Accuracy: 0.9519, CSI: 0.7389, Sensitivity: 0.8196, Specificity: 0.9783, False Alarm Ratio: 0.1175
#
#
# epoch n° 1818
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3146, Segmentation Loss:0.1227
# Train Confusion Matrix:
# [[3134848   68255]
#  [ 114701  522196]]
# Accuracy: 0.9524, CSI: 0.7405, Sensitivity: 0.8199, Specificity: 0.9787, False Alarm Ratio: 0.1156
#
#
# epoch n° 1819
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.4038, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3129440   70018]
#  [ 116067  524475]]
# Accuracy: 0.9515, CSI: 0.7381, Sensitivity: 0.8188, Specificity: 0.9781, False Alarm Ratio: 0.1178
#
#
# epoch n° 1820
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3471, Segmentation Loss:0.1238
# Train Confusion Matrix:
# [[3131804   68867]
#  [ 115027  524302]]
# Accuracy: 0.9521, CSI: 0.7403, Sensitivity: 0.8201, Specificity: 0.9785, False Alarm Ratio: 0.1161
#
#
# saving step
# epoch n° 1821
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3057, Segmentation Loss:0.1228
# Train Confusion Matrix:
# [[3135756   68527]
#  [ 114195  521522]]
# Accuracy: 0.9524, CSI: 0.7405, Sensitivity: 0.8204, Specificity: 0.9786, False Alarm Ratio: 0.1161
#
#
# epoch n° 1822
# Training, Regression Loss: 0.0345, Regression Loss 1h: 1.3746, Segmentation Loss:0.1311
# Train Confusion Matrix:
# [[3120041   70107]
#  [ 124330  525522]]
# Accuracy: 0.9494, CSI: 0.7299, Sensitivity: 0.8087, Specificity: 0.9780, False Alarm Ratio: 0.1177
#
#
# epoch n° 1823
# Training, Regression Loss: 0.0358, Regression Loss 1h: 1.3546, Segmentation Loss:0.1228
# Train Confusion Matrix:
# [[3123673   70927]
#  [ 113081  532319]]
# Accuracy: 0.9521, CSI: 0.7431, Sensitivity: 0.8248, Specificity: 0.9778, False Alarm Ratio: 0.1176
#
#
# epoch n° 1824
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3232, Segmentation Loss:0.1234
# Train Confusion Matrix:
# [[3130696   68395]
#  [ 115458  525451]]
# Accuracy: 0.9521, CSI: 0.7408, Sensitivity: 0.8199, Specificity: 0.9786, False Alarm Ratio: 0.1152
#
#
# epoch n° 1825
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3019, Segmentation Loss:0.1251
# Train Confusion Matrix:
# [[3134241   68563]
#  [ 117570  519626]]
# Accuracy: 0.9515, CSI: 0.7363, Sensitivity: 0.8155, Specificity: 0.9786, False Alarm Ratio: 0.1166
#
#
# epoch n° 1826
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3368, Segmentation Loss:0.1252
# Train Confusion Matrix:
# [[3126303   69509]
#  [ 116758  527430]]
# Accuracy: 0.9515, CSI: 0.7390, Sensitivity: 0.8188, Specificity: 0.9782, False Alarm Ratio: 0.1164
#
#
# epoch n° 1827
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.4503, Segmentation Loss:0.1223
# Train Confusion Matrix:
# [[3125485   69439]
#  [ 113287  531789]]
# Accuracy: 0.9524, CSI: 0.7443, Sensitivity: 0.8244, Specificity: 0.9783, False Alarm Ratio: 0.1155
#
#
# epoch n° 1828
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.3459, Segmentation Loss:0.1212
# Train Confusion Matrix:
# [[3125245   69418]
#  [ 112065  533272]]
# Accuracy: 0.9527, CSI: 0.7461, Sensitivity: 0.8263, Specificity: 0.9783, False Alarm Ratio: 0.1152
#
#
# epoch n° 1829
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3152, Segmentation Loss:0.1223
# Train Confusion Matrix:
# [[3122691   69022]
#  [ 113414  534873]]
# Accuracy: 0.9525, CSI: 0.7457, Sensitivity: 0.8251, Specificity: 0.9784, False Alarm Ratio: 0.1143
#
#
# epoch n° 1830
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.4379, Segmentation Loss:0.1205
# Train Confusion Matrix:
# [[3125702   68383]
#  [ 111213  534702]]
# Accuracy: 0.9532, CSI: 0.7486, Sensitivity: 0.8278, Specificity: 0.9786, False Alarm Ratio: 0.1134
#
#
# saving step
# epoch n° 1831
# Training, Regression Loss: 0.0363, Regression Loss 1h: 1.3316, Segmentation Loss:0.1229
# Train Confusion Matrix:
# [[3130903   68319]
#  [ 114161  526617]]
# Accuracy: 0.9525, CSI: 0.7427, Sensitivity: 0.8218, Specificity: 0.9786, False Alarm Ratio: 0.1148
#
#
# epoch n° 1832
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3309, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3136475   69208]
#  [ 115869  518448]]
# Accuracy: 0.9518, CSI: 0.7369, Sensitivity: 0.8173, Specificity: 0.9784, False Alarm Ratio: 0.1178
#
#
# epoch n° 1833
# Training, Regression Loss: 0.0343, Regression Loss 1h: 1.2968, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3133717   67998]
#  [ 121159  517126]]
# Accuracy: 0.9507, CSI: 0.7322, Sensitivity: 0.8102, Specificity: 0.9788, False Alarm Ratio: 0.1162
#
#
# epoch n° 1834
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3490, Segmentation Loss:0.1249
# Train Confusion Matrix:
# [[3123788   69199]
#  [ 115749  531264]]
# Accuracy: 0.9518, CSI: 0.7418, Sensitivity: 0.8211, Specificity: 0.9783, False Alarm Ratio: 0.1152
#
#
# epoch n° 1835
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3742, Segmentation Loss:0.1238
# Train Confusion Matrix:
# [[3131754   69195]
#  [ 115356  523695]]
# Accuracy: 0.9519, CSI: 0.7394, Sensitivity: 0.8195, Specificity: 0.9784, False Alarm Ratio: 0.1167
#
#
# epoch n° 1836
# Training, Regression Loss: 0.0347, Regression Loss 1h: 1.3534, Segmentation Loss:0.1247
# Train Confusion Matrix:
# [[3130889   69543]
#  [ 116172  523396]]
# Accuracy: 0.9516, CSI: 0.7381, Sensitivity: 0.8184, Specificity: 0.9783, False Alarm Ratio: 0.1173
#
#
# epoch n° 1837
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3082, Segmentation Loss:0.1273
# Train Confusion Matrix:
# [[3136403   69096]
#  [ 119435  515066]]
# Accuracy: 0.9509, CSI: 0.7320, Sensitivity: 0.8118, Specificity: 0.9784, False Alarm Ratio: 0.1183
#
#
# epoch n° 1838
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3204, Segmentation Loss:0.1246
# Train Confusion Matrix:
# [[3131489   69447]
#  [ 116818  522246]]
# Accuracy: 0.9515, CSI: 0.7371, Sensitivity: 0.8172, Specificity: 0.9783, False Alarm Ratio: 0.1174
#
#
# epoch n° 1839
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3046, Segmentation Loss:0.1231
# Train Confusion Matrix:
# [[3124144   69566]
#  [ 114624  531666]]
# Accuracy: 0.9520, CSI: 0.7427, Sensitivity: 0.8226, Specificity: 0.9782, False Alarm Ratio: 0.1157
#
#
# epoch n° 1840
# Training, Regression Loss: 0.0345, Regression Loss 1h: 1.2716, Segmentation Loss:0.1231
# Train Confusion Matrix:
# [[3134434   68740]
#  [ 114140  522686]]
# Accuracy: 0.9524, CSI: 0.7408, Sensitivity: 0.8208, Specificity: 0.9785, False Alarm Ratio: 0.1162
#
#
# saving step
# epoch n° 1841
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3155, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3120339   69603]
#  [ 115384  534674]]
# Accuracy: 0.9518, CSI: 0.7430, Sensitivity: 0.8225, Specificity: 0.9782, False Alarm Ratio: 0.1152
#
#
# epoch n° 1842
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3027, Segmentation Loss:0.1217
# Train Confusion Matrix:
# [[3125227   69283]
#  [ 112520  532970]]
# Accuracy: 0.9527, CSI: 0.7456, Sensitivity: 0.8257, Specificity: 0.9783, False Alarm Ratio: 0.1150
#
#
# epoch n° 1843
# Training, Regression Loss: 0.0336, Regression Loss 1h: 1.2400, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3130139   69472]
#  [ 116534  523855]]
# Accuracy: 0.9516, CSI: 0.7380, Sensitivity: 0.8180, Specificity: 0.9783, False Alarm Ratio: 0.1171
#
#
# epoch n° 1844
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.2980, Segmentation Loss:0.1241
# Train Confusion Matrix:
# [[3130392   68830]
#  [ 115618  525160]]
# Accuracy: 0.9520, CSI: 0.7401, Sensitivity: 0.8196, Specificity: 0.9785, False Alarm Ratio: 0.1159
#
#
# epoch n° 1845
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3557, Segmentation Loss:0.1222
# Train Confusion Matrix:
# [[3136147   68525]
#  [ 113793  521535]]
# Accuracy: 0.9525, CSI: 0.7410, Sensitivity: 0.8209, Specificity: 0.9786, False Alarm Ratio: 0.1161
#
#
# epoch n° 1846
# Training, Regression Loss: 0.0333, Regression Loss 1h: 1.3172, Segmentation Loss:0.1296
# Train Confusion Matrix:
# [[3124378   70324]
#  [ 122153  523145]]
# Accuracy: 0.9499, CSI: 0.7310, Sensitivity: 0.8107, Specificity: 0.9780, False Alarm Ratio: 0.1185
#
#
# epoch n° 1847
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3097, Segmentation Loss:0.1224
# Train Confusion Matrix:
# [[3127033   67957]
#  [ 113729  531281]]
# Accuracy: 0.9527, CSI: 0.7452, Sensitivity: 0.8237, Specificity: 0.9787, False Alarm Ratio: 0.1134
#
#
# epoch n° 1848
# Training, Regression Loss: 0.0355, Regression Loss 1h: 1.3409, Segmentation Loss:0.1215
# Train Confusion Matrix:
# [[3128261   68648]
#  [ 112680  530411]]
# Accuracy: 0.9528, CSI: 0.7452, Sensitivity: 0.8248, Specificity: 0.9785, False Alarm Ratio: 0.1146
#
#
# epoch n° 1849
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3528, Segmentation Loss:0.1226
# Train Confusion Matrix:
# [[3122539   69659]
#  [ 113009  534793]]
# Accuracy: 0.9524, CSI: 0.7454, Sensitivity: 0.8256, Specificity: 0.9782, False Alarm Ratio: 0.1152
#
#
# epoch n° 1850
# Training, Regression Loss: 0.0347, Regression Loss 1h: 1.3532, Segmentation Loss:0.1270
# Train Confusion Matrix:
# [[3130484   70546]
#  [ 119245  519725]]
# Accuracy: 0.9506, CSI: 0.7325, Sensitivity: 0.8134, Specificity: 0.9780, False Alarm Ratio: 0.1195
#
#
# saving step
# epoch n° 1851
# Training, Regression Loss: 0.0350, Regression Loss 1h: 1.3344, Segmentation Loss:0.1260
# Train Confusion Matrix:
# [[3123970   69292]
#  [ 117412  529326]]
# Accuracy: 0.9514, CSI: 0.7393, Sensitivity: 0.8185, Specificity: 0.9783, False Alarm Ratio: 0.1158
#
#
# epoch n° 1852
# Training, Regression Loss: 0.0348, Regression Loss 1h: 1.3136, Segmentation Loss:0.1223
# Train Confusion Matrix:
# [[3135836   69013]
#  [ 113197  521954]]
# Accuracy: 0.9525, CSI: 0.7412, Sensitivity: 0.8218, Specificity: 0.9785, False Alarm Ratio: 0.1168
#
#
# epoch n° 1853
# Training, Regression Loss: 0.0339, Regression Loss 1h: 1.3153, Segmentation Loss:0.1245
# Train Confusion Matrix:
# [[3127345   70219]
#  [ 115899  526537]]
# Accuracy: 0.9515, CSI: 0.7388, Sensitivity: 0.8196, Specificity: 0.9780, False Alarm Ratio: 0.1177
#
#
# epoch n° 1854
# Training, Regression Loss: 0.0342, Regression Loss 1h: 1.3124, Segmentation Loss:0.1255
# Train Confusion Matrix:
# [[3129341   69468]
#  [ 116801  524390]]
# Accuracy: 0.9515, CSI: 0.7379, Sensitivity: 0.8178, Specificity: 0.9783, False Alarm Ratio: 0.1170
#
#
# epoch n° 1855
# Training, Regression Loss: 0.0362, Regression Loss 1h: 1.3593, Segmentation Loss:0.1218
# Train Confusion Matrix:
# [[3139546   68347]
#  [ 113167  518940]]
# Accuracy: 0.9527, CSI: 0.7409, Sensitivity: 0.8210, Specificity: 0.9787, False Alarm Ratio: 0.1164
#
#
# epoch n° 1856
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3729, Segmentation Loss:0.1219
# Train Confusion Matrix:
# [[3132110   68882]
#  [ 113173  525835]]
# Accuracy: 0.9526, CSI: 0.7428, Sensitivity: 0.8229, Specificity: 0.9785, False Alarm Ratio: 0.1158
#
#
# epoch n° 1857
# Training, Regression Loss: 0.0354, Regression Loss 1h: 1.3013, Segmentation Loss:0.1226
# Train Confusion Matrix:
# [[3128755   68714]
#  [ 113673  528858]]
# Accuracy: 0.9525, CSI: 0.7436, Sensitivity: 0.8231, Specificity: 0.9785, False Alarm Ratio: 0.1150
#
#
# epoch n° 1858
# Training, Regression Loss: 0.0344, Regression Loss 1h: 1.3239, Segmentation Loss:0.1271
# Train Confusion Matrix:
# [[3136326   69160]
#  [ 119704  514810]]
# Accuracy: 0.9508, CSI: 0.7316, Sensitivity: 0.8113, Specificity: 0.9784, False Alarm Ratio: 0.1184
#
#
# epoch n° 1859
# Training, Regression Loss: 0.0347, Regression Loss 1h: 1.4225, Segmentation Loss:0.1286
# Train Confusion Matrix:
# [[3119383   71082]
#  [ 121268  528267]]
# Accuracy: 0.9499, CSI: 0.7331, Sensitivity: 0.8133, Specificity: 0.9777, False Alarm Ratio: 0.1186
#
#
# epoch n° 1860
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.2961, Segmentation Loss:0.1248
# Train Confusion Matrix:
# [[3131289   67698]
#  [ 116784  524229]]
# Accuracy: 0.9520, CSI: 0.7397, Sensitivity: 0.8178, Specificity: 0.9788, False Alarm Ratio: 0.1144
#
#
# saving step
# epoch n° 1861
# Training, Regression Loss: 0.0349, Regression Loss 1h: 1.3030, Segmentation Loss:0.1240
# Train Confusion Matrix:
# [[3126818   68761]
#  [ 115777  528644]]
# Accuracy: 0.9519, CSI: 0.7412, Sensitivity: 0.8203, Specificity: 0.9785, False Alarm Ratio: 0.1151
#
#
# epoch n° 1862
# Training, Regression Loss: 0.0352, Regression Loss 1h: 1.3326, Segmentation Loss:0.1217
# Train Confusion Matrix:
# [[3129033   69267]
#  [ 112495  529205]]
# Accuracy: 0.9527, CSI: 0.7443, Sensitivity: 0.8247, Specificity: 0.9783, False Alarm Ratio: 0.1157
#
#
# epoch n° 1863
# Training, Regression Loss: 0.0351, Regression Loss 1h: 1.3772, Segmentation Loss:0.1223
# Train Confusion Matrix:
# [[3133538   67278]
#  [ 114348  524836]]
# Accuracy: 0.9527, CSI: 0.7429, Sensitivity: 0.8211, Specificity: 0.9790, False Alarm Ratio: 0.1136
#
#
# epoch n° 1864
# Training, Regression Loss: 0.0341, Regression Loss 1h: 1.3347, Segmentation Loss:0.1253
# Train Confusion Matrix:
# [[3130612   69657]
#  [ 117194  522537]]
# Accuracy: 0.9513, CSI: 0.7366, Sensitivity: 0.8168, Specificity: 0.9782, False Alarm Ratio: 0.1176
#
#
# epoch n° 1865
# Training, Regression Loss: 0.0353, Regression Loss 1h: 1.4684, Segmentation Loss:0.1261
# Train Confusion Matrix:
# [[3127232   69931]
#  [ 118356  524481]]
# Accuracy: 0.9510, CSI: 0.7358, Sensitivity: 0.8159, Specificity: 0.9781, False Alarm Ratio: 0.1176
#
#
# epoch n° 1866
# Training, Regression Loss: 0.0347, Regression Loss 1h: 1.3166, Segmentation Loss:0.1281
# Train Confusion Matrix:
# [[3119507   70614]
#  [ 119975  529904]]
# Accuracy: 0.9504, CSI: 0.7355, Sensitivity: 0.8154, Specificity: 0.9779, False Alarm Ratio: 0.1176
#
#
# epoch n° 1867
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 38
#      35 optimizer.zero_grad()  # Zero the gradients
#      36 outputs = model(inputs)  # Forward pass
# ---> 38 regression_loss, regression_loss_1h, segmentation_loss, loss, batch_cm, _ = criterion(model.p, outputs, targets)
#      39 loss.backward()  # Backward pass
#      40 optimizer.step()  # Update the weights
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/ppc/WEBCAMS/src/raincell/ia/notebooks/learning/simulation/fusion/utils/cost_functions.py:95, in QPELoss_fcn.forward(self, p, outputs, targets, sampled_values_and_filters)
#      93 mask = (targets>=0)
#      94 masked_targets = targets[mask]
# ---> 95 outputs_rnr0 = outputs[:, :nsteps, ...].view(bs, 1, nsteps, S**2)
#      96 outputs_rnr1 = outputs[:, nsteps:2*nsteps, ...].view(bs, 1, nsteps, S**2)
#      97 masked_outputs_rnr = torch.cat([outputs_rnr0[mask].view(bs, 1, -1), outputs_rnr1[mask].view(bs, 1, -1)], dim=1)
#
# KeyboardInterrupt:
